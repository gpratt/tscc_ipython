# %%
# %matplotlib inline

import seaborn as sns
import pandas as pd

# %%
loc_matrix = pd.read_csv("/projects/ps-yeolab2/encode/analysis/ad-hoc/RBP_Localization_Matrix_March_2015.csv", index_col=0)

# %%
loc_data = """222_02_HNRNPM.merged.r2.bam.reads_by_loc.csv    17.13069635
222_01_HNRNPM.merged.r2.bam.reads_by_loc.csv    13.42816809
203_02_HNRNPC.merged.r2.bam.reads_by_loc.csv    13.10579863
271_01_HNRNPC.merged.r2.bam.reads_by_loc.csv    11.49494281
281_02_HNRNPU.merged.r2.bam.reads_by_loc.csv    10.0895848
388_02_TAF15.merged.r2.bam.reads_by_loc.csv    8.618207552
281_01_HNRNPU.merged.r2.bam.reads_by_loc.csv    8.540669802
283_02_HNRNPA1.merged.r2.bam.reads_by_loc.csv    7.095391863
388_01_TAF15.merged.r2.bam.reads_by_loc.csv    6.859027273
267_02_SAFB2.merged.r2.bam.reads_by_loc.csv    6.720986033
249_02_HNRNPU.merged.r2.bam.reads_by_loc.csv    6.708508522
353_01_KHDRBS1-SAM68.merged.r2.bam.reads_by_loc.csv    6.690505433
405_01_NONO.merged.r2.bam.reads_by_loc.csv    6.593583405
283_01_HNRNPA1.merged.r2.bam.reads_by_loc.csv    6.538154931
249_01_HNRNPU.merged.r2.bam.reads_by_loc.csv    6.409122904
405_02_NONO.merged.r2.bam.reads_by_loc.csv    5.952575689
224_02_HNRNPM.merged.r2.bam.reads_by_loc.csv    5.918673201
247_01_HNRNPA1.merged.r2.bam.reads_by_loc.csv    5.797521626
267_01_SAFB2.merged.r2.bam.reads_by_loc.csv    5.777508139
247_02_HNRNPA1.merged.r2.bam.reads_by_loc.csv    5.723508438
321_01_HNRNPUL1.merged.r2.bam.reads_by_loc.csv    5.53849447
339_02_TAF15.merged.r2.bam.reads_by_loc.csv    5.4400487
224_01_HNRNPM.merged.r2.bam.reads_by_loc.csv    5.433972574
289_01_HNRNPUL1.merged.r2.bam.reads_by_loc.csv    5.204329057
338_01_ILF3.merged.r2.bam.reads_by_loc.csv    5.18160009
292_02_CSTF2T.merged.r2.bam.reads_by_loc.csv    5.172335767
339_01_TAF15.merged.r2.bam.reads_by_loc.csv    5.170562968
321_02_HNRNPUL1.merged.r2.bam.reads_by_loc.csv    5.153447761
204_02_RBFOX2.merged.r2.bam.reads_by_loc.csv    4.864916157
227_01_SLTM.merged.r2.bam.reads_by_loc.csv    4.77831639
338_02_ILF3.merged.r2.bam.reads_by_loc.csv    4.77559862
353_02_KHDRBS1-SAM68.merged.r2.bam.reads_by_loc.csv    4.686606628
289_02_HNRNPUL1.merged.r2.bam.reads_by_loc.csv    4.654189137
206_01_HNRNPK.merged.r2.bam.reads_by_loc.csv    4.555639377
292_01_CSTF2T.merged.r2.bam.reads_by_loc.csv    4.538499242
206_02_HNRNPK.merged.r2.bam.reads_by_loc.csv    4.390998156
331_02_RBM22.merged.r2.bam.reads_by_loc.csv    4.180902322
223_01_FKBP4.merged.r2.bam.reads_by_loc.csv    4.172065176
204_01_RBFOX2.merged.r2.bam.reads_by_loc.csv    4.040966141
342_02_GTF2F1.merged.r2.bam.reads_by_loc.csv    3.991407271
215_01_TIA1.merged.r2.bam.reads_by_loc.csv    3.850142424
326_01_HNRNPK.merged.r2.bam.reads_by_loc.csv    3.815090033
331_01_RBM22.merged.r2.bam.reads_by_loc.csv    3.770393432
297_02_FAM120A.merged.r2.bam.reads_by_loc.csv    3.689146222
275_01_CSTF2T.merged.r2.bam.reads_by_loc.csv    3.455129559
228_02_SF3B4.merged.r2.bam.reads_by_loc.csv    3.376032133
326_02_HNRNPK.merged.r2.bam.reads_by_loc.csv    3.343561927
272_01_U2AF2.merged.r2.bam.reads_by_loc.csv    3.342621468
275_02_CSTF2T.merged.r2.bam.reads_by_loc.csv    3.274935498
230_01_BCCIP.merged.r2.bam.reads_by_loc.csv    3.17631511
345_02_PCBP2.merged.r2.bam.reads_by_loc.csv    3.165766484
368_01_PTBP1.merged.r2.bam.reads_by_loc.csv    3.136350539
256_01_SLTM.merged.r2.bam.reads_by_loc.csv    3.112235402
245_02_XRN2.merged.r2.bam.reads_by_loc.csv    3.038057911
227_02_SLTM.merged.r2.bam.reads_by_loc.csv    3.018290757
342_01_GTF2F1.merged.r2.bam.reads_by_loc.csv    3.005560198
272_02_U2AF2.merged.r2.bam.reads_by_loc.csv    2.979974739
341_01_DGCR8.merged.r2.bam.reads_by_loc.csv    2.953505137
384_02_GTF2F1.merged.r2.bam.reads_by_loc.csv    2.879215919
368_02_PTBP1.merged.r2.bam.reads_by_loc.csv    2.874287625
223_02_FKBP4.merged.r2.bam.reads_by_loc.csv    2.865181359
341_02_DGCR8.merged.r2.bam.reads_by_loc.csv    2.767447688
354_01_NPM1.merged.r2.bam.reads_by_loc.csv    2.750044043
256_02_SLTM.merged.r2.bam.reads_by_loc.csv    2.70678421
245_01_XRN2.merged.r2.bam.reads_by_loc.csv    2.656822247
241_02_DDX42.merged.r2.bam.reads_by_loc.csv    2.65648855
230_02_BCCIP.merged.r2.bam.reads_by_loc.csv    2.633343094
228_01_SF3B4.merged.r2.bam.reads_by_loc.csv    2.609821578
215_02_TIA1.merged.r2.bam.reads_by_loc.csv    2.565550625
246_02_AUH.merged.r2.bam.reads_by_loc.csv    2.56201275
354_02_NPM1.merged.r2.bam.reads_by_loc.csv    2.557475912
367_02_YWHAG.merged.r2.bam.reads_by_loc.csv    2.551614496
278_02_PRPF8.merged.r2.bam.reads_by_loc.csv    2.536301499
340_02_TARDBP.merged.r2.bam.reads_by_loc.csv    2.529694198
280_01_AUH.merged.r2.bam.reads_by_loc.csv    2.526133138
298_02_LARP7.merged.r2.bam.reads_by_loc.csv    2.472758253
260_02_EIF4G2.merged.r2.bam.reads_by_loc.csv    2.465372052
352_01_SBDS.merged.r2.bam.reads_by_loc.csv    2.406487825
384_01_GTF2F1.merged.r2.bam.reads_by_loc.csv    2.381048848
344_02_SMNDC1.merged.r2.bam.reads_by_loc.csv    2.371969901
241_01_DDX42.merged.r2.bam.reads_by_loc.csv    2.367877478
278_01_PRPF8.merged.r2.bam.reads_by_loc.csv    2.354828439
366_02_TRNC6A.merged.r2.bam.reads_by_loc.csv    2.350790995
393_02_SF3A3.merged.r2.bam.reads_by_loc.csv    2.340846301
246_01_AUH.merged.r2.bam.reads_by_loc.csv    2.336629693
358_02_GNL3.merged.r2.bam.reads_by_loc.csv    2.333340997
242_02_U2AF2.merged.r2.bam.reads_by_loc.csv    2.273703282
367_01_YWHAG.merged.r2.bam.reads_by_loc.csv    2.254827535
344_01_SMNDC1.merged.r2.bam.reads_by_loc.csv    2.230564391
366_01_TRNC6A.merged.r2.bam.reads_by_loc.csv    2.214535171
340_01_TARDBP.merged.r2.bam.reads_by_loc.csv    2.192765823
358_01_GNL3.merged.r2.bam.reads_by_loc.csv    2.184858047
280_02_AUH.merged.r2.bam.reads_by_loc.csv    2.174738527
332_02_RBM27.merged.r2.bam.reads_by_loc.csv    2.145950578
244_01_U2AF1.merged.r2.bam.reads_by_loc.csv    2.120339961
332_01_RBM27.merged.r2.bam.reads_by_loc.csv    2.115511514
209_01_SRSF7.merged.r2.bam.reads_by_loc.csv    2.075255424
282_01_U2AF1.merged.r2.bam.reads_by_loc.csv    2.035548325
352_02_SBDS.merged.r2.bam.reads_by_loc.csv    2.01548949
393_01_SF3A3.merged.r2.bam.reads_by_loc.csv    1.990420487
242_01_U2AF2.merged.r2.bam.reads_by_loc.csv    1.922524977
298_01_LARP7.merged.r2.bam.reads_by_loc.csv    1.89566997
216_02_SRSF9.merged.r2.bam.reads_by_loc.csv    1.852476114
244_02_U2AF1.merged.r2.bam.reads_by_loc.csv    1.843488902
291_02_PRPF8.merged.r2.bam.reads_by_loc.csv    1.702779622
243_01_LARP7.merged.r2.bam.reads_by_loc.csv    1.641176405
258_02_CPSF6.merged.r2.bam.reads_by_loc.csv    1.607761192
262_01_SLBP.merged.r2.bam.reads_by_loc.csv    1.601910208
258_01_CPSF6.merged.r2.bam.reads_by_loc.csv    1.579380829
243_02_LARP7.merged.r2.bam.reads_by_loc.csv    1.574388543
262_02_SLBP.merged.r2.bam.reads_by_loc.csv    1.542481239
260_01_EIF4G2.merged.r2.bam.reads_by_loc.csv    1.533403913
316_02_SND1.merged.r2.bam.reads_by_loc.csv    1.526588897
282_02_U2AF1.merged.r2.bam.reads_by_loc.csv    1.522421037
209_02_SRSF7.merged.r2.bam.reads_by_loc.csv    1.444715667
291_01_PRPF8.merged.r2.bam.reads_by_loc.csv    1.442769363
218_01_TRA2A.merged.r2.bam.reads_by_loc.csv    1.425110547
312_02_SRSF1.merged.r2.bam.reads_by_loc.csv    1.420905096
345_01_PCBP2.merged.r2.bam.reads_by_loc.csv    1.363124961
316_01_SND1.merged.r2.bam.reads_by_loc.csv    1.310258166
315_01_FXR1.merged.r2.bam.reads_by_loc.csv    1.270978986
297_01_FAM120A.merged.r2.bam.reads_by_loc.csv    1.233270185
240_02_TRA2A.merged.r2.bam.reads_by_loc.csv    1.217260774
216_01_SRSF9.merged.r2.bam.reads_by_loc.csv    1.205086439
312_01_SRSF1.merged.r2.bam.reads_by_loc.csv    1.170598358
218_02_TRA2A.merged.r2.bam.reads_by_loc.csv    1.159487201
301_02_SRSF1.merged.r2.bam.reads_by_loc.csv    0.985305505
325_01_LIN28B.merged.r2.bam.reads_by_loc.csv    0.870022951
350_01_DDX3X.merged.r2.bam.reads_by_loc.csv    0.834199297
301_01_SRSF1.merged.r2.bam.reads_by_loc.csv    0.829465555
387_02_LIN28B.merged.r2.bam.reads_by_loc.csv    0.767717621
279_02_FAM120A.merged.r2.bam.reads_by_loc.csv    0.756340964
240_01_TRA2A.merged.r2.bam.reads_by_loc.csv    0.753172451
205_01_IGF2BP1.merged.r2.bam.reads_by_loc.csv    0.708188399
315_02_FXR1.merged.r2.bam.reads_by_loc.csv    0.69457404
279_01_FAM120A.merged.r2.bam.reads_by_loc.csv    0.667032105
211_02_IGF2BP3.merged.r2.bam.reads_by_loc.csv    0.644202775
211_01_IGF2BP3.merged.r2.bam.reads_by_loc.csv    0.628920219
205_02_IGF2BP1.merged.r2.bam.reads_by_loc.csv    0.590410827
237_02_FXR2.merged.r2.bam.reads_by_loc.csv    0.548578273
387_01_LIN28B.merged.r2.bam.reads_by_loc.csv    0.542724032
325_02_LIN28B.merged.r2.bam.reads_by_loc.csv    0.497193519
350_02_DDX3X.merged.r2.bam.reads_by_loc.csv    0.463952331
220_02_IGF2BP1.merged.r2.bam.reads_by_loc.csv    0.462273563
236_02_FMR1.merged.r2.bam.reads_by_loc.csv    0.462202155
226_02_IGF2BP2.merged.r2.bam.reads_by_loc.csv    0.435868344
302_01_SND1.merged.r2.bam.reads_by_loc.csv    0.42998015
236_01_FMR1.merged.r2.bam.reads_by_loc.csv    0.386963662
302_02_SND1.merged.r2.bam.reads_by_loc.csv    0.27182054
226_01_IGF2BP2.merged.r2.bam.reads_by_loc.csv    0.268896604
220_01_IGF2BP1.merged.r2.bam.reads_by_loc.csv    0.237982166
237_01_FXR2.merged.r2.bam.reads_by_loc.csv    0.201005963""".split("\n")

loc_data = pd.DataFrame(pd.Series(dict([item.split() for item in loc_data])))

# %%
loc_data.columns = ["enrichment"]
loc_data['rbp'] = [item.split(".")[0].split("_")[-1] for item in loc_data.index]
loc_data = loc_data.sort_values("enrichment", ascending=False)

# %%
sns.heatmap(loc_matrix)
# Out:
# /home/gpratt/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
loc_matrix.columns
# Out:
# Index([u'Ubiquitous', u'Cytoplasm (UB)', u'Nuclei (UB)',
#        u'Marker Co-Localized', u'Nuclei', u'Nucleoplasm', u'Nucleolus',
#        u'Speckles', u'Nuclear Envelope', u'Cytoplasm',
#        u'Compartment/Organelle', u'Mitochondria', u'Golgi', u'P bodies',
#        u'Endosomal', u'ER', u'Cytoskeleton', u'Microtubule', u'Actin',
#        u'Cell Junctions', u'Cytosolic', u'Mitosis-related',
#        u'Mitotic Apparatus', u'Spindle',
#        u'Release of nuclear content into cytoplasm', u'Plasma Membrane',
#        u'Mutually Exclusive', u'Nuclei (ME)', u'Nucleolus (ME)',
#        u'Speckles (ME)', u'Cytoplasm (ME)', u'Compartment/Organelle (ME)',
#        u'Mitochondria (ME)', u'Golgi (ME)', u'Cytoskeleton (ME)',
#        u'Actin (ME)', u'Mitosis-related (ME)',
#        u'Release of nuclear content into cytoplasm (ME)',
#        u'Plasma Membrane (ME)', u'Unidentified', u'Cytoplasm (UN)',
#        u'Organelle-Like (UN)', u'Cyto Foci (UN)', u'Nuclei (UN)',
# ...

# %%
loc_matrix
# Out:
#          Ubiquitous  Cytoplasm (UB)  Nuclei (UB)  Marker Co-Localized  Nuclei  \
#  RBP
# ABTAP             0               0            0                    1       1
# AKAP1             0               0            0                    1       0
# ASCC1             0               0            0                    1       0
# CAPER             0               0            0                    1       1
# CPSF6             0               0            0                    1       1
# CUGBP1            0               0            0                    1       1
# DAZAP1            0               0            0                    1       1
# DDX24             0               0            0                    1       1
# DDX3X             0               0            0                    1       0
# DDX6              0               0            0                    1       0
# EIBAP5            0               0            0                    1       1
# ...

# %%
sns.heatmap(loc_matrix[['Cytoplasm (UB)', 'Nuclei (UB)', 'Cytoplasm', 'Nuclei (ME)']])

# %%
len(loc_data)
# Out:
# 152

# %%
merged_results = pd.merge(loc_data, loc_matrix, left_on="rbp", right_index=True)

# %%
merged_results = merged_results.sort_values("enrichment", ascending=False)

# %%
merged_results.index = [item.split(".")[0] for item in merged_results.index]

# %%
from gscripts.general import dataviz

# %%
import os

# %%
img_dir = "/home/gpratt/Dropbox/NatMethodsPaper/"
num_cols = 1
num_rows = 1
with dataviz.Figure(os.path.join(img_dir, "localization_ranking.svg"), figsize=(num_cols * 5,num_rows * 15)) as fig:
    ax = fig.add_subplot(1,1,1)
    sns.heatmap(merged_results[['Cytoplasm', 'Nuclei (ME)']], ax=ax)
