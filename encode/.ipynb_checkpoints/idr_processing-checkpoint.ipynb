# %%
# %matplotlib inline

import pandas as pd
import os
import pybedtools
import numpy as np
import seaborn as sns
import gspread

from gscripts.general import dataviz
from IPython.core.display import HTML

import json
from oauth2client.client import SignedJwtAssertionCredentials

import numpy as np
img_dir ="/home/gpratt/Dropbox/encode_integration/for_eric/idr_qc/"

peaks_dir = "/home/elvannostrand/data/clip/CLIPseq_analysis/ALLCLIP_v12_20160112/"

# %%
json_key = json.load(open("../public clip-588adbc137f3.json"))
scope = ['https://spreadsheets.google.com/feeds']

credentials = SignedJwtAssertionCredentials(json_key['client_email'], json_key['private_key'], scope)
gc = gspread.authorize(credentials)

sht1 = gc.open_by_url("https://docs.google.com/spreadsheets/d/1ZU2mQh54jentqvhR_oMnviLGWR8Nw_x338gULzKjNDI/edit#gid=0")
ws = sht1.worksheet("Sheet1")
list_of_lists = ws.get_all_values()
manifest = pd.DataFrame(list_of_lists[1:], columns=list_of_lists[0])
manifest['qc_id'] = manifest.apply(lambda x: "{}_{}".format(x.ENCODE_ID, x.RBP), axis=1)
manifest.is_encode = manifest.is_encode == "TRUE"
manifest['exp_id'] = manifest.ENCODE_ID.apply(lambda x: x.split("_")[0]).astype(str)

# %%
foo = pd.read_table("../py3_notebooks/203.txt", header=None, names=['chrom', 
                                                             'chromStar',
                                                             'chromEnd',
                                                             'name',
                                                             'score',
                                                             'strand',
                                                             'signalValue',
                                                             'p-value',
                                                             'q-value',
                                                             'summit',
                                                             'localIDR',
                                                             'globalIDR',
                                                            'rep1_chromStart',
                                                            'rep1_chromEnd'
                                                ])

# %%
df = pd.read_table("/home/elvannostrand/data/clip/CLIPseq_analysis/ALLCLIP_v12_20160112/encode_v12_filelist.MethodPaperSubmittedList_20160122.txt.listforIDR.txt")

# %%
def fix_score(interval):
    #column 8 is the column that gets sorted
    #sort by -log10 p-value
    interval.score = str(pow(2, float(interval.score)))

    return interval

# %%
def eplouge(name,count, run_dir="/home/gpratt/projects/encode/analysis/idr_analysis_p_value/"):
    return """#!/bin/bash
#PBS -N {0}
#PBS -l nodes=1:ppn=1
#PBS -o {0}.out
#PBS -e {0}.err
#PBS -V
#PBS -q home-yeo
#PBS -W group_list=yeo-group
#PBS -t 1-{1}
#PBS -l walltime=8:00:00
source activate py3
cd {2}
echo "hello, starting"
""".format(name, count, run_dir)

prolouge = "eval ${cmd[$PBS_ARRAYID]}"

# %%
idr_cmds = [] 
for name, row in df.iterrows():
    rep1 = os.path.join(peaks_dir, (row['uID_01.basedon_uID_01.peaks.l2inputnormnew.bed.compressed.bed']))
    rep2 = os.path.join(peaks_dir, (row['uID_02.basedon_uID_02.peaks.l2inputnormnew.bed.compressed.bed']))
    
    output = os.path.basename(rep1).split("_")[0] + ".txt"

    idr_cmds.append("idr --samples {} {} --input-file-type bed --rank 4 --peak-merge-method max --plot -o {}".format(rep1, rep2, output))

# %%
total = 0 
result = []
for cmd in idr_cmds:
    total += 1
    result.append('cmd[{}]="{}"'.format(total, cmd))
    
with open(os.path.join("/home/gpratt/projects/encode/scripts", "encode_idr_p_value.sh"), 'w') as out_file:
    out_file.write(eplouge("encode_idr", total))
    for line in result:
        out_file.write(line + "\n\n")
    out_file.write(prolouge + "\n")

# %%
idr_cmds = [] 
for name, row in df.iterrows():
    rep1 = os.path.join(peaks_dir, (row['uID_01.basedon_uID_01.peaks.l2inputnormnew.bed.compressed.bed']))
    rep2 = os.path.join(peaks_dir, (row['uID_02.basedon_uID_02.peaks.l2inputnormnew.bed.compressed.bed']))
    try:
        #rep1 = os.path.join(os.getcwd(), pybedtools.BedTool(rep1).each(fix_score).saveas(os.path.basename(rep1)).fn)
        #rep2 = os.path.join(os.getcwd(), pybedtools.BedTool(rep2).each(fix_score).saveas(os.path.basename(rep2)).fn)
        rep1 = os.path.join(os.getcwd(), os.path.basename(rep1))
        rep2 = os.path.join(os.getcwd(), os.path.basename(rep2))

    except ValueError as e:
        print e
        pass
    output = os.path.basename(rep1).split("_")[0] + ".txt"

    idr_cmds.append("idr --samples {} {} --input-file-type bed --rank 5 --peak-merge-method max --plot -o {}".format(rep1, rep2, output))

# %%
def eplouge(name,count):
    return """#!/bin/bash
#PBS -N {0}
#PBS -l nodes=1:ppn=1
#PBS -o {0}.out
#PBS -e {0}.err
#PBS -V
#PBS -q home-yeo
#PBS -W group_list=yeo-group
#PBS -t 1-{1}
#PBS -l walltime=8:00:00
source activate py3
cd /home/gpratt/projects/encode/analysis/idr_analysis_score/
echo "hello, starting"
""".format(name, count)

prolouge = "eval ${cmd[$PBS_ARRAYID]}"

# %%
total = 0 
result = []
for cmd in idr_cmds:
    total += 1
    result.append('cmd[{}]="{}"'.format(total, cmd))
    
with open(os.path.join("/home/gpratt/projects/encode/scripts", "encode_idr_score.sh"), 'w') as out_file:
    out_file.write(eplouge("encode_idr", total))
    for line in result:
        out_file.write(line + "\n\n")
    out_file.write(prolouge + "\n")

# %%
def filter_data(interval):
    #col4 is -log10 p-val
    #col5 is -log2 fold enrichment
    return (float(interval[4]) > 3) and (float(interval[3]) > 5)

# %%
result = {}
for name, row in df.iterrows():
    encode_id = row['uID_01.basedon_uID_01.peaks.l2inputnormnew.bed.compressed.bed'].split("_")[0]
    try:
        rep1 = pybedtools.BedTool(os.path.join(peaks_dir, (row['uID_01.basedon_uID_01.peaks.l2inputnormnew.bed.compressed.bed'])))
        rep2 = pybedtools.BedTool(os.path.join(peaks_dir, (row['uID_02.basedon_uID_02.peaks.l2inputnormnew.bed.compressed.bed'])))
        idr_peaks = pybedtools.BedTool("/home/gpratt/projects/encode/analysis/idr_analysis_score/{}.txt".format(encode_id))
    except ValueError as e:
        print e
        continue
    rep1_enriched = rep1.filter(filter_data).saveas()
    rep2_enriched = rep2.filter(filter_data).saveas()
    idr_peaks_filtered = idr_peaks.filter(lambda x: float(x.score) > 540).saveas()
    
    overlapping_r1_r2 = rep1.intersect(rep2, s=True, u=True)
    overlapping_r1_r2_enriched = overlapping_r1_r2.filter(filter_data).saveas()
    
    result[encode_id] = {"rep1_enriched_peaks": len(rep1_enriched),
                         "idr_peaks": len(idr_peaks),
                         "rep1_rep2_overlap": len(overlapping_r1_r2),
                         "rep1_rep2_overlap_enriched": len(overlapping_r1_r2_enriched),
                         "rep1_enriched_with_idr": len(rep1_enriched.intersect(idr_peaks_filtered, u=True)),
                         "overlapping_enriched_with_idr": len(overlapping_r1_r2_enriched.intersect(idr_peaks_filtered, u=True)) 
                        }
    
result = pd.DataFrame(result).T
# Out:
# File "/home/elvannostrand/data/clip/CLIPseq_analysis/ALLCLIP_v12_20160112/267_01.basedon_267_01.peaks.l2inputnormnew.bed.compressed.bed" does not exist

# %%
rep1
# Out:
# <BedTool(/home/elvannostrand/data/clip/CLIPseq_analysis/ALLCLIP_v12_20160112/508_01.basedon_508_01.peaks.l2inputnormnew.bed.compressed.bed)>

# %%
result['rep1_enriched_fraction'] = result.overlapping_enriched_with_idr / result.rep1_enriched_peaks
result['overlapping_enriched_fraction'] = result.overlapping_enriched_with_idr / result.rep1_rep2_overlap_enriched

# %%
img_dir = "."
num_cols = 1
num_rows = 1

# %%
with dataviz.Figure(os.path.join(img_dir, "overlapping_enriched.svg"), figsize=(2.5 * num_cols,2.5*num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    dataviz.plot_cdf(result.overlapping_enriched_fraction, ax=ax)
    ax.set_xlim(0,1)
    sns.despine(ax=ax)

# %%
with dataviz.Figure(os.path.join(img_dir, "overlapping_enriched.svg"), figsize=(4 * num_cols,4*num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    dataviz.plot_cdf(result.rep1_enriched_fraction, ax=ax, linewidth=4, alpha=.7, color='k')
    ax.set_xlim(0,1)
    sns.despine(ax=ax)
    ax.set_ylabel("Cumulative Fraction", fontsize=14)
    ax.set_xlabel("Fraction of enriched\npeaks overlapping with IDR peaks", fontsize=14)

# %%
with dataviz.Figure(os.path.join(img_dir, "enriched_scatter.svg"), figsize=(4 * num_cols,4*num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    ax.scatter(result.rep1_enriched_peaks, result.rep1_enriched_fraction, color='k', alpha=.5)
    sns.despine(ax=ax)
    ax.set_ylim(0,1)
    ax.set_xlabel("# of peaks stringently enriched above input\np-value <= $10^{-5}$, fold enrichment >= 3", fontsize=14)
    ax.set_ylabel("Fraction oberved in IDR", fontsize=14)
    ax.set_xlim(0,)

# %%
annotations = manifest.groupby("exp_id").first()
filtered_result = result[result.rep1_enriched_fraction < .6].copy()

# %%
len(filtered_result), len(result)
# Out:
# (9, 101)

# %%
len(result) - len(filtered_result)
# Out:
# 92

# %%
1- (len(filtered_result) / (len(result) * 1.0))
# Out:
# 0.9108910891089109

# %%
foo = pd.merge(filtered_result, annotations, right_index=True, left_index=True, how="left")

# %%
print " ".join(foo.RBP.values)
print " ".join(foo.index)
# Out:
# SRSF7 SLTM PRPF8 FAM120A XRCC6 YWHAG SF3A3 GPKOW SF3B1
# 209 227 291 297 311 367 393 450 506

# %%
HTML(foo.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>idr_peaks</th>
#       <th>overlapping_enriched_with_idr</th>
#       <th>rep1_enriched_peaks</th>
#       <th>rep1_enriched_with_idr</th>
#       <th>rep1_rep2_overlap</th>
#       <th>rep1_rep2_overlap_enriched</th>
#       <th>rep1_enriched_fraction</th>
#       <th>overlapping_enriched_fraction</th>
#       <th>Hiseq_file_name</th>
#       <th>ENCODE_ID</th>
#       <th>RBP</th>
#       <th>inline_1</th>
#       <th>inline_2</th>
#       <th>index_1</th>
#       <th>index_2</th>
#       <th>Lane</th>
#       <th>file_location</th>
#       <th>unmerged_location</th>
#       <th>original_file_name</th>
#       <th>is_encode</th>
#       <th>cell_type</th>
#       <th>hiseq_run_date</th>
#       <th>randomer_length</th>
#       <th></th>
#       <th>Method_Paper_flag</th>
#       <th>species</th>
#       <th>is_4000</th>
#       <th>qc_id</th>
#     </tr>
# ...

# %%
data = pd.read_table("/home/elvannostrand/data/clip/CLIPseq_analysis/test.csv", header=None, names=['ip', 'input'])

# %%
num_cols = 1
num_rows = 1
with dataviz.Figure(os.path.join(img_dir, "foo.svg"), figsize=(5 * num_cols,5 * num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    ax.scatter(np.log2(data.ip), np.log2(data.input), alpha=.7)
    ax.set_xlabel("ip")
    ax.set_ylabel("input")

# %%
from sklearn.mixture import GMM
from sklearn.cluster import KMeans, SpectralClustering, DBSCAN, AgglomerativeClustering, k_means
import matplotlib.pyplot as plt

# %%
classifier = GMM(n_components=2, covariance_type="tied", init_params='wc', n_iter=20)
classifier.fit(data)
y_training_predictions = classifier.predict(data)

# %%
gmm_1 = [True if x == 1 else False for x in y_training_predictions]
gmm_2 = [True if x == 0 else False for x in y_training_predictions]
print sum(gmm_1), sum(gmm_2)
# Out:
# 31 23877

# %%
with dataviz.Figure(os.path.join(img_dir, "foo.svg"), figsize=(5 * num_cols,5 * num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    ax.scatter(np.log2(data[gmm_1].ip), np.log2(data[gmm_1].input), alpha=.7, color='b')
    ax.scatter(np.log2(data[gmm_2].ip), np.log2(data[gmm_2].input), alpha=.7, color='r')

# %%
foo  = KMeans(n_clusters=2)
y_training_predictions_kmeans = foo.fit_predict(data)

# %%
gmm_1 = [True if x == 1 else False for x in y_training_predictions_kmeans]
gmm_2 = [True if x == 0 else False for x in y_training_predictions_kmeans]
print sum(gmm_1), sum(gmm_2)
# Out:
# 31 23877

# %%
with dataviz.Figure(os.path.join(img_dir, "foo.svg"), figsize=(5 * num_cols,5 * num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    ax.scatter(np.log2(data[gmm_1].ip), np.log2(data[gmm_1].input), alpha=.7, color='b')
    ax.scatter(np.log2(data[gmm_2].ip), np.log2(data[gmm_2].input), alpha=.7, color='r')

# %%
filtered_data = data[(data.ip > 10) & (data.input > 10)]

# %%
len(filtered_data)
# Out:
# 2660

# %%
num_cols = 1
num_rows = 1
with dataviz.Figure(os.path.join(img_dir, "foo.svg"), figsize=(5 * num_cols,5 * num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    ax.scatter(np.log2(filtered_data.ip), np.log2(filtered_data.input), alpha=.7)

# %%
cut_size = 7000
cut_data = np.log2(filtered_data)[:cut_size]

# %%
len(cut_data)
# Out:
# 2660

# %%
from sklearn.cluster import spectral_clustering, affinity_propagation

# %%
knn_graph = kneighbors_graph(np.log2(filtered_data), 250, mode='distance')
y_pred = spectral_clustering(knn_graph, n_clusters=2, assign_labels="discretize")

# %%
# y_pred = SpectralClustering(n_clusters=2, affinity="nearest_neighbors", n_neighbors=30, assign_labels="discretize").fit_predict(cut_data)

gmm_1 = [True if x == 1 else False for x in y_pred]
gmm_2 = [True if x == 0 else False for x in y_pred]
print sum(gmm_1), sum(gmm_2)
# Out:
# 1299 1361

# %%
with dataviz.Figure(os.path.join(img_dir, "foo.svg"), figsize=(5 * num_cols,5 * num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    ax.scatter(np.log2(filtered_data[gmm_1].ip), np.log2(filtered_data[gmm_1].input), alpha=.7, color='b')
    ax.scatter(np.log2(filtered_data[gmm_2].ip), np.log2(filtered_data[gmm_2].input), alpha=.7, color='r')

# %%
y_pred = Sp(n_clusters=2).fit_predict(np.log2(data))

gmm_1 = [True if x == 1 else False for x in y_training_predictions]
gmm_2 = [True if x == 0 else False for x in y_training_predictions]
print sum(gmm_1), sum(gmm_2)

# %%
y_pred = DBSCAN(eps=.3, min_samples=50).fit_predict(np.log2(data).as_matrix())

gmm_1 = [True if x == 1 else False for x in y_training_predictions]
gmm_2 = [True if x == 0 else False for x in y_training_predictions]
print sum(gmm_1), sum(gmm_2)
# Out:
# 1129 22779

# %%
with dataviz.Figure(os.path.join(img_dir, "foo.svg"), figsize=(5 * num_cols,5 * num_rows)) as fig:

    ax = fig.add_subplot(1,1,1)
    # Black removed and is used for noise instead.
    unique_labels = set(y_pred)
    colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))

    for k, col in zip(unique_labels, colors):
        if k == -1:
            # Black used for noise.
            col = 'k'

        class_member_mask = (y_pred == k)

        xy = np.log2(data)[class_member_mask]
        ax.plot(xy.ip, xy.input, 'o', markerfacecolor=col,
                 markeredgecolor='k', markersize=6)

# %%
with dataviz.Figure(os.path.join(img_dir, "foo.svg"), figsize=(5 * num_cols,5 * num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    ax.scatter(np.log2(data[gmm_1].ip), np.log2(data[gmm_1].input), alpha=.7, color='b')
    ax.scatter(np.log2(data[gmm_2].ip), np.log2(data[gmm_2].input), alpha=.7, color='r')

# %%
from sklearn.neighbors import kneighbors_graph

# %%
knn_graph = kneighbors_graph(np.log2(data), 50)

# %%
y_pred = AgglomerativeClustering(n_clusters=2, connectivity=knn_graph).fit_predict(np.log2(data))

gmm_1 = [True if x == 1 else False for x in y_pred]
gmm_2 = [True if x == 0 else False for x in y_pred]
print sum(gmm_1), sum(gmm_2)
# Out:
# 21199 2709
# /home/gpratt/anaconda/lib/python2.7/site-packages/sklearn/cluster/hierarchical.py:167: UserWarning: the number of connected components of the connectivity matrix is 255 > 1. Completing it to avoid stopping the tree early.
#   n_components=n_components)

# %%
with dataviz.Figure(os.path.join(img_dir, "foo.svg"), figsize=(5 * num_cols,5 * num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    ax.scatter(np.log2(data[gmm_1].ip), np.log2(data[gmm_1].input), alpha=.7, color='b')
    ax.scatter(np.log2(data[gmm_2].ip), np.log2(data[gmm_2].input), alpha=.7, color='r')

# %%
import scipy as sp

# %%
lena = sp.misc.lena()

# %%
lena
# Out:
# array([[162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        ...,
#        [ 43,  43,  50, ..., 104, 100,  98],
#        [ 44,  44,  55, ..., 104, 105, 108],
#        [ 44,  44,  55, ..., 104, 105, 108]])

# %%
from sklearn.feature_extraction import image

# %%
knn_graph
# Out:
# <2660x2660 sparse matrix of type '<type 'numpy.float64'>'
# 	with 665000 stored elements in Compressed Sparse Row format>

# %%
affinity_propagation(knn_graph)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-eff837bad8c2> in <module>()
# ----> 1 affinity_propagation(knn_graph)
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/sklearn/cluster/affinity_propagation_.pyc in affinity_propagation(S, preference, convergence_iter, max_iter, damping, copy, verbose)
#      77
#      78     if preference is None:
# ---> 79         preference = np.median(S)
#      80     if damping < 0.5 or damping >= 1:
#      81         raise ValueError('damping must be >= 0.5 and < 1')
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in median(a, axis, out, overwrite_input, keepdims)
#    3082     """
#    3083     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3084                     overwrite_input=overwrite_input)
#    3085     if keepdims:
#    3086         return r.reshape(k)
#
# ...

# %%
import maxflow
from itertools import izip

# %%
g = maxflow.Graph[float]()

# %%
g.add_nodes?

# %%
knn_graph = kneighbors_graph(np.log2(data), 50, mode="distance")
nodeids = g.add_nodes(knn_graph.shape[0])

# %%
knz = knn_graph.nonzero()
sparerows = knz[0]
sparecols = knz[1]

for row, col in izip(sparerows, sparecols):
    g.add_edge(nodeids[row], nodeids[col], knn_graph[row, col], knn_graph[row, col])

# %%
for node in nodeids:
    g.add_tedge(node, 1, -1)

# %%
g.maxflow()
# Out:
# 23908.0

# %%
sgm = g.get_grid_segments(nodeids)

# %%
sum(sgm)
# Out:
# 0

# %%
gmm_1 = [x for x in sgm]
gmm_2 = [not x for x in sgm]
print sum(gmm_1), sum(gmm_2)
# Out:
# 0 23908

# %%
with dataviz.Figure(os.path.join(img_dir, "foo.svg"), figsize=(5 * num_cols,5 * num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    ax.scatter(np.log2(data[gmm_1].ip), np.log2(data[gmm_1].input), alpha=.7, color='b')
    ax.scatter(np.log2(data[gmm_2].ip), np.log2(data[gmm_2].input), alpha=.7, color='r')

# %% [markdown]
# #Do self consistancy and merged replicates

# %%
merged_data = pd.read_table("/home/elvannostrand/data/clip/CLIPseq_analysis/ALLCLIP_v12_20160112/encode_v12_filelist.MethodPaperSubmittedList_20160122.txt")
merged_data.CLIP_rep1 = merged_data.CLIP_rep1.apply(lambda x: x.replace("/projects/ps-yeolab2/encode/analysis/encode_v12", "/home/gpratt/projects/encode/analysis/enhancer_rnas"))
merged_data.CLIP_rep2 = merged_data.CLIP_rep2.apply(lambda x: x.replace("/projects/ps-yeolab2/encode/analysis/encode_v12", "/home/gpratt/projects/encode/analysis/enhancer_rnas"))

# %%
idr_cmds = []
for name, row in merged_data.iterrows():
    idr_cmds.append("python ~/gscripts/gscripts/clipseq/perform_idr.py --bam {}  --premRNA --species hg19 --out baz --genome /projects/ps-yeolab/genomes/hg19/hg19.chrom.sizes".format(row.CLIP_rep1))
    idr_cmds.append("python ~/gscripts/gscripts/clipseq/perform_idr.py --bam {}  --premRNA --species hg19 --out baz --genome /projects/ps-yeolab/genomes/hg19/hg19.chrom.sizes".format(row.CLIP_rep2))

# %%
total = 0 
result = []
for cmd in idr_cmds:
    total += 1
    result.append('cmd[{}]="{}"'.format(total, cmd, ))
    
with open(os.path.join("/home/gpratt/projects/encode/scripts", "encode_self_consistancy.sh"), 'w') as out_file:
    out_file.write(eplouge("encode_idr_self_consistancy", total, "/home/gpratt/projects/encode/analysis/enhancer_rnas"))
    for line in result:
        out_file.write(line + "\n\n")
    out_file.write(prolouge + "\n")

# %%
idr_cmds = []

for name, row in merged_data.iterrows():
    idr_cmds.append("python ~/gscripts/gscripts/clipseq/perform_idr.py --bam {} --rep2 {} --merged_file_name {} --premRNA --species hg19 --out {} --genome /projects/ps-yeolab/genomes/hg19/hg19.chrom.sizes".format(row.CLIP_rep1, row.CLIP_rep2, str(row.uID) + "_", 'baz'))

# %%
total = 0 
result = []
for cmd in idr_cmds:
    total += 1
    result.append('cmd[{}]="{}"'.format(total, cmd, ))
    
with open(os.path.join("/home/gpratt/projects/encode/scripts", "encode_merged_pesudoreplicate.sh"), 'w') as out_file:
    out_file.write(eplouge("encode_merged_pesudoreplicate", total, "/home/gpratt/projects/encode/analysis/enhancer_rnas"))
    for line in result:
        out_file.write(line + "\n\n")
    out_file.write(prolouge + "\n")
