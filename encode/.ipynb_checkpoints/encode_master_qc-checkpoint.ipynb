# %%
# %matplotlib inline
from collections import defaultdict, Counter
import glob
import os
import json

from IPython.core.display import HTML, Image
from matplotlib_venn import venn3
import pandas as pd
import pybedtools
import pysam
import gspread
from gscripts.general import parsers
from gscripts.general import dataviz
# %load_ext autoreload
import numpy as np
# %autoreload 2
reload(parsers)
reload(pybedtools)
import seaborn as sns
import matplotlib
from oauth2client.client import SignedJwtAssertionCredentials
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from matplotlib import rc
rc('text', usetex=False)
matplotlib.rcParams['svg.fonttype'] = 'none'

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

# %%
json_key = json.load(open("../public clip-588adbc137f3.json"))
scope = ['https://spreadsheets.google.com/feeds']

credentials = SignedJwtAssertionCredentials(json_key['client_email'], json_key['private_key'], scope)
gc = gspread.authorize(credentials)

sht1 = gc.open_by_url("https://docs.google.com/spreadsheets/d/1ZU2mQh54jentqvhR_oMnviLGWR8Nw_x338gULzKjNDI/edit#gid=0")
ws = sht1.worksheet("Sheet1")
list_of_lists = ws.get_all_values()
manifest = pd.DataFrame(list_of_lists[1:], columns=list_of_lists[0])
manifest['qc_id'] = manifest.apply(lambda x: "{}_{}".format(x.ENCODE_ID, x.RBP), axis=1)
manifest.is_encode = manifest.is_encode == "TRUE"

# %%
def format_file(index, adapter):
    index_1 = illumina_adapters.ix[index.index_1].values[0]
    index_2 = illumina_adapters.ix[index.index_2].values[0]
    if index.Lane == "": #Incase we are doing a rapid run and there isn't lane info
        sample_name = "{}_{}-{}_{}.fastq.gz".format(index.Hiseq_file_name, index_2, index_1, adapter)
        dir_name = "Sample_{}".format(index.Hiseq_file_name)

    elif index.Lane.startswith("S"):
        name = index.Hiseq_file_name.split("-")[0].replace("_", "-")
        sample_name = "{}_{}_{}.fastq.gz".format(name, index.Lane, adapter)
        dir_name = index.Hiseq_file_name
    else:
        sample_name = "{}_{}-{}_{}_{}.fastq.gz".format(index.Hiseq_file_name, index_2, index_1, index.Lane, adapter)
        dir_name = "Sample_{}".format(index.Hiseq_file_name)
    return os.path.join(index.file_location, dir_name, sample_name)

# %%
analysis_dir = "/projects/ps-yeolab2/encode/analysis/encode_v12/"
encode_v7 = parsers.clipseq_metrics(analysis_dir, iclip=True)

encode_v7["Fraction Collapsed"] = encode_v7['Usable Reads'] / encode_v7['Uniquely Mapped Reads'].astype(float)
encode_v7["Fraction Usable"] = encode_v7['Usable Reads'] / encode_v7['Input Reads'].astype(float)
unmerged_clip_manifest = encode_v7[["merged" not in index for index in encode_v7.index]]

manifest_df = pd.read_table("/home/gpratt/projects/encode/scripts/encode_v8.txt", header=None,
             names=['fastq', 'species', 'encode_id', 'barcodes', 'barcodes_len', 'more_barcodes', "randomer_length"])
manifest_df['qc_name'] = manifest_df.fastq.apply(lambda x: ".".join(os.path.basename(x.split(";")[0]).split(".")[:2]))

tmp = pd.merge(manifest_df, unmerged_clip_manifest, left_on="qc_name", right_index=True)

final_qc_frame = pd.merge(manifest, tmp, left_on='qc_id', right_on='encode_id')
final_qc_frame['exp_id'] = final_qc_frame.ENCODE_ID.apply(lambda x:x.split("_")[0])

def get_rep_num(encode_id):
    try:
        return encode_id.split("_")[1]
    except: 
        return np.nan
final_qc_frame['rep_num'] = final_qc_frame.ENCODE_ID.apply(get_rep_num)
final_qc_frame['Input Reads'] = final_qc_frame['Input Reads'].fillna(0)

# %%
# analysis_dir = "/home/gpratt/projects/encode/analysis/encode_v8/"
# encode_v8 = parsers.clipseq_metrics(analysis_dir, iclip=True)

# encode_v8["Fraction Collapsed"] = encode_v8['Usable Reads'] / encode_v8['Uniquely Mapped Reads'].astype(float)
# encode_v8["Fraction Usable"] = encode_v8['Usable Reads'] / encode_v8['Input Reads'].astype(float)

# %%
encode_v7.to_csv("/home/gpratt/Dropbox/encode_integration/for_eric/unannoated_qc_v12.csv")

# %%
encode_v7 = pd.read_csv("/home/gpratt/Dropbox/encode_integration/for_eric/unannoated_qc_v9_stable.csv", index_col=0)

unmerged_clip_manifest = encode_v7[["merged" not in index for index in encode_v7.index]]

manifest_df = pd.read_table("/home/gpratt/projects/encode/scripts/encode_v8.txt", header=None,
             names=['fastq', 'species', 'encode_id', 'barcodes', 'barcodes_len', 'more_barcodes', "randomer_length"])
manifest_df['qc_name'] = manifest_df.fastq.apply(lambda x: ".".join(os.path.basename(x.split(";")[0]).split(".")[:2]))

tmp = pd.merge(manifest_df, unmerged_clip_manifest, left_on="qc_name", right_index=True)

final_qc_frame = pd.merge(manifest, tmp, left_on='qc_id', right_on='encode_id')
final_qc_frame['exp_id'] = final_qc_frame.ENCODE_ID.apply(lambda x:x.split("_")[0])

def get_rep_num(encode_id):
    try:
        return encode_id.split("_")[1]
    except: 
        return np.nan
final_qc_frame['rep_num'] = final_qc_frame.ENCODE_ID.apply(get_rep_num)
final_qc_frame['Input Reads'] = final_qc_frame['Input Reads'].fillna(0)

# %%
new_index = []
for index, row in final_qc_frame.iterrows():
    new_index.append([row.RBP, row.exp_id, row.rep_num, row.cell_type, row.ENCODE_ID])
    
final_qc_frame.index = pd.MultiIndex.from_tuples(new_index, names=['rbp', 'encode_id', 'rep', 'cell_type', "full_name"])
final_qc_frame = final_qc_frame.sort_index()

# %%
lf_frame = encode_v7[["LF_" in item for item in encode_v7.index]]

HTML(lf_frame[[ "Input Reads",
                                #'Trimmed bases',
                            "Reads Written",
                            "repetitive_count",
                            "Uniquely Mapped Reads",
                            "Uniquely mapped reads %",
                            "Usable Reads",
                            "Fraction Collapsed",
                            "Fraction Usable",
                            #"spot",
                            #"Num Peaks",
                            #"Passed QC"
                            ]].to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads Written" : parsers.commas,
                                     "repetitive_count": parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas}))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Reads Written</th>
#       <th>repetitive_count</th>
#       <th>Uniquely Mapped Reads</th>
#       <th>Uniquely mapped reads %</th>
#       <th>Usable Reads</th>
#       <th>Fraction Collapsed</th>
#       <th>Fraction Usable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LF_01_S33_L004_R1_001.unassigned</th>
#       <td>6,687,126</td>
#       <td>3,095,197</td>
#       <td>779,009</td>
#       <td>1,190,630</td>
#       <td>48.05%</td>
#       <td>185,826</td>
#       <td>0.156074</td>
#       <td>0.027789</td>
#     </tr>
#     <tr>
#       <th>LF_02_S34_L004_R1_001.unassigned</th>
#       <td>9,243,604</td>
#       <td>5,642,069</td>
#       <td>1,176,846</td>
#       <td>2,142,263</td>
#       <td>46.69%</td>
#       <td>204,238</td>
#       <td>0.095338</td>
#       <td>0.022095</td>
#     </tr>
#     <tr>
#       <th>LF_03_S35_L004_R1_001.unassigned</th>
#       <td>7,646,638</td>
#       <td>5,874,829</td>
#       <td>1,344,321</td>
#       <td>1,769,624</td>
#       <td>34.14%</td>
#       <td>189,625</td>
#       <td>0.107156</td>
#       <td>0.024798</td>
#     </tr>
#     <tr>
#       <th>LF_04_S36_L004_R1_001.unassigned</th>
#       <td>11,289,402</td>
#       <td>7,626,546</td>
#       <td>1,574,311</td>
#       <td>2,991,036</td>
#       <td>45.00%</td>
#       <td>298,897</td>
#       <td>0.099931</td>
#       <td>0.026476</td>
#     </tr>
#     <tr>
#       <th>LF_05_S37_L004_R1_001.unassigned</th>
#       <td>11,739,971</td>
#       <td>10,431,301</td>
#       <td>4,581,133</td>
#       <td>5,990,561</td>
#       <td>67.15%</td>
#       <td>2,496,167</td>
#       <td>0.416683</td>
#       <td>0.212621</td>
#     </tr>
#     <tr>
#       <th>LF_06_S38_L004_R1_001.unassigned</th>
#       <td>11,594,506</td>
#       <td>6,376,066</td>
#       <td>811,127</td>
#       <td>2,699,124</td>
#       <td>50.98%</td>
#       <td>357,710</td>
#       <td>0.132528</td>
#       <td>0.030852</td>
#     </tr>
#     <tr>
#       <th>LF_07_S39_L004_R1_001.unassigned</th>
#       <td>12,254,068</td>
#       <td>8,653,268</td>
#       <td>4,234,931</td>
#       <td>2,038,760</td>
#       <td>30.70%</td>
#       <td>471,932</td>
#       <td>0.231480</td>
#       <td>0.038512</td>
#     </tr>
#     <tr>
#       <th>LF_08_S40_L004_R1_001.unassigned</th>
#       <td>5,191,831</td>
#       <td>2,568,005</td>
#       <td>276,857</td>
#       <td>416,301</td>
#       <td>24.10%</td>
#       <td>240,385</td>
#       <td>0.577431</td>
#       <td>0.046301</td>
#     </tr>
#   </tbody>
# </table>

# %%
1215179
753457
# Out:
# 753457

# %%
filtered_final_qc_frame = final_qc_frame[[ "Input Reads",
                                #'Trimmed bases',
                            "Reads Written",
                            "repetitive_count",
                            "Uniquely Mapped Reads",
                            "Uniquely mapped reads %",
                            "Usable Reads",
                            "Fraction Collapsed",
                            "Fraction Usable",
                            #"spot",
                            "Num Peaks",
                            #"Passed QC"
                            ]]

#filtered_final_qc_frame = filtered_final_qc_frame.astype(float)

# %%
cvb_frame = unmerged_clip_manifest[["CVB" in item for item in unmerged_clip_manifest.index]]
cvb_frame.to_csv("CBV_stats_all.csv")

# %%
cvb_frame = unmerged_clip_manifest[["CVB" in item for item in unmerged_clip_manifest.index]]
cvb_frame['percent_repetitive'] = cvb_frame['repetitive_count'] / cvb_frame['Reads Written']
cvb_frame.to_csv("CBV_stats_all.csv")
filtered_cbv_frame = cvb_frame[[ "Input Reads",
                                #'Trimmed bases',
                            "Reads Written",
                            "repetitive_count",
                            'percent_repetitive',
                            "Uniquely Mapped Reads",
                            "Uniquely mapped reads %",
                            "Usable Reads",
                            "Fraction Collapsed",
                            "Fraction Usable",
                            #"spot",
                            "Num Peaks",
                            #"Passed QC"
                            ]]

HTML(filtered_cbv_frame.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads Written" : parsers.commas,
                                     "repetitive_count": parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas
                                     } ))
# Out:
# /home/gpratt/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Reads Written</th>
#       <th>repetitive_count</th>
#       <th>percent_repetitive</th>
#       <th>Uniquely Mapped Reads</th>
#       <th>Uniquely mapped reads %</th>
#       <th>Usable Reads</th>
#       <th>Fraction Collapsed</th>
#       <th>Fraction Usable</th>
#       <th>Num Peaks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CVB_MN_LF10_GAGATTCC-ATAGAGGC_L008_R1.unassigned</th>
#       <td>1,604,666</td>
#       <td>713,767</td>
#       <td>479,750</td>
#       <td>0.672138</td>
#       <td>100,645</td>
#       <td>29.43%</td>
#       <td>96,667</td>
#       <td>0.960475</td>
#       <td>0.060241</td>
#       <td>1,635</td>
#     </tr>
#     <tr>
#       <th>CVB_MN_LF11_ATTCAGAA-ATAGAGGC_L008_R1.unassigned</th>
#       <td>393,415</td>
#       <td>233,794</td>
#       <td>182,239</td>
#       <td>0.779485</td>
#       <td>96,490</td>
#       <td>71.25%</td>
#       <td>94,876</td>
#       <td>0.983273</td>
#       <td>0.241160</td>
#       <td>1,615</td>
#     </tr>
#     <tr>
#       <th>CVB_MN_LF12_GAATTCGT-ATAGAGGC_L008_R1.unassigned</th>
#       <td>1,417,724</td>
#       <td>567,117</td>
#       <td>424,398</td>
#       <td>0.748343</td>
#       <td>48,090</td>
#       <td>18.83%</td>
#       <td>46,019</td>
#       <td>0.956935</td>
#       <td>0.032460</td>
#       <td>859</td>
#     </tr>
#     <tr>
#       <th>CVB_MN_L
td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">KB3</th>
#       <th rowspan="2" valign="top">AIFM</th>
#       <th rowspan="2" valign="top">FIXME</th>
#       <th>KB3_AIFM_2</th>
#       <td>10333989</td>
#       <td>9646717</td>
#       <td>17747946</td>
#       <td>952727</td>
#       <td>26.46%</td>
#       <td>919336</td>
#       <td>0.964952</td>
#       <td>0.088962</td>
#       <td>19157</td>
#     </tr>
#     <tr>
#       <th>KB3_AIFM_2</th>
#       <td>7838299</td>
#       <td>7347020</td>
#       <td>13741996</td>
#       <td>707377</td>
#       <td>26.14%</td>
#       <td>687401</td>
#       <td>0.971760</td>
#       <td>0.087698</td>
#       <td>13837</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">APOBEC3C</th>
#       <th rowspan="5" valign="top">374</th>
#       <th rowspan="2" valign="top">01</th>
#       <th rowspan="2" valign="top"></th>
#       <th>374_01</th>
#       <td>5859875</td>
#       <td>5395321</td>
#       <td>12148435</td>
#       <td>1009788</td>
#       <td>50.25%</td>
#       <td>506106</td>
#       <td>0.501200</td>
#       <td>0.086368</td>
#       <td>14848</td>
#     </tr>
#     <tr>
#       <th>374_01</th>
#       <td>5982603</td>
#       <td>5498738</td>
#       <td>13108558</td>
#       <td>902235</td>
#       <td>48.06%</td>
#       <td>416204</td>
#       <td>0.461303</td>
#       <td>0.069569</td>
#       <td>13172</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">02</th>
#       <th rowspan="2" valign="top"></th>
#       <th>374_02</th>
#       <td>8355688</td>
#       <td>7582265</td>
#       <td>14725120</td>
#       <td>1876548</td>
#       <td>54.70%</td>
#       <td>1586815</td>
#       <td>0.845603</td>
#       <td>0.189908</td>
#       <td>28173</td>
#     </tr>
#     <tr>
#       <th>374_02</th>
#       <td>5

# %%
grouped_final_qc_frame = filtered_final_qc_frame.groupby(level=['rbp', 'encode_id', 'rep', 'cell_type', 
                                                                #'full_name'
                                                               ]).sum()
grouped_final_qc_frame["Fraction Collapsed"] = grouped_final_qc_frame['Usable Reads'] / grouped_final_qc_frame['Uniquely Mapped Reads'].astype(float)
grouped_final_qc_frame["Fraction Usable"] = grouped_final_qc_frame['Usable Reads'] / grouped_final_qc_frame['Input Reads'].astype(float)
grouped_final_qc_frame = grouped_final_qc_frame.drop("Num Peaks", axis=1)

# %%
grouped_final_qc_frame
# Out:
#                                       Input Reads  Reads Written  \
# rbp       encode_id rep   cell_type
# AATF      496       01                   29283145       27928910
#                     02                   31204815       28854139
#                     INPUT                28309360       28237746
#           511       01                   27599963       26835720
#                     02                   25789344       24678308
#                     INPUT                29268279       29226209
# ADAR1     396       01                   16100613       14787983
#                     02                   16032467       14333309
#                     INPUT                32093007       31299932
# AIFM1     KB12      AIFM  FIXME          10276666        9952948
#           KB2       AIFM  FIXME           7914641        7438567
#           KB3       AIFM  FIXME          18172288       16993737
# APOBEC3C  374       01                   11842478       10894059
#                     02                   14220446       13014728
#                     INPUT                19920851       19150823
# ASCC1     219       02    HepG2           6922785        6354822
#                     INPUT HepG2          14060169       13742528
#           323       01    K562            2615309        2480212
#                     02    K562            9347350        8811142
#                     INPUT K562           10914914       10558369
# AUH       246       01    K562           13631589       11572248
#                     02    K562           13850133       11591854
#                     INPUT K562           22738181       22136900
#           280       01    HepG2          13553232       12970237
#                     02    HepG2          15493437       13713051
#                     INPUT HepG2          19066270       18617190
# BAG2      KB13      BAG2                  5393071        4989343
#           KB14      BAG2                 17272546       15540796
#                     02                        16372943                2400501
#                     INPUT                     33458764                2222799
# hnRNPA2B1 F1        IN    FIXME               28211065                2884498
#                     IP    FIXME                6446690                4908288
#           F2        IN    FIXME               23500210                2485726
#                     IP    FIXME                8188319                5048882
#           F3        IN    FIXME               36517099                3258034
#                     IP    FIXME                6186700                3516245
#           F4        IN    FIXME               35192431                3364479
#                     IP    FIXME               10463050                7615936
#           F5        IN    FIXME               20138681                1788851
#                     IP    FIXME                8924332                6497765
#           F6        IN    FIXME               16048110                1238453
#                     IP    FIXME               10964790                6618162
#           F7        IN    FIXME               20124952                2211550
#                     IP    FIXME                    257                     58
#
#                                       Usable Reads  Fraction Collapsed  \
# rbp       encode_id rep   cell_type
# AATF      496       01                     1624671            0.279705
#                     02                      654316            0.246468
#                     INPUT                  9334699            0.977339
#           511       01                     1930314            0.860928
#                     02                     1122876            0.719714
#                     INPUT                  9445380            0.955046
# ADAR1     396       01                     5947027            0.865692
#                     02                     5287903            0.833679
#                     INPUT                 10294956            0.970219
# AIFM1     KB12      AIFM  FIXME             858679            0.951210
#           KB2       AIFM  FIXME             706628            0.978066
#           KB3       AIFM  FIXME            1606737            0.967853
# APOBEC3C  374       01                      922310            0.482374
#                     02                     2599279            0.839591
#                     INPUT                  2184233            0.979186
# ASCC1     219       02    HepG2            1315153            0.756321
#                     INPUT HepG2            2517257            0.980505
#           323       01    K562              329755            0.798945
#                     02    K562             1389127            0.752326
#                     INPUT K562             2179690            0.966431
# AUH       246       01    K562              740559            0.542271
#                     02    K562              500638            0.327262
#                     INPUT K562             2068242            0.960089
#           280       01    HepG2            2664051            0.748702
#                     02    HepG2            2520409            0.751411
#                     INPUT HepG2            3498407            0.970917
# BAG2      KB13      BAG2                    263804            0.609860
#           KB14      BAG2                    824878            0.483653
#           KB15      BAG2                    610011            0.959778
# BCCIP     230       01    HepG2            2470161            0.870268
# ...                                            ...                 ...
# XRCC6     311       02                     1995912            0.923784
#                     INPUT                  3287414            0.962733
#           480       01                     4368821            0.564296
#                     02                     2655709            0.550493
#                     INPUT                  9609676            0.963050
# XRN2      235       01    HepG2            4154448            0.907008
#                     02    HepG2            1359944            0.856873
#                     INPUT HepG2            3935798            0.982456
#           245       01    K562             2954548            0.854945
#                     02    K562             2333909            0.903797
#                     INPUT K562             3600591            0.985683
# YB1       EVN       YB1   293XT            5971451            0.895573
#           Skin      CLIP  SenLabSkin       7646886            0.814974
# YWHAG     367       01                     2628726            0.906367
#                     02                     2238599            0.932555
#                     INPUT                  2204331            0.991692
# hnRNPA2B1 F1        IN    FIXME            2788027            0.966555
#                     IP    FIXME            4639798            0.945299
#           F2        IN    FIXME            2438775            0.981112
#                     IP    FIXME            4428342            0.877094
#           F3        IN    FIXME            3163821            0.971083
#                     IP    FIXME            3240896            0.921692
#           F4        IN    FIXME            3288052            0.977284
#                     IP    FIXME            6695533            0.879148
#           F5        IN    FIXME            1734730            0.969745
#                     IP    FIXME            6016239            0.925894
#           F6        IN    FIXME            1208608            0.975901
#                     IP    FIXME            5955397            0.899857
#           F7        IN    FIXME            2162292            0.977727
#                     IP    FIXME                 54            0.931034
#
#                                       Fraction Usable
# rbp       encode_id rep   cell_type
# AATF      496       01                       0.055481
#                     02                       0.020968
#                     INPUT                    0.329739
#           511       01                       0.069939
#                     02                       0.043540
#                     INPUT                    0.322717
# ADAR1     396       01                       0.369366
#                     02                       0.329825
#                     INPUT                    0.320785
# AIFM1     KB12      AIFM  FIXME              0.083556
#           KB2       AIFM  FIXME              0.089281
#           KB3       AIFM  FIXME              0.088417
# APOBEC3C  374       01                       0.077882
#                     02                       0.182785
#                     INPUT                    0.109646
# ASCC1     219       02    HepG2              0.189975
#                     INPUT HepG2              0.179035
#           323       01    K562               0.126086
#                     02    K562               0.148612
#                     INPUT K562               0.199698
# AUH       246       01    K562               0.054327
#                     02    K562               0.036147
#                     INPUT K562               0.090959
#           280       01    HepG2              0.196562
#                     02    HepG2              0.162676
#                     INPUT HepG2              0.183487
# BAG2      KB13      BAG2                     0.048915
#           KB14      BAG2                     0.047757
#           KB15      BAG2                     0.058346
# BCCIP     230       01    HepG2              0.276178
# ...                                               ...
# XRCC6     311       02                       0.203158
#                     INPUT                    0.169904
#           480       01                       0.123585
#                     02                       0.084236
#                     INPUT                    0.303767
# XRN2      235       01    HepG2              0.395512
#                     02    HepG2              0.157779
#                     INPUT HepG2              0.347947
#           245       01    K562               0.273159
#                     02    K562               0.318403
#                     INPUT K562               0.260746
# YB1       EVN       YB1   293XT              0.360360
#           Skin      CLIP  SenLabSkin         0.295733
# YWHAG     367       01                       0.202510
#                     02                       0.193569
#                     INPUT                    0.133025
# hnRNPA2B1 F1        IN    FIXME              0.186796
#                     IP    FIXME              0.446160
#           F2        IN    FIXME              0.196439
#                     IP    FIXME              0.418435
#           F3        IN    FIXME              0.174682
#                     IP    FIXME              0.518312
#           F4        IN    FIXME              0.183114
#                     IP    FIXME              0.490753
#           F5        IN    FIXME              0.159711
#                     IP    FIXME              0.565978
#           F6        IN    FIXME              0.145076
#                     IP    FIXME              0.513473
#           F7        IN    FIXME              0.200446
#                     IP    FIXME              0.064286
#
# [600 rows x 7 columns]

# %%
encode_only_qc = grouped_final_qc_frame[[item[0].isdigit() and item[-1].isdigit() for item in grouped_final_qc_frame.index.get_level_values(level="encode_id")]]
encode_only_qc = encode_only_qc.drop("R60")
#encode_only_qc = encode_only_qc.drop('INPUT', level="rep")

# %%
encode_only_qc.to_csv("/home/gpratt/Dropbox/encode_integration/for_eric/encode_master_qc.csv")

# %%
HTML(grouped_final_qc_frame.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads Written" : parsers.commas,
                                     "repetitive_count": parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas
                                     } ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Input Reads</th>
#       <th>Reads Written</th>
#       <th>repetitive_count</th>
#       <th>Uniquely Mapped Reads</th>
#       <th>Usable Reads</th>
#       <th>Fraction Collapsed</th>
#       <th>Fraction Usable</th>
#     </tr>
#     <tr>
#       <th>rbp</th>
#       <th>encode_id</th>
#       <th>rep</th>
#       <th>cell_type</th>
#       <th>full_name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>IgG</th>
#       <th>293XT</th>
#       <th>CLIP</th>
#       <th>293XT</th>
#       <th>293XT_CLIP_IgG_1120_fixed</th>
#       <td>16,965,871</td>
#       <td>16,249,143</td>
#       <td>31,031,596</td>
#       <td>3,502,305</td>
#       <td>2,160,203</td>
#       <td>0.616795</td>
#       <td>0.127326</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top
to_csv("/home/gpratt/Dropbox/encode_integration/for_eric/master_qc_v12.csv")

# %%
grouped_final_qc_frame[grouped_final_qc_frame['Usable Reads'] < 1000000]

# %% [markdown]
# #Public CLIP QC

# %%
analysis_dir = "/home/gpratt/projects/public_clip/analysis/public_clip_v9/"
public_clip = parsers.clipseq_metrics(analysis_dir, iclip=True)

public_clip["Fraction Collapsed"] = public_clip['Usable Reads'] / public_clip['Uniquely Mapped Reads'].astype(float)
public_clip["Fraction Usable"] = public_clip['Usable Reads'] / public_clip['Input Reads'].astype(float)
unmerged_public_clip_manifest = public_clip[["merged" not in index for index in public_clip.index]]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-f78c0d4194f9> in <module>()
#       1 analysis_dir = "/home/gpratt/projects/public_clip/analysis/public_clip_v9/"
# ----> 2 public_clip = parsers.clipseq_metrics(analysis_dir, iclip=True)
#       3
#       4 public_clip["Fraction Collapsed"] = public_clip['Usable Reads'] / public_clip['Uniquely Mapped Reads'].astype(float)
#       5 public_clip["Fraction Usable"] = public_clip['Usable Reads'] / public_clip['Input Reads'].astype(float)
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/gscripts-0.1.6-py2.7.egg/gscripts/general/parsers.pyc in clipseq_metrics(analysis_dir, iclip, num_seps, sep, percent_usable, number_usable, frip)
#     123     rm_duped_df = pd.DataFrame({name: parse_rm_duped_metrics_file(rm_duped_file) for name, rm_duped_file in rm_duped_names.items()}).transpose()
#     124     spot_df = pd.DataFrame({name: parse_peak_metrics(spot_file) for name, spot_file in spot_names.items()}).transpose()
# --> 125     peaks_df = pd.DataFrame({name: {"Num Peaks": len(pybedtools.BedTool(peaks_file))} for name, peaks_file in peaks_names.items()}).transpose()
#     126     combined_df = rnaseq_metrics(analysis_dir, num_seps, sep)
#     127
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/gscripts-0.1.6-py2.7.egg/gscripts/general/parsers.pyc in <dictcomp>((name, peaks_file))
#     123     rm_duped_df = pd.DataFrame({name: parse_rm_duped_metrics_file(rm_duped_file) for name, rm_duped_file in rm_duped_names.items()}).transpose()
#     124     spot_df = pd.DataFrame({name: parse_peak_metrics(spot_file) for name, spot_file in spot_names.items()}).transpose()
# --> 125     peaks_df = pd.DataFrame({name: {"Num Peaks": len(pybedtools.BedTool(peaks_file))} for name, peaks_file in peaks_names.items()}).transpose()
#     126     combined_df = rnaseq_metrics(analysis_dir, num_seps, sep)
#     127
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/pybedtools-0.7.0-py2.7-linux-x86_64.egg/pybedtools/bedtool.pyc in __len__(self)
#    1075
#    1076     def __len__(self):
# -> 1077         return self.count()
#    1078
#    1079     def __eq__(self, other):
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/pybedtools-0.7.0-py2.7-linux-x86_64.egg/pybedtools/bedtool.pyc in count(self)
#    2257         if hasattr(self, 'next') or hasattr(self, '__next__'):
#    2258             return sum(1 for _ in self)
# -> 2259         return sum(1 for _ in iter(self))
#    2260
#    2261     def print_sequence(self):
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/pybedtools-0.7.0-py2.7-linux-x86_64.egg/pybedtools/bedtool.pyc in <genexpr>((_,))
#    2257         if hasattr(self, 'next') or hasattr(self, '__next__'):
#    2258             return sum(1 for _ in self)
# -> 2259         return sum(1 for _ in iter(self))
#    2260
#    2261     def print_sequence(self):
#
# KeyboardInterrupt:

# %%
filtered_unmerged_public_clip_manifest = unmerged_public_clip_manifest[[ "Input Reads",
                                #'Trimmed bases',
                            "Reads Written",
                            "repetitive_count",
                            "Uniquely Mapped Reads",
                            #"Uniquely mapped reads %",
                            "Usable Reads",
                            "Fraction Collapsed",
                            "Fraction Usable",
                            #"spot",
                            "Num Peaks",
                            #"Passed QC"
                            ]]

filtered_unmerged_public_clip_manifest = filtered_unmerged_public_clip_manifest.astype(float)
filtered_unmerged_public_clip_manifest.index = filtered_unmerged_public_clip_manifest.index.map(lambda x: x.split(".")[0])

# %%
HTML(filtered_unmerged_public_clip_manifest.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads Written" : parsers.commas,
                                     "repetitive_count": parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas
                                     } ))

# %%
analysis_dir = "/home/gpratt/projects/public_clip/analysis/public_iclip_v1/"
public_iclip = parsers.clipseq_metrics(analysis_dir, iclip=True)

public_iclip["Fraction Collapsed"] = public_iclip['Usable Reads'] / public_iclip['Uniquely Mapped Reads'].astype(float)
public_iclip["Fraction Usable"] = public_iclip['Usable Reads'] / public_iclip['Input Reads'].astype(float)
unmerged_public_iclip_manifest = public_iclip[["merged" not in index for index in public_iclip.index]]

unmerged_public_iclip_manifest.index = pd.MultiIndex.from_tuples([item.split(".") for item in unmerged_public_iclip_manifest.index], 
                          names=["sra_id", "barcode"])

# %%
unmerged_public_iclip_manifest = unmerged_public_iclip_manifest.groupby(level="sra_id").sum()
unmerged_public_iclip_manifest["Fraction Collapsed"] = unmerged_public_iclip_manifest['Usable Reads'] / unmerged_public_iclip_manifest['Uniquely Mapped Reads'].astype(float)
unmerged_public_iclip_manifest["Fraction Usable"] = unmerged_public_iclip_manifest['Usable Reads'] / unmerged_public_iclip_manifest['Input Reads'].astype(float)

# %%
filtered_unmerged_public_iclip_manifest = unmerged_public_iclip_manifest[[ "Input Reads",
                                #'Trimmed bases',
                            "Reads Written",
                            "repetitive_count",
                            "Uniquely Mapped Reads",
                            #"Uniquely mapped reads %",
                            "Usable Reads",
                            "Fraction Collapsed",
                            "Fraction Usable",
                            #"spot",
                            "Num Peaks",
                            #"Passed QC"
                            ]]

HTML(filtered_unmerged_public_iclip_manifest.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads Written" : parsers.commas,
                                     "repetitive_count": parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas
                                     } ))

# %%
public_clip_database = sht1.worksheet("public_clip_database")
list_of_lists = public_clip_database.get_all_values()
public_clip_database = pd.DataFrame(list_of_lists[1:], columns=list_of_lists[0])

merged_public_df = pd.merge(public_clip_database, filtered_unmerged_public_clip_manifest , left_on="SRA", right_index=True)
merged_public_df = merged_public_df[merged_public_df.Species.isin(["hg19", "mn9"])]
merged_public_df.index = merged_public_df.SRA

public_iclip = merged_public_df[merged_public_df['type'] == 'iclip']
public_clip = merged_public_df[merged_public_df['type'].isin({'clip', 'par-clip', 'par-clip 4SU'})]

# %%
analysis_dir = "/home/gpratt/projects/encode/analysis/v10/"
old_encode = parsers.clipseq_metrics(analysis_dir, iclip=True)

old_encode["Fraction Collapsed"] = old_encode['Usable Reads'] / old_encode['Uniquely Mapped Reads'].astype(float)
old_encode["Fraction Usable"] = old_encode['Usable Reads'] / old_encode['Input Reads'].astype(float)
unmerged_old_encode_manifest = old_encode[[len(index.split(".")[1].split("_")) > 1 for index in old_encode.index]]

# %%
img_dir = "/home/gpratt/Dropbox/encode_integration/for_eric/"

# %% [markdown]
# #Show that the total number of usable reads is far and away better than other non-encode stuff

# %%
publication_list = pd.read_table("/home/elvannostrand/data/clip/CLIPseq_analysis/Method_paper_figures/MethodPaperFileList_FINAL100415.txt")

# %%
stats_for_publication = encode_only_qc[[int(encode_id) in publication_list.uID.values for encode_id in encode_only_qc.index.get_level_values(level="encode_id")]]
stats_for_publication = stats_for_publication[["INPUT" != rep for rep in stats_for_publication.index.get_level_values(level="rep")]]
stats_for_publication = stats_for_publication.drop(("SF3B4", '228', '01', ''), axis=0)
stats_for_publication = stats_for_publication.dropna()

# %%
real_encode_v10 = unmerged_old_encode_manifest.ix[["DirectIP" not in name for name in unmerged_old_encode_manifest.index]]
real_encode_v10 = real_encode_v10.ix[[len(name.split(".")[1].split("_")) > 1 for name in real_encode_v10.index]]
real_encode_v10 = real_encode_v10.ix[["LiCLIP" not in name for name in real_encode_v10.index]]
real_encode_v10 = real_encode_v10.ix[["ZNL" not in name for name in real_encode_v10.index]]
real_encode_v10 = real_encode_v10.ix[["ZNH" not in name for name in real_encode_v10.index]]
real_encode_v10 = real_encode_v10.ix[[not name.endswith("_a") for name in real_encode_v10.index]]
real_encode_v10 = real_encode_v10.ix[[not name.endswith("_b") for name in real_encode_v10.index]]

fus = real_encode_v10.ix[[("FUS" in name) or ("EIF4G1" in name) or ("TAL1" in name) for name in real_encode_v10.index]]

imp_data = pd.read_table("/home/gpratt/projects/encode/scripts/encode_clipseq_imp.txt", header=None, names=['path', 'species', 'merge'])
imp_data['full_name'] = imp_data.path.apply(os.path.basename).apply(lambda x: ".".join(x.split(".")[:2]))
merged_imp = pd.merge(real_encode_v10, imp_data, left_index=True, right_on="full_name")
merged_imp = merged_imp.groupby("merge").sum()

merged_imp["Fraction Collapsed"] = merged_imp['Usable Reads'] / merged_imp['Uniquely Mapped Reads'].astype(float)
merged_imp["Fraction Usable"] = merged_imp['Usable Reads'] / merged_imp['Input Reads'].astype(float)
submitted_old_encode = pd.concat([fus, merged_imp])

# %%
all_iclip = pd.concat([submitted_old_encode, unmerged_public_iclip_manifest])
all_iclip['annotation'] = "All iCLIP"

# %%
stats_for_publication['annotation'] = "ENCODE eCLIP"
submitted_old_encode['annotation'] = "ENCODE iCLIP Submitted"
#unmerged_old_encode_manifest['annotation'] = "ENCODE iCLIP"
unmerged_public_iclip_manifest['annotation'] = "Public iCLIP"
public_clip['annotation'] = "Public CLIP"

master_df = pd.concat([stats_for_publication,
                       submitted_old_encode,
                       #unmerged_old_encode_manifest,
                       unmerged_public_iclip_manifest,
                       public_clip,
                       all_iclip])

# %%
master_df = master_df[master_df['Uniquely Mapped Reads'] > 100000]

# %%
master_df = master_df[[ "Input Reads",
                                #'Trimmed bases',
                            #"Reads Written",
                            #"repetitive_count",
                            "Uniquely Mapped Reads",
                            #"Uniquely mapped reads %",
                            "Usable Reads",
                            "Fraction Collapsed",
                            "Fraction Usable",
                            #"spot",
                            #"Num Peaks",
                       "annotation"
                            #"Passed QC"
                            ]]

# %%
num_rows = 1 
num_cols = 2 
with dataviz.Figure(os.path.join(img_dir, "usable_reads_plots_publication.svg"), figsize=(2.5 * num_cols,2.5*num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    sns.violinplot(y="Usable Reads", x="annotation", data=master_df,
                   ax=ax,
                   fontsize=10,
                  inner="box",
                   bw=.4,
                  )
    ax.set_ylim(0,15000000)
    xx = ax.get_yticks()
    ll = ['{:,d}'.format(int(a)) for a in xx]
    ax.set_yticklabels(ll, fontsize=10)
    sns.despine(ax=ax)
    ax.set_title("Number of Usable Reads", fontsize=12)
    ax.set_ylabel("Number of Usable Reads")
    ax.set_xlabel("")
    #[tick.set_rotation(90) for tick in ax.get_xticklabels()]
    #[tick.set_fontsize(8) for tick in ax.get_xticklabels()]

# %%
print stats_for_publication['Usable Reads'].dropna().mean(),unmerged_old_encode_manifest['Usable Reads'].dropna().mean(), public_iclip['Usable Reads'].dropna().mean(), public_clip['Usable Reads'].dropna().mean()
print stats_for_publication['Usable Reads'].dropna().median(),unmerged_old_encode_manifest['Usable Reads'].dropna().median(), public_iclip['Usable Reads'].dropna().median(), public_clip['Usable Reads'].dropna().median()

# %%
num_rows = 1 
num_cols = 2 
with dataviz.Figure(os.path.join(img_dir, "fraction_usable_reads_plots_publication.svg"), figsize=(2.5 * num_cols,2.5*num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)
    sns.violinplot(y="Fraction Usable", x="annotation", data=master_df,
                   ax=ax,
                   fontsize=10,
                  inner="box")

    ax.set_ylim(0,1)
    #xx = ax.get_yticks()
    #ll = ['{:,d}'.format(int(a)) for a in xx]
    #ax.set_yticklabels(ll, fontsize=10)
    sns.despine(ax=ax)
    ax.set_title("Fraction of Usable / Input", fontsize=12)
    ax.set_ylabel("Fraction of Usable / Input")
    ax.set_xlabel("")

# %%
print stats_for_publication['Fraction Usable'].dropna().mean(), unmerged_old_encode_manifest['Fraction Usable'].dropna().mean(), public_iclip['Fraction Usable'].dropna().mean(), public_clip['Fraction Usable'].dropna().mean()
print stats_for_publication['Fraction Usable'].dropna().median(), unmerged_old_encode_manifest['Fraction Usable'].dropna().median(), public_iclip['Fraction Usable'].dropna().median(), public_clip['Fraction Usable'].dropna().median()

# %%
num_rows = 1 
num_cols = 2 
with dataviz.Figure(os.path.join(img_dir, "fraction_collapsed_reads_publication.svg"), figsize=(2.5 * num_cols,2.5*num_rows)) as fig:
    ax = fig.add_subplot(1,1,1)

    sns.stripplot(y="Fraction Collapsed", x="annotation", data=master_df,
                   ax=ax,
                   #fontsize=10,
                  #inner="box",
                   # bw=.3,
                   #scale="width"
                  jitter=1,
                  edgecolor=None,
                  size=3
                  )
    sns.violinplot(y="Fraction Collapsed", x="annotation", data=master_df,
                   ax=ax,
                   fontsize=10,
                  inner="box",
                    bw=.3,
                   scale="width"
                  )
    
    ax.set_ylim(0,1)
    #xx = ax.get_yticks()
    #ll = ['{:,d}'.format(int(a)) for a in xx]
    #ax.set_yticklabels(ll, fontsize=10)
    sns.despine(ax=ax)
    ax.set_title("Fraction of Collapsed Reads / Mapped", fontsize=12)
    ax.set_ylabel("Fraction Usable / Mapped")
    ax.set_xlabel("")

# %%
print stats_for_publication['Fraction Collapsed'].dropna().mean(),unmerged_old_encode_manifest['Fraction Collapsed'].dropna().mean(), public_iclip['Fraction Collapsed'].dropna().mean(), public_clip['Fraction Collapsed'].dropna().mean()
print stats_for_publication['Fraction Collapsed'].dropna().median(),unmerged_old_encode_manifest['Fraction Collapsed'].dropna().median(), public_iclip['Fraction Collapsed'].dropna().median(), public_clip['Fraction Collapsed'].dropna().median()

# %%
len(stats_for_publication), len(submitted_old_encode), len(unmerged_old_encode_manifest), len(public_iclip), len(public_clip)

# %%
encode_only_qc.to_csv("/home/gpratt/for_eric/encode_only_qc.csv")

# %%
submitted_old_encode.to_csv('/home/gpratt/Dropbox/encode_integration/for_eric/old_encode_clips.csv')

# %%
public_clip.to_csv('/home/gpratt/Dropbox/encode_integration/for_eric/old_public_clips.csv')

# %%
public_iclip.to_csv('/home/gpratt/Dropbox/encode_integration/for_eric/old_public_iclips.csv')

# %%
unmerged_public_iclip_manifest.to_csv('/home/gpratt/Dropbox/encode_integration/for_eric/old_public_iclips.csv')

# %%
def join_if_tuple(item):
    if type(item) is tuple:
        return "_".join(item)
    else:
        return item
    
master_df.index = [join_if_tuple(item) for item in master_df.index]

# %%
pd.read_csv("/home/gpratt/Dropbox/encode_integration/for_eric/master_qc.csv")
# Out:
#             rbp encode_id    rep   cell_type          Hiseq_file_name  \
# 0          AATF       496     01         NaN             496_CLIP_S68
# 1          AATF       496     01         NaN             496_CLIP_S68
# 2          AATF       496     02         NaN             496_CLIP_S68
# 3          AATF       496     02         NaN             496_CLIP_S68
# 4          AATF       496  INPUT         NaN            496_INPUT_S69
# 5          AATF       511     01         NaN             511_CLIP_S17
# 6          AATF       511     01         NaN             511_CLIP_S17
# 7          AATF       511     02         NaN             511_CLIP_S17
# 8          AATF       511     02         NaN             511_CLIP_S17
# 9          AATF       511  INPUT         NaN            511_INPUT_S18
# 10        ADAR1       396     01         NaN                 396_CLIP
# 11        ADAR1       396     01         NaN                 396_CLIP
# 12        ADAR1       396     02         NaN                 396_CLIP
# 13        ADAR1       396     02         NaN                 396_CLIP
# 14        ADAR1       396  INPUT         NaN                396_INPUT
# 15        AIFM1      KB12   AIFM       FIXME  KB12_293_CLIP_AIFM_1_IP
# 16        AIFM1       KB2   AIFM       FIXME   KB2_293_CLIP_AIFM_1_IP
# 17        AIFM1       KB2   AIFM       FIXME   KB2_293_CLIP_AIFM_1_IP
# 18        AIFM1       KB3   AIFM       FIXME   KB3_293_CLIP_AIFM_2_IP
# 19        AIFM1       KB3   AIFM       FIXME   KB3_293_CLIP_AIFM_2_IP
# 20     APOBEC3C       374     01         NaN                 374_CLIP
# 21     APOBEC3C       374     01         NaN                 374_CLIP
# 22     APOBEC3C       374     02         NaN                 374_CLIP
# 23     APOBEC3C       374     02         NaN                 374_CLIP
# 24     APOBEC3C       374  INPUT         NaN                374_INPUT
# 25        ASCC1       219     02       HepG2                228_INPUT
# 26        ASCC1       219     02       HepG2                228_INPUT
# 27        ASCC1       219  INPUT       HepG2                219_INPUT
# 28        ASCC1       323     01        K562                 323_CLIP
# 29        ASCC1       323     01        K562                 323_CLIP
# ...         ...       ...    ...         ...                      ...
# 1094        YB1       EVN    YB1       293XT          YB1andDDX6_CLIP
# 1095        YB1       EVN    YB1       293XT          YB1_293XT_INPUT
# 1096        YB1      Skin   CLIP  SenLabSkin    Skin_CLIP_YB1and_DDX6
# 1097        YB1      Skin   CLIP  SenLabSkin    Skin_CLIP_YB1and_DDX6
# 1098      YWHAG       367     01         NaN                 367_CLIP
# 1099      YWHAG       367     01         NaN                 367_CLIP
# 1100      YWHAG       367     02         NaN                 367_CLIP
# 1101      YWHAG       367     02         NaN                 367_CLIP
# 1102      YWHAG       367  INPUT         NaN                367_INPUT
# 1103  hnRNPA2B1        F1     IN       FIXME               F1_IN_A2B1
# 1104  hnRNPA2B1        F1     IP       FIXME               F1_IP_A2B1
# 1105  hnRNPA2B1        F1     IP       FIXME               F1_IP_A2B1
# 1106  hnRNPA2B1        F2     IN       FIXME               F2_IN_A2B1
# 1107  hnRNPA2B1        F2     IP       FIXME               F2_IP_A2B1
# 1108  hnRNPA2B1        F2     IP       FIXME               F2_IP_A2B1
# 1109  hnRNPA2B1        F3     IN       FIXME               F3_IN_A2B1
# 1110  hnRNPA2B1        F3     IP       FIXME               F3_IP_A2B1
# 1111  hnRNPA2B1        F3     IP       FIXME               F3_IP_A2B1
# 1112  hnRNPA2B1        F4     IN       FIXME               F4_IN_A2B1
# 1113  hnRNPA2B1        F4     IP       FIXME               F4_IP_A2B1
# 1114  hnRNPA2B1        F4     IP       FIXME               F4_IP_A2B1
# 1115  hnRNPA2B1        F5     IN       FIXME               F5_IN_A2B1
# 1116  hnRNPA2B1        F5     IP       FIXME               F5_IP_A2B1
# 1117  hnRNPA2B1        F5     IP       FIXME               F5_IP_A2B1
# 1118  hnRNPA2B1        F6     IN       FIXME               F6_IN_A2B1
# 1119  hnRNPA2B1        F6     IP       FIXME               F6_IP_A2B1
# 1120  hnRNPA2B1        F6     IP       FIXME               F6_IP_A2B1
# 1121  hnRNPA2B1        F7     IN       FIXME                F7_IN_IgG
# 1122  hnRNPA2B1        F7     IP       FIXME                F7_IP_IgG
# 1123  hnRNPA2B1        F7     IP       FIXME                F7_IP_IgG
#
#                      ENCODE_ID        RBP inline_1  inline_2 index_1   ...    \
# 0                       496_01       AATF      A04       F05     502   ...
# 1                       496_01       AATF      A04       F05     502   ...
# 2                       496_02       AATF      A03       G07     502   ...
# 3                       496_02       AATF      A03       G07     502   ...
# 4                    496_INPUT       AATF     none      none     501   ...
# 5                       511_01       AATF      A04       F05     504   ...
# 6                       511_01       AATF      A04       F05     504   ...
# 7                       511_02       AATF      A03       G07     504   ...
# 8                       511_02       AATF      A03       G07     504   ...
# 9                    511_INPUT       AATF     none      none     503   ...
# 10                      396_01      ADAR1      A04       F05     504   ...
# 11                      396_01      ADAR1      A04       F05     504   ...
# 12                      396_02      ADAR1      A03       G07     504   ...
# 13                      396_02      ADAR1      A03       G07     504   ...
# 14                   396_INPUT      ADAR1     none      none     503   ...
# 15             KB12_AIFM_input      AIFM1     none      none     503   ...
# 16                  KB2_AIFM_1      AIFM1      A01       B06     501   ...
# 17                  KB2_AIFM_1      AIFM1      A01       B06     501   ...
# 18                  KB3_AIFM_2      AIFM1      C01  D08fixed     502   ...
# 19                  KB3_AIFM_2      AIFM1      C01  D08fixed     502   ...
# 20                      374_01   APOBEC3C      A01       B06     506   ...
# 21                      374_01   APOBEC3C      A01       B06     506   ...
# 22                      374_02   APOBEC3C      C01  D08fixed     506   ...
# 23                      374_02   APOBEC3C      C01  D08fixed     506   ...
# 24                   374_INPUT   APOBEC3C     none      none     506   ...
# 25                      219_02      ASCC1      C01  D08fixed     505   ...
# 26                      219_02      ASCC1      C01  D08fixed     505   ...
# 27                   219_INPUT      ASCC1     none      none     505   ...
# 28                      323_01      ASCC1      A01       B06     502   ...
# 29                      323_01      ASCC1      A01       B06     502   ...
# ...                        ...        ...      ...       ...     ...   ...
# 1094        EVN_YB1_293xt_CLIP        YB1      A03       G07     501   ...
# 1095       EVN_YB1_293XT_INPUT        YB1     none      none     505   ...
# 1096             Skin_CLIP_YB1        YB1      A04       F05     503   ...
# 1097             Skin_CLIP_YB1        YB1      A04       F05     503   ...
# 1098                    367_01      YWHAG      A04       F05     504   ...
# 1099                    367_01      YWHAG      A04       F05     504   ...
# 1100                    367_02      YWHAG      A03       G07     504   ...
# 1101                    367_02      YWHAG      A03       G07     504   ...
# 1102                 367_INPUT      YWHAG     none      none     504   ...
# 1103  F1_IN_mnCLIP_A2B1_high_1  hnRNPA2B1     none      none     501   ...
# 1104  F1_IP_mnCLIP_A2B1_high_1  hnRNPA2B1      A01       B06     501   ...
# 1105  F1_IP_mnCLIP_A2B1_high_1  hnRNPA2B1      A01       B06     501   ...
# 1106  F2_IN_mnCLIP_A2B1_high_2  hnRNPA2B1     none      none     501   ...
# 1107  F2_IP_mnCLIP_A2B1_high_2  hnRNPA2B1      C01  D08fixed     501   ...
# 1108  F2_IP_mnCLIP_A2B1_high_2  hnRNPA2B1      C01  D08fixed     501   ...
# 1109   F3_IN_mnCLIP_A2B1_med_1  hnRNPA2B1     none      none     501   ...
# 1110   F3_IP_mnCLIP_A2B1_med_1  hnRNPA2B1      A01       B06     501   ...
# 1111   F3_IP_mnCLIP_A2B1_med_1  hnRNPA2B1      A01       B06     501   ...
# 1112   F4_IN_mnCLIP_A2B1_med_2  hnRNPA2B1     none      none     502   ...
# 1113   F4_IP_mnCLIP_A2B1_med_2  hnRNPA2B1      C01  D08fixed     502   ...
# 1114   F4_IP_mnCLIP_A2B1_med_2  hnRNPA2B1      C01  D08fixed     502   ...
# 1115   F5_IN_mnCLIP_A2B1_low_1  hnRNPA2B1     none      none     502   ...
# 1116   F5_IP_mnCLIP_A2B1_low_1  hnRNPA2B1      A01       B06     502   ...
# 1117   F5_IP_mnCLIP_A2B1_low_1  hnRNPA2B1      A01       B06     502   ...
# 1118   F6_IN_mnCLIP_A2B1_low_2  hnRNPA2B1     none      none     502   ...
# 1119   F6_IP_mnCLIP_A2B1_low_2  hnRNPA2B1      C01  D08fixed     502   ...
# 19       KB3    AIFM
# 20       374      01
# 21       374      01
# 22       374      02
# 23       374      02
# 24       374   INPUT
# 25       219      02
# 26       219      02
# 27       219   INPUT
# 28       323      01
# 29       323      01
# ...      ...     ...
# 1094     EVN     YB1
# 1095     EVN     YB1
# 1096    Skin    CLIP
# 1097    Skin    CLIP
# 1098     367      01
# 1099     367      01
# 1100     367      02
# 1101     367      02
# 1102     367   INPUT
# 1103      F1      IN
# 1104      F1      IP
# 1105      F1      IP
# 1106      F2      IN
# 1107      F2      IP
# 1108      F2      IP
# 1109      F3      IN
# 1110      F3      IP
# 1111      F3      IP
# 1112      F4      IN
# 1113      F4      IP
# 1114      F4      IP
# 1115      F5      IN
# 1116      F5      IP
# 1117      F5      IP
# 1118      F6      IN
# 1119      F6      IP
# 1120      F6      IP
# 1121      F7      IN
# 1122      F7      IP
# 1123      F7      IP
#
# [1124 rows x 109 columns]

# %%
master_df.to_csv("/home/gpratt/Dropbox/encode_integration/for_eric/master_qc.csv", sep="\t")

# %%
HTML(master_df.to_html())

# %%
analysis_dir = "/home/gpratt/projects/encode/analysis/encode_mouse_v8/"
encode_mouse = parsers.clipseq_metrics(analysis_dir, iclip=True)

encode_mouse["Fraction Collapsed"] = encode_mouse['Usable Reads'] / encode_mouse['Uniquely Mapped Reads'].astype(float)
encode_mouse["Fraction Usable"] = encode_mouse['Usable Reads'] / encode_mouse['Input Reads'].astype(float)
unmerged_clip_manifest = encode_mouse[["merged" not in index for index in encode_mouse.index]]

manifest_df = pd.read_table("/home/gpratt/projects/encode/scripts/encode_mouse_v8.txt", header=None,
             names=['fastq', 'species', 'encode_id', 'barcodes', 'barcodes_len', 'more_barcodes', "randomer_length"])
manifest_df['qc_name'] = manifest_df.fastq.apply(lambda x: ".".join(os.path.basename(x.split(";")[0]).split(".")[:2]))

tmp = pd.merge(manifest_df, unmerged_clip_manifest, left_on="qc_name", right_index=True)

final_qc_frame = pd.merge(manifest, tmp, left_on='qc_id', right_on='encode_id')
final_qc_frame['exp_id'] = final_qc_frame.ENCODE_ID.apply(lambda x:x.split("_")[0])

def get_rep_num(encode_id):
    try:
        return encode_id.split("_")[1]
    except: 
        return np.nan
final_qc_frame['rep_num'] = final_qc_frame.ENCODE_ID.apply(get_rep_num)
final_qc_frame['Input Reads'] = final_qc_frame['Input Reads'].fillna(0)

# %%
filtered_final_qc_frame = final_qc_frame[["Hiseq_file_name", "ENCODE_ID", "RBP", "Input Reads",
                                #'Trimmed bases',
                            "Reads Written",
                            "repetitive_count",
                            "Uniquely Mapped Reads",
                            "Uniquely mapped reads %",
                            "Usable Reads",
                            "Fraction Collapsed",
                            "Fraction Usable",
                            #"spot",
                            "Num Peaks",
                            #"Passed QC"
                            ]]

#filtered_final_qc_frame = filtered_final_qc_frame.astype(float)

HTML(filtered_final_qc_frame.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads Written" : parsers.commas,
                                     "repetitive_count": parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas
                                     } ))

# %%
filtered_final_qc_frame.to_csv("/home/gpratt/Dropbox/Rbfox3/qc_table.csv")

# %%
foo = pd.read_table("/home/elvannostrand/data/clip/CLIPseq_analysis/ENCODE_v9_20151209/encode_v9_filelist.ENCODE.20151209_newsubset.txt")

# %%
foo = pd.concat([foo.CLIP_rep1, foo.CLIP_rep2, foo.INPUT]).dropna()

# %%
foo.CLIP_rep1.apply(os.path.basename)
# Out:
# 0          406_01_PABPC4.merged.r2.bam
# 1          415_01_TNRC6A.merged.r2.bam
# 2           429_01_SSRP1.merged.r2.bam
# 3           439_01_KHSRP.merged.r2.bam
# 4           440_01_EWSR1.merged.r2.bam
# 5            441_01_PUM2.merged.r2.bam
# 6           444_01_LSM11.merged.r2.bam
# 7          445_01_SMNDC1.merged.r2.bam
# 8     447_01_RO60-TROVE2.merged.r2.bam
# 9           450_01_GPKOW.merged.r2.bam
# 10           451_01_ILF2.merged.r2.bam
# 11          452_01_NSUN2.merged.r2.bam
# 12           463_01_ETF1.merged.r2.bam
# 13            464_01_FTO.merged.r2.bam
# 14           465_01_UPF1.merged.r2.bam
# 15          407_01_SF3A3.merged.r2.bam
# 16        410_01_DNAJC17.merged.r2.bam
# 17         412_01_EIF4A2.merged.r2.bam
# 18            416_01_WRN.merged.r2.bam
# 19         417_01_POLR2G.merged.r2.bam
# 20          419_01_EIF2B.merged.r2.bam
# 21            466_01_QKI.merged.r2.bam
# 22          477_01_NCBP2.merged.r2.bam
# 23            478_01_QKI.merged.r2.bam
# 24          480_01_XRCC6.merged.r2.bam
# 25         481_01_DROSHA.merged.r2.bam
# 26         484_01_POLR2G.merged.r2.bam
# 27          485_01_EIF2B.merged.r2.bam
# 28         486_01_HNRNPR.merged.r2.bam
# 29          492_01_DDX3X.merged.r2.bam
# 30          494_01_RBM22.merged.r2.bam
# 31           495_01_PPIG.merged.r2.bam
# 32           496_01_AATF.merged.r2.bam
# 33          497_01_BUD13.merged.r2.bam
# 34           498_01_RDBP.merged.r2.bam
# 35         499_01_SRFBP1.merged.r2.bam
# 36          506_01_SF3B1.merged.r2.bam
# 37          508_01_BUD13.merged.r2.bam
# 38           511_01_AATF.merged.r2.bam
# 39           512_01_RDBP.merged.r2.bam
# 40          396_01_ADAR1.merged.r2.bam
# 41           397_01_KRR1.merged.r2.bam
# 42         403_01_HNRNPR.merged.r2.bam
# 43          383_01_DGCR8.merged.r2.bam
# Name: CLIP_rep1, dtype: object

# %%
"scp tscc-login1.sdsc.edu:/home/gpratt/projects/encode/analysis/encode_v9/{" + ",".join(foo.apply(os.path.basename).values) + "} ."
# Out:
# 'scp tscc-login1.sdsc.edu:/home/gpratt/projects/encode/analysis/encode_v9/{406_01_PABPC4.merged.r2.bam,415_01_TNRC6A.merged.r2.bam,429_01_SSRP1.merged.r2.bam,439_01_KHSRP.merged.r2.bam,440_01_EWSR1.merged.r2.bam,441_01_PUM2.merged.r2.bam,444_01_LSM11.merged.r2.bam,445_01_SMNDC1.merged.r2.bam,447_01_RO60-TROVE2.merged.r2.bam,450_01_GPKOW.merged.r2.bam,451_01_ILF2.merged.r2.bam,452_01_NSUN2.merged.r2.bam,463_01_ETF1.merged.r2.bam,464_01_FTO.merged.r2.bam,465_01_UPF1.merged.r2.bam,407_01_SF3A3.merged.r2.bam,410_01_DNAJC17.merged.r2.bam,412_01_EIF4A2.merged.r2.bam,416_01_WRN.merged.r2.bam
R1.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.r2.bam,450_INPUT_CGCTCATT-TATAGCCT_L004_R1.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.r2.bam,451_INPUT_GAGATTCC-TATAGCCT_L004_R1.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.r2.bam,452_INPUT_CGCTCATT-CCTATCCT_L005_R1.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.r2.bam,463_INPUT_GAGATTCC-CCTATCCT_L003_R1.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.r2.bam,464_INPUT_CGCTCATT-AGGCGAAG_L002_R1.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.r2.bam,465_INPUT_GAGATTCC-AGGCGAAG_L001_R1.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.r2.bam,407_INPUT_S5_L001_R1_001.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.r2.bam,410_INPUT_S30_L004_R1_001.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.r2.bam,412_INPUT_S24_L003_R1_001.unass ...

# %% [markdown]
# #Remaking data from stable qc numbers

# %%
master_df = pd.read_table("/home/gpratt/Dropbox/encode_integration/for_eric/master_qc_stable.csv", index_col=0)

# %%
public_df = master_df[(master_df.annotation != "ENCODE eCLIP") & \
                      (master_df.annotation != "ENCODE iCLIP Submitted")
                     #(master_df.annotation != "All iCLIP") \
                     ]

public_clip_df = master_df[master_df.annotation == "Public CLIP"]
public_iclip_df = master_df[master_df.annotation == "Public iCLIP"]
all_iclip_df = master_df[master_df.annotation == "All iCLIP"]

# %%
sup_table_1 = pd.read_excel("/home/gpratt/Dropbox/encode_integration/for_eric/SupTables/SupTable1.xlsx", "Sheet1", index_col=0)
sup_table_1_public_clip = sup_table_1[sup_table_1['experiment type (general)'] == 'Public CLIP'].copy()
sup_table_1_all_iclip = sup_table_1[sup_table_1['experiment type (general)'] == 'All iCLIP'].copy()

# %%
public_clip_df = sup_table_1_public_clip.join(public_clip_df)
public_iclip_df = sup_table_1.join(public_iclip_df)
all_iclip_df = sup_table_1.join(all_iclip_df)

# %%
set(sup_table_1['experiment type (general)'])
# Out:
# {u'All iCLIP', u'Public CLIP'}

# %%
print len(public_clip_df), len(public_clip_df.dropna())
print len(all_iclip_df), len(all_iclip_df.dropna())
# Out:
# 152 152
# 279 115

# %%
all_iclip_df['iclip_joiner'] = all_iclip_df.RBP + all_iclip_df['Cell type']
master_df['iclip_joiner'] = [item.split("_")[0] + item.split("_")[-1] for item in master_df.index]

# %%
master_df

# %%
pd.merge?

# %%
master_df
# Out:
#                       Input Reads  Uniquely Mapped Reads  Usable Reads  \
# AUH_246_01_K562          13631589                1365661        740559
# AUH_246_02_K562          13850133                1529778        500638
# AUH_280_01_HepG2         13553232                3558228       2664051
# AUH_280_02_HepG2         15493437                3354237       2520409
# BCCIP_230_01_HepG2        8944087                2838390       2470161
# BCCIP_230_02_HepG2        8996636                3203943       2791263
# CPSF6_258_01_K562        11832728                4614808       2815791
# CPSF6_258_02_K562        11492161                5243635       2281621
# CSTF2T_275_01_K562       10164425                6527270       5794921
# CSTF2T_275_02_K562       15979572                9974471       9117670
# CSTF2T_292_01_HepG2      21035526               12258000      10516980
# CSTF2T_292_02_HepG2      16710536               10768032      10122009
# DDX3X_350_01_            13967203                4239302       2874105
# DDX3X_350_02_            12378451                3541674       2687447
# DDX42_241_01_K562        10098646                2702041       1694999
# DDX42_241_02_K562        11506894                3723666       2021997
# DGCR8_341_01_K562         7234081                2509557       2172584
# DGCR8_341_02_K562         7799556                2956873       2275232
# 10   ENCODE - ENCSR193PVE  IGF2BP2                               K562   human
# 11   ENCODE - ENCSR193PVE  IGF2BP2                               K562   human
# 12   ENCODE - ENCSR096IJV  IGF2BP3                               K562   human
# 13   ENCODE - ENCSR096IJV  IGF2BP3                               K562   human
# 14   ENCODE - ENCSR441YTO    TIAL1                               K562   human
# 15   ENCODE - ENCSR441YTO    TIAL1                               K562   human
# 16               22436691    SRSF3  embryonic carcinoma cells           mouse
# 17               22436691    SRSF3  embryonic carcinoma cells           mouse
# 18               22436691    SRSF3  embryonic carcinoma cells           mouse
# 19               22436691    SRSF4  embryonic carcinoma cells           mouse
# 20               22436691    SRSF4  embryonic carcinoma cells           mouse
# 21               22436691    SRSF4  embryonic carcinoma cells           mouse
# 22               21358640   TDP-43                              brain   human
# 23               21358640   TDP-43                              brain   human
# 24               21358640   TDP-43                              brain   human
# 25               21358640   TDP-43                              brain   human
# 26               21358640   TDP-43                              brain   human
# 27               21358640   TDP-43                              brain   human
# 28               22934129   TDP-43                              brain   mouse
# 29               22934129   TDP-43                              brain   mouse
# ..                    ...      ...                                ...     ...
# 808                   NaN      NaN                                NaN     NaN
# 809                   NaN      NaN                                NaN     NaN
# 810                   NaN      NaN                                NaN     NaN
# 811                   NaN      NaN                                NaN     NaN
# 812                   NaN      NaN                                NaN     NaN
# 813                   NaN      NaN                                NaN     NaN
# 814                   NaN      NaN                                NaN     NaN
# 815                   NaN      NaN                                NaN     NaN
# 816                   NaN      NaN                                NaN     NaN
# 817                   NaN      NaN                                NaN     NaN
# 818                   NaN      NaN                                NaN     NaN
# 819                   NaN      NaN                                NaN     NaN
# 820                   NaN      NaN                                NaN     NaN
# 821                   NaN      NaN                                NaN     NaN
# 822                   NaN      NaN                                NaN     NaN
# 823                   NaN      NaN                                NaN     NaN
# 824                   NaN      NaN                                NaN     NaN
# 825                   NaN      NaN                                NaN     NaN
# 826                   NaN      NaN                                NaN     NaN
# 827                   NaN      NaN                                NaN     NaN
# 828                   NaN      NaN                                NaN     NaN
# 829                   NaN      NaN                                NaN     NaN
# 830                   NaN      NaN                                NaN     NaN
# 831                   NaN      NaN                                NaN     NaN
# 832                   NaN      NaN                                NaN     NaN
# 833                   NaN      NaN                                NaN     NaN
# 834                   NaN      NaN                                NaN     NaN
# 835                   NaN      NaN                                NaN     NaN
# 836                   NaN      NaN                                NaN     NaN
# 837                   NaN      NaN                                NaN     NaN
#
#     experiment type (specific) experiment type (general)  Input Readsfoo  \
# 0                        iclip                 All iCLIP             NaN
# 1                        iclip                 All iCLIP             NaN
# 2                        iclip                 All iCLIP             NaN
# 3                        iclip                 All iCLIP             NaN
# 4                        iclip                 All iCLIP             NaN
# 5                        iclip                 All iCLIP             NaN
# 6                        iclip                 All iCLIP             NaN
# 7                        iclip                 All iCLIP             NaN
# 8                        iclip                 All iCLIP             NaN
# 9                        iclip                 All iCLIP             NaN
# 10                       iclip                 All iCLIP             NaN
# 11                       iclip                 All iCLIP             NaN
# 12                       iclip                 All iCLIP             NaN
# 13                       iclip                 All iCLIP             NaN
# 14                       iclip                 All iCLIP             NaN
# 15                       iclip                 All iCLIP             NaN
# 16                       iclip                 All iCLIP         1161916
# 17                       iclip                 All iCLIP         8238622
# 18                       iclip                 All iCLIP         1094384
# 19                       iclip                 All iCLIP          823710
# 20                       iclip                 All iCLIP         4868365
# 21                       iclip                 All iCLIP         2499333
# 22                       iclip                 All iCLIP         3488095
# 23                       iclip                 All iCLIP         2325826
# 24                       iclip                 All iCLIP         2477544
# 25                       iclip                 All iCLIP         1622407
# 26                       iclip                 All iCLIP         1776239
# 27                       iclip                 All iCLIP         1167148
# 28                       iclip                 All iCLIP          417767
# 29                       iclip                 All iCLIP          789392
# ..                         ...                       ...             ...
# 808                        NaN                       NaN             NaN
# 809                        NaN                       NaN             NaN
# 810                        NaN                       NaN             NaN
# 811                        NaN                       NaN             NaN
# 812                        NaN                       NaN             NaN
# 813                        NaN                       NaN             NaN
# 814                        NaN                       NaN             NaN
# 815                        NaN                       NaN             NaN
# 816                        NaN                       NaN             NaN
# 817                        NaN                       NaN             NaN
# 818                        NaN                       NaN             NaN
# 819                        NaN                       NaN             NaN
# 820                        NaN                       NaN             NaN
# 821                        NaN                       NaN             NaN
# 822                        NaN                       NaN             NaN
# 823                        NaN                       NaN             NaN
# 824                        NaN                       NaN             NaN
# 825                        NaN                       NaN             NaN
# 826                        NaN                       NaN             NaN
# 827                        NaN                       NaN             NaN
# 828                        NaN                       NaN             NaN
# 829                        NaN                       NaN             NaN
# 830                        NaN                       NaN             NaN
# 831                        NaN                       NaN             NaN
# 832                        NaN                       NaN             NaN
# 833                        NaN                       NaN             NaN
# 834                        NaN                       NaN             NaN
# 835                        NaN                       NaN             NaN
# 836                        NaN                       NaN             NaN
# 837                        NaN                       NaN             NaN
#
#      Uniquely Mapped Readsfoo  Usable Readsfoo  Fraction Collapsedfoo  \
# 0                         NaN              NaN                    NaN
# 1                         NaN              NaN                    NaN
# 2                         NaN              NaN                    NaN
# 3                         NaN              NaN                    NaN
# 4                         NaN              NaN                    NaN
# 5                         NaN              NaN                    NaN
# 6                         NaN              NaN                    NaN
# 7                         NaN              NaN                    NaN
# 8                         NaN              NaN                    NaN
# 9                         NaN              NaN                    NaN
# 10                        NaN              NaN                    NaN
# 11                        NaN              NaN                    NaN
# 12                        NaN              NaN                    NaN
# 13                        NaN              NaN                    NaN
# 14                        NaN              NaN                    NaN
# 15                        NaN              NaN                    NaN
# 16                     848002           401071               0.472960
# 17                    4540004           899570               0.198143
# 18                     716667            86915               0.121277
# 19                     359604           128309               0.356806
# 20                    2327262            93997               0.040390
# 21                    1375631           710750               0.516672
# 22                    2216207            45500               0.020531
# 23                     994563           112531               0.113146
# 24                     526575            67476               0.128141
# 25                     669293            98100               0.146573
# 26                     354303            89651               0.253035
# 27                     449751           126378               0.280995
# 28                     211908            25948               0.122449
# 29                     485834           203074               0.417991
# ..                        ...              ...                    ...
# 808                       NaN              NaN                    NaN
# 809                       NaN              NaN                    NaN
# 810                       NaN              NaN                    NaN
# 811                       NaN              NaN                    NaN
# 812                       NaN              NaN                    NaN
# 813                       NaN              NaN                    NaN
# 814                       NaN              NaN                    NaN
# 815                       NaN              NaN                    NaN
# 816                       NaN              NaN                    NaN
# 817                       NaN              NaN                    NaN
# 818                       NaN              NaN                    NaN
# 819                       NaN              NaN                    NaN
# 820                       NaN              NaN                    NaN
# 821                       NaN              NaN                    NaN
# 822                       NaN              NaN                    NaN
# 823                       NaN              NaN                    NaN
# 824                       NaN              NaN                    NaN
# 825                       NaN              NaN                    NaN
# 826                       NaN              NaN                    NaN
# 827                       NaN              NaN                    NaN
# 828                       NaN              NaN                    NaN
# 829                       NaN              NaN                    NaN
# 830                       NaN              NaN                    NaN
# 831                       NaN              NaN                    NaN
# 832                       NaN              NaN                    NaN
# 833                       NaN              NaN                    NaN
# 834                       NaN              NaN                    NaN
# 835                       NaN              NaN                    NaN
# 836                       NaN              NaN                    NaN
# 837                       NaN              NaN                    NaN
#
#      Fraction Usablefoo annotationfoo                            iclip_joiner  \
# 0                   NaN           NaN                              EIF4G1K562
# 1                   NaN           NaN                              EIF4G1K562
# 2                   NaN           NaN                                 FUSK562
# 3                   NaN           NaN                                 FUSK562
# 4                   NaN           NaN                             IGF2BP1K562
# 5                   NaN           NaN                             IGF2BP1K562
# 6                   NaN           NaN                             IGF2BP1K562
# 7                   NaN           NaN                             IGF2BP1K562
# 8                   NaN           NaN                             IGF2BP2K562
# 9                   NaN           NaN                             IGF2BP2K562
# 10                  NaN           NaN                             IGF2BP2K562
# 11                  NaN           NaN                             IGF2BP2K562
# 12                  NaN           NaN                             IGF2BP3K562
# 13                  NaN           NaN                             IGF2BP3K562
# 14                  NaN           NaN                               TIAL1K562
# 15                  NaN           NaN                               TIAL1K562
# 16             0.345181     All iCLIP  SRSF3embryonic carcinoma cells
# 17             0.109189     All iCLIP  SRSF3embryonic carcinoma cells
# 18             0.079419     All iCLIP  SRSF3embryonic carcinoma cells
# 19             0.155770     All iCLIP  SRSF4embryonic carcinoma cells
# 20             0.019308     All iCLIP  SRSF4embryonic carcinoma cells
# 21             0.284376     All iCLIP  SRSF4embryonic carcinoma cells
# 22             0.013044     All iCLIP                             TDP-43brain
# 23             0.048383     All iCLIP                             TDP-43brain
# 24             0.027235     All iCLIP                             TDP-43brain
# 25             0.060466     All iCLIP                             TDP-43brain
# 26             0.050472     All iCLIP                             TDP-43brain
# 27             0.108279     All iCLIP                             TDP-43brain
# 28             0.062111     All iCLIP                             TDP-43brain
# 29             0.257254     All iCLIP                             TDP-43brain
# ..                  ...           ...                                     ...
# 808                 NaN           NaN                      SRR488730SRR488730
# 809                 NaN           NaN                      SRR488731SRR488731
# 810                 NaN           NaN                      SRR488732SRR488732
# 811                 NaN           NaN                      SRR488733SRR488733
# 812                 NaN           NaN                      SRR488734SRR488734
# 813                 NaN           NaN                      SRR488735SRR488735
# 814                 NaN           NaN                      SRR488736SRR488736
# 815                 NaN           NaN                      SRR488738SRR488738
# 816                 NaN           NaN                      SRR488739SRR488739
# 817                 NaN           NaN                      SRR488740SRR488740
# 818                 NaN           NaN                      SRR488741SRR488741
# 819                 NaN           NaN                      SRR488742SRR488742
# 820                 NaN           NaN                      SRR644276SRR644276
# 821                 NaN           NaN                      SRR644275SRR644275
# 822                 NaN           NaN                      SRR644274SRR644274
# 823                 NaN           NaN                      SRR500481SRR500481
# 824                 NaN           NaN                      SRR500484SRR500484
# 825                 NaN           NaN                      SRR500485SRR500485
# 826                 NaN           NaN                      SRR500487SRR500487
# 827                 NaN           NaN                    SRR1260866SRR1260866
# 828                 NaN           NaN                    SRR1260867SRR1260867
# 829                 NaN           NaN                    SRR1260868SRR1260868
# 830                 NaN           NaN                      SRR070465SRR070465
# 831                 NaN           NaN                      SRR070464SRR070464
# 832                 NaN           NaN                      SRR070463SRR070463
# 833                 NaN           NaN                      SRR070462SRR070462
# 834                 NaN           NaN                      SRR070461SRR070461
# 835                 NaN           NaN                      SRR070449SRR070449
# 836                 NaN           NaN                      SRR070450SRR070450
# 837                 NaN           NaN                      SRR070448SRR070448
#
#      Input Readsbar  Uniquely Mapped Readsbar  Usable Readsbar  \
# 0               NaN                       NaN              NaN
# 1               NaN                       NaN              NaN
# 2               NaN                       NaN              NaN
# 3               NaN                       NaN              NaN
# 4           7662468                   4035598          3516187
# 5           6021641                   3246938          2438405
# 6           7662468                   4035598          3516187
# 7           6021641                   3246938          2438405
# 8           8517959                   3022279          2703705
# 9          10323092                   4055435          3604136
# 10          8517959                   3022279          2703705
# 11         10323092                   4055435          3604136
# 12              NaN                       NaN              NaN
# 13              NaN                       NaN              NaN
# 14              NaN                       NaN              NaN
# 15              NaN                       NaN              NaN
# 16              NaN                       NaN              NaN
# 17              NaN                       NaN              NaN
# 18              NaN                       NaN              NaN
# 19              NaN                       NaN              NaN
# 20              NaN                       NaN              NaN
# 21              NaN                       NaN              NaN
# 22              NaN                       NaN              NaN
# 23              NaN                       NaN              NaN
# 24              NaN                       NaN              NaN
# 25              NaN                       NaN              NaN
# 26              NaN                       NaN              NaN
# 27              NaN                       NaN              NaN
# 28              NaN                       NaN              NaN
# 29              NaN                       NaN              NaN
# ..              ...                       ...              ...
# 808        42497923                   2007881           194201
# 809        46414085                   1592395           203248
# 810        55135781                   5364997           207485
# 811        52673353                   1143604           156014
# 812        17120422                    821085            48382
# 813        46980056                   2522293            78646
# 814        35211644                  13532871          5009715
# 815        18522392                   8285360           743429
# 816        35402759                   5779135          1753173
# 817        21240858                   9113271          3747035
# 818        53263321                  18998215          8166542
# 819        56526371                   1588755           896674
# 820         6775718                    496449            45618
# 821        20006057                    585551           128047
# 822        16842608                    960835            83492
# 823        23136694                   2068575           219547
# 824        30168603                   4961794           172299
# 825        25130460                   5450466          1180868
# 826        20860453                    151044           115451
# 827        56689580                   8236003           236427
# 828        35023644                   5030296           194672
# 829        54422063                   8336350           430426
# 830        11022216                    212803            93028
# 831        13325493                    381593           172959
# 832         9814413                    676926           280902
# 833        14396183                    515407           194343
# 834        11568502                    445865           105059
# 835         8537179                    555447           434567
# 836         3463758                    338297           262636
# 837         9922520                    614847            96738
#
#      Fraction Collapsedbar  Fraction Usablebar annotationbar
# 0                      NaN                 NaN           NaN
# 1                      NaN                 NaN           NaN
# 2                      NaN                 NaN           NaN
# 3                      NaN                 NaN           NaN
# 4                 0.871293            0.458884  ENCODE eCLIP
# 5                 0.750986            0.404940  ENCODE eCLIP
# 6                 0.871293            0.458884  ENCODE eCLIP
# 7                 0.750986            0.404940  ENCODE eCLIP
# 8                 0.894591            0.317412  ENCODE eCLIP
# 9                 0.888717            0.349133  ENCODE eCLIP
# 10                0.894591            0.317412  ENCODE eCLIP
# 11                0.888717            0.349133  ENCODE eCLIP
# 12                     NaN                 NaN           NaN
# 13                     NaN                 NaN           NaN
# 14                     NaN                 NaN           NaN
# 15                     NaN                 NaN           NaN
# 16                     NaN                 NaN           NaN
# 17                     NaN                 NaN           NaN
# 18                     NaN                 NaN           NaN
# 19                     NaN                 NaN           NaN
# 20                     NaN                 NaN           NaN
# 21                     NaN                 NaN           NaN
# 22                     NaN                 NaN           NaN
# 23                     NaN                 NaN           NaN
# 24                     NaN                 NaN           NaN
# 25                     NaN                 NaN           NaN
# 26                     NaN                 NaN           NaN
# 27                     NaN                 NaN           NaN
# 28                     NaN                 NaN           NaN
# 29                     NaN                 NaN           NaN
# ..                     ...                 ...           ...
# 808               0.096719            0.004570   Public CLIP
# 809               0.127637            0.004379   Public CLIP
# 810               0.038674            0.003763   Public CLIP
# 811               0.136423            0.002962   Public CLIP
# 812               0.058924            0.002826   Public CLIP
# 813               0.031180            0.001674   Public CLIP
# 814               0.370189            0.142274   Public CLIP
# 815               0.089728            0.040137   Public CLIP
# 816               0.303363            0.049521   Public CLIP
# 817               0.411162            0.176407   Public CLIP
# 818               0.429858            0.153324   Public CLIP
# 819               0.564388            0.015863   Public CLIP
# 820               0.091889            0.006733   Public CLIP
# 821               0.218678            0.006400   Public CLIP
# 822               0.086895            0.004957   Public CLIP
# 823               0.106134            0.009489   Public CLIP
# 824               0.034725            0.005711   Public CLIP
# 825               0.216655            0.046990   Public CLIP
# 826               0.764353            0.005534   Public CLIP
# 827               0.028707            0.004171   Public CLIP
# 828               0.038700            0.005558   Public CLIP
# 829               0.051632            0.007909   Public CLIP
# 830               0.437155            0.008440   Public CLIP
# 831               0.453255            0.012980   Public CLIP
# 832               0.414967            0.028621   Public CLIP
# 833               0.377067            0.013500   Public CLIP
# 834               0.235630            0.009081   Public CLIP
# 835               0.782373            0.050903   Public CLIP
# 836               0.776347            0.075824   Public CLIP
# 837               0.157337            0.009749   Public CLIP
#
# [838 rows x 19 columns]

# %%
all_iclip_df.join(master_df, on="iclip_joiner", lsuffix="foo", rsuffix="bar", how="outer")
# Out:
#                                           iclip_joiner             Pubmed ID  \
# #Experiment ID
# ENCLB198MDG                                 EIF4G1K562  ENCODE - ENCSR961WWI
# ENCLB321IJI                                 EIF4G1K562  ENCODE - ENCSR961WWI
# ENCLB376GNW                                    FUSK562  ENCODE - ENCSR477TRN
# ENCLB725AHE                                    FUSK562  ENCODE - ENCSR477TRN
# ENCLB228RNI                                IGF2BP1K562  ENCODE - ENCSR427DED
# ENCLB741WVB                                IGF2BP1K562  ENCODE - ENCSR427DED
# ENCLB014OFT                                IGF2BP2K562  ENCODE - ENCSR193PVE
# ENCLB077IHV                                IGF2BP2K562  ENCODE - ENCSR193PVE
# ENCLB576NYG                                IGF2BP3K562  ENCODE - ENCSR096IJV
# ENCLB912JMG                                IGF2BP3K562  ENCODE - ENCSR096IJV
# ENCLB503ACY                                  TIAL1K562  ENCODE - ENCSR441YTO
# ENCLB700YSR                                  TIAL1K562  ENCODE - ENCSR441YTO
# ERR039836       SRSF3embryonic carcinoma cells                      22436691
# ERR039837       SRSF3embryonic carcinoma cells                      22436691
# ERR039838       SRSF3embryonic carcinoma cells                      22436691
# ERR039839       SRSF4embryonic carcinoma cells                      22436691
# ERR039840       SRSF4embryonic carcinoma cells                      22436691
# ERR039841       SRSF4embryonic carcinoma cells                      22436691
# ERR039842                                  TDP-43brain              21358640
# ERR039843                                  TDP-43brain              21358640
# ERR039844                                  TDP-43brain              21358640
# ERR039845                                  TDP-43brain              21358640
# ERR039846                                  TDP-43brain              21358640
# ERR039848                                  TDP-43brain              21358640
# ERR208895                                  TDP-43brain              22934129
# ERR208896                                  TDP-43brain              22934129
# ERR208900                                  TDP-43brain              22934129
# ERR039849                                   TDP-43hESC              21358640
# ERR039850                                TDP-43SH-SY5Y              21358640
# ERR039851                                TDP-43SH-SY5Y              21358640
# ...                                                ...                   ...
# SRR850552                                    SRR488730                   NaN
# SRR850552                                    SRR488731                   NaN
# SRR850552                                    SRR488732                   NaN
# SRR850552                                    SRR488733                   NaN
# SRR850552                                    SRR488734                   NaN
# SRR850552                                    SRR488735                   NaN
# SRR850552                                    SRR488736                   NaN
# SRR850552                                    SRR488738                   NaN
# SRR850552                                    SRR488739                   NaN
# SRR850552                                    SRR488740                   NaN
# SRR850552                                    SRR488741                   NaN
# SRR850552                                    SRR488742                   NaN
# SRR850552                                    SRR644276                   NaN
# SRR850552                                    SRR644275                   NaN
# SRR850552                                    SRR644274                   NaN
# SRR850552                                    SRR500481                   NaN
# SRR850552                                    SRR500484                   NaN
# SRR850552                                    SRR500485                   NaN
# SRR850552                                    SRR500487                   NaN
# SRR850552                                   SRR1260866                   NaN
# SRR850552                                   SRR1260867                   NaN
# SRR850552                                   SRR1260868                   NaN
# SRR850552                                    SRR070465                   NaN
# SRR850552                                    SRR070464                   NaN
# SRR850552                                    SRR070463                   NaN
# SRR850552                                    SRR070462                   NaN
# SRR850552                                    SRR070461                   NaN
# SRR850552                                    SRR070449                   NaN
# SRR850552                                    SRR070450                   NaN
# SRR850552                                    SRR070448                   NaN
#
#                     RBP                          Cell type Species  \
# #Experiment ID
# ENCLB198MDG      EIF4G1                               K562   human
# ENCLB321IJI      EIF4G1                               K562   human
# ENCLB376GNW         FUS                               K562   human
# ENCLB725AHE         FUS                               K562   human
# ENCLB228RNI     IGF2BP1                               K562   human
# ENCLB741WVB     IGF2BP1                               K562   human
# ENCLB014OFT     IGF2BP2                               K562   human
# ENCLB077IHV     IGF2BP2                               K562   human
# ENCLB576NYG     IGF2BP3                               K562   human
# ENCLB912JMG     IGF2BP3                               K562   human
# ENCLB503ACY       TIAL1                               K562   human
# ENCLB700YSR       TIAL1                               K562   human
# ERR039836         SRSF3  embryonic carcinoma cells           mouse
# ERR039837         SRSF3  embryonic carcinoma cells           mouse
# ERR039838         SRSF3  embryonic carcinoma cells           mouse
# ERR039839         SRSF4  embryonic carcinoma cells           mouse
# ERR039840         SRSF4  embryonic carcinoma cells           mouse
# ERR039841         SRSF4  embryonic carcinoma cells           mouse
# ERR039842        TDP-43                              brain   human
# ERR039843        TDP-43                              brain   human
# ERR039844        TDP-43                              brain   human
# ERR039845        TDP-43                              brain   human
# ERR039846        TDP-43                              brain   human
# ERR039848        TDP-43                              brain   human
# ERR208895        TDP-43                              brain   mouse
# ERR208896        TDP-43                              brain   mouse
# ERR208900        TDP-43                              brain   mouse
# ERR039849        TDP-43                               hESC   human
# ERR039850        TDP-43                            SH-SY5Y   human
# ERR039851        TDP-43                            SH-SY5Y   human
# ...                 ...                                ...     ...
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
# SRR850552           NaN                                NaN     NaN
#
#                experiment type (specific) experiment type (general)  \
# #Experiment ID
# ENCLB198MDG                         iclip                 All iCLIP
# ENCLB321IJI                         iclip                 All iCLIP
# ENCLB376GNW                         iclip                 All iCLIP
# ENCLB725AHE                         iclip                 All iCLIP
# ENCLB228RNI                         iclip                 All iCLIP
# ENCLB741WVB                         iclip                 All iCLIP
# ENCLB014OFT                         iclip                 All iCLIP
# ENCLB077IHV                         iclip                 All iCLIP
# ENCLB576NYG                         iclip                 All iCLIP
# ENCLB912JMG                         iclip                 All iCLIP
# ENCLB503ACY                         iclip                 All iCLIP
# ENCLB700YSR                         iclip                 All iCLIP
# ERR039836                           iclip                 All iCLIP
# ERR039837                           iclip                 All iCLIP
# ERR039838                           iclip                 All iCLIP
# ERR039839                           iclip                 All iCLIP
# ERR039840                           iclip                 All iCLIP
# ERR039841                           iclip                 All iCLIP
# ERR039842                           iclip                 All iCLIP
# ERR039843                           iclip                 All iCLIP
# ERR039844                           iclip                 All iCLIP
# ERR039845                           iclip                 All iCLIP
# ERR039846                           iclip                 All iCLIP
# ERR039848                           iclip                 All iCLIP
# ERR208895                           iclip                 All iCLIP
# ERR208896                           iclip                 All iCLIP
# ERR208900                           iclip                 All iCLIP
# ERR039849                           iclip                 All iCLIP
# ERR039850                           iclip                 All iCLIP
# ERR039851                           iclip                 All iCLIP
# ...                                   ...                       ...
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
# SRR850552                             NaN                       NaN
#
#                 Input Readsfoo  Uniquely Mapped Readsfoo  Usable Readsfoo  \
# #Experiment ID
# ENCLB198MDG                NaN                       NaN              NaN
# ENCLB321IJI                NaN                       NaN              NaN
# ENCLB376GNW                NaN                       NaN              NaN
# ENCLB725AHE                NaN                       NaN              NaN
# ENCLB228RNI                NaN                       NaN              NaN
# ENCLB741WVB                NaN                       NaN              NaN
# ENCLB014OFT                NaN                       NaN              NaN
# ENCLB077IHV                NaN                       NaN              NaN
# ENCLB576NYG                NaN                       NaN              NaN
# ENCLB912JMG                NaN                       NaN              NaN
# ENCLB503ACY                NaN                       NaN              NaN
# ENCLB700YSR                NaN                       NaN              NaN
# ERR039836              1161916                    848002           401071
# ERR039837              8238622                   4540004           899570
# ERR039838              1094384                    716667            86915
# ERR039839               823710                    359604           128309
# ERR039840              4868365                   2327262            93997
# ERR039841              2499333                   1375631           710750
# ERR039842              3488095                   2216207            45500
# ERR039843              2325826                    994563           112531
# ERR039844              2477544                    526575            67476
# ERR039845              1622407                    669293            98100
# ERR039846              1776239                    354303            89651
# ERR039848              1167148                    449751           126378
# ERR208895               417767                    211908            25948
# ERR208896               789392                    485834           203074
# ERR208900              8234348                   6759549          2626526
# ERR039849              9517777                   7175120          2727338
# ERR039850              1169230                    438397            24810
# ERR039851              1134514                    543378            24366
# ...                        ...                       ...              ...
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
# SRR850552                  NaN                       NaN              NaN
#
#                         ...           Fraction Usablefoo  annotationfoo  \
# #Experiment ID          ...
# ENCLB198MDG             ...                          NaN            NaN
# ENCLB321IJI             ...                          NaN            NaN
# ENCLB376GNW             ...                          NaN            NaN
# ENCLB725AHE             ...                          NaN            NaN
# ENCLB228RNI             ...                          NaN            NaN
# ENCLB741WVB             ...                          NaN            NaN
# ENCLB014OFT             ...                          NaN            NaN
# ENCLB077IHV             ...                          NaN            NaN
# ENCLB576NYG             ...                          NaN            NaN
# ENCLB912JMG             ...                          NaN            NaN
# ENCLB503ACY             ...                          NaN            NaN
# ENCLB700YSR             ...                          NaN            NaN
# ERR039836               ...                     0.345181      All iCLIP
# ERR039837               ...                     0.109189      All iCLIP
# ERR039838               ...                     0.079419      All iCLIP
# ERR039839               ...                     0.155770      All iCLIP
# ERR039840               ...                     0.019308      All iCLIP
# ERR039841               ...                     0.284376      All iCLIP
# ERR039842               ...                     0.013044      All iCLIP
# ERR039843               ...                     0.048383      All iCLIP
# ERR039844               ...                     0.027235      All iCLIP
# ERR039845               ...                     0.060466      All iCLIP
# ERR039846               ...                     0.050472      All iCLIP
# ERR039848               ...                     0.108279      All iCLIP
# ERR208895               ...                     0.062111      All iCLIP
# ERR208896               ...                     0.257254      All iCLIP
# ERR208900               ...                     0.318972      All iCLIP
# ERR039849               ...                     0.286552      All iCLIP
# ERR039850               ...                     0.021219      All iCLIP
# ERR039851               ...                     0.021477      All iCLIP
# ...                     ...                          ...            ...
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
# SRR850552               ...                          NaN            NaN
#
#                                        iclip_joinerfoo Input Readsbar  \
# #Experiment ID
# ENCLB198MDG                                 EIF4G1K562            NaN
# ENCLB321IJI                                 EIF4G1K562            NaN
# ENCLB376GNW                                    FUSK562            NaN
# ENCLB725AHE                                    FUSK562            NaN
# ENCLB228RNI                                IGF2BP1K562            NaN
# ENCLB741WVB                                IGF2BP1K562            NaN
# ENCLB014OFT                                IGF2BP2K562            NaN
# ENCLB077IHV                                IGF2BP2K562            NaN
# ENCLB576NYG                                IGF2BP3K562            NaN
# ENCLB912JMG                                IGF2BP3K562            NaN
# ENCLB503ACY                                  TIAL1K562            NaN
# ENCLB700YSR                                  TIAL1K562            NaN
# ERR039836       SRSF3embryonic carcinoma cells                    NaN
# ERR039837       SRSF3embryonic carcinoma cells                    NaN
# ERR039838       SRSF3embryonic carcinoma cells                    NaN
# ERR039839       SRSF4embryonic carcinoma cells                    NaN
# ERR039840       SRSF4embryonic carcinoma cells                    NaN
# ERR039841       SRSF4embryonic carcinoma cells                    NaN
# ERR039842                                  TDP-43brain            NaN
# ERR039843                                  TDP-43brain            NaN
# ERR039844                                  TDP-43brain            NaN
# ERR039845                                  TDP-43brain            NaN
# ERR039846                                  TDP-43brain            NaN
# ERR039848                                  TDP-43brain            NaN
# ERR208895                                  TDP-43brain            NaN
# ERR208896                                  TDP-43brain            NaN
# ERR208900                                  TDP-43brain            NaN
# ERR039849                                   TDP-43hESC            NaN
# ERR039850                                TDP-43SH-SY5Y            NaN
# ERR039851                                TDP-43SH-SY5Y            NaN
# ...                                                ...            ...
# SRR850552                                          NaN       42497923
# SRR850552                                          NaN       46414085
# SRR850552                                          NaN       55135781
# SRR850552                                          NaN       52673353
# SRR850552                                          NaN       17120422
# SRR850552                                          NaN       46980056
# SRR850552                                          NaN       35211644
# SRR850552                                          NaN       18522392
# SRR850552                                          NaN       35402759
# SRR850552                                          NaN       21240858
# SRR850552                                          NaN       53263321
# SRR850552                                          NaN       56526371
# SRR850552                                          NaN        6775718
# SRR850552                                          NaN       20006057
# SRR850552                                          NaN       16842608
# SRR850552                                          NaN       23136694
# SRR850552                                          NaN       30168603
# SRR850552                                          NaN       25130460
# SRR850552                                          NaN       20860453
# SRR850552                                          NaN       56689580
# SRR850552                                          NaN       35023644
# SRR850552                                          NaN       54422063
# SRR850552                                          NaN       11022216
# SRR850552                                          NaN       13325493
# SRR850552                                          NaN        9814413
# SRR850552                                          NaN       14396183
# SRR850552                                          NaN       11568502
# SRR850552                                          NaN        8537179
# SRR850552                                          NaN        3463758
# SRR850552                                          NaN        9922520
#
#                 Uniquely Mapped Readsbar  Usable Readsbar  \
# #Experiment ID
# ENCLB198MDG                          NaN              NaN
# ENCLB321IJI                          NaN              NaN
# ENCLB376GNW                          NaN              NaN
# ENCLB725AHE                          NaN              NaN
# ENCLB228RNI                          NaN              NaN
# ENCLB741WVB                          NaN              NaN
# ENCLB014OFT                          NaN              NaN
# ENCLB077IHV                          NaN              NaN
# ENCLB576NYG                          NaN              NaN
# ENCLB912JMG                          NaN              NaN
# ENCLB503ACY                          NaN              NaN
# ENCLB700YSR                          NaN              NaN
# ERR039836                            NaN              NaN
# ERR039837                            NaN              NaN
# ERR039838                            NaN              NaN
# ERR039839                            NaN              NaN
# ERR039840                            NaN              NaN
# ERR039841                            NaN              NaN
# ERR039842                            NaN              NaN
# ERR039843                            NaN              NaN
# ERR039844                            NaN              NaN
# ERR039845                            NaN              NaN
# ERR039846                            NaN              NaN
# ERR039848                            NaN              NaN
# ERR208895                            NaN              NaN
# ERR208896                            NaN              NaN
# ERR208900                            NaN              NaN
# ERR039849                            NaN              NaN
# ERR039850                            NaN              NaN
# ERR039851                            NaN              NaN
# ...                                  ...              ...
# SRR850552                        2007881           194201
# SRR850552                        1592395           203248
# SRR850552                        5364997           207485
# SRR850552                        1143604           156014
# SRR850552                         821085            48382
# SRR850552                        2522293            78646
# SRR850552                       13532871          5009715
# SRR850552                        8285360           743429
# SRR850552                        5779135          1753173
# SRR850552                        9113271          3747035
# SRR850552                       18998215          8166542
# SRR850552                        1588755           896674
# SRR850552                         496449            45618
# SRR850552                         585551           128047
# SRR850552                         960835            83492
# SRR850552                        2068575           219547
# SRR850552                        4961794           172299
# SRR850552                        5450466          1180868
# SRR850552                         151044           115451
# SRR850552                        8236003           236427
# SRR850552                        5030296           194672
# SRR850552                        8336350           430426
# SRR850552                         212803            93028
# SRR850552                         381593           172959
# SRR850552                         676926           280902
# SRR850552                         515407           194343
# SRR850552                         445865           105059
# SRR850552                         555447           434567
# SRR850552                         338297           262636
# SRR850552                         614847            96738
#
#                 Fraction Collapsedbar  Fraction Usablebar  annotationbar  \
# #Experiment ID
# ENCLB198MDG                       NaN                 NaN            NaN
# ENCLB321IJI                       NaN                 NaN            NaN
# ENCLB376GNW                       NaN                 NaN            NaN
# ENCLB725AHE                       NaN                 NaN            NaN
# ENCLB228RNI                       NaN                 NaN            NaN
# ENCLB741WVB                       NaN                 NaN            NaN
# ENCLB014OFT                       NaN                 NaN            NaN
# ENCLB077IHV                       NaN                 NaN            NaN
# ENCLB576NYG                       NaN                 NaN            NaN
# ENCLB912JMG                       NaN                 NaN            NaN
# ENCLB503ACY                       NaN                 NaN            NaN
# ENCLB700YSR                       NaN                 NaN            NaN
# ERR039836                         NaN                 NaN            NaN
# ERR039837                         NaN                 NaN            NaN
# ERR039838                         NaN                 NaN            NaN
# ERR039839                         NaN                 NaN            NaN
# ERR039840                         NaN                 NaN            NaN
# ERR039841                         NaN                 NaN            NaN
# ERR039842                         NaN                 NaN            NaN
# ERR039843                         NaN                 NaN            NaN
# ERR039844                         NaN                 NaN            NaN
# ERR039845                         NaN                 NaN            NaN
# ERR039846                         NaN                 NaN            NaN
# ERR039848                         NaN                 NaN            NaN
# ERR208895                         NaN                 NaN            NaN
# ERR208896                         NaN                 NaN            NaN
# ERR208900                         NaN                 NaN            NaN
# ERR039849                         NaN                 NaN            NaN
# ERR039850                         NaN                 NaN            NaN
# ERR039851                         NaN                 NaN            NaN
# ...                               ...                 ...            ...
# SRR850552                    0.096719            0.004570    Public CLIP
# SRR850552                    0.127637            0.004379    Public CLIP
# SRR850552                    0.038674            0.003763    Public CLIP
# SRR850552                    0.136423            0.002962    Public CLIP
# SRR850552                    0.058924            0.002826    Public CLIP
# SRR850552                    0.031180            0.001674    Public CLIP
# SRR850552                    0.370189            0.142274    Public CLIP
# SRR850552                    0.089728            0.040137    Public CLIP
# SRR850552                    0.303363            0.049521    Public CLIP
# SRR850552                    0.411162            0.176407    Public CLIP
# SRR850552                    0.429858            0.153324    Public CLIP
# SRR850552                    0.564388            0.015863    Public CLIP
# SRR850552                    0.091889            0.006733    Public CLIP
# SRR850552                    0.218678            0.006400    Public CLIP
# SRR850552                    0.086895            0.004957    Public CLIP
# SRR850552                    0.106134            0.009489    Public CLIP
# SRR850552                    0.034725            0.005711    Public CLIP
# SRR850552                    0.216655            0.046990    Public CLIP
# SRR850552                    0.764353            0.005534    Public CLIP
# SRR850552                    0.028707            0.004171    Public CLIP
# SRR850552                    0.038700            0.005558    Public CLIP
# SRR850552                    0.051632            0.007909    Public CLIP
# SRR850552                    0.437155            0.008440    Public CLIP
# SRR850552                    0.453255            0.012980    Public CLIP
# SRR850552                    0.414967            0.028621    Public CLIP
# SRR850552                    0.377067            0.013500    Public CLIP
# SRR850552                    0.235630            0.009081    Public CLIP
# SRR850552                    0.782373            0.050903    Public CLIP
# SRR850552                    0.776347            0.075824    Public CLIP
# SRR850552                    0.157337            0.009749    Public CLIP
#
#                      iclip_joinerbar
# #Experiment ID
# ENCLB198MDG                      NaN
# ENCLB321IJI                      NaN
# ENCLB376GNW                      NaN
# ENCLB725AHE                      NaN
# ENCLB228RNI                      NaN
# ENCLB741WVB                      NaN
# ENCLB014OFT                      NaN
# ENCLB077IHV                      NaN
# ENCLB576NYG                      NaN
# ENCLB912JMG                      NaN
# ENCLB503ACY                      NaN
# ENCLB700YSR                      NaN
# ERR039836                        NaN
# ERR039837                        NaN
# ERR039838                        NaN
# ERR039839                        NaN
# ERR039840                        NaN
# ERR039841                        NaN
# ERR039842                        NaN
# ERR039843                        NaN
# ERR039844                        NaN
# ERR039845                        NaN
# ERR039846                        NaN
# ERR039848                        NaN
# ERR208895                        NaN
# ERR208896                        NaN
# ERR208900                        NaN
# ERR039849                        NaN
# ERR039850                        NaN
# ERR039851                        NaN
# ...                              ...
# SRR850552         SRR488730SRR488730
# SRR850552         SRR488731SRR488731
# SRR850552         SRR488732SRR488732
# SRR850552         SRR488733SRR488733
# SRR850552         SRR488734SRR488734
# SRR850552         SRR488735SRR488735
# SRR850552         SRR488736SRR488736
# SRR850552         SRR488738SRR488738
# SRR850552         SRR488739SRR488739
# SRR850552         SRR488740SRR488740
# SRR850552         SRR488741SRR488741
# SRR850552         SRR488742SRR488742
# SRR850552         SRR644276SRR644276
# SRR850552         SRR644275SRR644275
# SRR850552         SRR644274SRR644274
# SRR850552         SRR500481SRR500481
# SRR850552         SRR500484SRR500484
# SRR850552         SRR500485SRR500485
# SRR850552         SRR500487SRR500487
# SRR850552       SRR1260866SRR1260866
# SRR850552       SRR1260867SRR1260867
# SRR850552       SRR1260868SRR1260868
# SRR850552         SRR070465SRR070465
# SRR850552         SRR070464SRR070464
# SRR850552         SRR070463SRR070463
# SRR850552         SRR070462SRR070462
# SRR850552         SRR070461SRR070461
# SRR850552         SRR070449SRR070449
# SRR850552         SRR070450SRR070450
# SRR850552         SRR070448SRR070448
#
# [838 rows x 21 columns]
