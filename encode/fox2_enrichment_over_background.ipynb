# %%
import subprocess
import pandas as pd
import numpy as np
from scipy.stats import hypergeom
from IPython.core.display import HTML
import pybedtools
import os
import glob
from IPython.core.display import HTML
from Bio import SeqIO

# %%
def annotatePeaks_stranded(peaks, motif, species="hg19", hist=10, size=1000):
    
    """
    
    runs homer with standard args
    output location is saved
    
    foreground - str, location of fasta file for the foreground distribution
    background - str, location of fasta file for the background distribution
    k - different k-mers to examine
    outloc - directory to output homer results 

    --make optional make work off locations and not fasta files 
    
    """
    #findMotifs.pl clusters.fa fasta outloc -nofacts p 4 -rna -S 10 -len 5,6,7,8,9 -noconvert -nogo -fasta background.fa
    #converts k to a string for use in subprocess
    #I'm forgetting strand specific information here
    try:
        with open("tmp.txt", 'w') as out:
            subprocess.call(["annotatePeaks.pl",
                             peaks,
                             species,
                             "-m", motif,
                             #"-hist", str(hist),
                             "-size", "given",
                             "-noann"], shell=False, stdout=out)
    except OSError:
        print "Homer not installed, ignoring motif generation, install homer for this to work"  
        raise   
    annotation = pd.read_table("tmp.txt", index_col=0)
    annotation['stranded_peaks'] = annotation.apply(only_stranded_motifs, axis=1)
    return annotation

def only_stranded_motifs(row):
    motifs = row[-1]
    try:
        true_peaks = "),".join([motif for motif in motifs.split("),") if row.Strand in motif])
        if len(true_peaks) == 0:
            return np.nan
        
        return true_peaks
    except AttributeError:
        return motifs
    
def get_strand_of_motif(motifs):
    try:
        return ",".join(list(set(motif.split(",")[1] for motif in motifs.split("),"))))
    except AttributeError:
        return np.nan
    
def bound(row):
    try:
        return row.Strand in row.motif_strands
    except TypeError:
        return False
    
def get_bound_motifs(bedtool, motif_file, motif_name):
    annoted_peaks = annotatePeaks(bedtool.fn, motif_file, "mm9")
    annoted_peaks['motif_strands'] = annoted_peaks['1-{} Distance From Peak(sequence,strand,conservation)'.format(motif_name)].apply(get_strand_of_motif)
    annoted_peaks['motif_present'] = annoted_peaks.apply(bound, axis=1)
    return annoted_peaks

# %%
def findMotifsGenome(peaks, motif, species="hg19"):
    try:
        with open("tmp.txt", 'w') as out:
            subprocess.call(["findMotifsGenome.pl",
                             peaks,
                             species,
                             "foo",
                             "-size", "given ",
                             "-rna",
                             "-find", motif,
                            ], shell=False, stdout=out)
    except OSError:
        print "Homer not installed, ignoring motif generation, install homer for this to work"  
        raise   
    return pd.read_table("tmp.txt", index_col=0)

# %%
def findMotifsGenome(peaks, motif, species="hg19"):
    # !findMotifsGenome.pl $peaks $species foo -size given -rna -find $motif > tmp.txt
    return pd.read_table("tmp.txt", index_col=0)

# %%
rbfox2_motif = "/home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif"

# %%
#dir_name = "/projects/ps-yeolab2/encode/analysis/encode_v9/assigned/"

# %%
# v12 = glob.glob("/projects/ps-yeolab2/encode/analysis/encode_v12/assigned/*")
# v8 = [item.replace("/projects/ps-yeolab2/encode/analysis/encode_v12/assigned/", 
#                    "/home/gpratt/projects/encode/analysis/encode_v8/assigned/") for item in v12]

# %%
# v12_peak_sizes = {}
# for item in v12:
#     try:
#         if "all" in item and "real" in item:
#             v12_peak_sizes[os.path.basename(item)] = len(pybedtools.BedTool(item)) 
#     except:
#         pass
    
# v8_peak_sizes = {}
# for item in v8:
#     try:
#         if "all" in item and "real" in item:
#             v8_peak_sizes[os.path.basename(item)] = len(pybedtools.BedTool(item))
#     except:
#         pass

# %%
# foo = pd.concat({"v12": pd.Series(v12_peak_sizes),
#                  "v8": pd.Series(v8_peak_sizes)}).unstack().T

# %%
# foo = foo[["all" in item for item in foo.index]]
# foo = foo[["real" in item for item in foo.index]]

# %%
# foo['same'] = foo.v12 == foo.v8

# %%
# HTML(foo.to_html())

# %%
# for item in foo.index:
#     !diff /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/$item /home/gpratt/projects/encode/analysis/encode_v8/assigned/$item

# %%
dir_name = "/home/gpratt/projects/encode/analysis/encode_v8/assigned"
peaks_to_annotate = {"RBFOX2_293XT_1to200_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "RBFOX2_293XT_1to100_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "RBFOX2_293XT_1to50_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "RBFOX2_293XT_1to25_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "RBFOX2_293XT_1to12_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP10_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP8_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP1_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP5_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP6_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.real.BED"),}

dir_name = "/projects/ps-yeolab2/encode/analysis/encode_v12/assigned/"
peaks_to_annotate_v12 = {"RBFOX2_293XT_1to200_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "RBFOX2_293XT_1to100_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "RBFOX2_293XT_1to50_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "RBFOX2_293XT_1to25_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "RBFOX2_293XT_1to12_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP10_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP8_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP1_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP5_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
                     "EVN_041315_CLIP6_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.real.BED"),}


# dir_name = "/projects/ps-yeolab2/encode/analysis/encode_v12/assigned/"
# peaks_to_annotate = {"RBFOX2_293XT_1to200_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
#                      "RBFOX2_293XT_1to100_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
#                      "RBFOX2_293XT_1to50_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
#                      "RBFOX2_293XT_1to25_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
#                      "RBFOX2_293XT_1to12_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
#                      "EVN_041315_CLIP10_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
#                      "EVN_041315_CLIP8_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
#                      "EVN_041315_CLIP1_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
#                      "EVN_041315_CLIP5_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.real.BED"),
#                      "EVN_041315_CLIP6_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.real.BED"),}


peaks_to_rand_1_annotate = {"RBFOX2_293XT_1to200_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),
                     "RBFOX2_293XT_1to100_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),
                     "RBFOX2_293XT_1to50_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),
                     "RBFOX2_293XT_1to25_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),
                     "RBFOX2_293XT_1to12_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),
                     "EVN_041315_CLIP10_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),
                     "EVN_041315_CLIP8_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),
                     "EVN_041315_CLIP1_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),
                     "EVN_041315_CLIP5_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),
                     "EVN_041315_CLIP6_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED"),}

peaks_to_rand_2_annotate = {"RBFOX2_293XT_1to200_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),
                     "RBFOX2_293XT_1to100_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),
                     "RBFOX2_293XT_1to50_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),
                     "RBFOX2_293XT_1to25_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),
                     "RBFOX2_293XT_1to12_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),
                     "EVN_041315_CLIP10_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),
                     "EVN_041315_CLIP8_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),
                     "EVN_041315_CLIP1_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),
                     "EVN_041315_CLIP5_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),
                     "EVN_041315_CLIP6_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED"),}

peaks_to_rand_3_annotate = {"RBFOX2_293XT_1to200_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),
                     "RBFOX2_293XT_1to100_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),
                     "RBFOX2_293XT_1to50_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),
                     "RBFOX2_293XT_1to25_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),
                     "RBFOX2_293XT_1to12_gel_RBFOX2": os.path.join(dir_name, "RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),
                     "EVN_041315_CLIP10_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),
                     "EVN_041315_CLIP8_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),
                     "EVN_041315_CLIP1_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),
                     "EVN_041315_CLIP5_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),
                     "EVN_041315_CLIP6_RBFOX2": os.path.join(dir_name, "EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED"),}

# %%
for name, fn in sorted(peaks_to_annotate_v12.items(), key=lambda x: x[0]):
    print fn, name, len(pybedtools.BedTool(fn))
# Out:
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP10_RBFOX2 33194
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP1_RBFOX2 27038
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP5_RBFOX2 20718
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP6_RBFOX2 914
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP8_RBFOX2 20495
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to100_gel_RBFOX2 34934
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to12_gel_RBFOX2 33665
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to200_gel_RBFOX2 22370
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to25_gel_RBFOX2 27088
# /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to50_gel_RBFOX2 28458

# %%
for name, fn in sorted(peaks_to_annotate_v8.items(), key=lambda x: x[0]):
    try:
        
        print fn, name, len(pybedtools.BedTool(fn))
    except:
        pass
# Out:
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP10_RBFOX2 33194
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP1_RBFOX2 27038
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP5_RBFOX2 20718
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP6_RBFOX2 914
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.real.BED EVN_041315_CLIP8_RBFOX2 20495
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to100_gel_RBFOX2 34934
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to12_gel_RBFOX2 33665
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to200_gel_RBFOX2 22370
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to25_gel_RBFOX2 27088
# /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED RBFOX2_293XT_1to50_gel_RBFOX2 28458

# %%
def bound_in_same_strand(row):
    try:
        motifs = row['1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_0.6(0.999) Distance From Peak(sequence,strand,conservation)'].split("),")
        return any(row.Strand in item.split(",")[1] for item in motifs)
    except:
        return False

# %%
#This approach is incorrect, doesn't get strand quite right and isn't as stringent with the kmer finding as the approach below
# results_annotate = {}
# for peak in peaks_to_annotate:
#     annotated_peak = annotatePeaks_stranded(peaks_to_annotate[peak], rbfox2_motif)
#     results_annotate[peak] = {"peaks_with_motif": len(annotated_peak.stranded_peaks.dropna()), "num_peaks": len(pybedtools.BedTool(peaks_to_annotate[peak]))}
    
# results_rand_1_annotate = {}
# for peak in peaks_to_rand_1_annotate:
#     annotated_peak = annotatePeaks_stranded(peaks_to_rand_1_annotate[peak], rbfox2_motif)
#     #annotated_peak['bound_in_same_strand'] = annotated_peak.apply(bound_in_same_strand, axis=1)
#     results_rand_1_annotate[peak] = {"peaks_with_motif": len(annotated_peak.stranded_peaks.dropna()), "num_peaks": len(pybedtools.BedTool(peaks_to_annotate[peak]))}
    
# results_rand_2_annotate = {}
# for peak in peaks_to_rand_2_annotate:
#     annotated_peak = annotatePeaks_stranded(peaks_to_rand_2_annotate[peak], rbfox2_motif)
#     annotated_peak['bound_in_same_strand'] = annotated_peak.apply(bound_in_same_strand, axis=1)
#     results_rand_2_annotate[peak] = {"peaks_with_motif": len(annotated_peak.stranded_peaks.dropna()), "num_peaks": len(pybedtools.BedTool(peaks_to_annotate[peak]))}
    
# results_rand_3_annotate = {}
# for peak in peaks_to_rand_3_annotate:
#     annotated_peak = annotatePeaks_stranded(peaks_to_rand_3_annotate[peak], rbfox2_motif)
#     #annotated_peak['bound_in_same_strand'] = annotated_peak.apply(bound_in_same_strand, axis=1)
#     results_rand_3_annotate[peak] = {"peaks_with_motif": len(annotated_peak.stranded_peaks.dropna()), "num_peaks": len(pybedtools.BedTool(peaks_to_annotate[peak]))}

# %%
results = {}
for peak in peaks_to_annotate:
    annotated_peak = findMotifsGenome(peaks_to_annotate[peak], rbfox2_motif)
    annotated_peak['bound_in_same_strand'] = annotated_peak.apply(bound_in_same_strand, axis=1)
    results[peak] = {"peaks_with_motif": len(set(annotated_peak.index)), "num_peaks": len(pybedtools.BedTool(peaks_to_annotate[peak]))}

results_rand_1 = {}
for peak in peaks_to_rand_1_annotate:
    annotated_peak = findMotifsGenome(peaks_to_rand_1_annotate[peak], rbfox2_motif)
    annotated_peak['bound_in_same_strand'] = annotated_peak.apply(bound_in_same_strand, axis=1)
    results_rand_1[peak] = {"peaks_with_motif": len(set(annotated_peak.index)), "num_peaks": len(pybedtools.BedTool(peaks_to_annotate[peak]))}
    
results_rand_2 = {}
for peak in peaks_to_rand_2_annotate:
    annotated_peak = findMotifsGenome(peaks_to_rand_2_annotate[peak], rbfox2_motif)
    annotated_peak['bound_in_same_strand'] = annotated_peak.apply(bound_in_same_strand, axis=1)
    results_rand_2[peak] = {"peaks_with_motif": len(set(annotated_peak.index)), "num_peaks": len(pybedtools.BedTool(peaks_to_annotate[peak]))}
    
results_rand_3 = {}
for peak in peaks_to_rand_3_annotate:
    annotated_peak = findMotifsGenome(peaks_to_rand_3_annotate[peak], rbfox2_motif)
    annotated_peak['bound_in_same_strand'] = annotated_peak.apply(bound_in_same_strand, axis=1)
    results_rand_3[peak] = {"peaks_with_motif": len(set(annotated_peak.index)), "num_peaks": len(pybedtools.BedTool(peaks_to_annotate[peak]))}
# Out:
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 33194
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 33194
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 38 (avg size of targets)
# 	Background files for 38 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 3573 sequences from chr1
# 	Extracting 2082 sequences from chr2
# 	Extracting 1760 sequences from chr3
# 	Extracting 892 sequences from chr4
# 	Extracting 1434 sequences from chr5
# 	Extracting 1597 sequences from chr6
# 	Extracting 1560 sequences from chr7
# 	Extracting 1000 sequences from chr8
# 	Extracting 1209 sequences from chr9
# 	Extracting 1113 sequences from chr10
# 	Extracting 1863 sequences from chr11
# 	Extracting 1975 sequences from chr12
# 	Extracting 427 sequences from chr13
# 	Extracting 1173 sequences from chr14
# 	Extracting 1041 sequences from chr15
# 	Extracting 1874 sequences from chr16
# 	Extracting 2592 sequences from chr17
# 	Extracting 414 sequences from chr18
# 	Extracting 2207 sequences from chr19
# 	Extracting 786 sequences from chr20
# 	Extracting 412 sequences from chr21
# 	Extracting 1038 sequences from chr22
# 	Extracting 1104 sequences from chrX
# 	Extracting 68 sequences from chrM
# 	511 of 33194 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	32683 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 914
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 914
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 35 (avg size of targets)
# 	Background files for 35 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 77 sequences from chr1
# 	Extracting 47 sequences from chr2
# 	Extracting 35 sequences from chr3
# 	Extracting 33 sequences from chr4
# 	Extracting 28 sequences from chr5
# 	Extracting 30 sequences from chr6
# 	Extracting 57 sequences from chr7
# 	Extracting 35 sequences from chr8
# 	Extracting 42 sequences from chr9
# 	Extracting 53 sequences from chr10
# 	Extracting 48 sequences from chr11
# 	Extracting 33 sequences from chr12
# 	Extracting 12 sequences from chr13
# 	Extracting 27 sequences from chr14
# 	Extracting 13 sequences from chr15
# 	Extracting 59 sequences from chr16
# 	Extracting 53 sequences from chr17
# 	Extracting 11 sequences from chr18
# 	Extracting 65 sequences from chr19
# 	Extracting 40 sequences from chr20
# 	Extracting 17 sequences from chr21
# 	Extracting 40 sequences from chr22
# 	Extracting 20 sequences from chrX
# 	Extracting 39 sequences from chrM
# 	1 of 914 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	913 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 20495
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 20495
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 33 (avg size of targets)
# 	Background files for 33 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2191 sequences from chr1
# 	Extracting 1245 sequences from chr2
# 	Extracting 1150 sequences from chr3
# 	Extracting 560 sequences from chr4
# 	Extracting 800 sequences from chr5
# 	Extracting 945 sequences from chr6
# 	Extracting 885 sequences from chr7
# 	Extracting 564 sequences from chr8
# 	Extracting 761 sequences from chr9
# 	Extracting 685 sequences from chr10
# 	Extracting 1153 sequences from chr11
# 	Extracting 1170 sequences from chr12
# 	Extracting 249 sequences from chr13
# 	Extracting 597 sequences from chr14
# 	Extracting 581 sequences from chr15
# 	Extracting 1208 sequences from chr16
# 	Extracting 1652 sequences from chr17
# 	Extracting 211 sequences from chr18
# 	Extracting 1489 sequences from chr19
# 	Extracting 541 sequences from chr20
# 	Extracting 279 sequences from chr21
# 	Extracting 757 sequences from chr22
# 	Extracting 759 sequences from chrX
# 	Extracting 63 sequences from chrM
# 	277 of 20495 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	20218 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 22370
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 22370
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 36 (avg size of targets)
# 	Background files for 36 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2386 sequences from chr1
# 	Extracting 1238 sequences from chr2
# 	Extracting 1147 sequences from chr3
# 	Extracting 544 sequences from chr4
# 	Extracting 807 sequences from chr5
# 	Extracting 958 sequences from chr6
# 	Extracting 1023 sequences from chr7
# 	Extracting 651 sequences from chr8
# 	Extracting 860 sequences from chr9
# 	Extracting 667 sequences from chr10
# 	Extracting 1356 sequences from chr11
# 	Extracting 1188 sequences from chr12
# 	Extracting 253 sequences from chr13
# 	Extracting 697 sequences from chr14
# 	Extracting 555 sequences from chr15
# 	Extracting 1456 sequences from chr16
# 	Extracting 1970 sequences from chr17
# 	Extracting 218 sequences from chr18
# 	Extracting 1831 sequences from chr19
# 	Extracting 636 sequences from chr20
# 	Extracting 308 sequences from chr21
# 	Extracting 879 sequences from chr22
# 	Extracting 701 sequences from chrX
# 	Extracting 41 sequences from chrM
# 	265 of 22370 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	22105 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 34934
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 34934
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 38 (avg size of targets)
# 	Background files for 38 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 3680 sequences from chr1
# 	Extracting 2093 sequences from chr2
# 	Extracting 1870 sequences from chr3
# 	Extracting 886 sequences from chr4
# 	Extracting 1304 sequences from chr5
# 	Extracting 1539 sequences from chr6
# 	Extracting 1591 sequences from chr7
# 	Extracting 1063 sequences from chr8
# 	Extracting 1301 sequences from chr9
# 	Extracting 1063 sequences from chr10
# 	Extracting 2045 sequences from chr11
# 	Extracting 1990 sequences from chr12
# 	Extracting 460 sequences from chr13
# 	Extracting 1147 sequences from chr14
# 	Extracting 1047 sequences from chr15
# 	Extracting 2210 sequences from chr16
# 	Extracting 2958 sequences from chr17
# 	Extracting 419 sequences from chr18
# 	Extracting 2522 sequences from chr19
# 	Extracting 875 sequences from chr20
# 	Extracting 427 sequences from chr21
# 	Extracting 1252 sequences from chr22
# 	Extracting 1145 sequences from chrX
# 	Extracting 47 sequences from chrM
# 	419 of 34934 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	34515 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 27038
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 27038
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 31 (avg size of targets)
# 	Background files for 31 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2806 sequences from chr1
# 	Extracting 1609 sequences from chr2
# 	Extracting 1452 sequences from chr3
# 	Extracting 751 sequences from chr4
# 	Extracting 978 sequences from chr5
# 	Extracting 1211 sequences from chr6
# 	Extracting 1291 sequences from chr7
# 	Extracting 760 sequences from chr8
# 	Extracting 1130 sequences from chr9
# 	Extracting 925 sequences from chr10
# 	Extracting 1442 sequences from chr11
# 	Extracting 1359 sequences from chr12
# 	Extracting 424 sequences from chr13
# 	Extracting 760 sequences from chr14
# 	Extracting 786 sequences from chr15
# 	Extracting 1571 sequences from chr16
# 	Extracting 2054 sequences from chr17
# 	Extracting 347 sequences from chr18
# 	Extracting 2101 sequences from chr19
# 	Extracting 816 sequences from chr20
# 	Extracting 423 sequences from chr21
# 	Extracting 1114 sequences from chr22
# 	Extracting 877 sequences from chrX
# 	Extracting 51 sequences from chrM
# 	255 of 27038 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	26783 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 33665
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 33665
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 41 (avg size of targets)
# 	Background files for 41 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 3475 sequences from chr1
# 	Extracting 1969 sequences from chr2
# 	Extracting 1793 sequences from chr3
# 	Extracting 899 sequences from chr4
# 	Extracting 1280 sequences from chr5
# 	Extracting 1362 sequences from chr6
# 	Extracting 1600 sequences from chr7
# 	Extracting 1056 sequences from chr8
# 	Extracting 1349 sequences from chr9
# 	Extracting 1069 sequences from chr10
# 	Extracting 1956 sequences from chr11
# 	Extracting 1706 sequences from chr12
# 	Extracting 437 sequences from chr13
# 	Extracting 1020 sequences from chr14
# 	Extracting 966 sequences from chr15
# 	Extracting 2149 sequences from chr16
# 	Extracting 2802 sequences from chr17
# 	Extracting 415 sequences from chr18
# 	Extracting 2622 sequences from chr19
# 	Extracting 922 sequences from chr20
# 	Extracting 466 sequences from chr21
# 	Extracting 1309 sequences from chr22
# 	Extracting 1003 sequences from chrX
# 	Extracting 40 sequences from chrM
# 	277 of 33665 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	33388 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 28458
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 28458
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 41 (avg size of targets)
# 	Background files for 41 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2986 sequences from chr1
# 	Extracting 1655 sequences from chr2
# 	Extracting 1472 sequences from chr3
# 	Extracting 740 sequences from chr4
# 	Extracting 1065 sequences from chr5
# 	Extracting 1208 sequences from chr6
# 	Extracting 1317 sequences from chr7
# 	Extracting 848 sequences from chr8
# 	Extracting 1088 sequences from chr9
# 	Extracting 863 sequences from chr10
# 	Extracting 1658 sequences from chr11
# 	Extracting 1496 sequences from chr12
# 	Extracting 348 sequences from chr13
# 	Extracting 867 sequences from chr14
# 	Extracting 750 sequences from chr15
# 	Extracting 1906 sequences from chr16
# 	Extracting 2406 sequences from chr17
# 	Extracting 341 sequences from chr18
# 	Extracting 2245 sequences from chr19
# 	Extracting 789 sequences from chr20
# 	Extracting 374 sequences from chr21
# 	Extracting 1103 sequences from chr22
# 	Extracting 887 sequences from chrX
# 	Extracting 46 sequences from chrM
# 	270 of 28458 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	28188 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 20718
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 20718
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 33 (avg size of targets)
# 	Background files for 33 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2019 sequences from chr1
# 	Extracting 1258 sequences from chr2
# 	Extracting 1165 sequences from chr3
# 	Extracting 621 sequences from chr4
# 	Extracting 721 sequences from chr5
# 	Extracting 958 sequences from chr6
# 	Extracting 988 sequences from chr7
# 	Extracting 604 sequences from chr8
# 	Extracting 882 sequences from chr9
# 	Extracting 760 sequences from chr10
# 	Extracting 1026 sequences from chr11
# 	Extracting 876 sequences from chr12
# 	Extracting 400 sequences from chr13
# 	Extracting 575 sequences from chr14
# 	Extracting 556 sequences from chr15
# 	Extracting 1041 sequences from chr16
# 	Extracting 1568 sequences from chr17
# 	Extracting 274 sequences from chr18
# 	Extracting 1710 sequences from chr19
# 	Extracting 654 sequences from chr20
# 	Extracting 341 sequences from chr21
# 	Extracting 946 sequences from chr22
# 	Extracting 733 sequences from chrX
# 	Extracting 42 sequences from chrM
# 	118 of 20718 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	20600 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /home/gpratt/projects/encode/analysis/encode_v8/assigned/RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.real.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 27088
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 27088
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 38 (avg size of targets)
# 	Background files for 38 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2873 sequences from chr1
# 	Extracting 1574 sequences from chr2
# 	Extracting 1370 sequences from chr3
# 	Extracting 708 sequences from chr4
# 	Extracting 1001 sequences from chr5
# 	Extracting 1125 sequences from chr6
# 	Extracting 1287 sequences from chr7
# 	Extracting 783 sequences from chr8
# 	Extracting 1094 sequences from chr9
# 	Extracting 849 sequences from chr10
# 	Extracting 1541 sequences from chr11
# 	Extracting 1420 sequences from chr12
# 	Extracting 326 sequences from chr13
# 	Extracting 826 sequences from chr14
# 	Extracting 713 sequences from chr15
# 	Extracting 1772 sequences from chr16
# 	Extracting 2280 sequences from chr17
# 	Extracting 271 sequences from chr18
# 	Extracting 2177 sequences from chr19
# 	Extracting 780 sequences from chr20
# 	Extracting 381 sequences from chr21
# 	Extracting 1081 sequences from chr22
# 	Extracting 819 sequences from chrX
# 	Extracting 37 sequences from chrM
# 	239 of 27088 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	26849 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 33194
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 33194
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 38 (avg size of targets)
# 	Background files for 38 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 3131 sequences from chr1
# 	Extracting 2592 sequences from chr2
# 	Extracting 1993 sequences from chr3
# 	Extracting 1424 sequences from chr4
# 	Extracting 1549 sequences from chr5
# 	Extracting 1535 sequences from chr6
# 	Extracting 1653 sequences from chr7
# 	Extracting 1252 sequences from chr8
# 	Extracting 1281 sequences from chr9
# 	Extracting 1324 sequences from chr10
# 	Extracting 1746 sequences from chr11
# 	Extracting 1885 sequences from chr12
# 	Extracting 620 sequences from chr13
# 	Extracting 1170 sequences from chr14
# 	Extracting 1268 sequences from chr15
# 	Extracting 1423 sequences from chr16
# 	Extracting 1940 sequences from chr17
# 	Extracting 593 sequences from chr18
# 	Extracting 1773 sequences from chr19
# 	Extracting 775 sequences from chr20
# 	Extracting 328 sequences from chr21
# 	Extracting 708 sequences from chr22
# 	Extracting 1071 sequences from chrX
# 	Extracting 159 sequences from chrY
# 	Extracting 1 sequences from chrM
# 	511 of 33194 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	32683 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP6_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 914
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 914
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 35 (avg size of targets)
# 	Background files for 35 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 83 sequences from chr1
# 	Extracting 71 sequences from chr2
# 	Extracting 58 sequences from chr3
# 	Extracting 42 sequences from chr4
# 	Extracting 36 sequences from chr5
# 	Extracting 43 sequences from chr6
# 	Extracting 43 sequences from chr7
# 	Extracting 33 sequences from chr8
# 	Extracting 36 sequences from chr9
# 	Extracting 47 sequences from chr10
# 	Extracting 48 sequences from chr11
# 	Extracting 45 sequences from chr12
# 	Extracting 20 sequences from chr13
# 	Extracting 32 sequences from chr14
# 	Extracting 37 sequences from chr15
# 	Extracting 39 sequences from chr16
# 	Extracting 53 sequences from chr17
# 	Extracting 19 sequences from chr18
# 	Extracting 39 sequences from chr19
# 	Extracting 23 sequences from chr20
# 	Extracting 14 sequences from chr21
# 	Extracting 20 sequences from chr22
# 	Extracting 27 sequences from chrX
# 	Extracting 6 sequences from chrY
# 	1 of 914 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	913 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP8_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 20495
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 20495
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 33 (avg size of targets)
# 	Background files for 33 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 1919 sequences from chr1
# 	Extracting 1608 sequences from chr2
# 	Extracting 1220 sequences from chr3
# 	Extracting 895 sequences from chr4
# 	Extracting 987 sequences from chr5
# 	Extracting 983 sequences from chr6
# 	Extracting 998 sequences from chr7
# 	Extracting 783 sequences from chr8
# 	Extracting 801 sequences from chr9
# 	Extracting 820 sequences from chr10
# 	Extracting 1090 sequences from chr11
# 	Extracting 1120 sequences from chr12
# 	Extracting 401 sequences from chr13
# 	Extracting 679 sequences from chr14
# 	Extracting 731 sequences from chr15
# 	Extracting 872 sequences from chr16
# 	Extracting 1142 sequences from chr17
# 	Extracting 380 sequences from chr18
# 	Extracting 1146 sequences from chr19
# 	Extracting 474 sequences from chr20
# 	Extracting 221 sequences from chr21
# 	Extracting 482 sequences from chr22
# 	Extracting 649 sequences from chrX
# 	Extracting 94 sequences from chrY
# 	277 of 20495 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	20218 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to200_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 22370
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 22370
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 36 (avg size of targets)
# 	Background files for 36 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2174 sequences from chr1
# 	Extracting 1697 sequences from chr2
# 	Extracting 1362 sequences from chr3
# 	Extracting 985 sequences from chr4
# 	Extracting 1012 sequences from chr5
# 	Extracting 1095 sequences from chr6
# 	Extracting 1126 sequences from chr7
# 	Extracting 878 sequences from chr8
# 	Extracting 853 sequences from chr9
# 	Extracting 884 sequences from chr10
# 	Extracting 1170 sequences from chr11
# 	Extracting 1252 sequences from chr12
# 	Extracting 408 sequences from chr13
# 	Extracting 732 sequences from chr14
# 	Extracting 854 sequences from chr15
# 	Extracting 951 sequences from chr16
# 	Extracting 1288 sequences from chr17
# 	Extracting 375 sequences from chr18
# 	Extracting 1204 sequences from chr19
# 	Extracting 509 sequences from chr20
# 	Extracting 233 sequences from chr21
# 	Extracting 481 sequences from chr22
# 	Extracting 752 sequences from chrX
# 	Extracting 95 sequences from chrY
# 	265 of 22370 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	22105 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 34934
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 34934
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 38 (avg size of targets)
# 	Background files for 38 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 3252 sequences from chr1
# 	Extracting 2742 sequences from chr2
# 	Extracting 2082 sequences from chr3
# 	Extracting 1484 sequences from chr4
# 	Extracting 1643 sequences from chr5
# 	Extracting 1673 sequences from chr6
# 	Extracting 1774 sequences from chr7
# 	Extracting 1350 sequences from chr8
# 	Extracting 1380 sequences from chr9
# 	Extracting 1394 sequences from chr10
# 	Extracting 1907 sequences from chr11
# 	Extracting 1985 sequences from chr12
# 	Extracting 683 sequences from chr13
# 	Extracting 1131 sequences from chr14
# 	Extracting 1325 sequences from chr15
# 	Extracting 1552 sequences from chr16
# 	Extracting 1972 sequences from chr17
# 	Extracting 592 sequences from chr18
# 	Extracting 1789 sequences from chr19
# 	Extracting 745 sequences from chr20
# 	Extracting 395 sequences from chr21
# 	Extracting 753 sequences from chr22
# 	Extracting 1137 sequences from chrX
# 	Extracting 194 sequences from chrY
# 	419 of 34934 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	34515 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 27038
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 27038
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 31 (avg size of targets)
# 	Background files for 31 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2534 sequences from chr1
# 	Extracting 2118 sequences from chr2
# 	Extracting 1651 sequences from chr3
# 	Extracting 1205 sequences from chr4
# 	Extracting 1350 sequences from chr5
# 	Extracting 1310 sequences from chr6
# 	Extracting 1325 sequences from chr7
# 	Extracting 1069 sequences from chr8
# 	Extracting 1074 sequences from chr9
# 	Extracting 1109 sequences from chr10
# 	Extracting 1345 sequences from chr11
# 	Extracting 1487 sequences from chr12
# 	Extracting 548 sequences from chr13
# 	Extracting 889 sequences from chr14
# 	Extracting 1051 sequences from chr15
# 	Extracting 1169 sequences from chr16
# 	Extracting 1475 sequences from chr17
# 	Extracting 491 sequences from chr18
# 	Extracting 1344 sequences from chr19
# 	Extracting 632 sequences from chr20
# 	Extracting 325 sequences from chr21
# 	Extracting 579 sequences from chr22
# 	Extracting 811 sequences from chrX
# 	Extracting 147 sequences from chrY
# 	255 of 27038 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	26783 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 33665
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 33665
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 41 (avg size of targets)
# 	Background files for 41 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 3216 sequences from chr1
# 	Extracting 2584 sequences from chr2
# 	Extracting 2070 sequences from chr3
# 	Extracting 1486 sequences from chr4
# 	Extracting 1551 sequences from chr5
# 	Extracting 1588 sequences from chr6
# 	Extracting 1743 sequences from chr7
# 	Extracting 1280 sequences from chr8
# 	Extracting 1312 sequences from chr9
# 	Extracting 1424 sequences from chr10
# 	Extracting 1719 sequences from chr11
# 	Extracting 1856 sequences from chr12
# 	Extracting 640 sequences from chr13
# 	Extracting 1134 sequences from chr14
# 	Extracting 1305 sequences from chr15
# 	Extracting 1442 sequences from chr16
# 	Extracting 1829 sequences from chr17
# 	Extracting 606 sequences from chr18
# 	Extracting 1755 sequences from chr19
# 	Extracting 783 sequences from chr20
# 	Extracting 351 sequences from chr21
# 	Extracting 716 sequences from chr22
# 	Extracting 1096 sequences from chrX
# 	Extracting 175 sequences from chrY
# 	Extracting 4 sequences from chrM
# 	277 of 33665 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	33388 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 28458
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 28458
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 41 (avg size of targets)
# 	Background files for 41 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2616 sequences from chr1
# 	Extracting 2247 sequences from chr2
# 	Extracting 1671 sequences from chr3
# 	Extracting 1213 sequences from chr4
# 	Extracting 1381 sequences from chr5
# 	Extracting 1400 sequences from chr6
# 	Extracting 1434 sequences from chr7
# 	Extracting 1118 sequences from chr8
# 	Extracting 1044 sequences from chr9
# 	Extracting 1199 sequences from chr10
# 	Extracting 1434 sequences from chr11
# 	Extracting 1634 sequences from chr12
# 	Extracting 573 sequences from chr13
# 	Extracting 912 sequences from chr14
# 	Extracting 1046 sequences from chr15
# 	Extracting 1262 sequences from chr16
# 	Extracting 1581 sequences from chr17
# 	Extracting 552 sequences from chr18
# 	Extracting 1491 sequences from chr19
# 	Extracting 693 sequences from chr20
# 	Extracting 329 sequences from chr21
# 	Extracting 600 sequences from chr22
# 	Extracting 892 sequences from chrX
# 	Extracting 136 sequences from chrY
# 	270 of 28458 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	28188 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 20718
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 20718
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 33 (avg size of targets)
# 	Background files for 33 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 1975 sequences from chr1
# 	Extracting 1559 sequences from chr2
# 	Extracting 1267 sequences from chr3
# 	Extracting 947 sequences from chr4
# 	Extracting 1020 sequences from chr5
# 	Extracting 1004 sequences from chr6
# 	Extracting 1092 sequences from chr7
# 	Extracting 803 sequences from chr8
# 	Extracting 849 sequences from chr9
# 	Extracting 863 sequences from chr10
# 	Extracting 1006 sequences from chr11
# 	Extracting 1157 sequences from chr12
# 	Extracting 443 sequences from chr13
# 	Extracting 667 sequences from chr14
# 	Extracting 795 sequences from chr15
# 	Extracting 867 sequences from chr16
# 	Extracting 1054 sequences from chr17
# 	Extracting 410 sequences from chr18
# 	Extracting 991 sequences from chr19
# 	Extracting 500 sequences from chr20
# 	Extracting 251 sequences from chr21
# 	Extracting 444 sequences from chr22
# 	Extracting 610 sequences from chrX
# 	Extracting 144 sequences from chrY
# 	118 of 20718 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	20600 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.rand.1.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 27088
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 27088
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 38 (avg size of targets)
# 	Background files for 38 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2600 sequences from chr1
# 	Extracting 2015 sequences from chr2
# 	Extracting 1632 sequences from chr3
# 	Extracting 1174 sequences from chr4
# 	Extracting 1280 sequences from chr5
# 	Extracting 1352 sequences from chr6
# 	Extracting 1352 sequences from chr7
# 	Extracting 1038 sequences from chr8
# 	Extracting 973 sequences from chr9
# 	Extracting 1153 sequences from chr10
# 	Extracting 1412 sequences from chr11
# 	Extracting 1575 sequences from chr12
# 	Extracting 521 sequences from chr13
# 	Extracting 931 sequences from chr14
# 	Extracting 1015 sequences from chr15
# 	Extracting 1130 sequences from chr16
# 	Extracting 1473 sequences from chr17
# 	Extracting 500 sequences from chr18
# 	Extracting 1483 sequences from chr19
# 	Extracting 608 sequences from chr20
# 	Extracting 298 sequences from chr21
# 	Extracting 544 sequences from chr22
# 	Extracting 901 sequences from chrX
# 	Extracting 128 sequences from chrY
# 	239 of 27088 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	26849 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP10_RBFOX2.merged.r2.peaks.bed.all.rand.2.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 33194
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 33194
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 38 (avg size of targets)
# 	Background files for 38 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 3111 sequences from chr1
# 	Extracting 2551 sequences from chr2
# 	Extracting 1971 sequences from chr3
# 	Extracting 1444 sequences from chr4
# 	Extracting 1500 sequences from chr5
# 	Extracting 1528 sequences from chr6
# 	Extracting 1630 sequences from chr7
# 	Extracting 1232 sequences from chr8
# 	Extracting 1319 sequences from chr9
# 	Extracting 1385 sequences from chr10
# 	Extracting 1805 sequences from chr11
# 	Extracting 1922 sequences from chr12
# 	Extracting 557 sequences from chr13
# 	Extracting 1061 sequences from chr14
# 	Extracting 1291 sequences from chr15
# ...
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 22370
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 22370
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 36 (avg size of targets)
# 	Background files for 36 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2072 sequences from chr1
# 	Extracting 1682 sequences from chr2
# 	Extracting 1286 sequences from chr3
# 	Extracting 964 sequences from chr4
# 	Extracting 1085 sequences from chr5
# 	Extracting 1065 sequences from chr6
# 	Extracting 1157 sequences from chr7
# 	Extracting 866 sequences from chr8
# 	Extracting 862 sequences from chr9
# 	Extracting 929 sequences from chr10
# 	Extracting 1201 sequences from chr11
# 	Extracting 1277 sequences from chr12
# 	Extracting 418 sequences from chr13
# 	Extracting 736 sequences from chr14
# 	Extracting 860 sequences from chr15
# 	Extracting 941 sequences from chr16
# 	Extracting 1334 sequences from chr17
# 	Extracting 364 sequences from chr18
# 	Extracting 1189 sequences from chr19
# 	Extracting 542 sequences from chr20
# 	Extracting 231 sequences from chr21
# 	Extracting 505 sequences from chr22
# 	Extracting 708 sequences from chrX
# 	Extracting 96 sequences from chrY
# 	265 of 22370 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	22105 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to100_gel_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 34934
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 34934
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 38 (avg size of targets)
# 	Background files for 38 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 3296 sequences from chr1
# 	Extracting 2644 sequences from chr2
# 	Extracting 2169 sequences from chr3
# 	Extracting 1459 sequences from chr4
# 	Extracting 1595 sequences from chr5
# 	Extracting 1718 sequences from chr6
# 	Extracting 1746 sequences from chr7
# 	Extracting 1372 sequences from chr8
# 	Extracting 1279 sequences from chr9
# 	Extracting 1469 sequences from chr10
# 	Extracting 1908 sequences from chr11
# 	Extracting 1981 sequences from chr12
# 	Extracting 621 sequences from chr13
# 	Extracting 1211 sequences from chr14
# 	Extracting 1349 sequences from chr15
# 	Extracting 1505 sequences from chr16
# 	Extracting 1948 sequences from chr17
# 	Extracting 631 sequences from chr18
# 	Extracting 1833 sequences from chr19
# 	Extracting 796 sequences from chr20
# 	Extracting 422 sequences from chr21
# 	Extracting 725 sequences from chr22
# 	Extracting 1060 sequences from chrX
# 	Extracting 196 sequences from chrY
# 	Extracting 1 sequences from chrM
# 	419 of 34934 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	34515 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP1_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 27038
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 27038
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 31 (avg size of targets)
# 	Background files for 31 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2509 sequences from chr1
# 	Extracting 2092 sequences from chr2
# 	Extracting 1682 sequences from chr3
# 	Extracting 1130 sequences from chr4
# 	Extracting 1334 sequences from chr5
# 	Extracting 1348 sequences from chr6
# 	Extracting 1348 sequences from chr7
# 	Extracting 1070 sequences from chr8
# 	Extracting 1061 sequences from chr9
# 	Extracting 1066 sequences from chr10
# 	Extracting 1346 sequences from chr11
# 	Extracting 1496 sequences from chr12
# 	Extracting 545 sequences from chr13
# 	Extracting 871 sequences from chr14
# 	Extracting 1026 sequences from chr15
# 	Extracting 1162 sequences from chr16
# 	Extracting 1474 sequences from chr17
# 	Extracting 495 sequences from chr18
# 	Extracting 1382 sequences from chr19
# 	Extracting 626 sequences from chr20
# 	Extracting 312 sequences from chr21
# 	Extracting 590 sequences from chr22
# 	Extracting 920 sequences from chrX
# 	Extracting 153 sequences from chrY
# 	255 of 27038 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	26783 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to12_gel_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 33665
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 33665
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 41 (avg size of targets)
# 	Background files for 41 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 3122 sequences from chr1
# 	Extracting 2572 sequences from chr2
# 	Extracting 2058 sequences from chr3
# 	Extracting 1458 sequences from chr4
# 	Extracting 1623 sequences from chr5
# 	Extracting 1575 sequences from chr6
# 	Extracting 1677 sequences from chr7
# 	Extracting 1291 sequences from chr8
# 	Extracting 1360 sequences from chr9
# 	Extracting 1445 sequences from chr10
# 	Extracting 1761 sequences from chr11
# 	Extracting 1864 sequences from chr12
# 	Extracting 696 sequences from chr13
# 	Extracting 1064 sequences from chr14
# 	Extracting 1322 sequences from chr15
# 	Extracting 1463 sequences from chr16
# 	Extracting 1807 sequences from chr17
# 	Extracting 603 sequences from chr18
# 	Extracting 1806 sequences from chr19
# 	Extracting 778 sequences from chr20
# 	Extracting 384 sequences from chr21
# 	Extracting 700 sequences from chr22
# 	Extracting 1060 sequences from chrX
# 	Extracting 175 sequences from chrY
# 	Extracting 1 sequences from chrM
# 	277 of 33665 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	33388 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to50_gel_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 28458
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 28458
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 41 (avg size of targets)
# 	Background files for 41 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2640 sequences from chr1
# 	Extracting 2141 sequences from chr2
# 	Extracting 1711 sequences from chr3
# 	Extracting 1263 sequences from chr4
# 	Extracting 1350 sequences from chr5
# 	Extracting 1359 sequences from chr6
# 	Extracting 1473 sequences from chr7
# 	Extracting 1131 sequences from chr8
# 	Extracting 1096 sequences from chr9
# 	Extracting 1212 sequences from chr10
# 	Extracting 1437 sequences from chr11
# 	Extracting 1639 sequences from chr12
# 	Extracting 531 sequences from chr13
# 	Extracting 938 sequences from chr14
# 	Extracting 1107 sequences from chr15
# 	Extracting 1221 sequences from chr16
# 	Extracting 1606 sequences from chr17
# 	Extracting 515 sequences from chr18
# 	Extracting 1517 sequences from chr19
# 	Extracting 655 sequences from chr20
# 	Extracting 299 sequences from chr21
# 	Extracting 612 sequences from chr22
# 	Extracting 867 sequences from chrX
# 	Extracting 136 sequences from chrY
# 	Extracting 2 sequences from chrM
# 	270 of 28458 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	28188 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/EVN_041315_CLIP5_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 20718
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 20718
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 33 (avg size of targets)
# 	Background files for 33 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 1855 sequences from chr1
# 	Extracting 1604 sequences from chr2
# 	Extracting 1266 sequences from chr3
# 	Extracting 992 sequences from chr4
# 	Extracting 1041 sequences from chr5
# 	Extracting 977 sequences from chr6
# 	Extracting 1106 sequences from chr7
# 	Extracting 807 sequences from chr8
# 	Extracting 836 sequences from chr9
# 	Extracting 931 sequences from chr10
# 	Extracting 1039 sequences from chr11
# 	Extracting 1122 sequences from chr12
# 	Extracting 430 sequences from chr13
# 	Extracting 650 sequences from chr14
# 	Extracting 815 sequences from chr15
# 	Extracting 879 sequences from chr16
# 	Extracting 1064 sequences from chr17
# 	Extracting 381 sequences from chr18
# 	Extracting 1018 sequences from chr19
# 	Extracting 506 sequences from chr20
# 	Extracting 198 sequences from chr21
# 	Extracting 420 sequences from chr22
# 	Extracting 647 sequences from chrX
# 	Extracting 133 sequences from chrY
# 	Extracting 1 sequences from chrM
# 	118 of 20718 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	20600 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = /projects/ps-yeolab2/encode/analysis/encode_v12/assigned/RBFOX2_293XT_1to25_gel_RBFOX2.merged.r2.peaks.bed.all.rand.0.BED
# 	Genome = hg19
# 	Output Directory = foo
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Operating in RNA mode
# 	Will find motif(s) in /home/gpratt/projects/encode/analysis/encode_v8/homer/293XT_CLIP_RBFOX2_1120_RBFOX2.merged.r2.peaks.bed/all/homerResults/motif1.motif
# 	Found mset for "human", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 27088
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 27088
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 38 (avg size of targets)
# 	Background files for 38 bp fragments found.
#
# 	Extracting sequences from directory: /home/yeo-lab/software/homer/.//data/genomes/hg19//
# 	Extracting 2533 sequences from chr1
# 	Extracting 2136 sequences from chr2
# 	Extracting 1673 sequences from chr3
# 	Extracting 1119 sequences from chr4
# 	Extracting 1309 sequences from chr5
# 	Extracting 1240 sequences from chr6
# 	Extracting 1390 sequences from chr7
# 	Extracting 1040 sequences from chr8
# 	Extracting 1066 sequences from chr9
# 	Extracting 1101 sequences from chr10
# 	Extracting 1441 sequences from chr11
# 	Extracting 1436 sequences from chr12
# 	Extracting 527 sequences from chr13
# 	Extracting 878 sequences from chr14
# 	Extracting 1035 sequences from chr15
# 	Extracting 1136 sequences from chr16
# 	Extracting 1494 sequences from chr17
# 	Extracting 465 sequences from chr18
# 	Extracting 1472 sequences from chr19
# 	Extracting 656 sequences from chr20
# 	Extracting 308 sequences from chr21
# 	Extracting 592 sequences from chr22
# 	Extracting 857 sequences from chrX
# 	Extracting 184 sequences from chrY
# 	239 of 27088 removed because they were shorter than 5 bp
#
#
# 	Reading input files...
# 	26849 total sequences read
# 	1 motifs loaded
# 	Finding instances of 1 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...

# %%
foo = pybedtools.BedTool(peaks_to_annotate[peak]).filter(lambda interval: interval.name in set(annotated_peak.index) - found).saveas()

# %%
annotated_peak.ix['ENSG00000078900.10_1_42_262']
# Out:
# Offset                                                                 51
# Sequence                                                           TGCATG
# Motif Name              1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# Strand                                                                  +
# MotifScore                                                        8.24193
# bound_in_same_strand                                                False
# Name: ENSG00000078900.10_1_42_262, dtype: object

# %%
annotated_peak.ix[set(annotated_peak.index) - found]
# Out:
#                                                     Offset Sequence  \
# PositionID
# ENSG00000105983.14_4_9_26031                             2   TGCATG
# ENSG00000159720.7_1_9_10474                             20   TGCATG
# ENSG00000031823.10_5_29_14272                            9   TGCATG
# ENSG00000092439.9_0_9_8522                               0   TGCATG
# ENSG00000135476.7_11_8_6130                             11   TGCATG
# ENSG00000185483.7_1_5_1372                               1   TGCATG
# ENSG00000198952.6_4_13_2140                              8   TGCATG
# ENSG00000163931.11_5_15_21041                            9   TGCATG
# ENSG00000009954.6_2_7_25260                              9   TGCATG
# ENSG00000181220.11_5_5_25863                            18   CGCATG
# ENSG00000173818.12_5_18_13188                           20   TGCATG
# ENSG00000095787.16_7_5_3215                              9   TGCATG
# ENSG00000250337.1_0_4_22528                              1   TGCATG
# ENSG00000116604.12_0_15_2153                             1   TGCATG
# ENSG00000170776.15_2_3_8942                              1   TGCATG
# ENSG00000175115.7_2_11_4996                              1   TGCATG
# ENSG00000101190.8_1_7_18441                              7   TGCATG
# ENSG00000139131.8_0_13_5922                             34   TGCATG
# ENSG00000178234.8_1_6_25974                              0   TGCATG
# ENSG00000100764.9_0_3_8021                               8   TGCATG
# ENSG00000126106.9_1_4_1184                               1   TGCATG
# ENSG00000111358.9_7_35_6953                              5   TGCATG
# ENSG00000100852.8_2_9_7689                              15   TGCATG
# ENSG00000173757.4_1_4_12204                             10   TGCATG
# ENSG00000163867.11_1_7_939                              27   TGCATG
# ENSG00000134769.17_4_5_13613                             0   TGCATG
# ENSG00000136699.15_11_161_17020,ENSG00000136699...      73   TGCATG
# ENSG00000170085.13_2_13_23199                           20   TGCATG
# ENSG00000149548.10_2_21_5549                             5   TGCATG
# ENSG00000151576.6_0_6_21219                              1   TGCATG
# ...                                                    ...      ...
# ENSG00000139629.11_0_3_6093                              2   TGCATG
# ENSG00000204681.6_0_10_23721                             0   TGCATG
# ENSG00000204681.6_0_10_23721                            36   TGCATG
# ENSG00000164051.9_1_8_20653                             30   TGCATG
# ENSG00000011405.9_1_4_4273                              17   TGCATG
# ENSG00000160439.10_2_4_15951                            29   TGCATG
# ENSG00000160439.10_2_4_15951                            33   TGCATG
# ENSG00000108264.12_1_4_12015                             1   TGCATG
# ENSG00000225032.1_0_5_27493                              9   TGCATG
# ENSG00000060339.9_2_6_3325                               0   TGCATG
# ENSG00000106603.13_7_18_25057                            4   TGCATG
# ENSG00000103365.11_3_29_9942                             3   TGCATG
# ENSG00000076555.11_3_6_6574                             15   TGCATG
# ENSG00000007168.7_0_7_11161                             38   CGCATG
# ENSG00000082898.12_3_13_16511                            6   TGCATG
# ENSG00000173473.6_3_12_20611                             3   TGCATG
# ENSG00000119514.5_0_8_27309                             16   TGCATG
# ENSG00000119514.5_0_8_27309                             30   TGCATG
# ENSG00000165626.12_9_6_3154                             18   TGCATG
# ENSG00000082898.12_1_13_16509                           13   TGCATG
# ENSG00000114388.8_3_43_20856                            15   TGCATG
# ENSG00000154380.11_4_48_2657                             3   TGCATG
# ENSG00000044459.10_1_6_26925                            20   TGCATG
# ENSG00000165322.13_0_3_3223                              2   TGCATG
# ENSG00000183723.8_4_4_10406                              1   TGCATG
# ENSG00000075643.5_2_9_13643                              8   TGCATG
# ENSG00000010017.9_1_4_23623                             14   TGCATG
# ENSG00000123739.6_0_4_22244                              1   CGCATG
# ENSG00000158467.12_0_8_25683                             5   TGCATG
# ENSG00000149541.5_3_38_4630                              0   CGCATG
#
#                                                                                            Motif Name  \
# PositionID
# ENSG00000105983.14_4_9_26031                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000159720.7_1_9_10474                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000031823.10_5_29_14272                       1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000092439.9_0_9_8522                          1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000135476.7_11_8_6130                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000185483.7_1_5_1372                          1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000198952.6_4_13_2140                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000163931.11_5_15_21041                       1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000009954.6_2_7_25260                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000181220.11_5_5_25863                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000173818.12_5_18_13188                       1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000095787.16_7_5_3215                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000250337.1_0_4_22528                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000116604.12_0_15_2153                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000170776.15_2_3_8942                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000175115.7_2_11_4996                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000101190.8_1_7_18441                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000139131.8_0_13_5922                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000178234.8_1_6_25974                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000100764.9_0_3_8021                          1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000126106.9_1_4_1184                          1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000111358.9_7_35_6953                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000100852.8_2_9_7689                          1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000173757.4_1_4_12204                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000163867.11_1_7_939                          1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000134769.17_4_5_13613                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000136699.15_11_161_17020,ENSG00000136699...  1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000170085.13_2_13_23199                       1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000149548.10_2_21_5549                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000151576.6_0_6_21219                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ...                                                                                               ...
# ENSG00000139629.11_0_3_6093                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000204681.6_0_10_23721                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000204681.6_0_10_23721                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000164051.9_1_8_20653                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000011405.9_1_4_4273                          1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000160439.10_2_4_15951                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000160439.10_2_4_15951                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000108264.12_1_4_12015                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000225032.1_0_5_27493                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000060339.9_2_6_3325                          1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000106603.13_7_18_25057                       1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000103365.11_3_29_9942                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000076555.11_3_6_6574                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000007168.7_0_7_11161                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000082898.12_3_13_16511                       1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000173473.6_3_12_20611                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000119514.5_0_8_27309                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000119514.5_0_8_27309                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000165626.12_9_6_3154                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000082898.12_1_13_16509                       1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000114388.8_3_43_20856                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000154380.11_4_48_2657                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000044459.10_1_6_26925                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000165322.13_0_3_3223                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000183723.8_4_4_10406                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000075643.5_2_9_13643                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000010017.9_1_4_23623                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000123739.6_0_4_22244                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000158467.12_0_8_25683                        1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
# ENSG00000149541.5_3_38_4630                         1-TGCATG,BestGuess:A2BP1_ENSG00000078328_M298_...
#
#                                                    Strand  MotifScore  \
# PositionID
# ENSG00000105983.14_4_9_26031                            +    8.241931
# ENSG00000159720.7_1_9_10474                             +    8.241931
# ENSG00000031823.10_5_29_14272                           +    8.241931
# ENSG00000092439.9_0_9_8522                              +    8.241931
# ENSG00000135476.7_11_8_6130                             +    8.241931
# ENSG00000185483.7_1_5_1372                              +    8.241931
# ENSG00000198952.6_4_13_2140                             +    8.241931
# ENSG00000163931.11_5_15_21041                           +    8.241931
# ENSG00000009954.6_2_7_25260                             +    8.241931
# ENSG00000181220.11_5_5_25863                            +    5.438040
# ENSG00000173818.12_5_18_13188                           +    8.241931
# ENSG00000095787.16_7_5_3215                             +    8.241931
# ENSG00000250337.1_0_4_22528                             +    8.241931
# ENSG00000116604.12_0_15_2153                            +    8.241931
# ENSG00000170776.15_2_3_8942                             +    8.241931
# ENSG00000175115.7_2_11_4996                             +    8.241931
# ENSG00000101190.8_1_7_18441                             +    8.241931
# ENSG00000139131.8_0_13_5922                             +    8.241931
# ENSG00000178234.8_1_6_25974                             +    8.241931
# ENSG00000100764.9_0_3_8021                              +    8.241931
# ENSG00000126106.9_1_4_1184                              +    8.241931
# ENSG00000111358.9_7_35_6953                             +    8.241931
# ENSG00000100852.8_2_9_7689                              +    8.241931
# ENSG00000173757.4_1_4_12204                             +    8.241931
# ENSG00000163867.11_1_7_939                              +    8.241931
# ENSG00000134769.17_4_5_13613                            +    8.241931
# ENSG00000136699.15_11_161_17020,ENSG00000136699...      +    8.241931
# ENSG00000170085.13_2_13_23199                           +    8.241931
# ENSG00000149548.10_2_21_5549                            +    8.241931
# ENSG00000151576.6_0_6_21219                             +    8.241931
# ...                                                   ...         ...
# ENSG00000139629.11_0_3_6093                             +    8.241931
# ENSG00000204681.6_0_10_23721                            +    8.241931
# ENSG00000204681.6_0_10_23721                            +    8.241931
# ENSG00000164051.9_1_8_20653                             +    8.241931
# ENSG00000011405.9_1_4_4273                              +    8.241931
# ENSG00000160439.10_2_4_15951                            +    8.241931
# ENSG00000160439.10_2_4_15951                            +    8.241931
# ENSG00000108264.12_1_4_12015                            +    8.241931
# ENSG00000225032.1_0_5_27493                             +    8.241931
# ENSG00000060339.9_2_6_3325                              +    8.241931
# ENSG00000106603.13_7_18_25057                           +    8.241931
# ENSG00000103365.11_3_29_9942                            +    8.241931
# ENSG00000076555.11_3_6_6574                             +    8.241931
# ENSG00000007168.7_0_7_11161                             +    5.438040
# ENSG00000082898.12_3_13_16511                           +    8.241931
# ENSG00000173473.6_3_12_20611                            +    8.241931
# ENSG00000119514.5_0_8_27309                             +    8.241931
# ENSG00000119514.5_0_8_27309                             +    8.241931
# ENSG00000165626.12_9_6_3154                             +    8.241931
# ENSG00000082898.12_1_13_16509                           +    8.241931
# ENSG00000114388.8_3_43_20856                            +    8.241931
# ENSG00000154380.11_4_48_2657                            +    8.241931
# ENSG00000044459.10_1_6_26925                            +    8.241931
# ENSG00000165322.13_0_3_3223                             +    8.241931
# ENSG00000183723.8_4_4_10406                             +    8.241931
# ENSG00000075643.5_2_9_13643                             +    8.241931
# ENSG00000010017.9_1_4_23623                             +    8.241931
# ENSG00000123739.6_0_4_22244                             +    5.438040
# ENSG00000158467.12_0_8_25683                            +    8.241931
# ENSG00000149541.5_3_38_4630                             +    5.438040
#
#                                                    bound_in_same_strand
# PositionID
# ENSG00000105983.14_4_9_26031                                      False
# ENSG00000159720.7_1_9_10474                                       False
# ENSG00000031823.10_5_29_14272                                     False
# ENSG00000092439.9_0_9_8522                                        False
# ENSG00000135476.7_11_8_6130                                       False
# ENSG00000185483.7_1_5_1372                                        False
# ENSG00000198952.6_4_13_2140                                       False
# ENSG00000163931.11_5_15_21041                                     False
# ENSG00000009954.6_2_7_25260                                       False
# ENSG00000181220.11_5_5_25863                                      False
# ENSG00000173818.12_5_18_13188                                     False
# ENSG00000095787.16_7_5_3215                                       False
# ENSG00000250337.1_0_4_22528                                       False
# ENSG00000116604.12_0_15_2153                                      False
# ENSG00000170776.15_2_3_8942                                       False
# ENSG00000175115.7_2_11_4996                                       False
# ENSG00000101190.8_1_7_18441                                       False
# ENSG00000139131.8_0_13_5922                                       False
# ENSG00000178234.8_1_6_25974                                       False
# ENSG00000100764.9_0_3_8021                                        False
# ENSG00000126106.9_1_4_1184                                        False
# ENSG00000111358.9_7_35_6953                                       False
# ENSG00000100852.8_2_9_7689                                        False
# ENSG00000173757.4_1_4_12204                                       False
# ENSG00000163867.11_1_7_939                                        False
# ENSG00000134769.17_4_5_13613                                      False
# ENSG00000136699.15_11_161_17020,ENSG00000136699...                False
# ENSG00000170085.13_2_13_23199                                     False
# ENSG00000149548.10_2_21_5549                                      False
# ENSG00000151576.6_0_6_21219                                       False
# ...                                                                 ...
# ENSG00000139629.11_0_3_6093                                       False
# ENSG00000204681.6_0_10_23721                                      False
# ENSG00000204681.6_0_10_23721                                      False
# ENSG00000164051.9_1_8_20653                                       False
# ENSG00000011405.9_1_4_4273                                        False
# ENSG00000160439.10_2_4_15951                                      False
# ENSG00000160439.10_2_4_15951                                      False
# ENSG00000108264.12_1_4_12015                                      False
# ENSG00000225032.1_0_5_27493                                       False
# ENSG00000060339.9_2_6_3325                                        False
# ENSG00000106603.13_7_18_25057                                     False
# ENSG00000103365.11_3_29_9942                                      False
# ENSG00000076555.11_3_6_6574                                       False
# ENSG00000007168.7_0_7_11161                                       False
# ENSG00000082898.12_3_13_16511                                     False
# ENSG00000173473.6_3_12_20611                                      False
# ENSG00000119514.5_0_8_27309                                       False
# ENSG00000119514.5_0_8_27309                                       False
# ENSG00000165626.12_9_6_3154                                       False
# ENSG00000082898.12_1_13_16509                                     False
# ENSG00000114388.8_3_43_20856                                      False
# ENSG00000154380.11_4_48_2657                                      False
# ENSG00000044459.10_1_6_26925                                      False
# ENSG00000165322.13_0_3_3223                                       False
# ENSG00000183723.8_4_4_10406                                       False
# ENSG00000075643.5_2_9_13643                                       False
# ENSG00000010017.9_1_4_23623                                       False
# ENSG00000123739.6_0_4_22244                                       False
# ENSG00000158467.12_0_8_25683                                      False
# ENSG00000149541.5_3_38_4630                                       False
#
# [357 rows x 6 columns]

# %%
foo = pybedtools.BedTool(peaks_to_annotate[peak]).filter(lambda interval: not interval.name in set(annotated_peak_v2.index)).saveas()

# %%
fasta_sequence = pybedtools.BedTool(peaks_to_annotate[peak]).sequence(fi="/projects/ps-yeolab/genomes/hg19/chromosomes/all.fa", name=True, fo="foo.fasta", s=True)

# %%
found_motif = 0
found = set([])
for record in SeqIO.parse("foo.fasta", format="fasta"):
    if "CGCATG".lower() in record.seq.lower() or "TGCATG".lower() in record.seq.lower():
        found_motif += 1
        found.add(record.name)

# %%
real = pd.DataFrame(results).T

random = pd.concat([pd.DataFrame(results_rand_1).T, 
           pd.DataFrame(results_rand_2).T, 
           pd.DataFrame(results_rand_3).T,])

# %%
real.to_csv("/home/gpratt/Dropbox/encode_integration/for_eric/real_counts_v12.txt")

# %%
random.groupby(level=0).sum().to_csv("/home/gpratt/Dropbox/encode_integration/for_eric/random_counts_v12.txt")
