# %%
import os
import shutil

import pandas as pd
import functools
import pybedtools

# %%
submitted_datasets = pd.read_table("/home/elvannostrand/data/clip/CLIPseq_analysis/ENCODE_CLIPperv2_20161120/ALLDATASETS_submittedonly.txt")

# %%
# submitted_datasets.CLIP_rep1 = submitted_datasets.CLIP_rep1.apply(lambda x: x.replace("encode_v12", "encode_master"))
# submitted_datasets.CLIP_rep1 = submitted_datasets.CLIP_rep1.apply(lambda x: x.replace("encode_v13", "encode_master"))

# submitted_datasets.CLIP_rep2 = submitted_datasets.CLIP_rep2.apply(lambda x: x.replace("encode_v12", "encode_master"))
# submitted_datasets.CLIP_rep2 = submitted_datasets.CLIP_rep2.apply(lambda x: x.replace("encode_v13", "encode_master"))

# submitted_datasets.INPUT = submitted_datasets.INPUT.apply(lambda x: x.replace("encode_v12", "encode_master"))
# submitted_datasets.INPUT = submitted_datasets.INPUT.apply(lambda x: x.replace("encode_v13", "encode_master"))

# %%
narrow_peak_dir = "/home/elvannostrand/data/clip/CLIPseq_analysis/ENCODE_CLIPperv2_20161120/for_encode_submission"
high_confidence_peaks = "/home/gpratt/projects/encode/analysis/encode_high_confidence_peaks"
medium_confidence_peaks = "/home/gpratt/projects/encode/analysis/encode_meduim_confidence_peaks"

# %%
def get_peak_file(uID, rep):
    encode_id = "_".join([uID, rep])
    peak_file = os.path.join(narrow_peak_dir, "{0}.basedon_{0}.peaks.l2inputnormnew.bed.compressed.bed.narrowPeak.encode.bed.gz").format(encode_id)
    return peak_file

def stringent_filter_peak(row, from_file, rep):
    bedtool = pybedtools.BedTool(row[from_file])
    filtered_bed_file = os.path.join(high_confidence_peaks, os.path.basename(bedtool.fn))
    filtered_bed_file = os.path.splitext(filtered_bed_file)[0]
    bedtool.filter(lambda x: int(x[4]) == 1000).sort().saveas(filtered_bed_file)
    
    bb_file = "{}_{}_{}_uID{}.bb".format(row.RBP, row['Cell line'], rep, row.uID)
    bb_file = os.path.join(high_confidence_peaks, bb_file)
    # !bedToBigBed -type=bed6+4 $filtered_bed_file /projects/ps-yeolab/genomes/hg19/hg19.chrom.sizes $bb_file
    return bb_file

def medium_filter_peak(row, from_file, rep):
    bedtool = pybedtools.BedTool(row[from_file])
    filtered_bed_file = os.path.join(medium_confidence_peaks, os.path.basename(bedtool.fn))
    filtered_bed_file = os.path.splitext(filtered_bed_file)[0]
    bedtool.filter(lambda x: float(x[6]) > 0).sort().saveas(filtered_bed_file)
    
    bb_file = "{}_{}_{}_uID{}.bb".format(row.RBP, row['Cell line'], rep, row.uID)
    bb_file = os.path.join(medium_confidence_peaks, bb_file)

    # !bedToBigBed -type=bed6+4 $filtered_bed_file /projects/ps-yeolab/genomes/hg19/hg19.chrom.sizes $bb_file
    return bb_file

def copy_bw_file(row, out_dir, from_file, rep, strand):
    out_file = "{}_{}_{}_uID{}.{}.bw".format(row.RBP, row['Cell line'], rep, row.uID, strand)
    out_file = os.path.join(out_dir, out_file)
    shutil.copy(row[from_file], out_file)

# %%
rep1_func = functools.partial(get_peak_file, rep="01")
rep2_func = functools.partial(get_peak_file, rep="02")

high_confidence_bw = functools.partial(copy_bw_file, out_dir=high_confidence_peaks)
medium_confidence_bw = functools.partial(copy_bw_file, out_dir=medium_confidence_peaks)

bw_high_pos_rep1 = functools.partial(high_confidence_bw, rep="Rep1", strand="pos", from_file="CLIP_rep1_bw_pos")
bw_high_neg_rep1 = functools.partial(high_confidence_bw, rep="Rep1", strand="neg", from_file="CLIP_rep1_bw_neg")

bw_high_pos_rep2 = functools.partial(high_confidence_bw, rep="Rep2", strand="pos", from_file="CLIP_rep2_bw_pos")
bw_high_neg_rep2 = functools.partial(high_confidence_bw, rep="Rep2", strand="neg", from_file="CLIP_rep2_bw_neg")

bw_medium_pos_rep1 = functools.partial(medium_confidence_bw, rep="Rep1", strand="pos", from_file="CLIP_rep1_bw_pos")
bw_medium_neg_rep1 = functools.partial(medium_confidence_bw, rep="Rep1", strand="neg", from_file="CLIP_rep1_bw_neg")

bw_medium_pos_rep2 = functools.partial(medium_confidence_bw, rep="Rep2", strand="pos", from_file="CLIP_rep2_bw_pos")
bw_medium_neg_rep2 = functools.partial(medium_confidence_bw, rep="Rep2", strand="neg", from_file="CLIP_rep2_bw_neg")

bw_high_INPUT_pos = functools.partial(high_confidence_bw, rep="Input", strand="pos", from_file="INPUT_bw_pos")
bw_high_INPUT_neg = functools.partial(high_confidence_bw, rep="Input", strand="neg", from_file="INPUT_bw_neg")

bw_medium_INPUT_pos = functools.partial(medium_confidence_bw, rep="Input", strand="pos", from_file="INPUT_bw_pos")
bw_medium_INPUT_neg = functools.partial(medium_confidence_bw, rep="Input", strand="neg", from_file="INPUT_bw_neg")

# %%
submitted_datasets["CLIP_rep1_bw_pos"] = submitted_datasets.CLIP_rep1.apply(lambda x: x.replace(".bam", ".norm.pos.bw"))
submitted_datasets["CLIP_rep1_bw_neg"] = submitted_datasets.CLIP_rep1.apply(lambda x: x.replace(".bam", ".norm.neg.bw"))

submitted_datasets.apply(bw_high_pos_rep1, axis=1)
submitted_datasets.apply(bw_high_neg_rep1, axis=1)
submitted_datasets.apply(bw_medium_pos_rep1, axis=1)
submitted_datasets.apply(bw_medium_neg_rep1, axis=1)

submitted_datasets["CLIP_rep2_bw_pos"] = submitted_datasets.CLIP_rep2.apply(lambda x: x.replace(".bam", ".norm.pos.bw"))
submitted_datasets["CLIP_rep2_bw_neg"] = submitted_datasets.CLIP_rep2.apply(lambda x: x.replace(".bam", ".norm.neg.bw"))

submitted_datasets.apply(bw_high_pos_rep2, axis=1)
submitted_datasets.apply(bw_high_neg_rep2, axis=1)
submitted_datasets.apply(bw_medium_pos_rep2, axis=1)
submitted_datasets.apply(bw_medium_neg_rep2, axis=1)

submitted_datasets["INPUT_bw_pos"] = submitted_datasets.INPUT.apply(lambda x: x.replace(".bam", ".norm.pos.bw"))
submitted_datasets["INPUT_bw_neg"] = submitted_datasets.INPUT.apply(lambda x: x.replace(".bam", ".norm.neg.bw"))

submitted_datasets.apply(bw_high_INPUT_pos, axis=1)
submitted_datasets.apply(bw_high_INPUT_neg, axis=1)
submitted_datasets.apply(bw_medium_INPUT_pos, axis=1)
submitted_datasets.apply(bw_medium_INPUT_neg, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 151    None
# 152    None
# 153    None
# 154    None
# 155    None
# 156    None
# 157    None
# 158    None
# 159    None
# 160    None
# 161    None
# 162    None
# 163    None
# 164    None
# 165    None
# 166    None
# 167    None
# 168    None
# 169    None
# 170    None
# 171    None
# 172    None
# 173    None
# 174    None
# 175    None
# 176    None
# 177    None
# 178    None
# 179    None
# 180    None
# dtype: object

# %%
submitted_datasets['CLIP_rep1_peak'] = submitted_datasets.uID.apply(rep1_func)
submitted_datasets['CLIP_rep2_peak'] = submitted_datasets.uID.apply(rep2_func)

stringent_filter_peak_rep1 = functools.partial(stringent_filter_peak, from_file="CLIP_rep1_peak", rep="Rep1")
stringent_filter_peak_rep2 = functools.partial(stringent_filter_peak, from_file="CLIP_rep2_peak", rep="Rep2")

submitted_datasets['CLIP_rep1_peak_bb'] = submitted_datasets.apply(stringent_filter_peak_rep1, axis=1)
submitted_datasets['CLIP_rep2_peak_bb'] = submitted_datasets.apply(stringent_filter_peak_rep2, axis=1)

medium_filter_peak_rep1 = functools.partial(medium_filter_peak, from_file="CLIP_rep1_peak", rep="Rep1")
medium_filter_peak_rep2 = functools.partial(medium_filter_peak, from_file="CLIP_rep2_peak", rep="Rep2")

submitted_datasets['CLIP_rep1_peak_bb'] = submitted_datasets.apply(medium_filter_peak_rep1, axis=1)
submitted_datasets['CLIP_rep2_peak_bb'] = submitted_datasets.apply(medium_filter_peak_rep2, axis=1)
# Out:
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (5547 records, 10 fields): 28 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (10221 records, 10 fields): 62 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (5316 records, 10 fields): 27 millis
# pass1 - making usageList (25 chroms): 3 millis
# pass2 - checking and writing primary data (7661 records, 10 fields): 37 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1772 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (3002 records, 10 fields): 14 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1735 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (1774 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 11 millis
# pass2 - checking and writing primary data (2010 records, 10 fields): 17 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (11517 records, 10 fields): 57 millis
# pass1 - making usageList (24 chroms): 11 millis
# pass2 - checking and writing primary data (20381 records, 10 fields): 95 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (3319 records, 10 fields): 12 millis
# pass1 - making usageList (23 chroms): 5 millis
# pass2 - checking and writing primary data (11323 records, 10 fields): 54 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (7485 records, 10 fields): 43 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (4072 records, 10 fields): 24 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (7846 records, 10 fields): 36 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (1331 records, 10 fields): 9 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (8207 records, 10 fields): 44 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (11272 records, 10 fields): 59 millis
# pass1 - making usageList (23 chroms): 8 millis
# pass2 - checking and writing primary data (3588 records, 10 fields): 24 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (660 records, 10 fields): 8 millis
# pass1 - making usageList (23 chroms): 5 millis
# pass2 - checking and writing primary data (4949 records, 10 fields): 30 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (613 records, 10 fields): 7 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (2247 records, 10 fields): 11 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (2183 records, 10 fields): 11 millis
# pass1 - making usageList (20 chroms): 1 millis
# pass2 - checking and writing primary data (71 records, 10 fields): 6 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (354 records, 10 fields): 6 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (498 records, 10 fields): 6 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (4719 records, 10 fields): 26 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (778 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6411 records, 10 fields): 37 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (449 records, 10 fields): 7 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (5328 records, 10 fields): 24 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (17709 records, 10 fields): 91 millis
# pass1 - making usageList (23 chroms): 4 millis
# pass2 - checking and writing primary data (12706 records, 10 fields): 61 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (14303 records, 10 fields): 71 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (8177 records, 10 fields): 39 millis
# pass1 - making usageList (15 chroms): 5 millis
# pass2 - checking and writing primary data (43 records, 10 fields): 5 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (322 records, 10 fields): 7 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1597 records, 10 fields): 10 millis
# pass1 - making usageList (22 chroms): 2 millis
# pass2 - checking and writing primary data (146 records, 10 fields): 19 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (369 records, 10 fields): 6 millis
# pass1 - making usageList (24 chroms): 10 millis
# pass2 - checking and writing primary data (30542 records, 10 fields): 111 millis
# pass1 - making usageList (24 chroms): 9 millis
# pass2 - checking and writing primary data (24091 records, 10 fields): 132 millis
# pass1 - making usageList (23 chroms): 4 millis
# pass2 - checking and writing primary data (13244 records, 10 fields): 77 millis
# pass1 - making usageList (25 chroms): 4 millis
# pass2 - checking and writing primary data (667 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (1992 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (7478 records, 10 fields): 38 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (408 records, 10 fields): 7 millis
# pass1 - making usageList (23 chroms): 4 millis
# pass2 - checking and writing primary data (3741 records, 10 fields): 17 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1309 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (6993 records, 10 fields): 35 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1501 records, 10 fields): 9 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (7280 records, 10 fields): 46 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4037 records, 10 fields): 15 millis
# pass1 - making usageList (23 chroms): 6 millis
# pass2 - checking and writing primary data (2487 records, 10 fields): 12 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (524 records, 10 fields): 6 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (5328 records, 10 fields): 28 millis
# pass1 - making usageList (23 chroms): 4 millis
# pass2 - checking and writing primary data (1304 records, 10 fields): 9 millis
# pass1 - making usageList (23 chroms): 6 millis
# pass2 - checking and writing primary data (7720 records, 10 fields): 36 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (1858 records, 10 fields): 10 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (7780 records, 10 fields): 46 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (857 records, 10 fields): 7 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (16731 records, 10 fields): 96 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (6147 records, 10 fields): 41 millis
# pass1 - making usageList (15 chroms): 1 millis
# pass2 - checking and writing primary data (49 records, 10 fields): 5 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (1908 records, 10 fields): 9 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (492 records, 10 fields): 7 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (357 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (3101 records, 10 fields): 14 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (1684 records, 10 fields): 10 millis
# pass1 - making usageList (23 chroms): 12 millis
# pass2 - checking and writing primary data (9978 records, 10 fields): 50 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1076 records, 10 fields): 8 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (2134 records, 10 fields): 12 millis
# pass1 - making usageList (23 chroms): 8 millis
# pass2 - checking and writing primary data (7779 records, 10 fields): 37 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (5903 records, 10 fields): 33 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (841 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (8514 records, 10 fields): 41 millis
# pass1 - making usageList (23 chroms): 10 millis
# pass2 - checking and writing primary data (13895 records, 10 fields): 70 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (1128 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (4788 records, 10 fields): 30 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (209 records, 10 fields): 5 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (3651 records, 10 fields): 14 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (5982 records, 10 fields): 29 millis
# pass1 - making usageList (23 chroms): 21 millis
# pass2 - checking and writing primary data (32398 records, 10 fields): 160 millis
# pass1 - making usageList (23 chroms): 4 millis
# pass2 - checking and writing primary data (13599 records, 10 fields): 74 millis
# pass1 - making usageList (25 chroms): 9 millis
# pass2 - checking and writing primary data (14141 records, 10 fields): 73 millis
# pass1 - making usageList (24 chroms): 9 millis
# pass2 - checking and writing primary data (2799 records, 10 fields): 12 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (5013 records, 10 fields): 18 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (659 records, 10 fields): 7 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6224 records, 10 fields): 29 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (270 records, 10 fields): 7 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (2716 records, 10 fields): 12 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (1168 records, 10 fields): 9 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (1803 records, 10 fields): 10 millis
# pass1 - making usageList (25 chroms): 6 millis
# pass2 - checking and writing primary data (16836 records, 10 fields): 95 millis
# pass1 - making usageList (24 chroms): 13 millis
# pass2 - checking and writing primary data (4914 records, 10 fields): 24 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1857 records, 10 fields): 13 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (3803 records, 10 fields): 22 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (15747 records, 10 fields): 70 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (2208 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (11389 records, 10 fields): 58 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (21116 records, 10 fields): 109 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (173 records, 10 fields): 6 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (17460 records, 10 fields): 73 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (5660 records, 10 fields): 25 millis
# pass1 - making usageList (25 chroms): 12 millis
# pass2 - checking and writing primary data (26014 records, 10 fields): 129 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (10391 records, 10 fields): 35 millis
# pass1 - making usageList (24 chroms): 10 millis
# pass2 - checking and writing primary data (30730 records, 10 fields): 95 millis
# pass1 - making usageList (23 chroms): 6 millis
# pass2 - checking and writing primary data (19124 records, 10 fields): 100 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (10570 records, 10 fields): 52 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (4399 records, 10 fields): 27 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (10006 records, 10 fields): 30 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (2537 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (8521 records, 10 fields): 38 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4936 records, 10 fields): 18 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (992 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 10 millis
# pass2 - checking and writing primary data (12099 records, 10 fields): 66 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4884 records, 10 fields): 40 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (3632 records, 10 fields): 22 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (6325 records, 10 fields): 32 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (5293 records, 10 fields): 34 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (2162 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (3048 records, 10 fields): 12 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (6001 records, 10 fields): 33 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (5606 records, 10 fields): 29 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1362 records, 10 fields): 9 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4862 records, 10 fields): 43 millis
# pass1 - making usageList (24 chroms): 9 millis
# pass2 - checking and writing primary data (16752 records, 10 fields): 74 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (546 records, 10 fields): 7 millis
# pass1 - making usageList (25 chroms): 1 millis
# pass2 - checking and writing primary data (404 records, 10 fields): 7 millis
# pass1 - making usageList (25 chroms): 2 millis
# pass2 - checking and writing primary data (313 records, 10 fields): 7 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (752 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (3407 records, 10 fields): 14 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (5852 records, 10 fields): 29 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (12998 records, 10 fields): 62 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (4155 records, 10 fields): 22 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (4655 records, 10 fields): 29 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1054 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (290 records, 10 fields): 7 millis
# pass1 - making usageList (25 chroms): 7 millis
# pass2 - checking and writing primary data (29136 records, 10 fields): 128 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (7675 records, 10 fields): 27 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (1650 records, 10 fields): 9 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (21719 records, 10 fields): 73 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (25964 records, 10 fields): 145 millis
# pass1 - making usageList (25 chroms): 6 millis
# pass2 - checking and writing primary data (1444 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (2906 records, 10 fields): 13 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (1830 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 10 millis
# pass2 - checking and writing primary data (6754 records, 10 fields): 32 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (18940 records, 10 fields): 97 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (4170 records, 10 fields): 26 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (3224 records, 10 fields): 13 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (12634 records, 10 fields): 56 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (19222 records, 10 fields): 105 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (2448 records, 10 fields): 12 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (22451 records, 10 fields): 111 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (3168 records, 10 fields): 17 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1618 records, 10 fields): 10 millis
# pass1 - making usageList (25 chroms): 3 millis
# pass2 - checking and writing primary data (7789 records, 10 fields): 38 millis
# pass1 - making usageList (25 chroms): 14 millis
# pass2 - checking and writing primary data (4350 records, 10 fields): 18 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (3641 records, 10 fields): 25 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (3052 records, 10 fields): 13 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (3976 records, 10 fields): 28 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (21301 records, 10 fields): 107 millis
# pass1 - making usageList (23 chroms): 5 millis
# pass2 - checking and writing primary data (6088 records, 10 fields): 36 millis
# pass1 - making usageList (25 chroms): 2 millis
# pass2 - checking and writing primary data (3604 records, 10 fields): 14 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (2187 records, 10 fields): 21 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (20500 records, 10 fields): 102 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (543 records, 10 fields): 8 millis
# pass1 - making usageList (25 chroms): 3 millis
# pass2 - checking and writing primary data (7059 records, 10 fields): 36 millis
# pass1 - making usageList (23 chroms): 7 millis
# pass2 - checking and writing primary data (5998 records, 10 fields): 31 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (695 records, 10 fields): 7 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (4231 records, 10 fields): 16 millis
# pass1 - making usageList (25 chroms): 4 millis
# pass2 - checking and writing primary data (12199 records, 10 fields): 72 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (16218 records, 10 fields): 90 millis
# pass1 - making usageList (24 chroms): 9 millis
# pass2 - checking and writing primary data (5293 records, 10 fields): 19 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (4017 records, 10 fields): 18 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (5075 records, 10 fields): 28 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (1689 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (19616 records, 10 fields): 66 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (14681 records, 10 fields): 73 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6713 records, 10 fields): 35 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (9562 records, 10 fields): 54 millis
# pass1 - making usageList (25 chroms): 4 millis
# pass2 - checking and writing primary data (6841 records, 10 fields): 36 millis
# pass1 - making usageList (25 chroms): 7 millis
# pass2 - checking and writing primary data (6402 records, 10 fields): 33 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (862 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 9 millis
# pass2 - checking and writing primary data (3088 records, 10 fields): 13 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4225 records, 10 fields): 17 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (1156 records, 10 fields): 9 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (1566 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (7611 records, 10 fields): 46 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (20074 records, 10 fields): 97 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (3265 records, 10 fields): 16 millis
# pass1 - making usageList (23 chroms): 4 millis
# pass2 - checking and writing primary data (12260 records, 10 fields): 76 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (4910 records, 10 fields): 33 millis
# pass1 - making usageList (23 chroms): 7 millis
# pass2 - checking and writing primary data (10192 records, 10 fields): 51 millis
# pass1 - making usageList (25 chroms): 4 millis
# pass2 - checking and writing primary data (9615 records, 10 fields): 48 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (566 records, 10 fields): 10 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (10894 records, 10 fields): 57 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (9719 records, 10 fields): 53 millis
# pass1 - making usageList (23 chroms): 4 millis
# pass2 - checking and writing primary data (1747 records, 10 fields): 10 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (1253 records, 10 fields): 9 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (5307 records, 10 fields): 19 millis
# pass1 - making usageList (24 chroms): 11 millis
# pass2 - checking and writing primary data (567 records, 10 fields): 8 millis
# pass1 - making usageList (23 chroms): 8 millis
# pass2 - checking and writing primary data (2002 records, 10 fields): 14 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (4531 records, 10 fields): 19 millis
# pass1 - making usageList (22 chroms): 1 millis
# pass2 - checking and writing primary data (106 records, 10 fields): 9 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (257 records, 10 fields): 9 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (267 records, 10 fields): 6 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (8450 records, 10 fields): 48 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (1381 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (8609 records, 10 fields): 40 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (275 records, 10 fields): 7 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (4606 records, 10 fields): 16 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (15395 records, 10 fields): 83 millis
# pass1 - making usageList (23 chroms): 6 millis
# pass2 - checking and writing primary data (14111 records, 10 fields): 71 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (17326 records, 10 fields): 92 millis
# pass1 - making usageList (25 chroms): 3 millis
# pass2 - checking and writing primary data (10224 records, 10 fields): 62 millis
# pass1 - making usageList (21 chroms): 2 millis
# pass2 - checking and writing primary data (104 records, 10 fields): 5 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (1223 records, 10 fields): 16 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (1887 records, 10 fields): 11 millis
# pass1 - making usageList (19 chroms): 2 millis
# pass2 - checking and writing primary data (175 records, 10 fields): 5 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (255 records, 10 fields): 6 millis
# pass1 - making usageList (24 chroms): 12 millis
# pass2 - checking and writing primary data (48173 records, 10 fields): 260 millis
# pass1 - making usageList (23 chroms): 7 millis
# pass2 - checking and writing primary data (27621 records, 10 fields): 88 millis
# pass1 - making usageList (23 chroms): 5 millis
# pass2 - checking and writing primary data (19154 records, 10 fields): 97 millis
# pass1 - making usageList (25 chroms): 9 millis
# pass2 - checking and writing primary data (2014 records, 10 fields): 11 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (3399 records, 10 fields): 14 millis
# pass1 - making usageList (24 chroms): 14 millis
# pass2 - checking and writing primary data (10042 records, 10 fields): 61 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (663 records, 10 fields): 7 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (3410 records, 10 fields): 14 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4328 records, 10 fields): 17 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (5016 records, 10 fields): 30 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (2201 records, 10 fields): 11 millis
# pass1 - making usageList (23 chroms): 9 millis
# pass2 - checking and writing primary data (9872 records, 10 fields): 52 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4600 records, 10 fields): 27 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (4695 records, 10 fields): 31 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1844 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (3320 records, 10 fields): 13 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (1164 records, 10 fields): 8 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (9082 records, 10 fields): 54 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (1944 records, 10 fields): 11 millis
# pass1 - making usageList (23 chroms): 4 millis
# pass2 - checking and writing primary data (8751 records, 10 fields): 38 millis
# pass1 - making usageList (25 chroms): 2 millis
# pass2 - checking and writing primary data (3111 records, 10 fields): 14 millis
# pass1 - making usageList (24 chroms): 9 millis
# pass2 - checking and writing primary data (18602 records, 10 fields): 91 millis
# pass1 - making usageList (25 chroms): 9 millis
# pass2 - checking and writing primary data (14586 records, 10 fields): 83 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (139 records, 10 fields): 6 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1783 records, 10 fields): 10 millis
# pass1 - making usageList (23 chroms): 4 millis
# pass2 - checking and writing primary data (120 records, 10 fields): 5 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (477 records, 10 fields): 6 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4139 records, 10 fields): 17 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (1413 records, 10 fields): 10 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (11963 records, 10 fields): 64 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (475 records, 10 fields): 7 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (3928 records, 10 fields): 16 millis
# pass1 - making usageList (23 chroms): 8 millis
# pass2 - checking and writing primary data (7104 records, 10 fields): 34 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4360 records, 10 fields): 17 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (2171 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (14553 records, 10 fields): 72 millis
# pass1 - making usageList (23 chroms): 8 millis
# pass2 - checking and writing primary data (18739 records, 10 fields): 92 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (697 records, 10 fields): 10 millis
# pass1 - making usageList (25 chroms): 6 millis
# pass2 - checking and writing primary data (5667 records, 10 fields): 20 millis
# pass1 - making usageList (22 chroms): 1 millis
# pass2 - checking and writing primary data (189 records, 10 fields): 5 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6523 records, 10 fields): 27 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (5849 records, 10 fields): 29 millis
# pass1 - making usageList (23 chroms): 7 millis
# pass2 - checking and writing primary data (22689 records, 10 fields): 115 millis
# pass1 - making usageList (23 chroms): 6 millis
# pass2 - checking and writing primary data (14024 records, 10 fields): 73 millis
# pass1 - making usageList (25 chroms): 3 millis
# pass2 - checking and writing primary data (8484 records, 10 fields): 46 millis
# pass1 - making usageList (23 chroms): 5 millis
# pass2 - checking and writing primary data (4987 records, 10 fields): 27 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (4926 records, 10 fields): 18 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (996 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (3919 records, 10 fields): 15 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (373 records, 10 fields): 7 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (3093 records, 10 fields): 13 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6473 records, 10 fields): 33 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (1959 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 9 millis
# pass2 - checking and writing primary data (16472 records, 10 fields): 90 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (5431 records, 10 fields): 28 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (2667 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (6433 records, 10 fields): 22 millis
# pass1 - making usageList (25 chroms): 6 millis
# pass2 - checking and writing primary data (13672 records, 10 fields): 72 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (2351 records, 10 fields): 12 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (8362 records, 10 fields): 38 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (24906 records, 10 fields): 102 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (420 records, 10 fields): 6 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (11531 records, 10 fields): 56 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (5111 records, 10 fields): 18 millis
# pass1 - making usageList (25 chroms): 20 millis
# pass2 - checking and writing primary data (37044 records, 10 fields): 185 millis
# pass1 - making usageList (25 chroms): 9 millis
# pass2 - checking and writing primary data (28032 records, 10 fields): 143 millis
# pass1 - making usageList (24 chroms): 11 millis
# pass2 - checking and writing primary data (42759 records, 10 fields): 194 millis
# pass1 - making usageList (23 chroms): 6 millis
# pass2 - checking and writing primary data (21571 records, 10 fields): 111 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (13951 records, 10 fields): 75 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6391 records, 10 fields): 29 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (15780 records, 10 fields): 75 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (1917 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (9806 records, 10 fields): 52 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (10864 records, 10 fields): 56 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (3396 records, 10 fields): 14 millis
# pass1 - making usageList (23 chroms): 5 millis
# pass2 - checking and writing primary data (11456 records, 10 fields): 56 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (7070 records, 10 fields): 35 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (7601 records, 10 fields): 36 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6855 records, 10 fields): 30 millis
# pass1 - making usageList (25 chroms): 4 millis
# pass2 - checking and writing primary data (5741 records, 10 fields): 29 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (2692 records, 10 fields): 12 millis
# pass1 - making usageList (25 chroms): 2 millis
# pass2 - checking and writing primary data (3782 records, 10 fields): 13 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (8299 records, 10 fields): 39 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (8100 records, 10 fields): 37 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (1161 records, 10 fields): 9 millis
# pass1 - making usageList (25 chroms): 3 millis
# pass2 - checking and writing primary data (5694 records, 10 fields): 19 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (14671 records, 10 fields): 62 millis
# pass1 - making usageList (25 chroms): 3 millis
# pass2 - checking and writing primary data (4314 records, 10 fields): 16 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (2398 records, 10 fields): 12 millis
# pass1 - making usageList (25 chroms): 2 millis
# pass2 - checking and writing primary data (173 records, 10 fields): 6 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (846 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 9 millis
# pass2 - checking and writing primary data (2530 records, 10 fields): 12 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (4516 records, 10 fields): 19 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (15633 records, 10 fields): 79 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (3198 records, 10 fields): 14 millis
# pass1 - making usageList (25 chroms): 3 millis
# pass2 - checking and writing primary data (5820 records, 10 fields): 26 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1842 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (498 records, 10 fields): 8 millis
# pass1 - making usageList (25 chroms): 6 millis
# pass2 - checking and writing primary data (5509 records, 10 fields): 29 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (7855 records, 10 fields): 37 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (2689 records, 10 fields): 12 millis
# pass1 - making usageList (24 chroms): 10 millis
# pass2 - checking and writing primary data (33691 records, 10 fields): 190 millis
# pass1 - making usageList (24 chroms): 8 millis
# pass2 - checking and writing primary data (28294 records, 10 fields): 147 millis
# pass1 - making usageList (25 chroms): 2 millis
# pass2 - checking and writing primary data (1872 records, 10 fields): 13 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (7266 records, 10 fields): 52 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (1054 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (4839 records, 10 fields): 27 millis
# pass1 - making usageList (25 chroms): 6 millis
# pass2 - checking and writing primary data (18813 records, 10 fields): 96 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (1059 records, 10 fields): 8 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (5002 records, 10 fields): 18 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (5504 records, 10 fields): 29 millis
# pass1 - making usageList (24 chroms): 7 millis
# pass2 - checking and writing primary data (20626 records, 10 fields): 116 millis
# pass1 - making usageList (24 chroms): 9 millis
# pass2 - checking and writing primary data (3747 records, 10 fields): 26 millis
# pass1 - making usageList (24 chroms): 13 millis
# pass2 - checking and writing primary data (31452 records, 10 fields): 141 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (14823 records, 10 fields): 74 millis
# pass1 - making usageList (23 chroms): 3 millis
# pass2 - checking and writing primary data (2542 records, 10 fields): 11 millis
# pass1 - making usageList (25 chroms): 4 millis
# pass2 - checking and writing primary data (7782 records, 10 fields): 45 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (8254 records, 10 fields): 33 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (3896 records, 10 fields): 15 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (5072 records, 10 fields): 33 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (2781 records, 10 fields): 12 millis
# pass1 - making usageList (24 chroms): 12 millis
# pass2 - checking and writing primary data (26007 records, 10 fields): 117 millis
# pass1 - making usageList (23 chroms): 10 millis
# pass2 - checking and writing primary data (7090 records, 10 fields): 33 millis
# pass1 - making usageList (25 chroms): 2 millis
# pass2 - checking and writing primary data (2501 records, 10 fields): 12 millis
# pass1 - making usageList (24 chroms): 6 millis
# pass2 - checking and writing primary data (1833 records, 10 fields): 10 millis
# pass1 - making usageList (25 chroms): 4 millis
# pass2 - checking and writing primary data (17754 records, 10 fields): 49 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (580 records, 10 fields): 9 millis
# pass1 - making usageList (25 chroms): 3 millis
# pass2 - checking and writing primary data (7270 records, 10 fields): 23 millis
# pass1 - making usageList (23 chroms): 2 millis
# pass2 - checking and writing primary data (4543 records, 10 fields): 16 millis
# pass1 - making usageList (21 chroms): 2 millis
# pass2 - checking and writing primary data (158 records, 10 fields): 5 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6700 records, 10 fields): 21 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (8006 records, 10 fields): 25 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (12580 records, 10 fields): 37 millis
# pass1 - making usageList (25 chroms): 2 millis
# pass2 - checking and writing primary data (5303 records, 10 fields): 23 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6431 records, 10 fields): 20 millis
# pass1 - making usageList (24 chroms): 2 millis
# pass2 - checking and writing primary data (3767 records, 10 fields): 15 millis
# pass1 - making usageList (24 chroms): 1 millis
# pass2 - checking and writing primary data (1145 records, 10 fields): 11 millis
# pass1 - making usageList (24 chroms): 4 millis
# pass2 - checking and writing primary data (10056 records, 10 fields): 28 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (9315 records, 10 fields): 28 millis
# pass1 - making usageList (24 chroms): 224 millis
# pass2 - checking and writing primary data (511767 records, 10 fields): 2177 millis
# pass1 - making usageList (24 chroms): 53 millis
# pass2 - checking and writing primary data (127487 records, 10 fields): 590 millis
# pass1 - making usageList (25 chroms): 31 millis
# pass2 - checking and writing primary data (87871 records, 10 fields): 371 millis
# pass1 - making usageList (25 chroms): 60 millis
# pass2 - checking and writing primary data (141872 records, 10 fields): 614 millis
# pass1 - making usageList (24 chroms): 30 millis
# pass2 - checking and writing primary data (78849 records, 10 fields): 356 millis
# pass1 - making usageList (25 chroms): 31 millis
# pass2 - checking and writing primary data (93172 records, 10 fields): 392 millis
# pass1 - making usageList (25 chroms): 52 millis
# pass2 - checking and writing primary data (132146 records, 10 fields): 543 millis
# pass1 - making usageList (24 chroms): 24 millis
# pass2 - checking and writing primary data (107321 records, 10 fields): 431 millis
# pass1 - making usageList (25 chroms): 8 millis
# pass2 - checking and writing primary data (28305 records, 10 fields): 114 millis
# pass1 - making usageList (25 chroms): 51 millis
# pass2 - checking and writing primary data (88611 records, 10 fields): 382 millis
# pass1 - making usageList (24 chroms): 84 millis
# pass2 - checking and writing primary data (204586 records, 10 fields): 840 millis
# pass1 - making usageList (25 chroms): 23 millis
# pass2 - checking and writing primary data (39682 records, 10 fields): 179 millis
# pass1 - making usageList (25 chroms): 50 millis
# pass2 - checking and writing primary data (122471 records, 10 fields): 533 millis
# pass1 - making usageList (25 chroms): 31 millis
# pass2 - checking and writing primary data (83762 records, 10 fields): 418 millis
# pass1 - making usageList (25 chroms): 14 millis
# pass2 - checking and writing primary data (60573 records, 10 fields): 241 millis
# pass1 - making usageList (25 chroms): 15 millis
# pass2 - checking and writing primary data (63042 records, 10 fields): 270 millis
# pass1 - making usageList (25 chroms): 34 millis
# pass2 - checking and writing primary data (77426 records, 10 fields): 328 millis
# pass1 - making usageList (24 chroms): 15 millis
# pass2 - checking and writing primary data (66101 records, 10 fields): 309 millis
# pass1 - making usageList (25 chroms): 29 millis
# ...
# pass1 - making usageList (25 chroms): 29 millis
# pass2 - checking and writing primary data (131515 records, 10 fields): 281 millis
# pass1 - making usageList (25 chroms): 21 millis
# pass2 - checking and writing primary data (90938 records, 10 fields): 215 millis
# pass1 - making usageList (25 chroms): 14 millis
# pass2 - checking and writing primary data (53932 records, 10 fields): 124 millis
# pass1 - making usageList (25 chroms): 16 millis
# pass2 - checking and writing primary data (71433 records, 10 fields): 168 millis
# pass1 - making usageList (25 chroms): 15 millis
# pass2 - checking and writing primary data (60877 records, 10 fields): 139 millis
# pass1 - making usageList (25 chroms): 28 millis
# pass2 - checking and writing primary data (115846 records, 10 fields): 276 millis
# pass1 - making usageList (25 chroms): 14 millis
# pass2 - checking and writing primary data (55858 records, 10 fields): 153 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (6593 records, 10 fields): 26 millis
# pass1 - making usageList (25 chroms): 62 millis
# pass2 - checking and writing primary data (272947 records, 10 fields): 565 millis
# pass1 - making usageList (25 chroms): 7 millis
# pass2 - checking and writing primary data (27763 records, 10 fields): 68 millis
# pass1 - making usageList (24 chroms): 13 millis
# pass2 - checking and writing primary data (50566 records, 10 fields): 120 millis
# pass1 - making usageList (24 chroms): 15 millis
# pass2 - checking and writing primary data (60725 records, 10 fields): 151 millis
# pass1 - making usageList (24 chroms): 11 millis
# pass2 - checking and writing primary data (44955 records, 10 fields): 101 millis
# pass1 - making usageList (25 chroms): 26 millis
# pass2 - checking and writing primary data (109563 records, 10 fields): 260 millis
# pass1 - making usageList (25 chroms): 17 millis
# pass2 - checking and writing primary data (73316 records, 10 fields): 161 millis
# pass1 - making usageList (25 chroms): 31 millis
# pass2 - checking and writing primary data (138184 records, 10 fields): 307 millis
# pass1 - making usageList (25 chroms): 30 millis
# pass2 - checking and writing primary data (124423 records, 10 fields): 277 millis
# pass1 - making usageList (25 chroms): 12 millis
# pass2 - checking and writing primary data (51579 records, 10 fields): 128 millis
# pass1 - making usageList (25 chroms): 66 millis
# pass2 - checking and writing primary data (289413 records, 10 fields): 607 millis
# pass1 - making usageList (25 chroms): 14 millis
# pass2 - checking and writing primary data (56770 records, 10 fields): 142 millis
# pass1 - making usageList (25 chroms): 35 millis
# pass2 - checking and writing primary data (156567 records, 10 fields): 349 millis
# pass1 - making usageList (25 chroms): 27 millis
# pass2 - checking and writing primary data (119118 records, 10 fields): 246 millis
# pass1 - making usageList (25 chroms): 14 millis
# pass2 - checking and writing primary data (56291 records, 10 fields): 139 millis
# pass1 - making usageList (25 chroms): 36 millis
# pass2 - checking and writing primary data (158870 records, 10 fields): 318 millis
# pass1 - making usageList (25 chroms): 25 millis
# pass2 - checking and writing primary data (107354 records, 10 fields): 254 millis
# pass1 - making usageList (25 chroms): 29 millis
# pass2 - checking and writing primary data (124471 records, 10 fields): 278 millis
# pass1 - making usageList (25 chroms): 75 millis
# pass2 - checking and writing primary data (332040 records, 10 fields): 773 millis
# pass1 - making usageList (24 chroms): 48 millis
# pass2 - checking and writing primary data (74964 records, 10 fields): 261 millis
# pass1 - making usageList (25 chroms): 20 millis
# pass2 - checking and writing primary data (82980 records, 10 fields): 206 millis
# pass1 - making usageList (25 chroms): 30 millis
# pass2 - checking and writing primary data (130253 records, 10 fields): 300 millis
# pass1 - making usageList (25 chroms): 21 millis
# pass2 - checking and writing primary data (89839 records, 10 fields): 205 millis
# pass1 - making usageList (25 chroms): 25 millis
# pass2 - checking and writing primary data (106925 records, 10 fields): 244 millis
# pass1 - making usageList (25 chroms): 25 millis
# pass2 - checking and writing primary data (105879 records, 10 fields): 246 millis
# pass1 - making usageList (25 chroms): 2 millis
# pass2 - checking and writing primary data (4463 records, 10 fields): 19 millis
# pass1 - making usageList (25 chroms): 20 millis
# pass2 - checking and writing primary data (86983 records, 10 fields): 204 millis
# pass1 - making usageList (24 chroms): 26 millis
# pass2 - checking and writing primary data (110500 records, 10 fields): 247 millis
# pass1 - making usageList (25 chroms): 24 millis
# pass2 - checking and writing primary data (98602 records, 10 fields): 221 millis
# pass1 - making usageList (25 chroms): 22 millis
# pass2 - checking and writing primary data (90748 records, 10 fields): 228 millis
# pass1 - making usageList (25 chroms): 15 millis
# pass2 - checking and writing primary data (64082 records, 10 fields): 149 millis
# pass1 - making usageList (25 chroms): 34 millis
# pass2 - checking and writing primary data (146754 records, 10 fields): 347 millis
# pass1 - making usageList (25 chroms): 39 millis
# pass2 - checking and writing primary data (166118 records, 10 fields): 372 millis
# pass1 - making usageList (25 chroms): 41 millis
# pass2 - checking and writing primary data (181966 records, 10 fields): 397 millis
# pass1 - making usageList (25 chroms): 25 millis
# pass2 - checking and writing primary data (106421 records, 10 fields): 252 millis
# pass1 - making usageList (25 chroms): 36 millis
# pass2 - checking and writing primary data (160808 records, 10 fields): 385 millis
# pass1 - making usageList (25 chroms): 24 millis
# pass2 - checking and writing primary data (79148 records, 10 fields): 268 millis
# pass1 - making usageList (25 chroms): 30 millis
# pass2 - checking and writing primary data (123695 records, 10 fields): 274 millis
# pass1 - making usageList (25 chroms): 12 millis
# pass2 - checking and writing primary data (52628 records, 10 fields): 138 millis
# pass1 - making usageList (25 chroms): 44 millis
# pass2 - checking and writing primary data (189321 records, 10 fields): 438 millis
# pass1 - making usageList (25 chroms): 34 millis
# pass2 - checking and writing primary data (152878 records, 10 fields): 397 millis
# pass1 - making usageList (25 chroms): 36 millis
# pass2 - checking and writing primary data (153276 records, 10 fields): 400 millis
# pass1 - making usageList (24 chroms): 13 millis
# pass2 - checking and writing primary data (56632 records, 10 fields): 133 millis
# pass1 - making usageList (25 chroms): 22 millis
# pass2 - checking and writing primary data (93617 records, 10 fields): 231 millis
# pass1 - making usageList (25 chroms): 40 millis
# pass2 - checking and writing primary data (174563 records, 10 fields): 439 millis
# pass1 - making usageList (25 chroms): 19 millis
# pass2 - checking and writing primary data (82141 records, 10 fields): 201 millis
# pass1 - making usageList (25 chroms): 38 millis
# pass2 - checking and writing primary data (164217 records, 10 fields): 392 millis
# pass1 - making usageList (25 chroms): 31 millis
# pass2 - checking and writing primary data (133672 records, 10 fields): 292 millis
# pass1 - making usageList (25 chroms): 11 millis
# pass2 - checking and writing primary data (43824 records, 10 fields): 112 millis
# pass1 - making usageList (25 chroms): 38 millis
# pass2 - checking and writing primary data (162602 records, 10 fields): 381 millis
# pass1 - making usageList (25 chroms): 10 millis
# pass2 - checking and writing primary data (38724 records, 10 fields): 97 millis
# pass1 - making usageList (25 chroms): 13 millis
# pass2 - checking and writing primary data (53558 records, 10 fields): 136 millis
# pass1 - making usageList (25 chroms): 30 millis
# pass2 - checking and writing primary data (129675 records, 10 fields): 293 millis
# pass1 - making usageList (25 chroms): 12 millis
# pass2 - checking and writing primary data (50360 records, 10 fields): 126 millis
# pass1 - making usageList (25 chroms): 54 millis
# pass2 - checking and writing primary data (235032 records, 10 fields): 530 millis
# pass1 - making usageList (25 chroms): 26 millis
# pass2 - checking and writing primary data (99923 records, 10 fields): 219 millis
# pass1 - making usageList (25 chroms): 10 millis
# pass2 - checking and writing primary data (41152 records, 10 fields): 104 millis
# pass1 - making usageList (25 chroms): 23 millis
# pass2 - checking and writing primary data (98594 records, 10 fields): 226 millis
# pass1 - making usageList (25 chroms): 135 millis
# pass2 - checking and writing primary data (156481 records, 10 fields): 494 millis
# pass1 - making usageList (25 chroms): 62 millis
# pass2 - checking and writing primary data (262719 records, 10 fields): 575 millis
# pass1 - making usageList (25 chroms): 23 millis
# pass2 - checking and writing primary data (79031 records, 10 fields): 240 millis
# pass1 - making usageList (25 chroms): 25 millis
# pass2 - checking and writing primary data (103972 records, 10 fields): 246 millis
# pass1 - making usageList (25 chroms): 28 millis
# pass2 - checking and writing primary data (106833 records, 10 fields): 249 millis
# pass1 - making usageList (25 chroms): 37 millis
# pass2 - checking and writing primary data (161422 records, 10 fields): 362 millis
# pass1 - making usageList (25 chroms): 31 millis
# pass2 - checking and writing primary data (133690 records, 10 fields): 316 millis
# pass1 - making usageList (25 chroms): 16 millis
# pass2 - checking and writing primary data (72038 records, 10 fields): 176 millis
# pass1 - making usageList (24 chroms): 3 millis
# pass2 - checking and writing primary data (4470 records, 10 fields): 20 millis
# pass1 - making usageList (24 chroms): 16 millis
# pass2 - checking and writing primary data (60466 records, 10 fields): 147 millis
# pass1 - making usageList (25 chroms): 34 millis
# pass2 - checking and writing primary data (137922 records, 10 fields): 332 millis
# pass1 - making usageList (25 chroms): 49 millis
# pass2 - checking and writing primary data (121953 records, 10 fields): 588 millis
# pass1 - making usageList (25 chroms): 33 millis
# pass2 - checking and writing primary data (137965 records, 10 fields): 325 millis
# pass1 - making usageList (25 chroms): 21 millis
# pass2 - checking and writing primary data (83029 records, 10 fields): 200 millis
# pass1 - making usageList (25 chroms): 12 millis
# pass2 - checking and writing primary data (45633 records, 10 fields): 114 millis
# pass1 - making usageList (24 chroms): 5 millis
# pass2 - checking and writing primary data (14855 records, 10 fields): 47 millis
# pass1 - making usageList (25 chroms): 18 millis
# pass2 - checking and writing primary data (73160 records, 10 fields): 161 millis
# pass1 - making usageList (25 chroms): 18 millis
# pass2 - checking and writing primary data (72495 records, 10 fields): 170 millis
# pass1 - making usageList (25 chroms): 58 millis
# pass2 - checking and writing primary data (250472 records, 10 fields): 587 millis
# pass1 - making usageList (25 chroms): 33 millis
# pass2 - checking and writing primary data (141387 records, 10 fields): 384 millis
# pass1 - making usageList (25 chroms): 49 millis
# pass2 - checking and writing primary data (207859 records, 10 fields): 538 millis
# pass1 - making usageList (25 chroms): 58 millis
# pass2 - checking and writing primary data (241706 records, 10 fields): 538 millis
# pass1 - making usageList (25 chroms): 15 millis
# pass2 - checking and writing primary data (59916 records, 10 fields): 141 millis
# pass1 - making usageList (25 chroms): 25 millis
# pass2 - checking and writing primary data (110325 records, 10 fields): 246 millis
# pass1 - making usageList (25 chroms): 16 millis
# pass2 - checking and writing primary data (66056 records, 10 fields): 161 millis
# pass1 - making usageList (25 chroms): 36 millis
# pass2 - checking and writing primary data (152936 records, 10 fields): 420 millis
# pass1 - making usageList (25 chroms): 20 millis
# pass2 - checking and writing primary data (78839 records, 10 fields): 198 millis
# pass1 - making usageList (24 chroms): 35 millis
# pass2 - checking and writing primary data (72224 records, 10 fields): 270 millis
# pass1 - making usageList (25 chroms): 49 millis
# pass2 - checking and writing primary data (101921 records, 10 fields): 463 millis
# pass1 - making usageList (25 chroms): 73 millis
# pass2 - checking and writing primary data (176837 records, 10 fields): 794 millis
# pass1 - making usageList (25 chroms): 34 millis
# pass2 - checking and writing primary data (147862 records, 10 fields): 610 millis
# pass1 - making usageList (25 chroms): 67 millis
# pass2 - checking and writing primary data (132863 records, 10 fields): 620 millis
# pass1 - making usageList (25 chroms): 46 millis
# pass2 - checking and writing primary data (97226 records, 10 fields): 459 millis
# pass1 - making usageList (25 chroms): 32 millis
# pass2 - checking and writing primary data (90127 records, 10 fields): 416 millis
# pass1 - making usageList (25 chroms): 110 millis
# pass2 - checking and writing primary data (257348 records, 10 fields): 1114 millis
# pass1 - making usageList (25 chroms): 54 millis
# pass2 - checking and writing primary data (170728 records, 10 fields): 749 millis
# pass1 - making usageList (25 chroms): 9 millis
# pass2 - checking and writing primary data (35049 records, 10 fields): 190 millis
# pass1 - making usageList (25 chroms): 66 millis
# pass2 - checking and writing primary data (159104 records, 10 fields): 640 millis
# pass1 - making usageList (25 chroms): 97 millis
# pass2 - checking and writing primary data (237210 records, 10 fields): 1026 millis
# pass1 - making usageList (25 chroms): 92 millis
# pass2 - checking and writing primary data (222380 records, 10 fields): 1045 millis
# pass1 - making usageList (25 chroms): 28 millis
# pass2 - checking and writing primary data (67862 records, 10 fields): 303 millis
# pass1 - making usageList (25 chroms): 47 millis
# pass2 - checking and writing primary data (115210 records, 10 fields): 545 millis
# pass1 - making usageList (25 chroms): 26 millis
# pass2 - checking and writing primary data (64987 records, 10 fields): 298 millis
# pass1 - making usageList (25 chroms): 143 millis
# pass2 - checking and writing primary data (312869 records, 10 fields): 1389 millis
# pass1 - making usageList (25 chroms): 26 millis
# pass2 - checking and writing primary data (72932 records, 10 fields): 300 millis
# pass1 - making usageList (25 chroms): 40 millis
# pass2 - checking and writing primary data (111448 records, 10 fields): 500 millis
# pass1 - making usageList (25 chroms): 46 millis
# pass2 - checking and writing primary data (103933 records, 10 fields): 443 millis
# pass1 - making usageList (25 chroms): 15 millis
# pass2 - checking and writing primary data (57890 records, 10 fields): 248 millis
# pass1 - making usageList (25 chroms): 71 millis
# pass2 - checking and writing primary data (167738 records, 10 fields): 713 millis
# pass1 - making usageList (25 chroms): 26 millis
# pass2 - checking and writing primary data (65101 records, 10 fields): 314 millis
# pass1 - making usageList (25 chroms): 99 millis
# pass2 - checking and writing primary data (229829 records, 10 fields): 1046 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (14462 records, 10 fields): 73 millis
# pass1 - making usageList (25 chroms): 15 millis
# pass2 - checking and writing primary data (60352 records, 10 fields): 294 millis
# pass1 - making usageList (25 chroms): 63 millis
# pass2 - checking and writing primary data (125360 records, 10 fields): 569 millis
# pass1 - making usageList (25 chroms): 5 millis
# pass2 - checking and writing primary data (1810 records, 10 fields): 12 millis
# pass1 - making usageList (25 chroms): 72 millis
# pass2 - checking and writing primary data (160784 records, 10 fields): 684 millis
# pass1 - making usageList (25 chroms): 63 millis
# pass2 - checking and writing primary data (145542 records, 10 fields): 663 millis

# %%
# !make_trackhubs.py --genome hg19 --hub 20170109_encode_stringent_master_peaks /home/gpratt/projects/encode/analysis/encode_high_confidence_peaks/*bb --num_sep 1
# !make_trackhubs.py --genome hg19 --hub 20170109_encode_stringent_master_wigs /home/gpratt/projects/encode/analysis/encode_high_confidence_peaks/*bw --num_sep 1

# %%
# !make_trackhubs.py --genome hg19 --hub 20170109_encode_lenient_master_peaks /home/gpratt/projects/encode/analysis/encode_meduim_confidence_peaks/*bb --num_sep 1
# !make_trackhubs.py --genome hg19 --hub 20170109_encode_lenient_master_wigs /home/gpratt/projects/encode/analysis/encode_meduim_confidence_peaks/*bw --num_sep 1
