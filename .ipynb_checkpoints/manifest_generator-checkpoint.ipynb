# %%
import glob
import functools
import urllib2

import pandas as pd
import json
import gspread
import pandas as pd
import os
from IPython.core.display import HTML
from oauth2client.client import SignedJwtAssertionCredentials
import numpy as np
import shutil

# %% [markdown]
# #Important Data Metadata
# Barcodes to split on and their ids
# illumina adapters and their IDs so I can make name dcisions

# %%
barcodes = """AAGCAAT A01
GGCTTGT B06
ACAAGTT C01
TGGTCCT D08fixed
ATGACCNNNNT  A03
TCCTGTNNNNT  G07
CAGCTTNNNNT  A04
GGATACNNNNT  F05
NNNNNCCTATAT X1A
NNNNNTGCTATT X1B
NNNNNTATACTT X2A
NNNNNATCTTCT X2B""".split("\n")


barcodes = dict([item.split() for item in barcodes])
barcode_name_to_sequence = {value.strip(): key.strip() for key, value in barcodes.items()}

#overlap is for the second trimimg round to throw out doube ligation events on the end of read 2 (we ignore tripple ligation events)
#only issue is actually A03-F05 where we might be trimming Ts off the start of read 1 and causing dove tailing events
overlap = """A01 5
B06 5
C01 5
D08fixed 5
A03 9
G07 9 
A04 9
F05 9
none 5
X1A 10
X1B 10
X2A 10
X2B 10""".split("\n")


overlap = dict([item.split() for item in overlap])

illumina_adapters = """501 TATAGCCT 
502 ATAGAGGC 
503 CCTATCCT 
504 GGCTCTGA 
505 AGGCGAAG 
506 TAATCTTA 
507 CAGGACGT 
508 GTACTGAC 
502s ATA 
503s CCT
504s GGC
505s AGG
506s TAA
507s CAG
508s GTA
701 ATTACTCG
702 TCCGGAGA
703 CGCTCATT
704 GAGATTCC
705 ATTCAGAA
706 GAATTCGT""".split("\n")

illumina_adapters = pd.DataFrame([item.strip().split() for item in illumina_adapters], columns=["label", "barcode"])
illumina_adapters = illumina_adapters.set_index("label")

adapters = """A01    ATTGCTTAGATCGGAAGAGCGTCGTGT
B06    ACAAGCCAGATCGGAAGAGCGTCGTGT
C01    AACTTGTAGATCGGAAGAGCGTCGTGT
D08fixed    AGGACCAAGATCGGAAGAGCGTCGTGT
A03    ANNNNGGTCATAGATCGGAAGAGCGTCGTGT
G07    ANNNNACAGGAAGATCGGAAGAGCGTCGTGT
A04    ANNNNAAGCTGAGATCGGAAGAGCGTCGTGT
F05    ANNNNGTATCCAGATCGGAAGAGCGTCGTGT
none   AGATCGGAAGAGCGTCGTGT
X1A    ATATAGGNNNNNAGATCGGAAGAGCGTCGTGTAG
X1B    AATAGCANNNNNAGATCGGAAGAGCGTCGTGTAG 
X2A    AAGTATANNNNNAGATCGGAAGAGCGTCGTGTAG
X2B    AGAAGATNNNNNAGATCGGAAGAGCGTCGTGTAG""".split("\n")
adapters = dict([item.split() for item in adapters])



five_prime_adapter = "CTTCCGATCT"

# %% [markdown]
# #Get Manifest from Google Docs

# %%
json_key = json.load(open("/home/gpratt/ipython_notebook/public clip-588adbc137f3.json"))
scope = ['https://spreadsheets.google.com/feeds']

credentials = SignedJwtAssertionCredentials(json_key['client_email'], json_key['private_key'], scope)
gc = gspread.authorize(credentials)

sht1 = gc.open_by_url("https://docs.google.com/spreadsheets/d/1ZU2mQh54jentqvhR_oMnviLGWR8Nw_x338gULzKjNDI/edit#gid=0")
ws = sht1.worksheet("Sheet1")
list_of_lists = ws.get_all_values()
manifest = pd.DataFrame(list_of_lists[1:], columns=list_of_lists[0])
manifest.is_encode = manifest.is_encode == "TRUE"
manifest.is_4000 = manifest.is_4000 == "TRUE"

manifest.method_Paper_flag = manifest.Method_Paper_flag == "TRUE" 
manifest['exp_id'] = manifest.ENCODE_ID.apply(lambda x: x.split("_")[0])

# %%
def format_file(index, adapter):
    index_1 = illumina_adapters.ix[index.index_1].values[0]
    index_2 = illumina_adapters.ix[index.index_2].values[0]
    if index.Lane == "": #Incase we are doing a rapid run and there isn't lane info
        sample_name = "{}_{}-{}_{}.fastq.gz".format(index.Hiseq_file_name, index_2, index_1, adapter)
        dir_name = "Sample_{}".format(index.Hiseq_file_name)

    #For Sebastians samples Sample_G3BP-S-input/G3BP-S-input_S1_L001_R1.fastq.gz
    elif index.Lane.startswith("S") and "L" in index.Lane:
        name = index.Hiseq_file_name
        sample_name = "{}_{}_{}.fastq.gz".format(name, index.Lane, adapter)
        dir_name = index.Hiseq_file_name
    
    elif index.Lane.startswith("S"):
        name = index.Hiseq_file_name.split("-")[0].replace("_", "-")
        sample_name = "{}_{}_{}.fastq.gz".format(name, index.Lane, adapter)
        dir_name = index.Hiseq_file_name
 
    #This needs to go above my other 4000 check because of name colisions
    elif index.is_4000:
        sample_name = "{}_{}_{}_001.fastq.gz".format(index.Hiseq_file_name, index.Lane, adapter)
        return os.path.join(index.file_location, sample_name)
    
    #this is a bit hacky, keep an eye on it
    elif "4000" in index.Hiseq_file_name:
        sample_name = index.Hiseq_file_name + ".fastq.gz"
        sample_name = sample_name.replace("R1", adapter)
        return os.path.join(index.file_location, sample_name)
      
    else:
        sample_name = "{}_{}-{}_{}_{}.fastq.gz".format(index.Hiseq_file_name, index_2, index_1, index.Lane, adapter)
        dir_name = "Sample_{}".format(index.Hiseq_file_name)
    return os.path.join(index.file_location, dir_name, sample_name)

# %%
manifest['r1'] = manifest.apply(functools.partial(format_file, adapter="R1"), axis=1)
manifest['r2'] = manifest.apply(functools.partial(format_file, adapter="R2"), axis=1)

# %% [markdown]
# #Make sure there are no duplicated names or ids in the encode manifest

# %%
input_manifest_check = manifest[manifest.inline_1 == "none"]
manifest_grouped_manifest = input_manifest_check.groupby(["Hiseq_file_name"]).count()
manifest_grouped_manifest[manifest_grouped_manifest.RBP > 1]

# %%
manifest_grouped_manifest = manifest.groupby(["Hiseq_file_name", "ENCODE_ID"]).count()
manifest_grouped_manifest[manifest_grouped_manifest.RBP > 1]

# %%
manifest_grouped_manifest = manifest.groupby(["ENCODE_ID"]).count()
manifest_grouped_manifest[manifest_grouped_manifest.RBP > 1]

# %%
unprocessed_datasets = manifest.ix[~manifest['r1'].apply(os.path.exists)]

for x in unprocessed_datasets.r1:
    print x

# %% [markdown]
# #Togle Datasets to be processed

# %%
#manifest = manifest[manifest.method_Paper_flag]

# %% [markdown]
# #Make demuxing stuffs

# %%
clip_seq_manifest = manifest[manifest.inline_1 != "none"].copy()
input_manifest = manifest[manifest.inline_1 == "none"].copy()

# %%
tscc_dir = "/home/gpratt/projects/encode/scripts/barcodes/encode_barcodes"

# %%
clip_seq_manifest['inline_name_1'] = clip_seq_manifest.apply(lambda x: "{}_{}_{}".format(x.inline_1, x.ENCODE_ID, x.RBP), axis=1)
clip_seq_manifest['inline_name_2'] = clip_seq_manifest.apply(lambda x: "{}_{}_{}".format(x.inline_2, x.ENCODE_ID, x.RBP), axis=1)

# %%
#Writes barcodes to approprate locations
for lane, manifest_by_lane in clip_seq_manifest.groupby("Lane"):
    for file_name, df in manifest_by_lane.groupby("Hiseq_file_name"):

        cur_barcodes = barcodes.copy()
        for key, series in df.iterrows():
            try:
                inline_1 = barcode_name_to_sequence[series.inline_1]
                inline_2 = barcode_name_to_sequence[series.inline_2]
                cur_barcodes[inline_1] = series.inline_name_1
                cur_barcodes[inline_2] = series.inline_name_2
            except KeyError as e:
                print "Key Error, barcode", e, "doesn't exit, won't demux", series.ENCODE_ID
        barcode_file = os.path.join(tscc_dir, file_name + ".txt")
        with open(barcode_file, 'w') as fn:
            for key, value in cur_barcodes.items():
                fn.write("{}\t{}\n".format(key, value))
                
barcode_file = os.path.join(tscc_dir, "barcodes.txt")
with open(barcode_file, 'w') as fn:
    for key, value in barcodes.items():
        fn.write("{}\t{}\n".format(key, value))

# %%
#Functions to format output
def create_demuxer(barcode, r1, r2, length, outdir):
    out_file_1 = os.path.join(outdir, os.path.basename(r1))
    out_file_2 = os.path.join(outdir, os.path.basename(r2))

    metrics = os.path.basename(barcode)
    
    return "demux_paired_end.py --fastq_1 {} --fastq_2 {} -b {} --out_file_1 {} --out_file_2 {} --length {} -m {}".format(r1, r2, barcode, out_file_1, out_file_2, length, metrics)


def create_demuxer_input(barcode, r1, r2, length, outdir):
    out_file_1 = os.path.join(outdir, os.path.basename(r1))
    out_file_2 = os.path.join(outdir, os.path.basename(r2))
    
    metrics = os.path.basename(barcode)
    
    return "demux_paired_end.py --fastq_1 {} --fastq_2 {} -b {} --out_file_1 {} --out_file_2 {} --length {} -m {}".format(r1, r2, barcode, out_file_1, out_file_2, length, metrics)

# %% [markdown]
# #Make downstream file names

# %%
#split_out_dir = "/projects/ps-yeolab2/encode/analysis/encode_split"
split_out_dir = "/home/gpratt/projects/encode/analysis/encode_split" #this is the old dir switching to stable ps-yeolab space

def make_processing_name(series, inline_name):
    
    r1 = os.path.basename(series.r1).split(".")
    r1.insert(-2, series[inline_name])
    r1 = ".".join(r1)
    
    r2 = os.path.basename(series.r2).split(".")
    r2.insert(-2, series[inline_name])
    r2 = ".".join(r2)

    return ";".join([os.path.join(split_out_dir, r1), 
                     os.path.join(split_out_dir, r2)])

def make_input_processing_name(series):
    
    r1 = os.path.basename(series.r1).split(".")
    r1.insert(-2, "unassigned")
    r1 = ".".join(r1)
    
    r2 = os.path.basename(series.r2).split(".")
    r2.insert(-2, "unassigned")
    r2 = ".".join(r2)

    return ";".join([os.path.join(split_out_dir, r1), 
                     os.path.join(split_out_dir, r2)])

# %%
clip_seq_manifest['processing_name_1'] = clip_seq_manifest.apply(functools.partial(make_processing_name, inline_name="inline_name_1"), axis=1)
clip_seq_manifest['processing_name_2'] = clip_seq_manifest.apply(functools.partial(make_processing_name, inline_name="inline_name_2"), axis=1)

input_manifest['processing_name'] = input_manifest.apply(make_input_processing_name, axis=1)

# %%
clip_seq_manifest.to_csv("clipseq_manifest.csv")
input_manifest.to_csv("input_manifest.csv")

# %% [markdown]
# #Write Demuxing Code

# %%
#output results in list, only outputs unprocessed datasets
total = 0 
result = []
for lane, manifest_by_lane in clip_seq_manifest.groupby("Lane"):
    for file_name, series in manifest_by_lane.groupby("Hiseq_file_name").first().iterrows():

        #Skip if the file has already been demuxed
        if os.path.exists(series.processing_name_1.split(";")[0]):
            continue

        total = total % 500
        total += 1
        barcode_location = os.path.join(tscc_dir, series.name + ".txt")
        result.append('cmd[{}]=\"{}\"'.format(total, create_demuxer(barcode_location, series.r1, series.r2, series.randomer_length, split_out_dir)))

for lane, manifest_by_lane in input_manifest.groupby("Lane"):
#for lane, manifest_by_lane in input_manifest[~input_manifest['r1'].apply(os.path.exists)].groupby("Lane"):
    for file_name, series in manifest_by_lane.groupby("Hiseq_file_name").first().iterrows():

        #Skip if the file has already been demuxed
        if os.path.exists(series.processing_name.split(";")[0]):
            continue

        total = total % 500
        total += 1
        barcode_location = "/home/gpratt/projects/encode/scripts/barcodes/encode_barcodes/barcodes.txt"
        result.append('cmd[{}]=\"{}\"'.format(total, create_demuxer_input(barcode_location, series.r1, series.r2, series.randomer_length, split_out_dir)))
        #result.append('cmd[{}]=\"{}\"'.format(total, create_demuxer_input(barcode_location, series.r2, split_out_dir)))

# %%
def eplouge(count):
    return """#!/bin/bash
#PBS -N barcode_spliter
#PBS -l nodes=1:ppn=1
#PBS -o 20150224_splitter.out
#PBS -e 20150224_splitter.err
#PBS -V
#PBS -q home-yeo
#PBS -W group_list=yeo-group
#PBS -t 1-{}
#PBS -l walltime=12:00:00
cd /home/gpratt/projects/encode/data/encode_split
echo "hello, starting"
""".format(count)

prolouge = "eval ${cmd[$PBS_ARRAYID]}"

# %%
with open(os.path.join("/home/gpratt/projects/encode/scripts", "encode_demux_1.sh"), 'w') as out_file:
    out_file.write(eplouge(500))
    for line in result[:500]:
        out_file.write(line + "\n\n")
    out_file.write(prolouge + "\n")
    
with open(os.path.join("/home/gpratt/projects/encode/scripts", "encode_demux_2.sh"), 'w') as out_file:
    out_file.write(eplouge(len(result[500:])))
    for line in result[500:]:
        out_file.write(line + "\n\n")
    out_file.write(prolouge + "\n")

# %% [markdown]
# #Make the files to process

# %%
def make_current_adapters(adapter1, adapter2, triming_len  = 15):
    result = []
    for x in range(len(adapter1) - triming_len + 1):
        short_adapter1 = adapter1[x:x+triming_len]
        short_adapter2 = adapter2[x:x+triming_len]
        if short_adapter1 == short_adapter2:
            result.append(short_adapter1)
        else:
            result += list([short_adapter1, short_adapter2])
    return ";".join(result)

def make_five_prime_adapters(adapter1, adapter2):
    result = []
    result.append(five_prime_adapter + adapter1)
    result.append(five_prime_adapter + adapter2)
    result = list(set(result))
    #This adapter is incase read 1 and read 2 overlap badly
    return ";".join(result)

# %% [markdown]
# #Check if individual files exist
# only make the manifest it they do

# %%
clip_seq_manifest.r1[0]

# %%
#out_dir_hg19 = "/projects/ps-yeolab/encode/analysis/encode_v13/"
out_dir_hg19 = "/projects/ps-yeolab2/encode/analysis/encode_v12/"

out_dir_mm9 = "/projects/ps-yeolab2/encode/analysis/encode_mouse_v8/"

def define_basename(row):
    if row.species == "hg19":
        return os.path.join(out_dir_hg19, ".".join(os.path.basename(row.processing_name.split(";")[0]).split(".")[:-2]))
    if row.species == "mm9":
        return os.path.join(out_dir_mm9, ".".join(os.path.basename(row.processing_name.split(";")[0]).split(".")[:-2]))

input_manifest['base_name'] = input_manifest.apply(define_basename, axis=1)
input_manifest['input_bam'] = input_manifest.base_name.apply(lambda x: ".".join([x, "adapterTrim.round2.rmRep.rmDup.sorted.bam"]))
input_manifest['trimmed_fastq_r1'] = input_manifest.base_name.apply(lambda x: ".".join([x, "adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1"]))
input_manifest['trimmed_fastq_r2'] = input_manifest.base_name.apply(lambda x: ".".join([x, "adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2"]))
input_manifest['input_peaks'] = input_manifest.base_name.apply(lambda x: ".".join([x, "adapterTrim.round2.rmRep.rmDup.sorted.r2.peaks.fixed.bb"]))

def define_basename_merged(row):
    if row.species == "hg19":
        return os.path.join(out_dir_hg19, "{}_{}".format(row['ENCODE_ID'], row['RBP']))
    if row.species == "mm9":
        return os.path.join(out_dir_mm9, "{}_{}".format(row['ENCODE_ID'], row['RBP']))

clip_seq_manifest['merged_base_name'] = clip_seq_manifest.apply(define_basename_merged, axis=1)
clip_seq_manifest['merged_bam'] = clip_seq_manifest.apply(lambda x: "{}.merged.r2.bam".format(x.merged_base_name), axis=1) 
clip_seq_manifest['trimmed_fastq_rep1_r1'] = clip_seq_manifest.base_name.apply(lambda x: ".".join([x, "adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1"]))
clip_seq_manifest['trimmed_fastq_rep1_r2'] = clip_seq_manifest.base_name.apply(lambda x: ".".join([x, "adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2"]))
clip_seq_manifest['trimmed_fastq_rep2_r1'] = clip_seq_manifest.base_name.apply(lambda x: ".".join([x, "adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1"]))
clip_seq_manifest['trimmed_fastq_rep2_r2'] = clip_seq_manifest.base_name.apply(lambda x: ".".join([x, "adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2"]))

clip_seq_manifest['merged_peaks'] = clip_seq_manifest.apply(lambda x:  "{}.merged.r2.peaks.fixed.bb".format(x.merged_base_name), axis=1)

# %%
rerun = """459_CLIP_S29
459_CLIP_S29
459_INPUT_S30
235_CLIP_S53
235_CLIP_S53
235_INPUT_S54
284_CLIP_S55
284_CLIP_S55
284_INPUT_S56
285_CLIP_S57
285_CLIP_S57
390_CLIP_S59
390_CLIP_S59
390_INPUT_S60
534_CLIP_S1
534_CLIP_S1
534_INPUT_S2
567_CLIP_S51
567_CLIP_S51
567_INPUT_S52
570_CLIP_S3
570_CLIP_S3
570_INPUT_S4
580_CLIP_S11
580_CLIP_S11
580_INPUT_S12
584_CLIP_S21
584_CLIP_S21
584_INPUT_S22
590_CLIP_S7
590_CLIP_S7
590_INPUT_S8
591_CLIP_S13
591_CLIP_S13
591_INPUT_S14
592_CLIP_S5
592_CLIP_S5
592_INPUT_S6
593_CLIP_S15
593_CLIP_S15
593_INPUT_S16
594_CLIP_S23
594_CLIP_S23
594_INPUT_S24
598_CLIP_S17
598_CLIP_S17
598_INPUT_S18
614_CLIP_S25
614_CLIP_S25
614_INPUT_S26
622_CLIP_S27
622_CLIP_S27
622_INPUT_S28
624_CLIP_S29
624_CLIP_S29
624_INPUT_S30
627_CLIP_S9
627_CLIP_S9
627_INPUT_S10
631_CLIP_S19
631_CLIP_S19
631_INPUT_S20
LNG10-E_INPUT_S61
LNG10-E_CLIP_S62
LNG10-N_INPUT_S63
LNG10-N_CLIP_S64
LNG10-M_INPUT_S65
LNG10-M_CLIP_S66
LNG10-S_INPUT_S67
LNG10-S_CLIP_S68
LNG9-E_INPUT_S69
LNG9-E_CLIP_S70
LNG9-N_INPUT_S71
LNG9-N_CLIP_S72
LNG9-M_INPUT_S73
LNG9-M_CLIP_S74
LNG9-S_INPUT_S75
LNG9-S_CLIP_S76
LNG1-E_INPUT_S77
LNG1-E_CLIP_S78
LNG1-N_INPUT_S79
LNG1-N_CLIP_S80
LNG1-M_INPUT_S81
LNG1-M_CLIP_S82
LNG1-S_INPUT_S83
LNG1-S_CLIP_S84
LNG19-E_INPUT_S85
LNG19-E_CLIP_S86
LNG19-N_INPUT_S87
LNG19-N_CLIP_S88
LNG20-E_INPUT_S89
LNG20-E_CLIP_S90
LNG20-N_INPUT_S91
LNG20-N_CLIP_S92
323_01_CLIP_S8""".split("\n")

# %%
#This is for just running stuff thats not done yet
input_manifest_run = input_manifest[~(input_manifest['input_bam'].apply(os.path.exists) & input_manifest['input_peaks'].apply(os.path.exists)) | (input_manifest.Hiseq_file_name.isin(rerun))]
# input_manifest_run = input_manifest_run[~input_manifest_run.inline_1.isin(['X1A', 'X1B', 'X2A', 'X2B', 'C06'])]
# input_manifest_run = input_manifest_run[~input_manifest_run.inline_2.isin(['X1A', 'X1B', 'X2A', 'X2B', 'C06'])]

clip_seq_manifest_run = clip_seq_manifest[~(clip_seq_manifest.merged_bam.apply(os.path.exists) & clip_seq_manifest.merged_peaks.apply(os.path.exists)) | clip_seq_manifest.Hiseq_file_name.isin(rerun)]
# clip_seq_manifest_run = clip_seq_manifest_run[~clip_seq_manifest_run.inline_1.isin(['X1A', 'X1B', 'X2A', 'X2B', 'C06'])]
# clip_seq_manifest_run = clip_seq_manifest_run[~clip_seq_manifest_run.inline_2.isin(['X1A', 'X1B', 'X2A', 'X2B', 'C06'])]

# #This is for an allup run
# input_manifest_run = input_manifest
# clip_seq_manifest_run = clip_seq_manifest

# %%
#Make Manifest for human files
with open(os.path.join("/home/gpratt/projects/encode/scripts", "encode_v12.txt"), 'w') as out_file: 
    for name, line in clip_seq_manifest_run[clip_seq_manifest_run.species == "hg19"].iterrows():
        current_adapters = make_current_adapters(adapters[line.inline_1], adapters[line.inline_2])
        five_prime_adapters = make_five_prime_adapters(barcode_name_to_sequence[line.inline_1], 
                                                       barcode_name_to_sequence[line.inline_2])
        
        out_file.write("\t".join([line.processing_name_1, 
                                  "hg19", 
                                  line.ENCODE_ID + "_" + line.RBP, 
                                  current_adapters,
                                  overlap[line.inline_1],
                                  five_prime_adapters,
                                 line.randomer_length]) + '\n')
        out_file.write("\t".join([line.processing_name_2, 
                                  "hg19", 
                                  line.ENCODE_ID + "_" + line.RBP, 
                                  current_adapters,
                                  overlap[line.inline_2],
                                  five_prime_adapters,
                                 line.randomer_length]) + '\n')
        
    for name, line in input_manifest_run[input_manifest_run.species == "hg19"].iterrows(): 
        
        #I wrote the function badly, this is a hack around that...
        current_adapters = make_current_adapters(adapters["none"], adapters["none"])
        five_prime_adapters = make_five_prime_adapters("", "")
        out_file.write("\t".join([line.processing_name, 
                                  "hg19", 
                                  line.ENCODE_ID + "_" + line.RBP,
                                  current_adapters,
                                  overlap["none"],
                                  five_prime_adapters,
                                  line.randomer_length
                                  ]) + '\n')
        
#Make Manifest for mouse files
with open(os.path.join("/home/gpratt/projects/encode/scripts", "encode_mouse_v8.txt"), 'w') as out_file: 
    for name, line in clip_seq_manifest[clip_seq_manifest.species == "mm9"].iterrows():
        current_adapters = make_current_adapters(adapters[line.inline_1], adapters[line.inline_2])
        five_prime_adapters = make_five_prime_adapters(barcode_name_to_sequence[line.inline_1], 
                                                       barcode_name_to_sequence[line.inline_2])
        
        out_file.write("\t".join([line.processing_name_1, 
                                  "mm9", 
                                  line.ENCODE_ID + "_" + line.RBP, 
                                  current_adapters,
                                  overlap[line.inline_1],
                                  five_prime_adapters,
                                 line.randomer_length]) + '\n')
        out_file.write("\t".join([line.processing_name_2, 
                                  "mm9", 
                                  line.ENCODE_ID + "_" + line.RBP, 
                                  current_adapters,
                                  overlap[line.inline_2],
                                  five_prime_adapters,
                                 line.randomer_length]) + '\n')
        
    for name, line in input_manifest_run[input_manifest_run.species == "mm9"].iterrows(): 
        
        #I wrote the function badly, this is a hack around that...
        current_adapters = make_current_adapters(adapters["none"], adapters["none"])
        five_prime_adapters = make_five_prime_adapters("", "")
        out_file.write("\t".join([line.processing_name, 
                                  "mm9", 
                                  line.ENCODE_ID + "_" + line.RBP,
                                  current_adapters,
                                  overlap["none"],
                                  five_prime_adapters,
                                  line.randomer_length
                                  ]) + '\n')
    
#     #get all the files in the processing directroy over 1mb in size
#     all_split_files = glob.glob(os.path.join(split_out_dir, "*R2*.gz"))
#     all_large_files = [fn for fn in all_split_files if os.path.getsize(fn) > 6000000]
#     for large_file in all_large_files:
#         annotation = large_file.split(".")[1]
#         if (len(annotation.split("_")) == 1) and (annotation != "unassigned"):
#             large_files = ";".join([large_file.replace("R2", "R1"), large_file])
#             print os.path.basename(large_file), annotation, os.path.getsize(large_file)
#             out_data = [large_files, "hg19"]
            
#             #Now for special cases!
#             #If these are any of KK's sample we will assume that she added all 4 barcodes and 
#             #that they belong to the analysis group that the other two samples came from
#             if os.path.basename(large_file).startswith("KK"):
#                 line = manifest[manifest.r2.apply(os.path.basename) == (os.path.basename(large_file).split(".")[0] + ".fastq.gz")].irow(0)
#                 out_data.append(line.ENCODE_ID + "_" + line.RBP)
            
#             out_data.append(line.randomer_length)
#             print len(out_data)
#             out_file.write("\t".join(out_data) + '\n')

# %% [markdown]
# #Check to See If Generated Files Exist
#
# Demuxed Files
# ---

# %%
clip_seq_manifest[~(clip_seq_manifest.processing_name_1.apply(lambda x: all(map(os.path.exists, x.split(';')))) | \
                   clip_seq_manifest.processing_name_2.apply(lambda x: all(map(os.path.exists, x.split(';')))))]

# %%
input_manifest[~input_manifest.processing_name.apply(lambda x: all(map(os.path.exists, x.split(';'))))]

# %% [markdown]
# Check if individual CLIP input output files exist
# ----

# %%
input_manifest[~input_manifest['input_bam'].apply(os.path.exists)]

# %%
input_manifest[~input_manifest['input_peaks'].apply(os.path.exists)]

# %% [markdown]
# Check if merged Individual CLIP Files output files exist
# ----

# %%
HTML(clip_seq_manifest[~clip_seq_manifest.merged_bam.apply(os.path.exists)].to_html())

# %%
HTML(clip_seq_manifest[~clip_seq_manifest.merged_peaks.apply(os.path.exists)].to_html())

# %%
clip_seq_manifest.to_csv("/home/gpratt/Dropbox/encode_integration/for_eric/full_IP_file_list.csv")
input_manifest.to_csv("/home/gpratt/Dropbox/encode_integration/for_eric/full_input_file_list.csv")

# %% [markdown]
# #Files that exist

# %%
v13_done_input = input_manifest[input_manifest['input_bam'].apply(os.path.exists) & input_manifest['input_peaks'].apply(os.path.exists) & (input_manifest.species == "hg19")]
v13_done_clip = clip_seq_manifest[clip_seq_manifest.merged_bam.apply(os.path.exists) & clip_seq_manifest.merged_peaks.apply(os.path.exists) & (clip_seq_manifest.species == "hg19")]
merged_v13_done = pd.merge(v13_done_clip, v13_done_input, left_on="exp_id", right_on="exp_id")

# %%
v13_done_clip = clip_seq_manifest[~(clip_seq_manifest.merged_bam.apply(os.path.exists) & clip_seq_manifest.merged_peaks.apply(os.path.exists) & (clip_seq_manifest.species == "hg19"))]

# %%
v13_done_clip[v13_done_clip.Hiseq_file_name.apply(lambda x: "LNG" in x)]

# %%
HTML(v13_done_clip.to_html())

# %% [markdown]
# #Upload Ok'ed files to sauron

# %%
ids_good_to_go = """
204
205
211
215
216
218
220
222
223
224
226
230
236
240
241
242
243
244
245
246
247
249
256
258
260
262
267
278
280
281
283
290
291
203
271
206
209
227
228
237
272
275
279
282
289
291
292
297
298
301
302
312
315
316
321
325
326
331
332
240
338
339
340
341
342
344
345
350
352
353
354
358
366
367
368
384
387
388
393
405
508
497
495
494
477
465
464
452
415
417
484
439
440
441
444
445
447
450
466
478
311
480
481
492
506
383
376
414
425
437
460
461
470
483
507
509
514
516
530
537
539
540
543
544
546
552
553
556
558
560
566
603
235
390
491
501
503
522
529
531
548
550
567
570
577
582
584
589
592
595
596
614
617
624
625
626
628
641
533
538
545
551
629
631""".split("\n")

ids_good_to_go_4000 = """235
390""".split("\n")

ids_good_to_go_4000 = map(int, ids_good_to_go_4000)
ids_good_to_go = ids_good_to_go_old + ids_good_to_go

# %%
merged_fastq_dir = "/home/gpratt/projects/encode/data/combined_fastqs_for_submission"
#analysis_dir = "/projects/ps-yeolab2/encode/analysis/encode_v12"
#analysis_dir = "/projects/ps-yeolab/encode/analysis/encode_v13"
analysis_dir = "/projects/ps-yeolab2/encode/analysis/encode_master/"

clip_seq_manifest['out_fastq_r1'] = clip_seq_manifest.apply(lambda x: os.path.join(merged_fastq_dir, "{}_{}.R1.fastq.gz".format(x.ENCODE_ID, x.RBP)), axis=1)
clip_seq_manifest['out_fastq_r2'] = clip_seq_manifest.apply(lambda x: os.path.join(merged_fastq_dir, "{}_{}.R2.fastq.gz".format(x.ENCODE_ID, x.RBP)), axis=1)

clip_seq_manifest['out_trimmed_fastq_r1'] = clip_seq_manifest.apply(lambda x: os.path.join(merged_fastq_dir, "{}_{}.trimmed.R1.fastq".format(x.ENCODE_ID, x.RBP)), axis=1)
clip_seq_manifest['out_trimmed_fastq_r2'] = clip_seq_manifest.apply(lambda x: os.path.join(merged_fastq_dir, "{}_{}.trimmed.R2.fastq".format(x.ENCODE_ID, x.RBP)), axis=1)

clip_seq_manifest['out_bam'] = clip_seq_manifest.apply(lambda x: os.path.join(analysis_dir, "{}_{}.merged.bam".format(x.ENCODE_ID, x.RBP)), axis=1)
clip_seq_manifest['out_peaks'] = clip_seq_manifest.apply(lambda x: os.path.join(analysis_dir, "{}_{}.merged.r2.peaks.fixed.bb".format(x.ENCODE_ID, x.RBP)), axis=1)

input_manifest['out_fastq_r1'] = input_manifest.apply(lambda x: os.path.join(merged_fastq_dir, "{}_{}.R1.fastq.gz".format(x.ENCODE_ID, x.RBP)), axis=1)
input_manifest['out_fastq_r2'] = input_manifest.apply(lambda x: os.path.join(merged_fastq_dir, "{}_{}.R2.fastq.gz".format(x.ENCODE_ID, x.RBP)), axis=1) 

input_manifest['out_bam'] = input_manifest.apply(lambda x: os.path.join(analysis_dir, "{}.adapterTrim.round2.rmRep.rmDup.sorted.bam".format(x.base_name, x.RBP)), axis=1)

# %%
def get_4000(row):
    #If we've specified this clip as a 4000 clip only uploads the _4000 version of the dataset
    if row.exp_id in ids_good_to_go_4000:
        return "4000" in row.ENCODE_ID
    else:
        return True

# %%
good_to_go_clip = clip_seq_manifest[clip_seq_manifest.exp_id.isin(ids_good_to_go) & clip_seq_manifest.apply(get_4000, axis=1)]
good_to_go_input = input_manifest[input_manifest.exp_id.isin(ids_good_to_go) & input_manifest.apply(get_4000, axis=1)]

good_to_go_input.exp_id = good_to_go_input.exp_id.astype(float)
good_to_go_clip.exp_id = good_to_go_clip.exp_id.astype(float)
# Out:
# /home/gpratt/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# #Merge fastq files for submission to sauron

# %%
encode_submission_dir = "/home/gpratt/projects/encode/data/combined_fastqs_for_submission"

# %%
for name, row in good_to_go_clip.iterrows():
    r1_out_file = os.path.join(encode_submission_dir, "{}_{}.R1.fastq.gz".format(row.ENCODE_ID, row.RBP))
    r2_out_file = os.path.join(encode_submission_dir, "{}_{}.R2.fastq.gz".format(row.ENCODE_ID, row.RBP)) 
    #print r1_out_file

    barcode_1_read_1 = row.processing_name_1.split(";")[0]
    barcode_2_read_1 = row.processing_name_2.split(";")[0]

    barcode_1_read_2 = row.processing_name_1.split(";")[1]
    barcode_2_read_2 = row.processing_name_2.split(";")[1]
    
    if not os.path.exists(barcode_1_read_1):
        print barcode_1_read_1
    if not  os.path.exists(barcode_2_read_1):
        print barcode_2_read_1
    if not  os.path.exists(barcode_1_read_2):
        print barcode_1_read_2
    if not  os.path.exists(barcode_2_read_2):
        print barcode_2_read_2
        
    try:
        with open(r1_out_file, 'wb') as out_file, open(barcode_1_read_1) as fn_1, open(barcode_2_read_1) as fn_2:
            shutil.copyfileobj(fn_1, out_file)
            shutil.copyfileobj(fn_2, out_file)
    except IOError as e:
        print e
    try:
        with open(r2_out_file, 'wb') as out_file, open(barcode_1_read_2) as fn_1, open(barcode_2_read_2) as fn_2:
            shutil.copyfileobj(fn_1, out_file)
            shutil.copyfileobj(fn_2, out_file)
    except IOError as e:
        print e

# %%
for name, row in good_to_go_input.iterrows():
    r1_out_file = os.path.join(encode_submission_dir, "{}_{}.R1.fastq.gz".format(row.ENCODE_ID, row.RBP))
    r2_out_file = os.path.join(encode_submission_dir, "{}_{}.R2.fastq.gz".format(row.ENCODE_ID, row.RBP)) 
    barcode_1_read_1 = row.processing_name.split(";")[0]
    barcode_1_read_2 = row.processing_name.split(";")[1]
    
    print r1_out_file, barcode_1_read_1
    print r2_out_file, barcode_1_read_2

    try:
        with open(r1_out_file, 'wb') as out_file, open(barcode_1_read_1) as fn_1:
            shutil.copyfileobj(fn_1, out_file)
    except IOError as e:
        print e
        
    try:
        with open(r2_out_file, 'wb') as out_file, open(barcode_1_read_2) as fn_1:
            shutil.copyfileobj(fn_1, out_file)
    except IOError as e:
        print e
# Out:
# /home/gpratt/projects/encode/data/combined_fastqs_for_submission/631_INPUT_EFTUD2.R1.fastq.gz /home/gpratt/projects/encode/analysis/encode_split/631_INPUT_S20_L002_R1_001.unassigned.fastq.gz
# /home/gpratt/projects/encode/data/combined_fastqs_for_submission/631_INPUT_EFTUD2.R2.fastq.gz /home/gpratt/projects/encode/analysis/encode_split/631_INPUT_S20_L002_R2_001.unassigned.fastq.gz
# /home/gpratt/projects/encode/data/combined_fastqs_for_submission/545_INPUT_EIF3H.R1.fastq.gz /home/gpratt/projects/encode/analysis/encode_split/545_INPUT_S18_L002_R1_001.unassigned.fastq.gz
# /home/gpratt/projects/encode/data/combined_fastqs_for_submission/545_INPUT_EIF3H.R2.fastq.gz /home/gpratt/projects/encode/analysis/encode_split/545_INPUT_S18_L002_R2_001.unassigned.fastq.gz
# /home/gpratt/projects/encode/data/combined_fastqs_for_submission/551_INPUT_YBX3.R1.fastq.gz /home/gpratt/projects/encode/analysis/encode_split/551_INPUT_S28_L003_R1_001.unassigned.fastq.gz
# /home/gpratt/projects/encode/data/combined_fastqs_for_submission/551_INPUT_YBX3.R2.fastq.gz /home/gpratt/projects/encode/analysis/encode_split/551_INPUT_S28_L003_R2_001.unassigned.fastq.gz
# /home/gpratt/projects/encode/data/combined_fastqs_for_submission/629_INPUT_UCHL5.R1.fastq.gz /home/gpratt/projects/encode/analysis/encode_split/629_INPUT_S22_L005_R1_001.unassigned.fastq.gz
# /home/gpratt/projects/encode/data/combined_fastqs_for_submission/629_INPUT_UCHL5.R2.fastq.gz /home/gpratt/projects/encode/analysis/encode_split/629_INPUT_S22_L005_R2_001.unassigned.fastq.gz

# %% [markdown]
# #Merge trimmed fastq files for sharing with collaborators

# %%
for name, row in good_to_go_clip.iterrows():
    r1_out_file = os.path.join(encode_submission_dir, "{}_{}.trimmed.R1.fastq".format(row.ENCODE_ID, row.RBP))
    r2_out_file = os.path.join(encode_submission_dir, "{}_{}.trimmed.R2.fastq".format(row.ENCODE_ID, row.RBP)) 
    #print r1_out_file

    barcode_1_read_1 = row.processing_name_1.split(";")[0]
    barcode_2_read_1 = row.processing_name_2.split(";")[0]
    
    barcode_1_read_1 = os.path.join(analysis_dir, ".".join(os.path.basename(barcode_1_read_1).split(".")[:-2]) + ".adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1")
    barcode_2_read_1 = os.path.join(analysis_dir, ".".join(os.path.basename(barcode_2_read_1).split(".")[:-2]) + ".adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1")
    
    barcode_1_read_2 = row.processing_name_1.split(";")[1]
    barcode_2_read_2 = row.processing_name_2.split(";")[1]
    
    barcode_1_read_2 = os.path.join(analysis_dir, ".".join(os.path.basename(barcode_1_read_1).split(".")[:-2]) + ".adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2")
    barcode_2_read_2 = os.path.join(analysis_dir, ".".join(os.path.basename(barcode_2_read_1).split(".")[:-2]) + ".adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2")

    
    if not os.path.exists(barcode_1_read_1):
        print barcode_1_read_1
    if not  os.path.exists(barcode_2_read_1):
        print barcode_2_read_1
    if not  os.path.exists(barcode_1_read_2):
        print barcode_1_read_2
    if not  os.path.exists(barcode_2_read_2):
        print barcode_2_read_2
        
#     try:
#         with open(r1_out_file, 'wb') as out_file, open(barcode_1_read_1) as fn_1, open(barcode_2_read_1) as fn_2:
#             shutil.copyfileobj(fn_1, out_file)
#             shutil.copyfileobj(fn_2, out_file)
#     except IOError as e:
#         print e
#     try:
#         with open(r2_out_file, 'wb') as out_file, open(barcode_1_read_2) as fn_1, open(barcode_2_read_2) as fn_2:
#             shutil.copyfileobj(fn_1, out_file)
#             shutil.copyfileobj(fn_2, out_file)
#     except IOError as e:
#         print e
# Out:
# /projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.C01_222_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.D08fixed_222_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.C01_222_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.D08fixed_222_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.C01_222_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.C01_222_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.A01_222_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.B06_222_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.A01_222_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.B06_222_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.A01_222_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/222_CLIP_ATTACTCG-CCTATCCT_L001_R1.A01_222_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.A01_223_01_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.B06_223_01_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.A01_223_01_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.B06_223_01_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.A01_223_01_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.A01_223_01_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.C01_223_02_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.D08fixed_223_02_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.C01_223_02_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.D08fixed_223_02_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.C01_223_02_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/223_CLIP_TCCGGAGA-CCTATCCT_L001_R1.C01_223_02_FKBP4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.A01_224_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.B06_224_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.A01_224_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.B06_224_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.A01_224_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.A01_224_01_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.C01_224_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.D08fixed_224_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.C01_224_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.D08fixed_224_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.C01_224_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/224_CLIP_TCCGGAGA-GGCTCTGA_L001_R1.C01_224_02_HNRNPM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.A03_236_01_FMR1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.G07_236_01_FMR1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.A03_236_01_FMR1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.G07_236_01_FMR1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.A03_236_01_FMR1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.A03_236_01_FMR1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.A04_236_02_FMR1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.F05_236_02_FMR1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.A04_236_02_FMR1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.F05_236_02_FMR1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.A04_236_02_FMR1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/236_CLIP_ATTACTCG-TATAGCCT_L001_R1.A04_236_02_FMR1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.A01_227_01_SLTM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.B06_227_01_SLTM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.A01_227_01_SLTM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.B06_227_01_SLTM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.A01_227_01_SLTM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.A01_227_01_SLTM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.C01_227_02_SLTM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.D08fixed_227_02_SLTM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.C01_227_02_SLTM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.D08fixed_227_02_SLTM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.C01_227_02_SLTM.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/227_CLIP_ATTCAGAA-TAATCTTA_L002_R1.C01_227_02_SLTM.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.A01_230_01_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.B06_230_01_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.A01_230_01_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.B06_230_01_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.A01_230_01_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.A01_230_01_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.C01_230_02_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.D08fixed_230_02_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.C01_230_02_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.D08fixed_230_02_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.C01_230_02_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.C01_230_02_BCCIP.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.A04_235_01_XRN2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.F05_235_01_XRN2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.A04_235_01_XRN2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.F05_235_01_XRN2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.A04_235_01_XRN2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.A04_235_01_XRN2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.A03_235_02_XRN2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.G07_235_02_XRN2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.A03_235_02_XRN2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.G07_235_02_XRN2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.A03_235_02_XRN2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/235_CLIP_ATTCAGAA-CCTATCCT_L002_R1.A03_235_02_XRN2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.C01_226_01_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.D08fixed_226_01_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.C01_226_01_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.D08fixed_226_01_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.C01_226_01_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.C01_226_01_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.A01_226_02_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.B06_226_02_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.A01_226_02_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.B06_226_02_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.A01_226_02_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/226_CLIP_GAATTCGT-GGCTCTGA_L003_R1.A01_226_02_IGF2BP2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.A01_228_01_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.B06_228_01_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.A01_228_01_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.B06_228_01_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.A01_228_01_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.A01_228_01_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.C01_228_02_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.D08fixed_228_02_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.C01_228_02_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.D08fixed_228_02_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.C01_228_02_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/228_CLIP_ATTACTCG-AGGCGAAG_L003_R1.C01_228_02_SF3B4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.A03_237_01_FXR2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.G07_237_01_FXR2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.A03_237_01_FXR2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.G07_237_01_FXR2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.A03_237_01_FXR2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.A03_237_01_FXR2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.A04_237_02_FXR2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.F05_237_02_FXR2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.A04_237_02_FXR2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.F05_237_02_FXR2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.A04_237_02_FXR2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/234_CLIP_GAATTCGT-TATAGCCT_L003_R1.A04_237_02_FXR2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.A01_220_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.B06_220_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.A01_220_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.B06_220_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.A01_220_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.A01_220_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.C01_220_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.D08fixed_220_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.C01_220_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.D08fixed_220_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.C01_220_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/220-CLIPs_S1_R1.C01_220_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.C01_218_01_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.D08fixed_218_01_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.C01_218_01_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.D08fixed_218_01_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.C01_218_01_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.C01_218_01_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.A01_218_02_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.B06_218_02_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.A01_218_02_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.B06_218_02_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.A01_218_02_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/218-CLIPs_S3_R1.A01_218_02_TRA2A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.C01_203_01_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.D08fixed_203_01_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.C01_203_01_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.D08fixed_203_01_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.C01_203_01_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.C01_203_01_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.A01_203_02_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.B06_203_02_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.A01_203_02_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.B06_203_02_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.A01_203_02_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/203-CLIPs_S6_R1.A01_203_02_HNRNPC.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/206-01_S8_R1.C01_206_01_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/206-01_S8_R1.D08fixed_206_01_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/206-01_S8_R1.C01_206_01_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/206-01_S8_R1.D08fixed_206_01_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/206-01_S8_R1.C01_206_01_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/206-01_S8_R1.C01_206_01_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/206-NL_S9_R1.A01_206_02_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/206-NL_S9_R1.B06_206_02_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/206-NL_S9_R1.A01_206_02_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/206-NL_S9_R1.B06_206_02_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/206-NL_S9_R1.A01_206_02_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/206-NL_S9_R1.A01_206_02_HNRNPK.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.A01_209_01_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.B06_209_01_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.A01_209_01_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.B06_209_01_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.A01_209_01_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.A01_209_01_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.C01_209_02_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.D08fixed_209_02_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.C01_209_02_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.D08fixed_209_02_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.C01_209_02_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/209-CLIPs_S11_R1.C01_209_02_SRSF7.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.A01_204_01_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.B06_204_01_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.A01_204_01_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.B06_204_01_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.A01_204_01_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.A01_204_01_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.C01_204_02_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.D08fixed_204_02_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.C01_204_02_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.D08fixed_204_02_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.C01_204_02_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/RBFOX2-204-CLIP_S1_R1.C01_204_02_RBFOX2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.A01_205_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.B06_205_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.A01_205_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.B06_205_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.A01_205_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.A01_205_01_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.C01_205_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.D08fixed_205_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.C01_205_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.D08fixed_205_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.C01_205_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP1-205-CLIP_S3_R1.C01_205_02_IGF2BP1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.A01_211_01_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.B06_211_01_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.A01_211_01_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.B06_211_01_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.A01_211_01_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.A01_211_01_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.C01_211_02_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.D08fixed_211_02_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.C01_211_02_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.D08fixed_211_02_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.C01_211_02_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/IGF2BP3-211-CLIP_S7_R1.C01_211_02_IGF2BP3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.A01_215_01_TIA1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.B06_215_01_TIA1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.A01_215_01_TIA1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.B06_215_01_TIA1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.A01_215_01_TIA1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.A01_215_01_TIA1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.C01_215_02_TIA1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.D08fixed_215_02_TIA1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.C01_215_02_TIA1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.D08fixed_215_02_TIA1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.C01_215_02_TIA1.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/TIA1-215-CLIP_S9_R1.C01_215_02_TIA1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.C01_216_01_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.D08fixed_216_01_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.C01_216_01_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.D08fixed_216_01_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.C01_216_01_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.C01_216_01_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.A01_216_02_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.B06_216_02_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.A01_216_02_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.B06_216_02_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.A01_216_02_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/SRSF9-216-CLIP_S11_R1.A01_216_02_SRSF9.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.C01_280_01_AUH.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.D08fixed_280_01_AUH.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.C01_280_01_AUH.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.D08fixed_280_01_AUH.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.C01_280_01_AUH.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.C01_280_01_AUH.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.A03_280_02_AUH.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.G07_280_02_AUH.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.A03_280_02_AUH.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.G07_280_02_AUH.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.A03_280_02_AUH.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/280_CLIP_TCCGGAGA-TATAGCCT_L001_R1.A03_280_02_AUH.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.A01_258_01_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.B06_258_01_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.A01_258_01_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.B06_258_01_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.A01_258_01_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.A01_258_01_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.C01_258_02_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.D08fixed_258_02_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# /projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.C01_258_02_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.D08fixed_258_02_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.C01_258_02_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1'
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/258_CLIP_TCCGGAGA-ATAGAGGC_L001_R1.C01_258_02_CPSF6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/281_CLIP_TCCGGAGA-CCTATCCT_L001_R1.A03_281_01_HNRNPU.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate1
# ...
# /projects/ps-yeolab2/encode/analysis/encode_master/548_CLIP_S25_L003_R1_001.X2A_548_02_ZRANB2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/548_CLIP_S25_L003_R1_001.X2B_548_02_ZRANB2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/548_CLIP_S25_L003_R1_001.X2A_548_02_ZRANB2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/550_CLIP_S33_L004_R1_001.X1A_550_01_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/550_CLIP_S33_L004_R1_001.X1B_550_01_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/550_CLIP_S33_L004_R1_001.X1A_550_01_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/550_CLIP_S33_L004_R1_001.X2A_550_02_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/550_CLIP_S33_L004_R1_001.X2B_550_02_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/550_CLIP_S33_L004_R1_001.X2A_550_02_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/551_CLIP_S27_L003_R1_001.X1A_551_01_YBX3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/551_CLIP_S27_L003_R1_001.X1B_551_01_YBX3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/551_CLIP_S27_L003_R1_001.X1A_551_01_YBX3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/551_CLIP_S27_L003_R1_001.X2A_551_02_YBX3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/551_CLIP_S27_L003_R1_001.X2B_551_02_YBX3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/551_CLIP_S27_L003_R1_001.X2A_551_02_YBX3.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/577_CLIP_S19_L002_R1_001.A01_577_01_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/577_CLIP_S19_L002_R1_001.B06_577_01_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/577_CLIP_S19_L002_R1_001.A01_577_01_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/577_CLIP_S19_L002_R1_001.C01_577_02_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/577_CLIP_S19_L002_R1_001.D08fixed_577_02_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/577_CLIP_S19_L002_R1_001.C01_577_02_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/582_CLIP_S9_L001_R1_001.C01_582_01_EFTUD2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/582_CLIP_S9_L001_R1_001.D08fixed_582_01_EFTUD2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/582_CLIP_S9_L001_R1_001.C01_582_01_EFTUD2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/582_CLIP_S9_L001_R1_001.A01_582_02_EFTUD2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/582_CLIP_S9_L001_R1_001.B06_582_02_EFTUD2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/582_CLIP_S9_L001_R1_001.A01_582_02_EFTUD2.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/617_CLIP_S35_L004_R1_001.A04_617_01_TBRG4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/617_CLIP_S35_L004_R1_001.F05_617_01_TBRG4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/617_CLIP_S35_L004_R1_001.A04_617_01_TBRG4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/617_CLIP_S35_L004_R1_001.A03_617_02_TBRG4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/617_CLIP_S35_L004_R1_001.G07_617_02_TBRG4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/617_CLIP_S35_L004_R1_001.A03_617_02_TBRG4.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/589_CLIP_S11_L004_R1_001.X1A_589_01_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/589_CLIP_S11_L004_R1_001.X1B_589_01_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/589_CLIP_S11_L004_R1_001.X1A_589_01_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/589_CLIP_S11_L004_R1_001.X2A_589_02_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/589_CLIP_S11_L004_R1_001.X2B_589_02_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/589_CLIP_S11_L004_R1_001.X2A_589_02_DDX6.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/625_CLIP_S7_L004_R1_001.A04_625_01_EIF3D.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/625_CLIP_S7_L004_R1_001.F05_625_01_EIF3D.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/625_CLIP_S7_L004_R1_001.A04_625_01_EIF3D.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/625_CLIP_S7_L004_R1_001.A03_625_02_EIF3D.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/625_CLIP_S7_L004_R1_001.G07_625_02_EIF3D.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/625_CLIP_S7_L004_R1_001.A03_625_02_EIF3D.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/626_CLIP_S13_L005_R1_001.A04_626_01_EIF4B.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/626_CLIP_S13_L005_R1_001.F05_626_01_EIF4B.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/626_CLIP_S13_L005_R1_001.A04_626_01_EIF4B.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/626_CLIP_S13_L005_R1_001.A03_626_02_EIF4B.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/626_CLIP_S13_L005_R1_001.G07_626_02_EIF4B.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/626_CLIP_S13_L005_R1_001.A03_626_02_EIF4B.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/628_CLIP_S15_L005_R1_001.A04_628_01_GRWD1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/628_CLIP_S15_L005_R1_001.F05_628_01_GRWD1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/628_CLIP_S15_L005_R1_001.A04_628_01_GRWD1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/628_CLIP_S15_L005_R1_001.A03_628_02_GRWD1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/628_CLIP_S15_L005_R1_001.G07_628_02_GRWD1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/628_CLIP_S15_L005_R1_001.A03_628_02_GRWD1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/629_CLIP_S21_L005_R1_001.A04_629_01_UCHL5.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/629_CLIP_S21_L005_R1_001.F05_629_01_UCHL5.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/629_CLIP_S21_L005_R1_001.A04_629_01_UCHL5.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/629_CLIP_S21_L005_R1_001.A03_629_02_UCHL5.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/629_CLIP_S21_L005_R1_001.G07_629_02_UCHL5.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/629_CLIP_S21_L005_R1_001.A03_629_02_UCHL5.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/595_CLIP_S104_L008_R1_001.A04_595_01_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/595_CLIP_S104_L008_R1_001.F05_595_01_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/595_CLIP_S104_L008_R1_001.A04_595_01_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/595_CLIP_S104_L008_R1_001.A03_595_02_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/595_CLIP_S104_L008_R1_001.G07_595_02_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/595_CLIP_S104_L008_R1_001.A03_595_02_DDX55.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/596_CLIP_S106_L008_R1_001.A04_596_01_GRSF1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/596_CLIP_S106_L008_R1_001.F05_596_01_GRSF1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/596_CLIP_S106_L008_R1_001.A04_596_01_GRSF1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/596_CLIP_S106_L008_R1_001.A03_596_02_GRSF1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/596_CLIP_S106_L008_R1_001.G07_596_02_GRSF1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/596_CLIP_S106_L008_R1_001.A03_596_02_GRSF1.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/641_CLIP_S110_L008_R1_001.A04_641_01_ZC3H11A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/641_CLIP_S110_L008_R1_001.F05_641_01_ZC3H11A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/641_CLIP_S110_L008_R1_001.A04_641_01_ZC3H11A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'
# /projects/ps-yeolab2/encode/analysis/encode_master/641_CLIP_S110_L008_R1_001.A03_641_02_ZC3H11A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# /projects/ps-yeolab2/encode/analysis/encode_master/641_CLIP_S110_L008_R1_001.G07_641_02_ZC3H11A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2
# [Errno 2] No such file or directory: '/projects/ps-yeolab2/encode/analysis/encode_master/641_CLIP_S110_L008_R1_001.A03_641_02_ZC3H11A.adapterTrim.round2.rep.bamUnmapped.out.adapterTrim.round2.rep.bamUnmapped.out.sorted.mate2'

# %% [markdown]
# #upload files to sauron

# %%
for fn in good_to_go_input.out_fastq_r1:
    # !scp $fn sauron.ucsd.edu:/rpool/www/for_encode
    
for fn in good_to_go_input.out_fastq_r2:
    # !scp $fn sauron.ucsd.edu:/rpool/www/for_encode
# Out:
# 631_INPUT_EFTUD2.R1.fastq.gz        100%  789MB  65.8MB/s  64.8MB/s   00:12
# 545_INPUT_EIF3H.R1.fastq.gz         100%  740MB  67.3MB/s  65.2MB/s   00:11
# 551_INPUT_YBX3.R1.fastq.gz          100%  692MB  69.2MB/s  66.7MB/s   00:10
# 629_INPUT_UCHL5.R1.fastq.gz         100%  328MB  65.6MB/s  65.0MB/s   00:05
# 631_INPUT_EFTUD2.R2.fastq.gz        100%  745MB  62.1MB/s  64.3MB/s   00:12
# 545_INPUT_EIF3H.R2.fastq.gz         100%  696MB  63.3MB/s  65.1MB/s   00:11
# 551_INPUT_YBX3.R2.fastq.gz          100%  692MB  62.9MB/s  64.8MB/s   00:11
# 629_INPUT_UCHL5.R2.fastq.gz         100%  313MB  78.4MB/s  66.6MB/s   00:04

# %%
for fn in good_to_go_clip.out_fastq_r1:
    # !scp $fn sauron.ucsd.edu:/rpool/www/for_encode
    
for fn in good_to_go_clip.out_fastq_r2:
    # !scp $fn sauron.ucsd.edu:/rpool/www/for_encode
# Out:
# 631_01_EFTUD2.R1.fastq.gz           100%  652MB  36.2MB/s  55.1MB/s   00:18
# 631_02_EFTUD2.R1.fastq.gz           100%  674MB  33.7MB/s  51.7MB/s   00:20
# 545_01_EIF3H.R1.fastq.gz            100%  680MB  35.8MB/s  48.3MB/s   00:19
# 545_02_EIF3H.R1.fastq.gz            100%  654MB  54.5MB/s  64.6MB/s   00:12
# 551_01_YBX3.R1.fastq.gz             100%  703MB  63.9MB/s  64.8MB/s   00:11
# 551_02_YBX3.R1.fastq.gz             100%  620MB  62.0MB/s  65.0MB/s   00:10
# 629_01_UCHL5.R1.fastq.gz            100%  981MB  65.4MB/s  65.3MB/s   00:15
# 629_02_UCHL5.R1.fastq.gz            100%  583MB  58.4MB/s  64.3MB/s   00:10
# 631_01_EFTUD2.R2.fastq.gz           100%  703MB  29.3MB/s  47.2MB/s   00:24
# 631_02_EFTUD2.R2.fastq.gz           100%  721MB  34.3MB/s  53.0MB/s   00:21
# 545_01_EIF3H.R2.fastq.gz            100%  680MB  35.8MB/s  65.0MB/s   00:19
# 545_02_EIF3H.R2.fastq.gz            100%  671MB  67.1MB/s  65.0MB/s   00:10
# 551_01_YBX3.R2.fastq.gz             100%  763MB  63.6MB/s  65.1MB/s   00:12
# 551_02_YBX3.R2.fastq.gz             100%  671MB  61.0MB/s  65.1MB/s   00:11
# 629_01_UCHL5.R2.fastq.gz            100% 1033MB  64.6MB/s  65.1MB/s   00:16
# 629_02_UCHL5.R2.fastq.gz            100%  621MB  51.7MB/s  66.7MB/s   00:12

# %%
for fn in good_to_go_clip.out_bam:
    # !scp $fn sauron.ucsd.edu:/rpool/www/for_encode
    
for fn in good_to_go_input.out_bam:
    # !scp $fn sauron.ucsd.edu:/rpool/www/for_encode
    
for fn in good_to_go_clip.out_peaks:
    # !scp $fn sauron.ucsd.edu:/rpool/www/for_encode
# Out:
# 631_01_EFTUD2.merged.bam            100%  445MB  34.2MB/s  52.1MB/s   00:13
# 631_02_EFTUD2.merged.bam            100%  158MB  31.7MB/s  48.1MB/s   00:05
# 545_01_EIF3H.merged.bam             100%  240MB  39.9MB/s  52.0MB/s   00:06
# 545_02_EIF3H.merged.bam             100%  211MB  42.3MB/s  49.5MB/s   00:05
# 551_01_YBX3.merged.bam              100%  684MB  40.2MB/s  52.5MB/s   00:17
# 551_02_YBX3.merged.bam              100%  708MB  35.4MB/s  52.1MB/s   00:20
# 629_01_UCHL5.merged.bam             100% 1057MB  34.1MB/s  52.2MB/s   00:31
# 629_02_UCHL5.merged.bam             100%  687MB  38.2MB/s  59.6MB/s   00:18
# /projects/ps-yeolab2/encode/analysis/encode_v12/631_INPUT_S20_L002_R1_001.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.bam: No such file or directory
# /projects/ps-yeolab2/encode/analysis/encode_v12/545_INPUT_S18_L002_R1_001.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.bam: No such file or directory
# /projects/ps-yeolab2/encode/analysis/encode_v12/551_INPUT_S28_L003_R1_001.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.bam: No such file or directory
# /projects/ps-yeolab2/encode/analysis/encode_v12/629_INPUT_S22_L005_R1_001.unassigned.adapterTrim.round2.rmRep.rmDup.sorted.bam: No such file or directory
# 631_01_EFTUD2.merged.r2.peaks.fixed 100% 3001KB   2.9MB/s   2.9MB/s   00:00
# 631_02_EFTUD2.merged.r2.peaks.fixed 100% 3653KB   3.6MB/s   3.6MB/s   00:01
# 545_01_EIF3H.merged.r2.peaks.fixed. 100% 3670KB   3.6MB/s   3.6MB/s   00:01
# 545_02_EIF3H.merged.r2.peaks.fixed. 100% 2494KB   2.4MB/s   2.4MB/s   00:00
# 551_01_YBX3.merged.r2.peaks.fixed.b 100% 7744KB   3.8MB/s   4.1MB/s   00:02
# 551_02_YBX3.merged.r2.peaks.fixed.b 100% 7989KB   7.8MB/s   7.8MB/s   00:00
# 629_01_UCHL5.merged.r2.peaks.fixed. 100% 5883KB   5.7MB/s   5.7MB/s   00:00
# 629_02_UCHL5.merged.r2.peaks.fixed. 100% 5276KB   5.2MB/s   5.2MB/s   00:01

# %% [markdown]
# #Create report to paste into xintao's spreadsheet

# %%
merged_good_to_go = pd.concat([good_to_go_clip, good_to_go_input], axis=0)

# %%
sauron_url = "sauron.ucsd.edu/for_encode"

# %%
def to_sauron_url(fn):
    try:
        return os.path.join(sauron_url, os.path.basename(fn))
    except AttributeError:
        return np.nan

# %%
merged_good_to_go['out_fastq_r1'] = merged_good_to_go.out_fastq_r1.apply(to_sauron_url)
merged_good_to_go['out_fastq_r2'] = merged_good_to_go.out_fastq_r2.apply(to_sauron_url)
merged_good_to_go['out_bam'] = merged_good_to_go.out_bam.apply(to_sauron_url)
merged_good_to_go['out_peaks'] = merged_good_to_go.out_peaks.apply(to_sauron_url)

# %%
#xintao_manifest = pd.read_csv("/home/gpratt/Dropbox/encode_integration/for_eric/ENCODE_YEO_submission - 2015_1211.csv")
#xintao_manifest = pd.read_csv("/home/gpratt/Dropbox/encode_integration/for_eric/ENCODE_YEO_submission - 2016_0309.csv")
xintao_manifest = pd.read_csv("/home/gpratt/Dropbox/encode_integration/for_eric/ENCODE_YEO_submission - 2016_0315.csv")
#xintao_manifest = pd.read_csv("/home/gpratt/Dropbox/encode_integration/for_eric/ENCODE_YEO_submission - ENTEX.csv")

# %%
merged_good_to_go['ENCODE_ID'] = merged_good_to_go.ENCODE_ID.apply(lambda x: x.replace("_4000", ""))

# %%
merged_good_to_go
# Out:
#         ENCODE_ID Hiseq_file_name  Lane Method_Paper_flag     RBP  \
# 1011       631_01    631_CLIP_S19  L002             FALSE  EFTUD2
# 1012       631_02    631_CLIP_S19  L002             FALSE  EFTUD2
# 1120       545_01    545_CLIP_S17  L002             FALSE   EIF3H
# 1121       545_02    545_CLIP_S17  L002             FALSE   EIF3H
# 1129       551_01    551_CLIP_S27  L003             FALSE    YBX3
# 1130       551_02    551_CLIP_S27  L003             FALSE    YBX3
# 1195       629_01    629_CLIP_S21  L005             FALSE   UCHL5
# 1196       629_02    629_CLIP_S21  L005             FALSE   UCHL5
# 1013    631_INPUT   631_INPUT_S20  L002             FALSE  EFTUD2
# 1122    545_INPUT   545_INPUT_S18  L002             FALSE   EIF3H
# 1131    551_INPUT   551_INPUT_S28  L003             FALSE    YBX3
# 1197    629_INPUT   629_INPUT_S22  L005             FALSE   UCHL5
#
#                                               base_name cell_type  exp_id  \
# 1011                                                NaN               631
# 1012                                                NaN               631
# 1120                                                NaN               545
# 1121                                                NaN               545
# 1129                                                NaN               551
# 1130                                                NaN               551
# 1195                                                NaN               629
# 1196                                                NaN               629
# 1013  /projects/ps-yeolab2/encode/analysis/encode_v1...               631
# 1122  /projects/ps-yeolab2/encode/analysis/encode_v1...               545
# 1131  /projects/ps-yeolab2/encode/analysis/encode_v1...               551
# 1197  /projects/ps-yeolab2/encode/analysis/encode_v1...               629
#
#                                           file_location        ...         \
# 1011  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1012  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1120  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1121  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1129  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1130  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1195  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1196  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1013  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1122  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1131  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
# 1197  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....        ...
#
#                                            out_fastq_r2  \
# 1011  sauron.ucsd.edu/for_encode/631_01_EFTUD2.R2.fa...
# 1012  sauron.ucsd.edu/for_encode/631_02_EFTUD2.R2.fa...
# 1120  sauron.ucsd.edu/for_encode/545_01_EIF3H.R2.fas...
# 1121  sauron.ucsd.edu/for_encode/545_02_EIF3H.R2.fas...
# 1129  sauron.ucsd.edu/for_encode/551_01_YBX3.R2.fast...
# 1130  sauron.ucsd.edu/for_encode/551_02_YBX3.R2.fast...
# 1195  sauron.ucsd.edu/for_encode/629_01_UCHL5.R2.fas...
# 1196  sauron.ucsd.edu/for_encode/629_02_UCHL5.R2.fas...
# 1013  sauron.ucsd.edu/for_encode/631_INPUT_EFTUD2.R2...
# 1122  sauron.ucsd.edu/for_encode/545_INPUT_EIF3H.R2....
# 1131  sauron.ucsd.edu/for_encode/551_INPUT_YBX3.R2.f...
# 1197  sauron.ucsd.edu/for_encode/629_INPUT_UCHL5.R2....
#
#                                               out_peaks  \
# 1011  sauron.ucsd.edu/for_encode/631_01_EFTUD2.merge...
# 1012  sauron.ucsd.edu/for_encode/631_02_EFTUD2.merge...
# 1120  sauron.ucsd.edu/for_encode/545_01_EIF3H.merged...
# 1121  sauron.ucsd.edu/for_encode/545_02_EIF3H.merged...
# 1129  sauron.ucsd.edu/for_encode/551_01_YBX3.merged....
# 1130  sauron.ucsd.edu/for_encode/551_02_YBX3.merged....
# 1195  sauron.ucsd.edu/for_encode/629_01_UCHL5.merged...
# 1196  sauron.ucsd.edu/for_encode/629_02_UCHL5.merged...
# 1013                                                NaN
# 1122                                                NaN
# 1131                                                NaN
# 1197                                                NaN
#
#                                         processing_name  \
# 1011                                                NaN
# 1012                                                NaN
# 1120                                                NaN
# 1121                                                NaN
# 1129                                                NaN
# 1130                                                NaN
# 1195                                                NaN
# 1196                                                NaN
# 1013  /home/gpratt/projects/encode/analysis/encode_s...
# 1122  /home/gpratt/projects/encode/analysis/encode_s...
# 1131  /home/gpratt/projects/encode/analysis/encode_s...
# 1197  /home/gpratt/projects/encode/analysis/encode_s...
#
#                                       processing_name_1  \
# 1011  /home/gpratt/projects/encode/analysis/encode_s...
# 1012  /home/gpratt/projects/encode/analysis/encode_s...
# 1120  /home/gpratt/projects/encode/analysis/encode_s...
# 1121  /home/gpratt/projects/encode/analysis/encode_s...
# 1129  /home/gpratt/projects/encode/analysis/encode_s...
# 1130  /home/gpratt/projects/encode/analysis/encode_s...
# 1195  /home/gpratt/projects/encode/analysis/encode_s...
# 1196  /home/gpratt/projects/encode/analysis/encode_s...
# 1013                                                NaN
# 1122                                                NaN
# 1131                                                NaN
# 1197                                                NaN
#
#                                       processing_name_2  \
# 1011  /home/gpratt/projects/encode/analysis/encode_s...
# 1012  /home/gpratt/projects/encode/analysis/encode_s...
# 1120  /home/gpratt/projects/encode/analysis/encode_s...
# 1121  /home/gpratt/projects/encode/analysis/encode_s...
# 1129  /home/gpratt/projects/encode/analysis/encode_s...
# 1130  /home/gpratt/projects/encode/analysis/encode_s...
# 1195  /home/gpratt/projects/encode/analysis/encode_s...
# 1196  /home/gpratt/projects/encode/analysis/encode_s...
# 1013                                                NaN
# 1122                                                NaN
# 1131                                                NaN
# 1197                                                NaN
#
#                                                      r1  \
# 1011  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1012  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1120  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1121  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1129  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1130  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1195  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1196  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1013  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1122  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1131  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1197  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
#
#                                                      r2 randomer_length  \
# 1011  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1012  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1120  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1121  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1129  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1130  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1195  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1196  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1013  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1122  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1131  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 1197  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
#
#      species unmerged_location
# 1011    hg19
# 1012    hg19
# 1120    hg19
# 1121    hg19
# 1129    hg19
# 1130    hg19
# 1195    hg19
# 1196    hg19
# 1013    hg19
# 1122    hg19
# 1131    hg19
# 1197    hg19
#
# [12 rows x 37 columns]

# %%
xintao_manifest
# Out:
#     UID ENCODE_ACCESSION  ENCODE_aliases    Rep_UID Replicate      RBP  \
# 0   235            FIXME             NaN     235_01      rep1     XRN2
# 1   235            FIXME             NaN     235_02      rep2     XRN2
# 2   235            FIXME             NaN  235_INPUT   control     XRN2
# 3   390            FIXME             NaN     390_01      rep1    DDX20
# 4   390            FIXME             NaN     390_02      rep2    DDX20
# 5   390            FIXME             NaN  390_INPUT   control    DDX20
# 6   491            FIXME             NaN     491_01      rep1   EXOSC5
# 7   491            FIXME             NaN     491_02      rep2   EXOSC5
# 8   491            FIXME             NaN  491_INPUT   control   EXOSC5
# 9   501            FIXME             NaN     501_01      rep1     RBM5
# 10  501            FIXME             NaN     501_02      rep2     RBM5
# 11  501            FIXME             NaN  501_INPUT   control     RBM5
# 12  503            FIXME             NaN     503_01      rep1   TROVE2
# 13  503            FIXME             NaN     503_02      rep2   TROVE2
# 14  503            FIXME             NaN  503_INPUT   control   TROVE2
# 15  522            FIXME             NaN     522_01      rep1     HLTF
# 16  522            FIXME             NaN     522_02      rep2     HLTF
# 17  522            FIXME             NaN  522_INPUT   control     HLTF
# 18  529            FIXME             NaN     529_01      rep1    RPS24
# 19  529            FIXME             NaN     529_02      rep2    RPS24
# 20  529            FIXME             NaN  529_INPUT   control    RPS24
# 21  531            FIXME             NaN     531_01      rep1     RPS5
# 22  531            FIXME             NaN     531_02      rep2     RPS5
# 23  531            FIXME             NaN  531_INPUT   control     RPS5
# 24  548            FIXME             NaN     548_01      rep1   ZRANB2
# 25  548            FIXME             NaN     548_02      rep2   ZRANB2
# 26  548            FIXME             NaN  548_INPUT   control   ZRANB2
# 27  550            FIXME             NaN     550_01      rep1    DDX55
# 28  550            FIXME             NaN     550_02      rep2    DDX55
# 29  550            FIXME             NaN  550_INPUT   control    DDX55
# ..  ...              ...             ...        ...       ...      ...
# 60  617            FIXME             NaN     617_01      rep1    TBRG4
# 61  617            FIXME             NaN     617_02      rep2    TBRG4
# 62  617            FIXME             NaN  617_INPUT   control    TBRG4
# 63  624            FIXME             NaN     624_01      rep1     AARS
# 64  624            FIXME             NaN     624_02      rep2     AARS
# 65  624            FIXME             NaN  624_INPUT   control     AARS
# 66  625            FIXME             NaN     625_01      rep1    EIF3D
# 67  625            FIXME             NaN     625_02      rep2    EIF3D
# 68  625            FIXME             NaN  625_INPUT   control    EIF3D
# 69  626            FIXME             NaN     626_01      rep1    EIF4B
# 70  626            FIXME             NaN     626_02      rep2    EIF4B
# 71  626            FIXME             NaN  626_INPUT   control    EIF4B
# 72  628            FIXME             NaN     628_01      rep1    GRWD1
# 73  628            FIXME             NaN     628_02      rep2    GRWD1
# 74  628            FIXME             NaN  628_INPUT   control    GRWD1
# 75  641            FIXME             NaN     641_01      rep1  ZC3H11A
# 76  641            FIXME             NaN     641_02      rep2  ZC3H11A
# 77  641            FIXME             NaN  641_INPUT   control  ZC3H11A
# 78  545            FIXME             NaN     545_01      rep1    EIF3H
# 79  545            FIXME             NaN     545_02      rep2    EIF3H
# 80  545            FIXME             NaN  545_INPUT   control    EIF3H
# 81  551            FIXME             NaN     551_01      rep1     YBX3
# 82  551            FIXME             NaN     551_02      rep2     YBX3
# 83  551            FIXME             NaN  551_INPUT   control     YBX3
# 84  629            FIXME             NaN     629_01      rep1    UCHL5
# 85  629            FIXME             NaN     629_02      rep2    UCHL5
# 86  629            FIXME             NaN  629_INPUT   control    UCHL5
# 87  631            FIXME             NaN     631_01      rep1   EFTUD2
# 88  631            FIXME             NaN     631_02      rep2   EFTUD2
# 89  631            FIXME             NaN  631_INPUT   control   EFTUD2
#
#    Cell_Line   Antibody  Lot# inline_barcode_1  ...  strand_specificity  \
# 0      HepG2  A301-103A     1              A04  ...                 yes
# 1      HepG2  A301-103A     1              A03  ...                 yes
# 2      HepG2  A301-103A     1             none  ...                 yes
# 3      HepG2  A300-651A     1              A04  ...                 yes
# 4      HepG2  A300-651A     1              A03  ...                 yes
# 5      HepG2  A300-651A     1             none  ...                 yes
# 6       K562    RN100PW     1              A01  ...                 yes
# 7       K562    RN100PW     1              C01  ...                 yes
# 8       K562    RN100PW     1             none  ...                 yes
# 9      HepG2  A302-228A     1              A01  ...                 yes
# 10     HepG2  A302-228A     1              C01  ...                 yes
# 11     HepG2  A302-228A     1             none  ...                 yes
# 12     HepG2  A303-692A     1              A01  ...                 yes
# 13     HepG2  A303-692A     1              C01  ...                 yes
# 14     HepG2  A303-692A     1             none  ...                 yes
# 15      K562  A300-230A     1              A01  ...                 yes
# 16      K562  A300-230A     1              C01  ...                 yes
# 17      K562  A300-230A     1             none  ...                 yes
# 18      K562  A303-842A     1              A01  ...                 yes
# 19      K562  A303-842A     1              C01  ...                 yes
# 20      K562  A303-842A     1             none  ...                 yes
# 21      K562  A304-010A     1              A01  ...                 yes
# 22      K562  A304-010A     1              C01  ...                 yes
# 23      K562  A304-010A     1             none  ...                 yes
# 24      K562  A301-029A     1              X1A  ...                 yes
# 25      K562  A301-029A     1              X2A  ...                 yes
# 26      K562  A301-029A     1             none  ...                 yes
# 27      K562  A303-027A     1              X1A  ...                 yes
# 28      K562  A303-027A     1              X2A  ...                 yes
# 29      K562  A303-027A     1             none  ...                 yes
# ..       ...        ...   ...              ...  ...                 ...
# 60     HepG2  A301-392A     1              A04  ...                 yes
# 61     HepG2  A301-392A     1              A03  ...                 yes
# 62     HepG2  A301-392A     1             none  ...                 yes
# 63      K562  A303-475A     1              A03  ...                 yes
# 64      K562  A303-475A     1              A04  ...                 yes
# 65      K562  A303-475A     1             none  ...                 yes
# 66     HepG2  A301-758A     1              A04  ...                 yes
# 67     HepG2  A301-758A     1              A03  ...                 yes
# 68     HepG2  A301-758A     1             none  ...                 yes
# 69     HepG2  A301-767A     1              A04  ...                 yes
# 70     HepG2  A301-767A     1              A03  ...                 yes
# 71     HepG2  A301-767A     1             none  ...                 yes
# 72     HepG2  A301-576A     1              A04  ...                 yes
# 73     HepG2  A301-576A     1              A03  ...                 yes
# 74     HepG2  A301-576A     1             none  ...                 yes
# 75     HepG2  A301-524A     1              A04  ...                 yes
# 76     HepG2  A301-524A     1              A03  ...                 yes
# 77     HepG2  A301-524A     1             none  ...                 yes
# 78     HepG2  A301-754A     1              C01  ...                 yes
# 79     HepG2  A301-754A     1              A01  ...                 yes
# 80     HepG2  A301-754A     1             none  ...                 yes
# 81      K562  A303-070A     1              X1A  ...                 yes
# 82      K562  A303-070A     1              X2A  ...                 yes
# 83      K562  A303-070A     1             none  ...                 yes
# 84     HepG2  A304-099A     1              A04  ...                 yes
# 85     HepG2  A304-099A     1              A03  ...                 yes
# 86     HepG2  A304-099A     1             none  ...                 yes
# 87     HepG2  A300-957A     1              X1A  ...                 yes
# 88     HepG2  A300-957A     1              X2A  ...                 yes
# 89     HepG2  A300-957A     1             none  ...                 yes
#
#     paired_ended                                     out_fastq_r1_y  \
# 0            yes  sauron.ucsd.edu/for_encode/235_01_4000_XRN2.R1...
# 1            yes  sauron.ucsd.edu/for_encode/235_02_4000_XRN2.R1...
# 2            yes  sauron.ucsd.edu/for_encode/235_INPUT_4000_XRN2...
# 3            yes  sauron.ucsd.edu/for_encode/390_01_4000_DDX20.R...
# 4            yes  sauron.ucsd.edu/for_encode/390_02_4000_DDX20.R...
# 5            yes  sauron.ucsd.edu/for_encode/390_INPUT_4000_DDX2...
# 6            yes  sauron.ucsd.edu/for_encode/491_01_EXOSC5.R1.fa...
# 7            yes  sauron.ucsd.edu/for_encode/491_02_EXOSC5.R1.fa...
# 8            yes  sauron.ucsd.edu/for_encode/491_INPUT_EXOSC5.R1...
# 9            yes  sauron.ucsd.edu/for_encode/501_01_RBM5.R1.fast...
# 10           yes  sauron.ucsd.edu/for_encode/501_02_RBM5.R1.fast...
# 11           yes  sauron.ucsd.edu/for_encode/501_INPUT_RBM5.R1.f...
# 12           yes  sauron.ucsd.edu/for_encode/503_01_TROVE2.R1.fa...
# 13           yes  sauron.ucsd.edu/for_encode/503_02_TROVE2.R1.fa...
# 14           yes  sauron.ucsd.edu/for_encode/503_INPUT_TROVE2.R1...
# 15           yes  sauron.ucsd.edu/for_encode/522_01_HLTF.R1.fast...
# 16           yes  sauron.ucsd.edu/for_encode/522_02_HLTF.R1.fast...
# 17           yes  sauron.ucsd.edu/for_encode/522_INPUT_HLTF.R1.f...
# 18           yes  sauron.ucsd.edu/for_encode/529_01_RPS24.R1.fas...
# 19           yes  sauron.ucsd.edu/for_encode/529_02_RPS24.R1.fas...
# 20           yes  sauron.ucsd.edu/for_encode/529_INPUT_RPS24.R1....
# 21           yes  sauron.ucsd.edu/for_encode/531_01_RPS5.R1.fast...
# 22           yes  sauron.ucsd.edu/for_encode/531_02_RPS5.R1.fast...
# 23           yes  sauron.ucsd.edu/for_encode/531_INPUT_RPS5.R1.f...
# 24           yes  sauron.ucsd.edu/for_encode/548_01_ZRANB2.R1.fa...
# 25           yes  sauron.ucsd.edu/for_encode/548_02_ZRANB2.R1.fa...
# 26           yes  sauron.ucsd.edu/for_encode/548_INPUT_ZRANB2.R1...
# 27           yes  sauron.ucsd.edu/for_encode/550_01_DDX55.R1.fas...
# 28           yes  sauron.ucsd.edu/for_encode/550_02_DDX55.R1.fas...
# 29           yes  sauron.ucsd.edu/for_encode/550_INPUT_DDX55.R1....
# ..           ...                                                ...
# 60           yes  sauron.ucsd.edu/for_encode/617_01_TBRG4.R1.fas...
# 61           yes  sauron.ucsd.edu/for_encode/617_02_TBRG4.R1.fas...
# 62           yes  sauron.ucsd.edu/for_encode/617_INPUT_TBRG4.R1....
# 63           yes  sauron.ucsd.edu/for_encode/624_01_AARS.R1.fast...
# 64           yes  sauron.ucsd.edu/for_encode/624_02_AARS.R1.fast...
# 65           yes  sauron.ucsd.edu/for_encode/624_INPUT_AARS.R1.f...
# 66           yes  sauron.ucsd.edu/for_encode/625_01_EIF3D.R1.fas...
# 67           yes  sauron.ucsd.edu/for_encode/625_02_EIF3D.R1.fas...
# 68           yes  sauron.ucsd.edu/for_encode/625_INPUT_EIF3D.R1....
# 69           yes  sauron.ucsd.edu/for_encode/626_01_EIF4B.R1.fas...
# 70           yes  sauron.ucsd.edu/for_encode/626_02_EIF4B.R1.fas...
# 71           yes  sauron.ucsd.edu/for_encode/626_INPUT_EIF4B.R1....
# 72           yes  sauron.ucsd.edu/for_encode/628_01_GRWD1.R1.fas...
# 73           yes  sauron.ucsd.edu/for_encode/628_02_GRWD1.R1.fas...
# 74           yes  sauron.ucsd.edu/for_encode/628_INPUT_GRWD1.R1....
# 75           yes  sauron.ucsd.edu/for_encode/641_01_ZC3H11A.R1.f...
# 76           yes  sauron.ucsd.edu/for_encode/641_02_ZC3H11A.R1.f...
# 77           yes  sauron.ucsd.edu/for_encode/641_INPUT_ZC3H11A.R...
# 78           yes                                     fastq_filename
# 79           yes                                     fastq_filename
# 80           yes                                     fastq_filename
# 81           yes                                     fastq_filename
# 82           yes                                     fastq_filename
# 83           yes                                     fastq_filename
# 84           yes                                     fastq_filename
# 85           yes                                     fastq_filename
# 86           yes                                     fastq_filename
# 87           yes                                     fastq_filename
# 88           yes                                     fastq_filename
# 89           yes                                     fastq_filename
#
#                                        out_fastq_r2_y  \
# 0   sauron.ucsd.edu/for_encode/235_01_4000_XRN2.R2...
# 1   sauron.ucsd.edu/for_encode/235_02_4000_XRN2.R2...
# 2   sauron.ucsd.edu/for_encode/235_INPUT_4000_XRN2...
# 3   sauron.ucsd.edu/for_encode/390_01_4000_DDX20.R...
# 4   sauron.ucsd.edu/for_encode/390_02_4000_DDX20.R...
# 5   sauron.ucsd.edu/for_encode/390_INPUT_4000_DDX2...
# 6   sauron.ucsd.edu/for_encode/491_01_EXOSC5.R2.fa...
# 7   sauron.ucsd.edu/for_encode/491_02_EXOSC5.R2.fa...
# 8   sauron.ucsd.edu/for_encode/491_INPUT_EXOSC5.R2...
# 9   sauron.ucsd.edu/for_encode/501_01_RBM5.R2.fast...
# 10  sauron.ucsd.edu/for_encode/501_02_RBM5.R2.fast...
# 11  sauron.ucsd.edu/for_encode/501_INPUT_RBM5.R2.f...
# 12  sauron.ucsd.edu/for_encode/503_01_TROVE2.R2.fa...
# 13  sauron.ucsd.edu/for_encode/503_02_TROVE2.R2.fa...
# 14  sauron.ucsd.edu/for_encode/503_INPUT_TROVE2.R2...
# 15  sauron.ucsd.edu/for_encode/522_01_HLTF.R2.fast...
# 16  sauron.ucsd.edu/for_encode/522_02_HLTF.R2.fast...
# 17  sauron.ucsd.edu/for_encode/522_INPUT_HLTF.R2.f...
# 18  sauron.ucsd.edu/for_encode/529_01_RPS24.R2.fas...
# 19  sauron.ucsd.edu/for_encode/529_02_RPS24.R2.fas...
# 20  sauron.ucsd.edu/for_encode/529_INPUT_RPS24.R2....
# 21  sauron.ucsd.edu/for_encode/531_01_RPS5.R2.fast...
# 22  sauron.ucsd.edu/for_encode/531_02_RPS5.R2.fast...
# 23  sauron.ucsd.edu/for_encode/531_INPUT_RPS5.R2.f...
# 24  sauron.ucsd.edu/for_encode/548_01_ZRANB2.R2.fa...
# 25  sauron.ucsd.edu/for_encode/548_02_ZRANB2.R2.fa...
# 26  sauron.ucsd.edu/for_encode/548_INPUT_ZRANB2.R2...
# 27  sauron.ucsd.edu/for_encode/550_01_DDX55.R2.fas...
# 28  sauron.ucsd.edu/for_encode/550_02_DDX55.R2.fas...
# 29  sauron.ucsd.edu/for_encode/550_INPUT_DDX55.R2....
# ..                                                ...
# 60  sauron.ucsd.edu/for_encode/617_01_TBRG4.R2.fas...
# 61  sauron.ucsd.edu/for_encode/617_02_TBRG4.R2.fas...
# 62  sauron.ucsd.edu/for_encode/617_INPUT_TBRG4.R2....
# 63  sauron.ucsd.edu/for_encode/624_01_AARS.R2.fast...
# 64  sauron.ucsd.edu/for_encode/624_02_AARS.R2.fast...
# 65  sauron.ucsd.edu/for_encode/624_INPUT_AARS.R2.f...
# 66  sauron.ucsd.edu/for_encode/625_01_EIF3D.R2.fas...
# 67  sauron.ucsd.edu/for_encode/625_02_EIF3D.R2.fas...
# 68  sauron.ucsd.edu/for_encode/625_INPUT_EIF3D.R2....
# 69  sauron.ucsd.edu/for_encode/626_01_EIF4B.R2.fas...
# 70  sauron.ucsd.edu/for_encode/626_02_EIF4B.R2.fas...
# 71  sauron.ucsd.edu/for_encode/626_INPUT_EIF4B.R2....
# 72  sauron.ucsd.edu/for_encode/628_01_GRWD1.R2.fas...
# 73  sauron.ucsd.edu/for_encode/628_02_GRWD1.R2.fas...
# 74  sauron.ucsd.edu/for_encode/628_INPUT_GRWD1.R2....
# 75  sauron.ucsd.edu/for_encode/641_01_ZC3H11A.R2.f...
# 76  sauron.ucsd.edu/for_encode/641_02_ZC3H11A.R2.f...
# 77  sauron.ucsd.edu/for_encode/641_INPUT_ZC3H11A.R...
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
#
#                                             out_bam_y  \
# 0   sauron.ucsd.edu/for_encode/235_01_4000_XRN2.me...
# 1   sauron.ucsd.edu/for_encode/235_02_4000_XRN2.me...
# 2   sauron.ucsd.edu/for_encode/235_INPUT_S54_L006_...
# 3   sauron.ucsd.edu/for_encode/390_01_4000_DDX20.m...
# 4   sauron.ucsd.edu/for_encode/390_02_4000_DDX20.m...
# 5   sauron.ucsd.edu/for_encode/390_INPUT_S60_L006_...
# 6   sauron.ucsd.edu/for_encode/491_01_EXOSC5.merge...
# 7   sauron.ucsd.edu/for_encode/491_02_EXOSC5.merge...
# 8   sauron.ucsd.edu/for_encode/491_INPUT_S2_L001_R...
# 9   sauron.ucsd.edu/for_encode/501_01_RBM5.merged.bam
# 10  sauron.ucsd.edu/for_encode/501_02_RBM5.merged.bam
# 11  sauron.ucsd.edu/for_encode/501_INPUT_S12_L002_...
# 12  sauron.ucsd.edu/for_encode/503_01_TROVE2.merge...
# 13  sauron.ucsd.edu/for_encode/503_02_TROVE2.merge...
# 14  sauron.ucsd.edu/for_encode/503_INPUT_S22_L003_...
# 15  sauron.ucsd.edu/for_encode/522_01_HLTF.merged.bam
# 16  sauron.ucsd.edu/for_encode/522_02_HLTF.merged.bam
# 17  sauron.ucsd.edu/for_encode/522_INPUT_S32_L004_...
# 18  sauron.ucsd.edu/for_encode/529_01_RPS24.merged...
# 19  sauron.ucsd.edu/for_encode/529_02_RPS24.merged...
# 20  sauron.ucsd.edu/for_encode/529_INPUT_S16_L002_...
# 21  sauron.ucsd.edu/for_encode/531_01_RPS5.merged.bam
# 22  sauron.ucsd.edu/for_encode/531_02_RPS5.merged.bam
# 23  sauron.ucsd.edu/for_encode/531_INPUT_S8_L001_R...
# 24  sauron.ucsd.edu/for_encode/548_01_ZRANB2.merge...
# 25  sauron.ucsd.edu/for_encode/548_02_ZRANB2.merge...
# 26  sauron.ucsd.edu/for_encode/548_INPUT_S26_L003_...
# 27  sauron.ucsd.edu/for_encode/550_01_DDX55.merged...
# 28  sauron.ucsd.edu/for_encode/550_02_DDX55.merged...
# 29  sauron.ucsd.edu/for_encode/550_INPUT_S34_L004_...
# ..                                                ...
# 60  sauron.ucsd.edu/for_encode/617_01_TBRG4.merged...
# 61  sauron.ucsd.edu/for_encode/617_02_TBRG4.merged...
# 62  sauron.ucsd.edu/for_encode/617_INPUT_S36_L004_...
# 63  sauron.ucsd.edu/for_encode/624_01_AARS.merged.bam
# 64  sauron.ucsd.edu/for_encode/624_02_AARS.merged.bam
# 65  sauron.ucsd.edu/for_encode/624_INPUT_S30_L003_...
# 66  sauron.ucsd.edu/for_encode/625_01_EIF3D.merged...
# 67  sauron.ucsd.edu/for_encode/625_02_EIF3D.merged...
# 68  sauron.ucsd.edu/for_encode/625_INPUT_S8_L004_R...
# 69  sauron.ucsd.edu/for_encode/626_01_EIF4B.merged...
# 70  sauron.ucsd.edu/for_encode/626_02_EIF4B.merged...
# 71  sauron.ucsd.edu/for_encode/626_INPUT_S14_L005_...
# 72  sauron.ucsd.edu/for_encode/628_01_GRWD1.merged...
# 73  sauron.ucsd.edu/for_encode/628_02_GRWD1.merged...
# 74  sauron.ucsd.edu/for_encode/628_INPUT_S16_L005_...
# 75  sauron.ucsd.edu/for_encode/641_01_ZC3H11A.merg...
# 76  sauron.ucsd.edu/for_encode/641_02_ZC3H11A.merg...
# 77  sauron.ucsd.edu/for_encode/641_INPUT_S111_L008...
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
#
#                                           out_peaks_y read_length     machine  \
# 0   sauron.ucsd.edu/for_encode/235_01_4000_XRN2.me...          50  hiseq 4000
# 1   sauron.ucsd.edu/for_encode/235_02_4000_XRN2.me...          50  hiseq 4000
# 2                                             no_file          50  hiseq 4000
# 3   sauron.ucsd.edu/for_encode/390_01_4000_DDX20.m...          50  hiseq 4000
# 4   sauron.ucsd.edu/for_encode/390_02_4000_DDX20.m...          50  hiseq 4000
# 5                                             no_file          50  hiseq 4000
# 6   sauron.ucsd.edu/for_encode/491_01_EXOSC5.merge...          50  hiseq 4000
# 7   sauron.ucsd.edu/for_encode/491_02_EXOSC5.merge...          50  hiseq 4000
# 8                                             no_file          50  hiseq 4000
# 9   sauron.ucsd.edu/for_encode/501_01_RBM5.merged....          50  hiseq 4000
# 10  sauron.ucsd.edu/for_encode/501_02_RBM5.merged....          50  hiseq 4000
# 11                                            no_file          50  hiseq 4000
# 12  sauron.ucsd.edu/for_encode/503_01_TROVE2.merge...          50  hiseq 4000
# 13  sauron.ucsd.edu/for_encode/503_02_TROVE2.merge...          50  hiseq 4000
# 14                                            no_file          50  hiseq 4000
# 15  sauron.ucsd.edu/for_encode/522_01_HLTF.merged....          50  hiseq 4000
# 16  sauron.ucsd.edu/for_encode/522_02_HLTF.merged....          50  hiseq 4000
# 17                                            no_file          50  hiseq 4000
# 18  sauron.ucsd.edu/for_encode/529_01_RPS24.merged...          50  hiseq 4000
# 19  sauron.ucsd.edu/for_encode/529_02_RPS24.merged...          50  hiseq 4000
# 20                                            no_file          50  hiseq 4000
# 21  sauron.ucsd.edu/for_encode/531_01_RPS5.merged....          50  hiseq 4000
# 22  sauron.ucsd.edu/for_encode/531_02_RPS5.merged....          50  hiseq 4000
# 23                                            no_file          50  hiseq 4000
# 24  sauron.ucsd.edu/for_encode/548_01_ZRANB2.merge...          50  hiseq 4000
# 25  sauron.ucsd.edu/for_encode/548_02_ZRANB2.merge...          50  hiseq 4000
# 26                                            no_file          50  hiseq 4000
# 27  sauron.ucsd.edu/for_encode/550_01_DDX55.merged...          50  hiseq 4000
# 28  sauron.ucsd.edu/for_encode/550_02_DDX55.merged...          50  hiseq 4000
# 29                                            no_file          50  hiseq 4000
# ..                                                ...         ...         ...
# 60  sauron.ucsd.edu/for_encode/617_01_TBRG4.merged...          50  hiseq 4000
# 61  sauron.ucsd.edu/for_encode/617_02_TBRG4.merged...          50  hiseq 4000
# 62                                            no_file          50  hiseq 4000
# 63  sauron.ucsd.edu/for_encode/624_01_AARS.merged....          50  hiseq 4000
# 64  sauron.ucsd.edu/for_encode/624_02_AARS.merged....          50  hiseq 4000
# 65                                            no_file          50  hiseq 4000
# 66  sauron.ucsd.edu/for_encode/625_01_EIF3D.merged...          50  hiseq 4000
# 67  sauron.ucsd.edu/for_encode/625_02_EIF3D.merged...          50  hiseq 4000
# 68                                            no_file          50  hiseq 4000
# 69  sauron.ucsd.edu/for_encode/626_01_EIF4B.merged...          50  hiseq 4000
# 70  sauron.ucsd.edu/for_encode/626_02_EIF4B.merged...          50  hiseq 4000
# 71                                            no_file          50  hiseq 4000
# 72  sauron.ucsd.edu/for_encode/628_01_GRWD1.merged...          50  hiseq 4000
# 73  sauron.ucsd.edu/for_encode/628_02_GRWD1.merged...          50  hiseq 4000
# 74                                            no_file          50  hiseq 4000
# 75  sauron.ucsd.edu/for_encode/641_01_ZC3H11A.merg...          50  hiseq 4000
# 76  sauron.ucsd.edu/for_encode/641_02_ZC3H11A.merg...          50  hiseq 4000
# 77                                            no_file          50  hiseq 4000
# 78                                                NaN          50  hiseq 4000
# 79                                                NaN          50  hiseq 4000
# 80                                                NaN          50  hiseq 4000
# 81                                                NaN          50  hiseq 4000
# 82                                                NaN          50  hiseq 4000
# 83                                                NaN          50  hiseq 4000
# 84                                                NaN          50  hiseq 4000
# 85                                                NaN          50  hiseq 4000
# 86                                                NaN          50  hiseq 4000
# 87                                                NaN          50  hiseq 4000
# 88                                                NaN          50  hiseq 4000
# 89                                                NaN          50  hiseq 4000
#
#    Flowcell ID  lane
# 0     flowcell  lane
# 1     flowcell  lane
# 2     flowcell  lane
# 3     flowcell  lane
# 4     flowcell  lane
# 5     flowcell  lane
# 6     flowcell  lane
# 7     flowcell  lane
# 8     flowcell  lane
# 9     flowcell  lane
# 10    flowcell  lane
# 11    flowcell  lane
# 12    flowcell  lane
# 13    flowcell  lane
# 14    flowcell  lane
# 15    flowcell  lane
# 16    flowcell  lane
# 17    flowcell  lane
# 18    flowcell  lane
# 19    flowcell  lane
# 20    flowcell  lane
# 21    flowcell  lane
# 22    flowcell  lane
# 23    flowcell  lane
# 24    flowcell  lane
# 25    flowcell  lane
# 26    flowcell  lane
# 27    flowcell  lane
# 28    flowcell  lane
# 29    flowcell  lane
# ..         ...   ...
# 60    flowcell  lane
# 61    flowcell  lane
# 62    flowcell  lane
# 63    flowcell  lane
# 64    flowcell  lane
# 65    flowcell  lane
# 66    flowcell  lane
# 67    flowcell  lane
# 68    flowcell  lane
# 69    flowcell  lane
# 70    flowcell  lane
# 71    flowcell  lane
# 72    flowcell  lane
# 73    flowcell  lane
# 74    flowcell  lane
# 75    flowcell  lane
# 76    flowcell  lane
# 77    flowcell  lane
# 78    flowcell  lane
# 79    flowcell  lane
# 80    flowcell  lane
# 81    flowcell  lane
# 82    flowcell  lane
# 83    flowcell  lane
# 84    flowcell  lane
# 85    flowcell  lane
# 86    flowcell  lane
# 87    flowcell  lane
# 88    flowcell  lane
# 89    flowcell  lane
#
# [90 rows x 30 columns]

# %%
foo = pd.merge(xintao_manifest, merged_good_to_go, left_on="Rep_UID", right_on="ENCODE_ID", how="outer").fillna("no_file")
foo.to_csv("/home/gpratt/ipython_notebook/xintao_file_locations.csv")
foo.to_csv("/home/gpratt/Dropbox/encode_integration/for_eric/xintao_file_locations.csv")

# %%
def check_exists(url):
    try:
        urllib2.urlopen('http://{}'.format(url))
        return "ok"
    except urllib2.HTTPError, e:
        return "error"
    except urllib2.URLError, e:
        return "error"

# %%
foo
# Out:
#     UID ENCODE_ACCESSION ENCODE_aliases    Rep_UID Replicate    RBP_x  \
# 0   235            FIXME        no_file     235_01      rep1     XRN2
# 1   235            FIXME        no_file     235_02      rep2     XRN2
# 2   235            FIXME        no_file  235_INPUT   control     XRN2
# 3   390            FIXME        no_file     390_01      rep1    DDX20
# 4   390            FIXME        no_file     390_02      rep2    DDX20
# 5   390            FIXME        no_file  390_INPUT   control    DDX20
# 6   491            FIXME        no_file     491_01      rep1   EXOSC5
# 7   491            FIXME        no_file     491_02      rep2   EXOSC5
# 8   491            FIXME        no_file  491_INPUT   control   EXOSC5
# 9   501            FIXME        no_file     501_01      rep1     RBM5
# 10  501            FIXME        no_file     501_02      rep2     RBM5
# 11  501            FIXME        no_file  501_INPUT   control     RBM5
# 12  503            FIXME        no_file     503_01      rep1   TROVE2
# 13  503            FIXME        no_file     503_02      rep2   TROVE2
# 14  503            FIXME        no_file  503_INPUT   control   TROVE2
# 15  522            FIXME        no_file     522_01      rep1     HLTF
# 16  522            FIXME        no_file     522_02      rep2     HLTF
# 17  522            FIXME        no_file  522_INPUT   control     HLTF
# 18  529            FIXME        no_file     529_01      rep1    RPS24
# 19  529            FIXME        no_file     529_02      rep2    RPS24
# 20  529            FIXME        no_file  529_INPUT   control    RPS24
# 21  531            FIXME        no_file     531_01      rep1     RPS5
# 22  531            FIXME        no_file     531_02      rep2     RPS5
# 23  531            FIXME        no_file  531_INPUT   control     RPS5
# 24  548            FIXME        no_file     548_01      rep1   ZRANB2
# 25  548            FIXME        no_file     548_02      rep2   ZRANB2
# 26  548            FIXME        no_file  548_INPUT   control   ZRANB2
# 27  550            FIXME        no_file     550_01      rep1    DDX55
# 28  550            FIXME        no_file     550_02      rep2    DDX55
# 29  550            FIXME        no_file  550_INPUT   control    DDX55
# ..  ...              ...            ...        ...       ...      ...
# 60  617            FIXME        no_file     617_01      rep1    TBRG4
# 61  617            FIXME        no_file     617_02      rep2    TBRG4
# 62  617            FIXME        no_file  617_INPUT   control    TBRG4
# 63  624            FIXME        no_file     624_01      rep1     AARS
# 64  624            FIXME        no_file     624_02      rep2     AARS
# 65  624            FIXME        no_file  624_INPUT   control     AARS
# 66  625            FIXME        no_file     625_01      rep1    EIF3D
# 67  625            FIXME        no_file     625_02      rep2    EIF3D
# 68  625            FIXME        no_file  625_INPUT   control    EIF3D
# 69  626            FIXME        no_file     626_01      rep1    EIF4B
# 70  626            FIXME        no_file     626_02      rep2    EIF4B
# 71  626            FIXME        no_file  626_INPUT   control    EIF4B
# 72  628            FIXME        no_file     628_01      rep1    GRWD1
# 73  628            FIXME        no_file     628_02      rep2    GRWD1
# 74  628            FIXME        no_file  628_INPUT   control    GRWD1
# 75  641            FIXME        no_file     641_01      rep1  ZC3H11A
# 76  641            FIXME        no_file     641_02      rep2  ZC3H11A
# 77  641            FIXME        no_file  641_INPUT   control  ZC3H11A
# 78  545            FIXME        no_file     545_01      rep1    EIF3H
# 79  545            FIXME        no_file     545_02      rep2    EIF3H
# 80  545            FIXME        no_file  545_INPUT   control    EIF3H
# 81  551            FIXME        no_file     551_01      rep1     YBX3
# 82  551            FIXME        no_file     551_02      rep2     YBX3
# 83  551            FIXME        no_file  551_INPUT   control     YBX3
# 84  629            FIXME        no_file     629_01      rep1    UCHL5
# 85  629            FIXME        no_file     629_02      rep2    UCHL5
# 86  629            FIXME        no_file  629_INPUT   control    UCHL5
# 87  631            FIXME        no_file     631_01      rep1   EFTUD2
# 88  631            FIXME        no_file     631_02      rep2   EFTUD2
# 89  631            FIXME        no_file  631_INPUT   control   EFTUD2
#
#    Cell_Line   Antibody  Lot# inline_barcode_1        ...         \
# 0      HepG2  A301-103A     1              A04        ...
# 1      HepG2  A301-103A     1              A03        ...
# 2      HepG2  A301-103A     1             none        ...
# 3      HepG2  A300-651A     1              A04        ...
# 4      HepG2  A300-651A     1              A03        ...
# 5      HepG2  A300-651A     1             none        ...
# 6       K562    RN100PW     1              A01        ...
# 7       K562    RN100PW     1              C01        ...
# 8       K562    RN100PW     1             none        ...
# 9      HepG2  A302-228A     1              A01        ...
# 10     HepG2  A302-228A     1              C01        ...
# 11     HepG2  A302-228A     1             none        ...
# 12     HepG2  A303-692A     1              A01        ...
# 13     HepG2  A303-692A     1              C01        ...
# 14     HepG2  A303-692A     1             none        ...
# 15      K562  A300-230A     1              A01        ...
# 16      K562  A300-230A     1              C01        ...
# 17      K562  A300-230A     1             none        ...
# 18      K562  A303-842A     1              A01        ...
# 19      K562  A303-842A     1              C01        ...
# 20      K562  A303-842A     1             none        ...
# 21      K562  A304-010A     1              A01        ...
# 22      K562  A304-010A     1              C01        ...
# 23      K562  A304-010A     1             none        ...
# 24      K562  A301-029A     1              X1A        ...
# 25      K562  A301-029A     1              X2A        ...
# 26      K562  A301-029A     1             none        ...
# 27      K562  A303-027A     1              X1A        ...
# 28      K562  A303-027A     1              X2A        ...
# 29      K562  A303-027A     1             none        ...
# ..       ...        ...   ...              ...        ...
# 60     HepG2  A301-392A     1              A04        ...
# 61     HepG2  A301-392A     1              A03        ...
# 62     HepG2  A301-392A     1             none        ...
# 63      K562  A303-475A     1              A03        ...
# 64      K562  A303-475A     1              A04        ...
# 65      K562  A303-475A     1             none        ...
# 66     HepG2  A301-758A     1              A04        ...
# 67     HepG2  A301-758A     1              A03        ...
# 68     HepG2  A301-758A     1             none        ...
# 69     HepG2  A301-767A     1              A04        ...
# 70     HepG2  A301-767A     1              A03        ...
# 71     HepG2  A301-767A     1             none        ...
# 72     HepG2  A301-576A     1              A04        ...
# 73     HepG2  A301-576A     1              A03        ...
# 74     HepG2  A301-576A     1             none        ...
# 75     HepG2  A301-524A     1              A04        ...
# 76     HepG2  A301-524A     1              A03        ...
# 77     HepG2  A301-524A     1             none        ...
# 78     HepG2  A301-754A     1              C01        ...
# 79     HepG2  A301-754A     1              A01        ...
# 80     HepG2  A301-754A     1             none        ...
# 81      K562  A303-070A     1              X1A        ...
# 82      K562  A303-070A     1              X2A        ...
# 83      K562  A303-070A     1             none        ...
# 84     HepG2  A304-099A     1              A04        ...
# 85     HepG2  A304-099A     1              A03        ...
# 86     HepG2  A304-099A     1             none        ...
# 87     HepG2  A300-957A     1              X1A        ...
# 88     HepG2  A300-957A     1              X2A        ...
# 89     HepG2  A300-957A     1             none        ...
#
#                                          out_fastq_r2  \
# 0                                             no_file
# 1                                             no_file
# 2                                             no_file
# 3                                             no_file
# 4                                             no_file
# 5                                             no_file
# 6                                             no_file
# 7                                             no_file
# 8                                             no_file
# 9                                             no_file
# 10                                            no_file
# 11                                            no_file
# 12                                            no_file
# 13                                            no_file
# 14                                            no_file
# 15                                            no_file
# 16                                            no_file
# 17                                            no_file
# 18                                            no_file
# 19                                            no_file
# 20                                            no_file
# 21                                            no_file
# 22                                            no_file
# 23                                            no_file
# 24                                            no_file
# 25                                            no_file
# 26                                            no_file
# 27                                            no_file
# 28                                            no_file
# 29                                            no_file
# ..                                                ...
# 60                                            no_file
# 61                                            no_file
# 62                                            no_file
# 63                                            no_file
# 64                                            no_file
# 65                                            no_file
# 66                                            no_file
# 67                                            no_file
# 68                                            no_file
# 69                                            no_file
# 70                                            no_file
# 71                                            no_file
# 72                                            no_file
# 73                                            no_file
# 74                                            no_file
# 75                                            no_file
# 76                                            no_file
# 77                                            no_file
# 78  sauron.ucsd.edu/for_encode/545_01_EIF3H.R2.fas...
# 79  sauron.ucsd.edu/for_encode/545_02_EIF3H.R2.fas...
# 80  sauron.ucsd.edu/for_encode/545_INPUT_EIF3H.R2....
# 81  sauron.ucsd.edu/for_encode/551_01_YBX3.R2.fast...
# 82  sauron.ucsd.edu/for_encode/551_02_YBX3.R2.fast...
# 83  sauron.ucsd.edu/for_encode/551_INPUT_YBX3.R2.f...
# 84  sauron.ucsd.edu/for_encode/629_01_UCHL5.R2.fas...
# 85  sauron.ucsd.edu/for_encode/629_02_UCHL5.R2.fas...
# 86  sauron.ucsd.edu/for_encode/629_INPUT_UCHL5.R2....
# 87  sauron.ucsd.edu/for_encode/631_01_EFTUD2.R2.fa...
# 88  sauron.ucsd.edu/for_encode/631_02_EFTUD2.R2.fa...
# 89  sauron.ucsd.edu/for_encode/631_INPUT_EFTUD2.R2...
#
#                                             out_peaks  \
# 0                                             no_file
# 1                                             no_file
# 2                                             no_file
# 3                                             no_file
# 4                                             no_file
# 5                                             no_file
# 6                                             no_file
# 7                                             no_file
# 8                                             no_file
# 9                                             no_file
# 10                                            no_file
# 11                                            no_file
# 12                                            no_file
# 13                                            no_file
# 14                                            no_file
# 15                                            no_file
# 16                                            no_file
# 17                                            no_file
# 18                                            no_file
# 19                                            no_file
# 20                                            no_file
# 21                                            no_file
# 22                                            no_file
# 23                                            no_file
# 24                                            no_file
# 25                                            no_file
# 26                                            no_file
# 27                                            no_file
# 28                                            no_file
# 29                                            no_file
# ..                                                ...
# 60                                            no_file
# 61                                            no_file
# 62                                            no_file
# 63                                            no_file
# 64                                            no_file
# 65                                            no_file
# 66                                            no_file
# 67                                            no_file
# 68                                            no_file
# 69                                            no_file
# 70                                            no_file
# 71                                            no_file
# 72                                            no_file
# 73                                            no_file
# 74                                            no_file
# 75                                            no_file
# 76                                            no_file
# 77                                            no_file
# 78  sauron.ucsd.edu/for_encode/545_01_EIF3H.merged...
# 79  sauron.ucsd.edu/for_encode/545_02_EIF3H.merged...
# 80                                            no_file
# 81  sauron.ucsd.edu/for_encode/551_01_YBX3.merged....
# 82  sauron.ucsd.edu/for_encode/551_02_YBX3.merged....
# 83                                            no_file
# 84  sauron.ucsd.edu/for_encode/629_01_UCHL5.merged...
# 85  sauron.ucsd.edu/for_encode/629_02_UCHL5.merged...
# 86                                            no_file
# 87  sauron.ucsd.edu/for_encode/631_01_EFTUD2.merge...
# 88  sauron.ucsd.edu/for_encode/631_02_EFTUD2.merge...
# 89                                            no_file
#
#                                       processing_name  \
# 0                                             no_file
# 1                                             no_file
# 2                                             no_file
# 3                                             no_file
# 4                                             no_file
# 5                                             no_file
# 6                                             no_file
# 7                                             no_file
# 8                                             no_file
# 9                                             no_file
# 10                                            no_file
# 11                                            no_file
# 12                                            no_file
# 13                                            no_file
# 14                                            no_file
# 15                                            no_file
# 16                                            no_file
# 17                                            no_file
# 18                                            no_file
# 19                                            no_file
# 20                                            no_file
# 21                                            no_file
# 22                                            no_file
# 23                                            no_file
# 24                                            no_file
# 25                                            no_file
# 26                                            no_file
# 27                                            no_file
# 28                                            no_file
# 29                                            no_file
# ..                                                ...
# 60                                            no_file
# 61                                            no_file
# 62                                            no_file
# 63                                            no_file
# 64                                            no_file
# 65                                            no_file
# 66                                            no_file
# 67                                            no_file
# 68                                            no_file
# 69                                            no_file
# 70                                            no_file
# 71                                            no_file
# 72                                            no_file
# 73                                            no_file
# 74                                            no_file
# 75                                            no_file
# 76                                            no_file
# 77                                            no_file
# 78                                            no_file
# 79                                            no_file
# 80  /home/gpratt/projects/encode/analysis/encode_s...
# 81                                            no_file
# 82                                            no_file
# 83  /home/gpratt/projects/encode/analysis/encode_s...
# 84                                            no_file
# 85                                            no_file
# 86  /home/gpratt/projects/encode/analysis/encode_s...
# 87                                            no_file
# 88                                            no_file
# 89  /home/gpratt/projects/encode/analysis/encode_s...
#
#                                     processing_name_1  \
# 0                                             no_file
# 1                                             no_file
# 2                                             no_file
# 3                                             no_file
# 4                                             no_file
# 5                                             no_file
# 6                                             no_file
# 7                                             no_file
# 8                                             no_file
# 9                                             no_file
# 10                                            no_file
# 11                                            no_file
# 12                                            no_file
# 13                                            no_file
# 14                                            no_file
# 15                                            no_file
# 16                                            no_file
# 17                                            no_file
# 18                                            no_file
# 19                                            no_file
# 20                                            no_file
# 21                                            no_file
# 22                                            no_file
# 23                                            no_file
# 24                                            no_file
# 25                                            no_file
# 26                                            no_file
# 27                                            no_file
# 28                                            no_file
# 29                                            no_file
# ..                                                ...
# 60                                            no_file
# 61                                            no_file
# 62                                            no_file
# 63                                            no_file
# 64                                            no_file
# 65                                            no_file
# 66                                            no_file
# 67                                            no_file
# 68                                            no_file
# 69                                            no_file
# 70                                            no_file
# 71                                            no_file
# 72                                            no_file
# 73                                            no_file
# 74                                            no_file
# 75                                            no_file
# 76                                            no_file
# 77                                            no_file
# 78  /home/gpratt/projects/encode/analysis/encode_s...
# 79  /home/gpratt/projects/encode/analysis/encode_s...
# 80                                            no_file
# 81  /home/gpratt/projects/encode/analysis/encode_s...
# 82  /home/gpratt/projects/encode/analysis/encode_s...
# 83                                            no_file
# 84  /home/gpratt/projects/encode/analysis/encode_s...
# 85  /home/gpratt/projects/encode/analysis/encode_s...
# 86                                            no_file
# 87  /home/gpratt/projects/encode/analysis/encode_s...
# 88  /home/gpratt/projects/encode/analysis/encode_s...
# 89                                            no_file
#
#                                     processing_name_2  \
# 0                                             no_file
# 1                                             no_file
# 2                                             no_file
# 3                                             no_file
# 4                                             no_file
# 5                                             no_file
# 6                                             no_file
# 7                                             no_file
# 8                                             no_file
# 9                                             no_file
# 10                                            no_file
# 11                                            no_file
# 12                                            no_file
# 13                                            no_file
# 14                                            no_file
# 15                                            no_file
# 16                                            no_file
# 17                                            no_file
# 18                                            no_file
# 19                                            no_file
# 20                                            no_file
# 21                                            no_file
# 22                                            no_file
# 23                                            no_file
# 24                                            no_file
# 25                                            no_file
# 26                                            no_file
# 27                                            no_file
# 28                                            no_file
# 29                                            no_file
# ..                                                ...
# 60                                            no_file
# 61                                            no_file
# 62                                            no_file
# 63                                            no_file
# 64                                            no_file
# 65                                            no_file
# 66                                            no_file
# 67                                            no_file
# 68                                            no_file
# 69                                            no_file
# 70                                            no_file
# 71                                            no_file
# 72                                            no_file
# 73                                            no_file
# 74                                            no_file
# 75                                            no_file
# 76                                            no_file
# 77                                            no_file
# 78  /home/gpratt/projects/encode/analysis/encode_s...
# 79  /home/gpratt/projects/encode/analysis/encode_s...
# 80                                            no_file
# 81  /home/gpratt/projects/encode/analysis/encode_s...
# 82  /home/gpratt/projects/encode/analysis/encode_s...
# 83                                            no_file
# 84  /home/gpratt/projects/encode/analysis/encode_s...
# 85  /home/gpratt/projects/encode/analysis/encode_s...
# 86                                            no_file
# 87  /home/gpratt/projects/encode/analysis/encode_s...
# 88  /home/gpratt/projects/encode/analysis/encode_s...
# 89                                            no_file
#
#                                                    r1  \
# 0                                             no_file
# 1                                             no_file
# 2                                             no_file
# 3                                             no_file
# 4                                             no_file
# 5                                             no_file
# 6                                             no_file
# 7                                             no_file
# 8                                             no_file
# 9                                             no_file
# 10                                            no_file
# 11                                            no_file
# 12                                            no_file
# 13                                            no_file
# 14                                            no_file
# 15                                            no_file
# 16                                            no_file
# 17                                            no_file
# 18                                            no_file
# 19                                            no_file
# 20                                            no_file
# 21                                            no_file
# 22                                            no_file
# 23                                            no_file
# 24                                            no_file
# 25                                            no_file
# 26                                            no_file
# 27                                            no_file
# 28                                            no_file
# 29                                            no_file
# ..                                                ...
# 60                                            no_file
# 61                                            no_file
# 62                                            no_file
# 63                                            no_file
# 64                                            no_file
# 65                                            no_file
# 66                                            no_file
# 67                                            no_file
# 68                                            no_file
# 69                                            no_file
# 70                                            no_file
# 71                                            no_file
# 72                                            no_file
# 73                                            no_file
# 74                                            no_file
# 75                                            no_file
# 76                                            no_file
# 77                                            no_file
# 78  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 79  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 80  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 81  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 82  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 83  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 84  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 85  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 86  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 87  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 88  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 89  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
#
#                                                    r2 randomer_length  \
# 0                                             no_file         no_file
# 1                                             no_file         no_file
# 2                                             no_file         no_file
# 3                                             no_file         no_file
# 4                                             no_file         no_file
# 5                                             no_file         no_file
# 6                                             no_file         no_file
# 7                                             no_file         no_file
# 8                                             no_file         no_file
# 9                                             no_file         no_file
# 10                                            no_file         no_file
# 11                                            no_file         no_file
# 12                                            no_file         no_file
# 13                                            no_file         no_file
# 14                                            no_file         no_file
# 15                                            no_file         no_file
# 16                                            no_file         no_file
# 17                                            no_file         no_file
# 18                                            no_file         no_file
# 19                                            no_file         no_file
# 20                                            no_file         no_file
# 21                                            no_file         no_file
# 22                                            no_file         no_file
# 23                                            no_file         no_file
# 24                                            no_file         no_file
# 25                                            no_file         no_file
# 26                                            no_file         no_file
# 27                                            no_file         no_file
# 28                                            no_file         no_file
# 29                                            no_file         no_file
# ..                                                ...             ...
# 60                                            no_file         no_file
# 61                                            no_file         no_file
# 62                                            no_file         no_file
# 63                                            no_file         no_file
# 64                                            no_file         no_file
# 65                                            no_file         no_file
# 66                                            no_file         no_file
# 67                                            no_file         no_file
# 68                                            no_file         no_file
# 69                                            no_file         no_file
# 70                                            no_file         no_file
# 71                                            no_file         no_file
# 72                                            no_file         no_file
# 73                                            no_file         no_file
# 74                                            no_file         no_file
# 75                                            no_file         no_file
# 76                                            no_file         no_file
# 77                                            no_file         no_file
# 78  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 79  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 80  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 81  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 82  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 83  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 84  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 85  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 86  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 87  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 88  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
# 89  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....              10
#
#     species unmerged_location
# 0   no_file           no_file
# 1   no_file           no_file
# 2   no_file           no_file
# 3   no_file           no_file
# 4   no_file           no_file
# 5   no_file           no_file
# 6   no_file           no_file
# 7   no_file           no_file
# 8   no_file           no_file
# 9   no_file           no_file
# 10  no_file           no_file
# 11  no_file           no_file
# 12  no_file           no_file
# 13  no_file           no_file
# 14  no_file           no_file
# 15  no_file           no_file
# 16  no_file           no_file
# 17  no_file           no_file
# 18  no_file           no_file
# 19  no_file           no_file
# 20  no_file           no_file
# 21  no_file           no_file
# 22  no_file           no_file
# 23  no_file           no_file
# 24  no_file           no_file
# 25  no_file           no_file
# 26  no_file           no_file
# 27  no_file           no_file
# 28  no_file           no_file
# 29  no_file           no_file
# ..      ...               ...
# 60  no_file           no_file
# 61  no_file           no_file
# 62  no_file           no_file
# 63  no_file           no_file
# 64  no_file           no_file
# 65  no_file           no_file
# 66  no_file           no_file
# 67  no_file           no_file
# 68  no_file           no_file
# 69  no_file           no_file
# 70  no_file           no_file
# 71  no_file           no_file
# 72  no_file           no_file
# 73  no_file           no_file
# 74  no_file           no_file
# 75  no_file           no_file
# 76  no_file           no_file
# 77  no_file           no_file
# 78     hg19
# 79     hg19
# 80     hg19
# 81     hg19
# 82     hg19
# 83     hg19
# 84     hg19
# 85     hg19
# 86     hg19
# 87     hg19
# 88     hg19
# 89     hg19
#
# [90 rows x 67 columns]

# %%
result = pd.concat([foo.Rep_UID,
            foo.out_fastq_r1.apply(check_exists),
          foo.out_fastq_r2.apply(check_exists),
          foo.out_bam.apply(check_exists),
          foo.out_peaks.apply(check_exists)], axis=1)

# %%
HTML(result.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rep_UID</th>
#       <th>out_fastq_r1</th>
#       <th>out_fastq_r2</th>
#       <th>out_bam</th>
#       <th>out_peaks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>235_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>235_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>235_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>390_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>390_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>390_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>491_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>491_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>491_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>501_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>501_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>501_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>503_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>503_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>503_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>522_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>522_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>522_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>529_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>529_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>529_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>531_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>531_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>531_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>548_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>548_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>548_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>550_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>550_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>550_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>567_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>567_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>567_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>570_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>570_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>570_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>577_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>577_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>577_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>582_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>582_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>582_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>584_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>584_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>584_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>589_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>589_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>589_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>592_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>592_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>592_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>595_01</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>595_02</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>595_INPUT</td>
#       <td>error</td>
#       <td>error</td>
#       <td>error</td>
#       <t

# %%
#For the mass reupload
#combined_data = pd.read_csv("/home/gpratt/Dropbox/encode_integration/ENCODE_DCC_submittedlist_pre2016.csv", header=None, index_col=0)
# result = pd.concat([combined_data[1],
#             combined_data[21].apply(check_exists),
#           combined_data[22].apply(check_exists),
#           combined_data[23].apply(check_exists),
#           combined_data[24].apply(check_exists)], axis=1)

# HTML(result.to_html())

# %% [markdown]
# #Make trackhub with just encode data

# %%
only_encode_files = set(list(clip_seq_manifest[clip_seq_manifest.is_encode].Hiseq_file_name.values) + list(input_manifest[input_manifest.is_encode].Hiseq_file_name.values))

# %%
",".join(only_encode_files)

# %%
encode_files = "{" + (",".join(only_encode_files)) + "}"

# %%
encode_files

# %%
# !echo make_trackhubs.py --genome hg19 --hub 20150921_encode $encode_files *{merged,unassigned}*.{bb,bw}

# %%
make_trackhub --genome hg19 --hub 20150921_encode {}merged

# %%
import pandas as pd

# %%
foo = pd.read_table("/home/elvannostrand/data/clip/CLIPseq_analysis/ENCODE_v9_20151209/encode_v9_filelist.ENCODE.20151209.txt")

# %%
not_in_rep_1 = foo[~foo.CLIP_rep1.apply(lambda x: x.replace(".bam", ".norm.neg.bw")).apply(os.path.exists)]
not_in_input = foo[~foo.INPUT.apply(lambda x: x.replace(".bam", ".norm.neg.bw")).apply(os.path.exists)]

# %%
def make_bigwig(bam):
    pos = bam.replace(".bam", ".norm.pos.bw")
    neg = bam.replace(".bam", ".norm.neg.bw")
    return "make_bigwig_files.py  '--bam' '{}'  '--genome' '/projects/ps-yeolab/genomes/hg19/hg19.chrom.sizes'  '--bw_pos' '{}'  '--bw_neg' '{}'".format(bam, pos, neg)

# %%
not_in_rep_1.ix[149].CLIP_rep1

# %%
make_bigwig(not_in_rep_1.ix[149].CLIP_rep1)

# %%
not_in_input

# %%
make_bigwig(not_in_input.ix[148].INPUT)

# %%
import pybedtools

# %%
foo = pybedtools.BedTool("/home/gpratt/clipper/clipper/data/hg19.AS.STRUCTURE.COMPILED.gff")

# %%
# Out:
# 29986.866936680573

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
sns.distplot([len(interval) for interval in foo])

# %%
",".join("""TAG9_CLIP_S64_L005
TAG10_CLIP_S68
TAG13_CLIP
TAG11_CLIP_S69
TAG12_CLIP_S70
TAG14_CLIP_S73
TAG15_CLIP_S75
TAG16_CLIP_S77
TAG9_INPUT_S63
TAG10_INPUT_S65
TAG11_INPUT_S66
TAG12_INPUT_S67
TAG13_INPUT_S71
TAG14_INPUT_S72
TAG15_INPUT_S74
TAG16_INPUT_S76
TAG11_CLIP_S26
TAG14_CLIP_S30
SEB9_S92_L007
SEB5_S88_L007
SEB6_S89_L007
SEB7_S90_L007
SEB8_S91_L007
SEB17_S96_L007
SEB20_S99_L007
SEB10_S93_L007
SEB11_S94_L007
SEB12_S95_L007
SEB18_S97_L007
SEB19_S98_L007
SEB21_S100_L007
SEB23_S102_L007
SEB24_S103_L007
SEB22_S101_L007
SEB_unknown706504_S51
SEB_unknown706504
643_CLIP_S78_L005
363_INPUT_4000_S17_L001
386_INPUT_4000_S18""".split("\n"))
# Out:
# 'TAG9_CLIP_S64_L005,TAG10_CLIP_S68,TAG13_CLIP,TAG11_CLIP_S69,TAG12_CLIP_S70,TAG14_CLIP_S73,TAG15_CLIP_S75,TAG16_CLIP_S77,TAG9_INPUT_S63,TAG10_INPUT_S65,TAG11_INPUT_S66,TAG12_INPUT_S67,TAG13_INPUT_S71,TAG14_INPUT_S72,TAG15_INPUT_S74,TAG16_INPUT_S76,TAG11_CLIP_S26,TAG14_CLIP_S30,SEB9_S92_L007,SEB5_S88_L007,SEB6_S89_L007,SEB7_S90_L007,SEB8_S91_L007,SEB17_S96_L007,SEB20_S99_L007,SEB10_S93_L007,SEB11_S94_L007,SEB12_S95_L007,SEB18_S97_L007,SEB19_S98_L007,SEB21_S100_L007,SEB23_S102_L007,SEB24_S103_L007,SEB22_S101_L007,SEB_unknown706504_S51,SEB_unknown706504,643_CLIP_S78_L005,363_INPUT_4000_S17_L001,386_INPUT_4000_S18'
