# %%
# %matplotlib inline
import pybedtools
from matplotlib_venn import venn2, venn3
import pandas as pd
import os
from gscripts.general import dataviz
img_dir = "."

# %%
df = pd.read_table("/home/elvannostrand/data/clip/CLIPseq_analysis/SM_v9_20151211/encode_v9_filelist_SM_20151211.txt.l2foldenr_files.txt",
              header=None, names=['encode_id', 
                                   'rbp', 
                                   'cell_type', 
                                   'bam_file_1', 
                                   'bam_file_2', 
                                   'input_file', 
                                   'peaks_file_1', 
                                   'peaks_file_2'])


#tidy the data up
result = []
for index, line in df.iterrows():
    result.append({'encode_id': line.encode_id,
                   'rep': 1,
                   'rbp': line.rbp, 
                   'cell_type': line.cell_type, 
                   'bam_file': line.bam_file_1, 
                   'input_file': line.input_file, 
                   'peaks_file': line.peaks_file_1, })
    result.append({'encode_id': line.encode_id,
                       'rep': 2,
                       'rbp': line.rbp, 
                       'cell_type': line.cell_type, 
                       'bam_file': line.bam_file_2, 
                       'input_file': line.input_file, 
                       'peaks_file': line.peaks_file_2, })

df = pd.DataFrame(result)

def l2fc_peak_names(peak_file):
    return os.path.join("/home/gpratt/projects/encode/analysis/encode_v9_secondary_processing", 
                                         os.path.basename(peak_file)) + ".filtered.bed"

df['filtered_peaks'] = df.peaks_file.apply(l2fc_peak_names)

# %%
#This is hacky, but good enough for now.
#pd.read_table("/home/elvannostrand/data/clip/CLIPseq_analysis/SM_v9_20151211/encode_v9_filelist_SM_20151211.txt")
df['stress'] = "s s us us s s us us".split()

# %%
# Out:
#     uID   RBP Cell line                                          CLIP_rep1  \
# 0  SEB1  G3BP         X  /home/gpratt/projects/encode/analysis/encode_v...
# 1  SEB2  G3BP         X  /home/gpratt/projects/encode/analysis/encode_v...
# 2  SEB3  TIA1         X  /home/gpratt/projects/encode/analysis/encode_v...
# 3  SEB4  TIA1         X  /home/gpratt/projects/encode/analysis/encode_v...
#
#                                            CLIP_rep2  \
# 0  /home/gpratt/projects/encode/analysis/encode_v...
# 1  /home/gpratt/projects/encode/analysis/encode_v...
# 2  /home/gpratt/projects/encode/analysis/encode_v...
# 3  /home/gpratt/projects/encode/analysis/encode_v...
#
#                                                INPUT
# 0  /home/gpratt/projects/encode/analysis/encode_v...
# 1  /home/gpratt/projects/encode/analysis/encode_v...
# 2  /home/gpratt/projects/encode/analysis/encode_v...
# 3  /home/gpratt/projects/encode/analysis/encode_v...

# %% [markdown]
# #Quality control, how many peaks overlap between reps?

# %%
num_rows = 2
num_cols = 2
with dataviz.Figure(os.path.join(img_dir, "replicate_plotting.svg"), figsize=(2.5 * num_cols,2.5*num_rows)) as fig:

    for x, (name, dfs) in enumerate(df.groupby("encode_id")):
        ax = fig.add_subplot(num_rows, num_cols, x + 1)
        rep1, rep2 = dfs.filtered_peaks
        rep1 = pybedtools.BedTool(rep1)
        rep2 = pybedtools.BedTool(rep2)
        both = rep1.intersect(rep2, u=True, s=True)
        rep1_only = rep1.intersect(rep2, v=True, s=True)
        rep2_only = rep2.intersect(rep1, v=True, s=True)
        venn2({"01": len(rep1_only),
               "10": len(rep2_only),
               "11": len(both)},
              set_labels= ["Rep 1", "Rep 2"],
              ax=ax)
        ax.set_title(name)

# %% [markdown]
# ok I'll be conservative and take only overlapping peaks for futher analysis, too many that don't overlap to be safe

# %%
genes = pybedtools.BedTool("/home/gpratt/clipper/clipper/data/regions/hg19_genes.bed")


merged_peaks = {}
for name, dfs in df.groupby("encode_id"):
        rep1, rep2 = dfs.filtered_peaks
        rep1 = pybedtools.BedTool(rep1)
        rep2 = pybedtools.BedTool(rep2)
        both = rep1.intersect(rep2, u=True, s=True)
        
        #This is a hack, I need to pair down the number of peaks / merge genes eventually
        overlapping_genes = both.intersect(genes, wo=True, s=True).saveas(name + ".merged.bed")

        merged_peaks[name] = overlapping_genes
        
merged_peaks = pd.DataFrame(pd.Series(merged_peaks), columns=['bed_file'])
merged_peaks['stress'] = 's us s us'.split()
merged_peaks['rbp'] = 'g3bp g3bp tia1 tia1'.split()

# %% [markdown]
# #How many targets are unique or shared for the two proteins in unstressed conditions?

# %%
num_rows = 1
num_cols = 2
with dataviz.Figure(os.path.join(img_dir, "replicate_plotting.svg"), figsize=(2.5 * num_cols,2.5*num_rows)) as fig:

    for x, (name, dfs) in enumerate(merged_peaks.groupby("stress")):
        ax = fig.add_subplot(num_rows, num_cols, x + 1)
        rep1, rep2 = dfs.bed_file
        rep1 = pybedtools.BedTool(rep1)
        rep2 = pybedtools.BedTool(rep2)
        both = rep1.intersect(rep2, u=True, s=True)
        rep1_only = rep1.intersect(rep2, v=True, s=True)
        rep2_only = rep2.intersect(rep1, v=True, s=True)
        venn2({"01": len(rep1_only),
               "10": len(rep2_only),
               "11": len(both)},
              set_labels= [dfs.iloc[0].rbp, dfs.iloc[1].rbp],
              ax=ax)
        ax.set_title(dfs.iloc[0].stress)

# %% [markdown]
# The overlap of G3BP1 peaks is pretty poor with TIA1 peaks in both stressed and unstressed conditions

# %%
num_rows = 1
num_cols = 2
with dataviz.Figure(os.path.join(img_dir, "replicate_plotting.svg"), figsize=(2.5 * num_cols,2.5*num_rows)) as fig:

    for x, (name, dfs) in enumerate(merged_peaks.groupby("stress")):
        ax = fig.add_subplot(num_rows, num_cols, x + 1)
        rep1, rep2 = dfs.bed_file
        rep1 = pybedtools.BedTool(rep1)
        rep2 = pybedtools.BedTool(rep2)
        rep1 = {interval[9] for interval in rep1}
        rep2 = {interval[9] for interval in rep2}

        venn2([rep1, rep2],
              set_labels= [dfs.iloc[0].rbp, dfs.iloc[1].rbp],
              ax=ax)
        ax.set_title(dfs.iloc[0].stress)

# %% [markdown]
# Looks like ~50% of genes / targets overlap.  Probably greather than siginifcant.  Its a pretty distinct subset of genes that are targeted

# %% [markdown]
# #how does the target pool for each protein shift upon stress?

# %%
num_rows = 1
num_cols = 2
with dataviz.Figure(os.path.join(img_dir, "replicate_plotting.svg"), figsize=(2.5 * num_cols,2.5*num_rows)) as fig:

    for x, (name, dfs) in enumerate(merged_peaks.groupby("rbp")):
        ax = fig.add_subplot(num_rows, num_cols, x + 1)
        rep1, rep2 = dfs.bed_file
        rep1 = pybedtools.BedTool(rep1)
        rep2 = pybedtools.BedTool(rep2)
        both = rep1.intersect(rep2, u=True, s=True)
        rep1_only = rep1.intersect(rep2, v=True, s=True)
        rep2_only = rep2.intersect(rep1, v=True, s=True)
        venn2({"01": len(rep1_only),
               "10": len(rep2_only),
               "11": len(both)},
              set_labels= [dfs.iloc[0].stress, dfs.iloc[1].stress],
              ax=ax)
        ax.set_title(dfs.iloc[0].rbp)

# %%
num_rows = 1
num_cols = 2
with dataviz.Figure(os.path.join(img_dir, "replicate_plotting.svg"), figsize=(2.5 * num_cols,2.5*num_rows)) as fig:

    for x, (name, dfs) in enumerate(merged_peaks.groupby("rbp")):
        ax = fig.add_subplot(num_rows, num_cols, x + 1)
        rep1, rep2 = dfs.bed_file
        rep1 = pybedtools.BedTool(rep1)
        rep2 = pybedtools.BedTool(rep2)
        rep1 = {interval[9] for interval in rep1}
        rep2 = {interval[9] for interval in rep2}

        venn2([rep1, rep2],
              set_labels= [dfs.iloc[0].stress, dfs.iloc[1].stress],
              ax=ax)
        ax.set_title(dfs.iloc[0].rbp)

# %% [markdown]
# No obvious shift towards increase or decrease of targetting for Peaks or Genes, we can dig into interesting genes later.  Looks like general random noise for shifting, need to do a go analysis on unique sites to really get at this question

# %% [markdown]
# #if they acquire new targets under stress, are these unique or shared between the proteins?

# %%
#get new targets under stress
new_targets = {}
for name, dfs in merged_peaks.groupby("rbp"):
    rep1, rep2 = dfs.bed_file
    stress = pybedtools.BedTool(rep1)
    unstressed = pybedtools.BedTool(rep2)
    new_targets[name] = stress.intersect(unstressed, v=True, s=True)

# %%
overlapping_targets = new_targets['g3bp'].intersect(new_targets['tia1'], s=True, u=True)
print len(overlapping_targets)
# Out:
# 316

# %% [markdown]
# Fully half of the new targets under stress are bound by both G3BP and TIA1.  This is useful

# %%
from gscripts import GO
def gencode_to_ensembl(gene_list):
    for gene in gene_list:
        yield gene.split(".")[0]

# %%
hg19go = GO.GO("/projects/ps-yeolab/genomes/hg19/hg19.ENSG_to_GO.txt.gz")

# %%
overlapping_genes = {interval[9] for interval in overlapping_targets}

# %%
overlapping_genes_go = hg19go.enrichment(gencode_to_ensembl(overlapping_genes))
overlapping_genes_go = overlapping_genes_go[overlapping_genes_go['Bonferroni-corrected Hypergeometric p-Value'] < .05]

# %%
overlapping_genes_go.to_csv("/home/gpratt/Dropbox/")
# Out:
#                                                  GO Term Description  \
# GO Term Accession
# GO:0005634                                                   nucleus
# GO:0005829                                                   cytosol
# GO:0005515                                           protein binding
# GO:0003723                                               RNA binding
# GO:0008380                                              RNA splicing
# GO:0016607                                             nuclear speck
# GO:0005730                                                 nucleolus
# GO:0030529                                 ribonucleoprotein complex
# GO:0000776                                               kinetochore
# GO:0000785                                                 chromatin
# GO:0005737                                                 cytoplasm
# GO:0000236                                      mitotic prometaphase
# GO:0030496                                                   midbody
# GO:0005819                                                   spindle
# GO:0000278                                        mitotic cell cycle
# GO:0000777                          condensed chromosome kinetochore
# GO:0030529         XPO1,LARP4,HSPA1B,LSM14B,CELF1,DDX5,HNRNPK,NCL...
# GO:0000776               XPO1,SMC1A,MAD2L1,BUB3,SEH1L,SUMO3,PPP1R12A
# GO:0000785                TMPO,TP53,RAN,PDS5A,SIRT1,PDS5B,STAG2,CBX3
# GO:0005737         CPM,RAB4A,SUMO1,SUMO3,PPP4R2,BRK1,HIPK1,TROVE2...
# GO:0000236           XPO1,SMC1A,MAD2L1,BUB3,SEH1L,STAG2,BIRC5,PPP1CC
# GO:0030496             PPP1CC,HSPA5,BIRC6,BIRC5,PDXP,KLHL9,ERH,SEPT2
# GO:0005819         CCSAP,PRPF19,CBX3,BIRC5,MYH9,PTP4A1,CLTC,MZT1,...
# GO:0000278         XPO1,SMC1A,MAD2L1,E2F3,PPP1CC,SEH1L,STAG2,BIRC...
# GO:0000777                SMC1A,MAD2L1,BUB3,SEH1L,BIRC5,SEPT2,PPP1CC
# GO:0000087           XPO1,SMC1A,MAD2L1,BUB3,SEH1L,STAG2,BIRC5,PPP1CC
# GO:0005654         RAD23B,SUMO1,SF3B1,HIF1A,TLE4,PES1,HNRNPH1,MCL...
# GO:0042470          HSPA5,RAN,NAP1L1,TMEM33,CLTC,YWHAB,HSP90AA1,AHCY
# GO:0032154                             PDXP,RAB11A,MYH9,PPP1CC,SEPT2
# GO:0000398         DDX23,SMC1A,PRPF19,SF3B1,DDX5,HNRNPK,HNRNPH1,H...
# GO:0006886         COPZ1,XPO1,SEC23A,RAB4A,RAN,ARF6,RAB11A,IPO8,S...
# GO:0000381                                   DDX5,PTBP1,THRAP3,TRA2B
# GO:0000910                          NEK7,BIRC5,MYH9,SON,RAB11A,KLHL9
# GO:0071013          DDX23,PRPF19,SF3B1,DDX5,HNRNPK,HNRNPH1,HNRNPA2B1
# GO:0000075         SMC1A,MAD2L1,TP53,BUB3,RPA1,PSMA4,WEE1,DDB1,PSMC6
# GO:0051301         SMC1A,MAD2L1,BUB3,SEH1L,RAN,BIRC6,BIRC5,PDS5A,...
# GO:0005643                           XPO1,MAD2L1,SUMO1,RAN,IPO8,IPO7
# GO:0008565                        XPO1,VPS26A,RAB4A,IPO8,IPO7,SEC61G
# GO:0001077                       TCF4,TP53,HIF1A,MEF2A,HNRNPK,POU2F1
# GO:0004004                                    DDX23,DDX5,DDX3X,G3BP1
# GO:0001085                                      SPEN,TBX3,MEF2A,TP53
# GO:0006397         YTHDC1,QKI,THRAP3,CDK12,PPP4R2,SON,NONO,WBP11,...
# GO:0045892         SIRT1,TP53,FOXK1,TBX3,SUMO1,BIRC5,TLE4,SPEN,ZN...
# GO:0019048         XPO1,SIRT1,DDX3X,TP53,TBK1,RAN,VAPB,SPEN,HNRNP...
# GO:0055037                         RAB11A,RAP2B,RAB11FIP1,ARF6,RAB14
# GO:0042645                                    VDAC2,VDAC1,TFAM,HSPA9
# GO:0010467         SF3B1,HSPA1B,HNRNPH1,GTF2A1,XPO1,SMG1,RAN,EIF1...
# GO:0032880                                  SUMO1,RAB14,NCKAP1,SEPT2
# GO:0045893         TCF4,TFAM,TP53,FOXK1,TBX3,RAN,ARID1A,THRAP3,HI...
# GO:0030512                              XPO1,SIRT1,TP53,PPP1CC,HSPA5
# GO:0015629         CAPZA2,ARPC3,MYH9,RPA1,ARPC5,MARCKS,HNRNPH1,RA...
# GO:0003697                             SPEN,RAD23B,HNRNPK,RPA1,WBP11
#
#                             GO domain  Hypergeometric p-Value
# GO Term Accession
# GO:0005634         cellular_component            3.581948e-13
# GO:0005829         cellular_component            1.955304e-09
# GO:0005515         molecular_function            1.399173e-08
# GO:0003723         molecular_function            2.137626e-08
# GO:0008380         biological_process            5.544722e-08
# GO:0016607         cellular_component            9.784616e-08
# GO:0005730         cellular_component            7.004389e-07
# GO:0030529         cellular_component            8.977615e-07
# GO:0000776         cellular_component            1.053537e-06
# GO:0000785         cellular_component            1.105299e-06
# GO:0005737         cellular_component            1.201165e-06
# GO:0000236         biological_process            1.642092e-06
# GO:0030496         cellular_component            1.806985e-06
# GO:0005819         cellular_component            2.273847e-06
# GO:0000278         biological_process            2.532377e-06
# GO:0000777         cellular_component            3.007244e-06
# GO:0000087         biological_process            4.055051e-06
# GO:0005654         cellular_component            4.161391e-06
# GO:0042470         cellular_component            5.207942e-06
# GO:0032154         cellular_component            7.339925e-06
# GO:0000398         biological_process            7.447183e-06
# GO:0006886         biological_process            7.497410e-06
# GO:0000381         biological_process            1.056091e-05
# GO:0000910         biological_process            1.389435e-05
# GO:0071013         cellular_component            1.511752e-05
# GO:0000075         biological_process            1.741490e-05
# GO:0051301         biological_process            2.030459e-05
# GO:0005643         cellular_component            2.793718e-05
# GO:0008565         molecular_function            2.793718e-05
# GO:0001077         molecular_function            2.793718e-05
# GO:0004004         molecular_function            4.608945e-05
# GO:0001085         molecular_function            5.376545e-05
# GO:0006397         biological_process            5.545482e-05
# GO:0045892         biological_process            6.122319e-05
# GO:0019048         biological_process            7.495966e-05
# GO:0055037         cellular_component            1.056527e-04
# GO:0042645         cellular_component            1.080291e-04
# GO:0010467         biological_process            1.206591e-04
# GO:0032880         biological_process            1.226534e-04
# GO:0045893         biological_process            1.256442e-04
# GO:0030512         biological_process            1.517323e-04
# GO:0015629         cellular_component            1.547007e-04
# GO:0003697         molecular_function            1.957239e-04

# %%
overlapping_genes_go.ix['GO:0003723']['Gene symbols in List']
# Out:
# 'CELF1,PUM2,SETD1B,HNRNPH1,RPS2,HNRNPH3,LARP4,TROVE2,XPO1,QKI,NONO,EIF1AX,SON,HNRNPK,HNRNPA2B1,PTBP1,IREB2,DCP2,DDX3X,ZFP36L2,MEX3C,DAZAP1,DIS3,EIF4G2,SPEN,THUMPD1,NCL,G3BP2'

# %%
overlapping_genes_go.ix['GO:0008380']['Gene symbols in List']
# Out:
# 'DDX23,YTHDC1,QKI,THRAP3,CDK12,SF3B1,PPP4R2,SON,NONO,HNRNPK,HNRNPH1,WBP11,HNRNPH3,PTBP1,SMC1A,HNRNPA2B1'

# %%
GO:0008380
