# %%
import pandas as pd

# %%
#in encode_split
for x in *.gz; do echo -n "$x "; zcat $x | wc -l; done > ~/v1_m5dsum.txt

#in encode_split_v2
for x in *.gz; do echo -n "$x "; zcat $x | wc -l; done > ~/v2_m5dsum.txt

# %%
v1 = pd.read_table("/home/gpratt/v1_m5dsum_tmp.txt", header=None, names=['fn', 'file_length'], sep=None)
v2 = pd.read_table("/home/gpratt/v2_m5dsum_tmp.txt", header=None, names=['fn', 'file_length'], sep=None)
# Out:
# /home/gpratt/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# /home/gpratt/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
merged_files = pd.merge(v1, v2, left_on="fn", right_on="fn", how="inner")

# %%
merged_files['matches'] = merged_files.file_length_x == merged_files.file_length_y

# %%
len(merged_files)
# Out:
# 845

# %%
matching = merged_files[merged_files.matches]

# %%
matching
# Out:
#                                                     fn  file_length_x  \
# 0    230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.A01_230_01_...       20243712
# 1    230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.B06_230_01_...       15532636
# 2    230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.C01_230_02_...       20669584
# 3    230_CLIP_CGCTCATT-AGGCGAAG_L002_R1.D08fixed_23...       15316960
# 4    230_CLIP_CGCTCATT-AGGCGAAG_L002_R2.A01_230_01_...       20243712
# 5    230_CLIP_CGCTCATT-AGGCGAAG_L002_R2.B06_230_01_...       15532636
# 6    230_CLIP_CGCTCATT-AGGCGAAG_L002_R2.C01_230_02_...       20669584
# 7    230_CLIP_CGCTCATT-AGGCGAAG_L002_R2.D08fixed_23...       15316960
# 8    231_CLIP_ATTCAGAA-TATAGCCT_L002_R1.A01_231_01_...       16610256
# 9    231_CLIP_ATTCAGAA-TATAGCCT_L002_R1.B06_231_01_...       22378076
# 10   231_CLIP_ATTCAGAA-TATAGCCT_L002_R2.A01_231_01_...       16610256
# 11   231_CLIP_ATTCAGAA-TATAGCCT_L002_R2.B06_231_01_...       22378076
# ...

# %%
not_matching = merged_files[~merged_files.matches]

# %%
len(not_matching)
# Out:
# 273
