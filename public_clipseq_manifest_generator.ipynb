# %%
import gspread
import pandas as pd
import os
from IPython.core.display import HTML
from oauth2client.client import SignedJwtAssertionCredentials
import json
import numpy as np

# %%
json_key = json.load(open("/home/gpratt/ipython_notebook/public clip-588adbc137f3.json"))
scope = ['https://spreadsheets.google.com/feeds']

credentials = SignedJwtAssertionCredentials(json_key['client_email'], json_key['private_key'], scope)
gc = gspread.authorize(credentials)

sht1 = gc.open_by_url("https://docs.google.com/spreadsheets/d/1ZU2mQh54jentqvhR_oMnviLGWR8Nw_x338gULzKjNDI/edit#gid=0")
ws = sht1.worksheet("public_clip_database")
list_of_lists = ws.get_all_values()
df = pd.DataFrame(list_of_lists[1:], columns=list_of_lists[0])
df.index = df.SRA

clip_df = df[df['CLIP-seq?'] == "Yes"]
clip_df = clip_df[clip_df.type != "iclip"]
clip_df['file_names'] = clip_df.SRA.apply(lambda x: os.path.join("/home/gpratt/projects/public_clip/data/public_clip_v4", x.strip()) + ".fastq.gz")

# %%
#manifest
clip_df.to_csv("/home/gpratt/projects/public_clip/scripts/public_fastq.txt", columns=['file_names', 'Species', 'replicate'], sep="\t", index=False, header=False)

# %% [markdown]
# #Run CLIP-seq demux

# %%
#demux sra files
result_file = []
with open("/home/gpratt/projects/public_clip/scripts/sra_files.txt", 'w') as out_file:
    for root, subFolders, files in os.walk("/projects/ps-yeolab/clip_public/clip/"):
        for fn in files:
            if fn.endswith("sra"):
                result_file.append(os.path.abspath(os.path.join(root, fn)))

cmd_list = []

with open("/home/gpratt/projects/public_clip/scripts/fastq_dump_clip.sh", 'w') as out_file:

    out_file.write("""#!/bin/bash                                                                                                                                           
#PBS -N fastq_dump_clip                                                                                                                                       
#PBS -o fastq_dump_clip.sh.out                                                                                                                                
#PBS -e fastq_dump_clip.sh.err                                                                                                                                
#PBS -V                                                                                                                                                       
#PBS -l walltime=4:00:00                                                                                                                                      
#PBS -l nodes=1:ppn=1                                                                                                                                         
#PBS -A yeo-group                                                                                                                                             
#PBS -q home-yeo                                                                                                                                                 
#PBS -t 1-335                                                                                                                                                  
# Go to the directory from which the script was called                                                                                                         
cd /home/gpratt/projects/public_clip/data/public_clip_v4
""")

    for line in result_file:
        line = line.strip()
        sra_name = os.path.basename(line).split(".")[0]
        cmd_list.append('fastq-dump --gzip %s' % (line))

    for x,  line in enumerate(cmd_list):
        x += 1
        out_file.write("cmd[{}]=\"{}\"\n".format(x, line))

    out_file.write("eval ${cmd[$PBS_ARRAYID]}\n")

# %% [markdown]
# #Get iCLIP files from SRA

# %%
iclip_df = df[df['CLIP-seq?'] == "Yes"]
#iclip_df = iclip_df[(iclip_df.type == "par-iclip")]

iclip_df = iclip_df[(iclip_df.type == "iclip") | (iclip_df.type == "par-iclip")]
iclip_df['file_names'] = iclip_df.SRA.apply(lambda x: os.path.join("/home/gpratt/projects/public_clip/data/public_iclip", x.strip()) + ".fastq.gz")

# %%
cmd_list = []

with open("/home/gpratt/projects/public_clip/scripts/fastq_dump_iclip.sh", 'w') as out_file:

    out_file.write("""#!/bin/bash                                                                                                                                           
#PBS -N fastq_dump_clip                                                                                                                                       
#PBS -o fastq_dump_clip.sh.out                                                                                                                                
#PBS -e fastq_dump_clip.sh.err                                                                                                                                
#PBS -V                                                                                                                                                       
#PBS -l walltime=24:00:00                                                                                                                                      
#PBS -l nodes=1:ppn=1                                                                                                                                         
#PBS -A yeo-group                                                                                                                                             
#PBS -q home-yeo                                                                                                                                                 
#PBS -t 1-335                                                                                                                                                  
# Go to the directory from which the script was called                                                                                                         
cd /home/gpratt/projects/public_clip/data/public_iclip/
""")

    for line in iclip_df.SRA:
        line = line.strip()
        sra_name = os.path.basename(line).split(".")[0]
        cmd_list.append('fastq-dump --gzip %s' % (line))

    for x,  line in enumerate(cmd_list):
        x += 1    
        out_file.write("cmd[{}]=\"{}\"\n".format(x, line))

    out_file.write("eval ${cmd[$PBS_ARRAYID]}\n")

# %%
#manifest
iclip_df.to_csv("/home/gpratt/projects/public_clip/scripts/public_iclip.txt", columns=['file_names', 'Species', 'replicate'], sep="\t", index=False, header=False)

# %% [markdown]
# #Generate demuxer

# %%
def calculate_barcode(randomers):
    if randomers.lower() == "none":
        return None
    
    if all("N" == base for base in randomers):
        return randomers

    barcodes = []
    for randomer in randomers.split(";"):
          
        randomer = randomer.split("N")
        for n_before, x in enumerate(randomer):
            if len(x) != 0:
                barcodes.append(x)
                break
    return ";".join(barcodes)

def calculate_n_front(row):
    randomer = row['barcode_and_randomer']
    barcode = row['barcode']
    
    if barcode is None:
        return None
    
    barcode = barcode.split(";")[0]

        
    #Special case if we are just trimming, "front" is total length of randomers
    if all("N" == base for base in randomer):
        return len(randomer)
    

    
    randomer = randomer.split(barcode)
    return len(randomer[0])

def calculate_n_back(row):
    randomer = row['barcode_and_randomer'].split(";")[0]


    barcode = row['barcode']
    
    if barcode is None:
        return None
    
    barcode = barcode.split(";")[0]

    #Special case if we are just trimming, "back" is nothing
    if all("N" == base for base in randomer):
        return 0
    


    randomer = randomer.split(barcode)
    return len(randomer[1])

# %%
iclip_df['barcode'] = iclip_df['barcode_and_randomer'].apply(calculate_barcode)

# %%
iclip_df['front'] = iclip_df.apply(calculate_n_front, axis=1)
iclip_df['back'] = iclip_df.apply(calculate_n_back, axis=1)

# %%
HTML(iclip_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SRA</th>
#       <th>Cell Type</th>
#       <th>Antibody</th>
#       <th>Modification</th>
#       <th>Species</th>
#       <th>Notes</th>
#       <th>CLIP-seq?</th>
#       <th>type</th>
#       <th>gencode_v17_id</th>
#       <th>PMID</th>
#       <th>replicate</th>
#       <th>barcode_and_randomer</th>
#       <th>hg19_equivalent_gencode</th>
#       <th>GEO</th>
#       <th>file_names</th>
#       <th>barcode</th>
#       <th>front</th>
#       <th>back</th>
#     </tr>
#     <tr>
#       <th>SRA</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ERR018283</th>
#       <td>ERR018283</td>
#       <td>HeLa</td>
#       <td>hnRNPC</td>
#       <td>WT</td>
#       <td>hg19</td>
#       <td>iclip</td>
#       <td>Yes</td>
#       <td>iclip</td>
#       <td>EN
td>
#       <td></td>
#       <td>/home/gpratt/projects/public_clip/data/public_...</td>
#       <td>TG</td>
#       <td>0</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>ERR208895</th>
#       <td>ERR208895</td>
#       <td>brain</td>
#       <td>TDP-43</td>
#       <td>WT</td>
#       <td>mm9</td>
#       <td>iclip</td>
#       <td>Yes</td>
#       <td>iclip</td>
#       <td>ENSMUSG00000041459.8</td>
#       <td>22934129</td>
#       <td>rep1</td>
#       <td>NNNNTGGGCNN</td>
#       <td>ENSG00000277726.2</td>
#       <td></td>
#       <td>/home/gpratt/projects/public_clip/data/public_...</td>
#       <td>TGGGC</td>
#       <td>4</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>ERR208896</th>
#       <td>ERR208896</td>
#       <td>brain</td>
#       <td>TDP-43</td>
#       <td>WT</td>
#       <td>mm9</td>
#       <td>iclip</td>
#       <td>Yes</td>
#       <td>iclip</td>
#       <td>ENSMUSG00000041459.8</td>
#       <td>22934129</td>
#       <td>rep1</td>
#       <td>NNNNTGGGCNN</td>
#       <td>ENSG00000277726.2</td>
#       <td></td>
#       <td>/home/gpratt/projects/public_clip/data/public_...</td>
#       <td>TGGGC</td>
#       <td>4</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>ERR208901</th>
#       <td>ERR208901</td>
#       <td>brain</td>
#       <td>fus</td>
#       <td>WT</td>
#       <td>mm9</td>
#       <td>iclip</td>
#       <td>Yes</td>
#       <td>iclip</td>
#       <td>ENSMUSG00000030795.12</td>
#       <td>22934129</td>
#       <td>rep1</td>
#       <td>AATANNN</td>
#       <td>ENSG00000089280.14</td>
#       <td></td>
#       <td>/hom

# %%
#HTML(iclip_df[iclip_df.SRA == "ERR676907"].to_html())

# %%
def make_barcode_file(row):
    if row.barcode is None:
        return 
    out_name = "/home/gpratt/projects/public_clip/scripts/barcodes/{}.txt".format(row.SRA.strip())
    with open(out_name, 'w') as out_file:
        for barcode in row.barcode.split(";"):
            if all("N" == base for base in barcode):
                out_file.write("" + "\t" + barcode + "\n")
            else:
                out_file.write(barcode + "\t" + barcode + "\n")
        
    return out_name

# %%
iclip_df['barcode_file'] = iclip_df.apply(make_barcode_file, axis=1)

# %%
def make_output_file(row):
    try:
        return "python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/{}.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/{}.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/{}.metrics -b {} --front {} --back {}".format(row.SRA.strip(),
    row.SRA.strip(),
    row.SRA.strip(),
    row.barcode_file,
    int(row.front),
    int(row.back)
    )
    except ValueError:
        pass

# %%
iclip_df['final'] = iclip_df.apply(make_output_file, axis=1)

# %%
with open("/home/gpratt/projects/public_clip/scripts/barcode_split.sh", 'w') as out_file:

    out_file.write("""#!/bin/bash                                                                                                                                           
#PBS -N barcode_split                                                                                                                                       
#PBS -o barcode_split.sh.out                                                                                                                                
#PBS -e barcode_split.sh.err                                                                                                                                
#PBS -V                                                                                                                                                       
#PBS -l walltime=16:00:00                                                                                                                                      
#PBS -l nodes=1:ppn=1                                                                                                                                         
#PBS -A yeo-group                                                                                                                                             
#PBS -q home-yeo                                                                                                                                                 
#PBS -t 1-135                                                                                                                                                  
# Go to the directory from which the script was called                                                                                                         
cd /home/gpratt/projects/public_clip/analysis/split_fastq
""")

    for x, line in enumerate(iclip_df.final.values):
        print line
        x += 1
        out_file.write("cmd[{}]=\"{}\"\n".format(x, line))

    out_file.write("eval ${cmd[$PBS_ARRAYID]}\n")
# Out:
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR018283.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR018283.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR018283.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR018283.txt --front 3 --back 0
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR018284.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR018284.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR018284.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR018284.txt --front 3 --back 0
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR901494.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR901494.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR901494.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR901494.txt --front 0 --back 4
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR901495.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR901495.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR901495.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR901495.txt --front 0 --back 4
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR901496.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR901496.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SR
txt --front 0 --back 3
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR868536.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR868536.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR868536.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR868536.txt --front 0 --back 3
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1548666.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1548666.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1548666.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1548666.txt --front 0 --back 0
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1548667.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1548667.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1548667.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1548667.txt --front 0 --back 0
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1548664.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1548664.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1548664.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1548664.txt --front 0 --back 0
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1548665.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1548665.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1548665.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1548665.txt --front 0 --back 0
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419263.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419263.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419263.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419263.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419255.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419255.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419255.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419255.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419264.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419264.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419264.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419264.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419257.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419257.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419257.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419257.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419261.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419261.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419261.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419261.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419259.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419259.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419259.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419259.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419258.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419258.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419258.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419258.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419256.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419256.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419256.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419256.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419262.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419262.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419262.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419262.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419260.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419260.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419260.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419260.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419254.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419254.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419254.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419254.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR419253.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR419253.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR419253.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR419253.txt --front 3 --back 2
# None
# None
# None
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR676907.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR676907.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR676907.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR676907.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR676909.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR676909.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR676909.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR676909.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR676911.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR676911.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR676911.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR676911.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR676908.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR676908.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR676908.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR676908.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR676910.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR676910.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR676910.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR676910.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR689066.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR689066.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR689066.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR689066.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR689064.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR689064.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR689064.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR689064.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR689063.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR689063.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR689063.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR689063.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR689065.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR689065.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR689065.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR689065.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/ERR689067.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/ERR689067.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/ERR689067.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/ERR689067.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1013512.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1013512.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1013512.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1013512.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1013513.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1013513.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1013513.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1013513.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1013514.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1013514.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1013514.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1013514.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1013515.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1013515.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1013515.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1013515.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1513335.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1513335.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1513335.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1513335.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1513336.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1513336.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1513336.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1513336.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1513337.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1513337.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1513337.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1513337.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1269756.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1269756.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1269756.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1269756.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1269757.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1269757.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1269757.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1269757.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1269758.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1269758.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1269758.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1269758.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1269759.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1269759.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1269759.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1269759.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1269760.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1269760.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1269760.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1269760.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1269761.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1269761.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1269761.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1269761.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1556932.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1556932.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1556932.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1556932.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1556933.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1556933.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1556933.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1556933.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1556934.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1556934.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1556934.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1556934.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1556935.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1556935.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1556935.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1556935.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1556936.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1556936.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1556936.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1556936.txt --front 3 --back 2
# python ~/gscripts/gscripts/clipseq/demultiplex_barcoded_fastq.py -f ~/projects/public_clip/data/public_iclip/SRR1556937.fastq.gz -o ~/projects/public_clip/analysis/split_fastq/SRR1556937.fastq.gz -m ~/projects/public_clip/analysis/split_fastq/SRR1556937.metrics -b /home/gpratt/projects/public_clip/scripts/barcodes/SRR1556937.txt --front 3 --back 2

# %%
with open("/home/gpratt/projects/public_clip/scripts/public_iclip_v1.txt", 'w') as out_file:
    for name, row in iclip_df.iterrows():
        if row.barcode is None:
            fastq_file = "/home/gpratt/projects/public_clip/data/public_iclip/{}.fastq.gz".format(row.SRA.strip())
            out_file.write("{}\t{}\n".format(fastq_file, row.Species))
            print os.path.exists(fastq_file)
            continue
        for barcode in row.barcode.split(";"):
            fastq_file = "/home/gpratt/projects/public_clip/analysis/split_fastq/{}.{}.fastq.gz".format(row.SRA.strip(),
                                                                                                       barcode.strip())
            out_file.write("{}\t{}\n".format(fastq_file, row.Species))
            if not os.path.exists(fastq_file):
                print fastq_file
# Out:
# /home/gpratt/projects/public_clip/analysis/split_fastq/SRR1665044.GGTC.fastq.gz
# True
# True
# True
