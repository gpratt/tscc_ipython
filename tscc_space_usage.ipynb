# %%
import pandas as pd

# %%
space = """43351105636	ace_progenity
140689	ace_progenity.rsync_log
30815191	arraydata
13	barcodes
9	BaseSpace_Mount
31384729	bay001
1442	bin
32683578	biom200_module1_2016
81722261	biom262-2015
81339089	biom262_2016
171776067	biom262-2016
129234074	biom262_2017
2213410950	bkakarad
4850046	CARDIPS_vcf
482827606	clip_public
14366	compara
911209088	conservation
87753676	conservation_v2
49003789	dfam
529	disprot
39441	drylab_meetings
9	elvannostrand
956386555	eoverbey
116954582	ewyeo
144289	examples
56741179	for_eric
116954550	geneyeo_oolite_backup
2814321855	genomes
1054301	geo
20605548	git-repos
6476033915	gpratt
13495	gsea_gene_sets
27739984	gtex
765523817	Hubs.tar.gz
9	imagedata
262573768	jbrought
221948559	jnussbac
1793927667	jsc021
9	kkapeli
1627475654	ljamal
5025344468	lovci
429	modulefiles
46911792	mstp_bootcamp_2016
3506354480	obotvinnik
295360306	old_software
5515107494	oolite_backup
1	plate1
441793501	ppliu_sebas_shsathe
33	ps_yeolab_usage.txt
5561484	rnaseq_public
35920117	ron
341230	salima
9	scratch
40073723287	seqdata
911	sfari
47	share
1878229595	shsathe
3014812357	shuelga
18424638	singularity
396936286	smarkmiller
1056109626	software
26992	software-tmp
531217149	sonal
16942794	test_gatk_queue
492525889	tjstark
5	tscc_bash_settings_current
9	tstark
3835864450	wjin
2596482172	ysong
281421720	zhh033""".split("\n")

space = {item.split("\t")[1]: item.split("\t")[0] for item in space}
space = pd.Series(space)
space = space.astype(int)

# %%
total_info = pd.DataFrame({"space": space, "fraction": (space / space.sum()) * 100})
total_info_filtered = total_info[total_info.fraction > 1]
total_info_filtered.sort_values("fraction", ascending=False)
# Out:
#                 fraction        space
# ace_progenity  32.845946  43351105636
# seqdata        30.362763  40073723287
# gpratt          4.906714   6476033915
# oolite_backup   4.178646   5515107494
# lovci           3.807566   5025344468
# wjin            2.906329   3835864450
# obotvinnik      2.656669   3506354480
# shuelga         2.284241   3014812357
# genomes         2.132335   2814321855
# ysong           1.967283   2596482172
# bkakarad        1.677041   2213410950
# shsathe         1.423083   1878229595
# jsc021          1.359210   1793927667
# ljamal          1.233094   1627475654

# %%
space = """18372464	20110128_JasonGiordano_smRNA
571437243	adomissy
33596799778	bay001
3608471824	clip_not_encode
34730	copacabana
9	disk_usage.txt
70064459	ecwheele
14349922832	elvannostrand
1407752034	enching
91649320011	encode
123322647	eric_oolite_backup
31970647873	from_hotel_node
1168811	gabe_encode_comparison
1162726636	gabe_oolite_backup
86359799	gpratt
1	igm-storage1.ucsd.edu
13234245	jnussbac
43033387392	oolite_backup
59980069	seqdata
68838562	seqdata_20170104_SimoneDallari_viral-protein_alain""".split("\n")

space = {item.split("\t")[1]: item.split("\t")[0] for item in space}
space = pd.Series(space)
space = space.astype(int)

# %%
total_info = pd.DataFrame({"space": space, "fraction": (space / space.sum()) * 100})
total_info_filtered = total_info[total_info.fraction > 1]
total_info_filtered.sort_values("fraction", ascending=False)
# Out:
#                   fraction        space
# encode           41.322223  91649320011
# oolite_backup    19.402602  43033387392
# bay001           15.147897  33596799778
# from_hotel_node  14.414709  31970647873
# elvannostrand     6.469996  14349922832
# clip_not_encode   1.626963   3608471824
