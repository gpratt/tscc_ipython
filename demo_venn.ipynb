# %%
# %matplotlib inline
from matplotlib_venn import venn2

# %%
venn2({'01': 100, '11': 100, '10':100}, set_labels=['Peaks', 'CDS Regions'])
# Out:
# <matplotlib_venn._common.VennDiagram instance at 0x2ab33d923320>
