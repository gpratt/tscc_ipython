# %%
15436.Yeo.1_HTA-2_0.CEL 
15437.Yeo.2_HTA-2_0.CEL 
15438.Yeo.3_HTA-2_0.CEL 
15439.Yeo.4_HTA-2_0.CEL 
15440.Yeo.5_HTA-2_0.CEL 
15441.Yeo.6_HTA-2_0.CEL 
15442.Yeo.7_HTA-2_0.CEL 
15443.Yeo.8_HTA-2_0.CEL 
15444.Yeo.9_HTA-2_0.CEL 
15445.Yeo.10_HTA-2_0.CEL        
15446.Yeo.11_HTA-2_0.CEL        
15447.Yeo.12_HTA-2_0.CEL        
15448.Yeo.13_HTA-2_0.CEL        
15449.Yeo.14_HTA-2_0.CEL        
15450.Yeo.15_HTA-2_0.CEL        
15451.Yeo.16_HTA-2_0.CEL       
15452.Yeo.17_HTA-2_0.CEL        
15453.Yeo.18_HTA-2_0.CEL        
15454.Yeo.19_HTA-2_0.CEL        
15455.Yeo.20_HTA-2_0.CEL        
15456.Yeo.21_HTA-2_0.CEL        
15457.Yeo.22_HTA-2_0.CEL        
15458.Yeo.23_HTA-2_0.CEL       
15459.Yeo.24_HTA-2_0.CEL       
15460.Yeo.25_HTA-2_0.CEL        
15461.Yeo.26_HTA-2_0.CEL        
15462.Yeo.27_HTA-2_0.CEL        
15463.Yeo.28_HTA-2_0.CEL        
15464.Yeo.29_HTA-2_0.CEL        
15465.Yeo.30_HTA-2_0.CEL        
15466.Yeo.31_HTA-2_0.CEL       
15467.Yeo.32_HTA-2_0.CEL      
15468.Yeo.33_HTA-2_0.CEL     
15469.Yeo.34_HTA-2_0.CEL     
15470.Yeo.35_HTA-2_0.CEL     
15471.Yeo.36_HTA-2_0.CEL     
15472.Yeo.37_HTA-2_0.CEL     
15473.Yeo.38_HTA-2_0.CEL     
15474.Yeo.39_HTA-2_0.CEL
15475.Yeo.40_HTA-2_0.CEL        
15476.Yeo.41_HTA-2_0.CEL        
15477.Yeo.42_HTA-2_0.CEL

# %%
import pandas as pd

# %%
pd.read_table?

# %%
probset_fernando = pd.read_table("/home/gpratt/projects/hnrnpa2b1/data/geo_data_submission/hnrnpa2b1_arrays_human_ipsc_mn_stress_quant-norm.pm-gcbg.iter-plier.summary.txt",
              comment="#")

# %%
probset_affy = pd.read_csv("/home/gpratt/ad-hoc/HTA-2_0.na36.hg19.probeset.csv",
              comment="#")

# %%
probset_gpl = pd.read_table("/home/gpratt/ad-hoc/GPL17585-45238.txt",
              comment="#", dtype="str")

# %%
probeset_from_geo = set(probset_gpl.probeset_id.dropna())
probeset_from_fernando = set(probset_fernando.probeset_id.astype(str))
probeset_from_affy = set(probset_affy.probeset_id)

# %%
len(probeset_from_geo & probeset_from_fernando)
# Out:
# 914585

# %%
len(probeset_from_geo)
# Out:
# 914585

# %%
len(probeset_from_fernando)
# Out:
# 925032

# %%
len(probeset_from_fernando - probeset_from_geo)
# Out:
# 10447

# %%
" ".join(probeset_from_fernando - probeset_from_geo)
# Out:
# '18678639 18678638 18671530 18678635 18678634 18678637 18678636 18678631 18678630 18678633 18678632 18674060 18674108 18677814 19020578 18673942 18679033 18677815 18673943 18677816 18670021 18670008 18677058 18677059 18677054 18677055 18677056 18677057 18677050 18677051 18677052 18677053 18676899 18676898 18676893 18676892 18676891 18676890 18676897 18676896 18676895 18676894 18679863 18679862 18679861 18679860 18679867 18679866 18679865 18679864 18679869 18679868 18676093 18676092 18676091 18676090 18676097 18676096 18676095 18676094 18676099 18676098 18673119 18673118 18673111 18673110 18673113 18673112 18673115 18673114 18673117 18673116 18671841 18671840 18671843 18671842 18671845 18671844 18671847 18671846 18671849 18671848 18672255 18678808 18678809 18672579 18672254 18672574 18672575 18672576 18672577 18672570 18678807 18678804 18678805 18672256 18672251 18673389 18672252 18674932 18674933 18674930 18674931 18674936 18674937 18674934 18674935 18674938 18674939 18680159 1867279
# ...

# %%
len(probeset_from_geo - probeset_from_fernando)
# Out:
# 0

# %%
probset_probset_ids
# Out:
# {'JUC6_cox_hap2001609.hg.1',
#  'PSR20002726.hg.1',
#  'PSR17017040.hg.1',
#  'JUC18003525.hg.1',
#  'PSR08025542.hg.1',
#  'JUC03011705.hg.1',
#  'PSR17027568.hg.1',
#  'PSR03042484.hg.1',
#  'JUC02013319.hg.1',
#  'PSR22014191.hg.1',
#  'JUC11014385.hg.1',
#  'PSR05032412.hg.1',
#  'PSR11022524.hg.1',
#  'JUC08008600.hg.1',
#  'JUC11009992.hg.1',
#  'JUC07007752.hg.1',
#  'PSR22005469.hg.1',
#  'PSR6_qbl_hap6002899.hg.1',
#  'PSR15012481.hg.1',
#  'PSR12028552.hg.1',
#  'JUC04007932.hg.1',
#  'JUC16008788.hg.1',
#  'JUC03008110.hg.1',
#  'JUC07000022.hg.1',
#  'JUC11010691.hg.1',
#  'JUC17006242.hg.1',
#  'JUC06003734.hg.1',
#  'PSR22007857.hg.1',
#  'PSR03010892.hg.1',
#  'PSR05019786.hg.1',
#  'JUC02005498.hg.1',
#  'JUC17007737.hg.1',
#  'PSR08015665.hg.1',
#  'JUC08007534.hg.1',
#  'PSR10025995.hg.1',
#  'JUC12009769.hg.1',
#  'PSR6_ssto_hap7002547.hg.1',
#  'JUC05014628.hg.1',
#  'PSR07034846.hg.1',
#  'PSR6_cox_hap2000769.hg.1',
#  'PSR12029761.hg.1',
#  'PSR02014322.hg.1',
# ...

# %%
len(expression_probset_ids & probset_probset_ids)
# Out:
# 10498

# %%
len(expression_probset_ids & probset_probset_ids)
