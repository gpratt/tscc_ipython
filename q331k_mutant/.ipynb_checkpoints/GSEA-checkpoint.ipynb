# %%
import pandas as pd

# %%
pc2 = pd.read_table("ranked_gene_list_MALE_versus_FEMALE_1455561427103.xls")

# %%
pc2
# Out:
#                       NAME DESCRIPTION GENE_SYMBOL  \
# 0                LOC390940        null   LOC390940
# 1                    PTGDR        null       PTGDR
# 2                 C1ORF121        null    C1ORF121
# 3                   ZNF154        null      ZNF154
# 4                     CLTB        null        CLTB
# 5                LOC646756        null   LOC646756
# 6                   MST101        null      MST101
# 7                    LIMK1        null       LIMK1
# 8                     FLT1        null        FLT1
# 9                    VPS35        null       VPS35
# 10                  VPS13A        null      VPS13A
# 11                    SOX4        null        SOX4
# 12               LOC642236        null   LOC642236
# 13               LOC653256        null   LOC653256
# 14                 SEC14L1        null     SEC14L1
# 15                   EMID2        null       EMID2
# 16                   HNRPU        null       HNRPU
# 17                   DCHS2        null       DCHS2
# 18                    GYPB        null        GYPB
# 19                 HRASLS2        null     HRASLS2
# 20                    XPO1        null        XPO1
# 21                 TMEM163        null     TMEM163
# 22                   FGFR2        null       FGFR2
# 23                   EEF1G        null       EEF1G
# 24               LOC390999        null        null
# 25                   DPPA4        null       DPPA4
# 26               LOC654434        null        null
# 27                   MCF2L        null       MCF2L
# 28                 C7ORF26        null     C7ORF26
# 29                   PTPRJ        null       PTPRJ
# ...                    ...         ...         ...
# 1117             LOC439992        null   LOC439992
# 1118                  ARF6        null        ARF6
# 1119                HNRPH1        null      HNRPH1
# 1120  PPIA /// LOC128192 /        null        null
# 1121                  TFRC        null        TFRC
# 1122      IGKC /// IGKV1-5        null        null
# 1123                SWAP70        null      SWAP70
# 1124                  DPP6        null        DPP6
# 1125             LOC652745        null   LOC652745
# 1126                NPEPPS        null      NPEPPS
# 1127                  NIP7        null        NIP7
# 1128                 RKHD1        null       RKHD1
# 1129                 HUWE1        null       HUWE1
# 1130                   ZFX        null         ZFX
# 1131                  SDHC        null        SDHC
# 1132             LOC339562        null   LOC339562
# 1133                  PHF7        null        PHF7
# 1134                  NCR2        null        NCR2
# 1135             LOC388796        null   LOC388796
# 1136                RIMBP2        null      RIMBP2
# 1137              H2-ALPHA        null    H2-ALPHA
# 1138                COL6A1        null      COL6A1
# 1139               ARHGEF4        null     ARHGEF4
# 1140                  MYH9        null        MYH9
# 1141                 LRRN5        null       LRRN5
# 1142                  WTAP        null        WTAP
# 1143             LOC440334        null        null
# 1144                  RNF5        null        RNF5
# 1145                   PRX        null         PRX
# 1146                RECQL4        null      RECQL4
#
#                                              GENE_TITLE     SCORE  Unnamed: 5
# 0                                                     -  0.718807         NaN
# 1                        prostaglandin D2 receptor (DP)  0.576024         NaN
# 2                   chromosome 1 open reading frame 121  0.540143         NaN
# 3                               zinc finger protein 154  0.533930         NaN
# 4                           clathrin, light chain (Lcb)  0.533040         NaN
# 5                                                     -  0.515346         NaN
# 6                                                     -  0.506093         NaN
# 7                                   LIM domain kinase 1  0.469039         NaN
# 8     fms-related tyrosine kinase 1 (vascular endoth...  0.462463         NaN
# 9                   vacuolar protein sorting 35 (yeast)  0.460702         NaN
# 10    vacuolar protein sorting 13 homolog A (S. cere...  0.442321         NaN
# 11                 SRY (sex determining region Y)-box 4  0.441109         NaN
# 12                                                    -  0.439106         NaN
# 13                                                    -  0.436828         NaN
# 14                         SEC14-like 1 (S. cerevisiae)  0.436283         NaN
# 15                              EMI domain containing 2  0.434573         NaN
# 16    heterogeneous nuclear ribonucleoprotein U (sca...  0.431452         NaN
# 17                              dachsous 2 (Drosophila)  0.428548         NaN
# 18                      glycophorin B (MNS blood group)  0.424945         NaN
# 19                               HRAS-like suppressor 2  0.424578         NaN
# 20                     exportin 1 (CRM1 homolog, yeast)  0.418912         NaN
# 21                            transmembrane protein 163  0.413057         NaN
# 22               ffer syndrome, Jackson-Weiss syndrome)  0.409080         NaN
# 23     eukaryotic translation elongation factor 1 gamma  0.408294         NaN
# 24                                                 null  0.407776         NaN
# 25              developmental pluripotency associated 4  0.396967         NaN
# 26                                                 null  0.393604         NaN
# 27    MCF.2 cell line derived transforming sequence-...  0.392988         NaN
# 28                   chromosome 7 open reading frame 26  0.385720         NaN
# 29       protein tyrosine phosphatase, receptor type, J  0.385570         NaN
# ...                                                 ...       ...         ...
# 1117                                                  - -0.310572         NaN
# 1118                          ADP-ribosylation factor 6 -0.311706         NaN
# 1119     heterogeneous nuclear ribonucleoprotein H1 (H) -0.314702         NaN
# 1120                                               null -0.317530         NaN
# 1121                   transferrin receptor (p90, CD71) -0.319987         NaN
# 1122                                               null -0.326436         NaN
# 1123                                                  - -0.330721         NaN
# 1124                             dipeptidyl-peptidase 6 -0.331707         NaN
# 1125                                                  - -0.336813         NaN
# 1126                 aminopeptidase puromycin sensitive -0.336966         NaN
# 1127           nuclear import 7 homolog (S. cerevisiae) -0.337683         NaN
# 1128             ring finger and KH domain containing 1 -0.337933         NaN
# 1129              HECT, UBA and WWE domain containing 1 -0.339776         NaN
# 1130                      zinc finger protein, X-linked -0.342882         NaN
# 1131  succinate dehydrogenase complex, subunit C, in... -0.343157         NaN
# 1132                                                  - -0.346963         NaN
# 1133                               PHD finger protein 7 -0.347517         NaN
# 1134         natural cytotoxicity triggering receptor 2 -0.350800         NaN
# 1135                                                  - -0.354259         NaN
# 1136                             RIMS binding protein 2 -0.357464         NaN
# 1137                                                  - -0.359387         NaN
# 1138                         collagen, type VI, alpha 1 -0.359741         NaN
# 1139     Rho guanine nucleotide exchange factor (GEF) 4 -0.371664         NaN
# 1140                  myosin, heavy chain 9, non-muscle -0.398900         NaN
# 1141                     leucine rich repeat neuronal 5 -0.407247         NaN
# 1142                   Wilms tumor 1 associated protein -0.419341         NaN
# 1143                                               null -0.422161         NaN
# 1144                              ring finger protein 5 -0.423207         NaN
# 1145                                           periaxin -0.540669         NaN
# 1146                                RecQ protein-like 4 -0.608265         NaN
#
# [1147 rows x 6 columns]

# %%
pc2 = unstressed_protein_coding_pca.loadings.ix['pc_2'].sort_values(ascending=False)
large_sets = mm10GO.GO[(mm10GO.GO['nGenes'] > 25) & (mm10GO.GO['nGenes'] < 500)]

# %%
result = {}
in_set = {}
for name, genes in large_sets['Ensembl Gene ID'].iteritems():
    result[name] = pc2.copy()
    in_set[name] = {gene_id: True for gene_id in genes}

result = pd.DataFrame(result)
in_set = pd.DataFrame(in_set)
in_set = in_set.fillna(False)

incomplete_in_set = in_set.T

for gene in result.index.difference(in_set.index):
    incomplete_in_set[gene] = False
    
in_set = incomplete_in_set[result.index].T

#is_set = in_set.reindex(result.index, fill_value=False)

hit_values = result.copy()
miss_values = result.copy()

# %%
hit_values[~in_set] = 0
hit_values = np.abs(hit_values)
miss_values[:] = 0
miss_values[~in_set] = 1

# %%
def enrichment_score_vectorized(hit_values, miss_values):
    normalized_hit_values = hit_values / hit_values.sum()
    normalized_miss_values = miss_values / miss_values.sum()

    enrichment_score = normalized_hit_values.cumsum() - normalized_miss_values.cumsum()
    return enrichment_score

def get_largest_score_vectorized(enrichment_score):
    combined_scores = pd.concat({"max_score": enrichment_score.max(), "min_score": enrichment_score.min()}).unstack()
    return combined_scores.apply(lambda x: x.max_score if np.abs(x.max_score) > np.abs(x.min_score) else x.min_score, axis=0)

# %%
enrichment_score = enrichment_score_vectorized(hit_values, miss_values)

# %%
largest_enrichment = get_largest_score_vectorized(enrichment_score)

# %%
results = {}
for x in range(100):
    index = list(hit_values.index)
    #np.random.shuffle(df.index.get_values())
    random.shuffle(index)
    shuffled_hit_values = hit_values.copy().ix[index]
    shuffled_miss_values = miss_values.copy().ix[index]

    shuffled_hit_values.reset_index()
    shuffled_miss_values.reset_index()
    results[x] = get_largest_score_vectorized(enrichment_score_vectorized(shuffled_hit_values, shuffled_miss_values))
shuffled_results = pd.concat(results).unstack()
