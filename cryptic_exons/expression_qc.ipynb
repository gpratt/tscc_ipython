# %%
# %matplotlib inline
from collections import Counter, OrderedDict, defaultdict
import copy
import glob
import itertools
from itertools import izip
import itertools
import os
import subprocess
import tempfile
import random

from IPython.core.display import HTML, Image
import itertools
import pandas as pd
from matplotlib import gridspec
from matplotlib import pyplot
import matplotlib.patches as mpatches

import matplotlib as mpl
from matplotlib_venn import venn2, venn3
import numpy as np
import scipy
import seaborn as sns

from clipper.src import CLIP_analysis
from clipper.src import get_genomic_regions
import flotilla
from gscripts import GO
from gscripts.general import dataviz
from gscripts.general import parsers
from gscripts.general import region_helpers
from gscripts.rnaseq.helpers import counts_to_rpkm

img_dir = "/home/gpratt/Dropbox/mouse_stress/figures"
# Out:
# /home/gpratt/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e1ffa57e191b> in <module>()
#      26 from clipper.src import CLIP_analysis
#      27 from clipper.src import get_genomic_regions
# ---> 28 import flotilla
#      29 from gscripts import GO
#      30 from gscripts.general import dataviz
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/flotilla/__init__.py in <module>()
#       1 import os
#       2
# ----> 3 from .data_model import Study, ExpressionData, SplicingData, MetaData, \
#       4     MappingStatsData, SpikeInData, GeneOntologyData
#       5 from .compute.predict import PredictorConfigManager, PredictorDataSetManager
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/flotilla/data_model/__init__.py in <module>()
# ----> 1 from .expression import ExpressionData, SpikeInData
#       2 from .gene_ontology import GeneOntologyData
#       3 from .metadata import MetaData
#       4 from .quality_control import MappingStatsData
#       5 from .splicing import SplicingData
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/flotilla/data_model/expression.py in <module>()
#       7 import numpy as np
#       8
# ----> 9 from .base import BaseData
#      10 from ..util import memoize, timestamp
#      11
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/flotilla/data_model/base.py in <module>()
#      16 from ..compute.predict import PredictorConfigManager, \
#      17     PredictorDataSetManager, CLASSIFIER
# ---> 18 from ..visualize.decomposition import DecompositionViz
#      19 from ..visualize.generic import violinplot, nmf_space_transitions, \
#      20     simple_twoway_scatter
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/flotilla/visualize/__init__.py in <module>()
#       3 import seaborn
#       4
# ----> 5 from .ipython_interact import Interactive
#       6 from .predict import PredictorBaseViz
#       7
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/flotilla/visualize/ipython_interact.py in <module>()
#       7 import warnings
#       8
# ----> 9 from IPython.html.widgets import interact, TextWidget, ButtonWidget
#      10 import matplotlib.pyplot as plt
#      11
#
# ImportError: cannot import name TextWidget

# %%
av_resequencing = parsers.rnaseq_metrics("/home/gpratt/projects/cryptic_exons/analysis/encode_stress_v1/")

# %%
av_resequencing_filtered = av_resequencing[[ "Input Reads",
                            #"Reads After Triming",
                            "Uniquely Mapped Reads",
                            "Uniquely mapped reads %",
                            ]]

HTML(av_resequencing_filtered.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads After Triming" : parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     } ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Uniquely Mapped Reads</th>
#       <th>Uniquely mapped reads %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th
#       <th>K562_CA3_AGTTCC_L002_001</th>
#       <td>32,081,800</td>
#       <td>27,705,406</td>
#       <td>89.89%</td>
#     </tr>
#     <tr>
#       <th>K562_PQ1_GATCAG_L001_001</th>
#       <td>27,734,008</td>
#       <td>23,658,155</td>
#       <td>87.95%</td>
#     </tr>
#     <tr>
#       <th>K562_PQ2_TAGCTT_L002_001</th>
#       <td>30,474,615</td>
#       <td>26,522,032</td>
#       <td>88.95%</td>
#     </tr>
#     <tr>
#       <th>K562_PQ3_GGCTAC_L002_001</th>
#       <td>31,322,454</td>
#       <td>26,760,729</td>
#       <td>87.45%</td>
#     </tr>
#     <tr>
#       <th>K562_PQCA1_ATGTCA_L002_001</th>
#       <td>35,141,115</td>
#       <td>30,263,038</td>
#       <td>89.35%</td>
#     </tr>
#     <tr>
#       <th>K562_PQCA2_CCGTCC_L002_001</th>
#       <td>38,981,244</td>
#       <td>32,631,476</td>
#       <td>87.09%</td>
#     </tr>
#     <tr>
#       <th>K562_PQCA3_pippin_GTGAAA_L002_001</th>
#       <td>18,493,441</td>
#       <td>15,514,589</td>
#       <td>87.00%</td>
#     </tr>
#     <tr>
#       <th>K562_ars1_TGACCA_L001_001</th>
#       <td>36,296,653</td>
#       <td>31,925,340</td>
#       <td>89.92%</td>
#     </tr>
#     <tr>
#       <th>K562_ars2_ACAGTG_L001_001</th>
#       <td>25,274,890</td>
#       <td>22,292,896</td>
#       <td>90.27%</td>
#     </tr>
#     <tr>
#       <th>K562_ars3_GCCAAT_L001_001</th>
#       <td>32,465,490</td>
#       <td>28,812,415</td>
#       <td>90.87%</td>
#     </tr>
#     <tr>
#       <th>K562_hs1_CAGATC_L001_001</th>
#       <td>25,097,112</td>
#       <td>21,874,732</td>
#       <td>89.38%</td>
#     </tr>
#     <tr>
#       <th>K562_hs2_ACTTGA_L001_001</th>
#       <td>25,503,718</td>
#       <td>22,477,811</td>
#       <td>90.39%</td>
#     </tr>
#     <tr>
#       <th>K562_hs3_GTCCGC_L002_001</th>
#       <td>29,825,166</td>
#       <td>25,876,636</td>
#       <td>88.87%</td>
#     </tr>
#     <tr>
#       <th>K562_ut1_ATCACG_L001_001</th>
#       <td>25,134,058</td>
#       <td>21,910,595</td>
#       <td>89.44%</td>
#     </tr>
#     <tr>
#       <th>K562_ut2_CGATGT_L001_001</th>
#       <td>24,395,652</td>
#       <td>21,261,207</td>
#       <td>89.20%</td>
#     </tr>
#     <tr>
#       <th>K562_ut3_TTAGGC_L001_001</th>
#       <td>37,922,192</td>
#       <td>32,519,142</td>
#       <td>88.17%</td>
#     </tr>
#   </tbody>
# </table>
