# %%
# %matplotlib inline
from collections import Counter, OrderedDict, defaultdict
import copy
import glob
from itertools import izip
import itertools
import os
import subprocess
import tempfile

from IPython.core.display import HTML, Image
import itertools
import pandas as pd
from matplotlib import gridspec
from matplotlib_venn import venn2, venn3
import numpy as np
import scipy
import seaborn as sns

from clipper.src import CLIP_analysis
from clipper.src import get_genomic_regions
import flotilla
from gscripts import GO
from gscripts.general import dataviz
from gscripts.general import parsers
from gscripts.general import region_helpers
from gscripts.rnaseq.helpers import counts_to_rpkm

img_dir = "/nas3/gpratt/Dropbox/TAF15/Data/mouse_integration"
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
count_df = pd.read_table("/home/gpratt/projects/cryptic_exons/analysis/av_resequencing_v1/all_counts.txt", skiprows=1, index_col=0)
count_df.columns = [item.split(".")[0] for item in count_df.columns]
rpkm_df = counts_to_rpkm(count_df).T
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-b3f55f7eb840> in <module>()
# ----> 1 count_df = pd.read_table("/home/gpratt/projects/cryptic_exons/analysis/av_resequencing_v1/all_counts.txt", skiprows=1, index_col=0)
#       2 count_df.columns = [item.split(".")[0] for item in count_df.columns]
#       3 rpkm_df = counts_to_rpkm(count_df).T
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     489                     skip_blank_lines=skip_blank_lines)
#     490
# --> 491         return _read(filepath_or_buffer, kwds)
#     492
#     493     parser_f.__name__ = name
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     266
#     267     # Create the parser.
# --> 268     parser = TextFileReader(filepath_or_buffer, **kwds)
#     269
#     270     if (nrows is not None) and (chunksize is not None):
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     581             self.options['has_index_names'] = kwds['has_index_names']
#     582
# --> 583         self._make_engine(self.engine)
#     584
#     585     def _get_options_with_defaults(self, engine):
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     722     def _make_engine(self, engine='c'):
#     723         if engine == 'c':
# --> 724             self._engine = CParserWrapper(self.f, **self.options)
#     725         else:
#     726             if engine == 'python':
#
# /home/gpratt/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1091         kwds['allow_leading_cols'] = self.index_col is not False
#    1092
# -> 1093         self._reader = _parser.TextReader(src, **kwds)
#    1094
#    1095         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3229)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6042)()
#
# IOError: File /home/gpratt/projects/cryptic_exons/analysis/av_resequencing_v1/all_counts.txt does not exist

# %%
all_splicing_events = pd.read_csv("/home/gpratt/projects/cryptic_exons/analysis/av_resequencing_v1/combined_output/miso_summary_filtered.csv", index_col=[-2, 2, -1])

# %%
all_splicing_events.groupby(level=["sample_id", "splice_type"]).count().miso_posterior_mean.unstack()
# Out:
# /home/gpratt/anaconda/lib/python2.7/site-packages/pandas/core/index.py:4281: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return np.sum(name == np.asarray(self.names)) > 1
# splice_type                          A3SS  A5SS    AFE   ALE   MXE    RI  \
# sample_id
# AV_47d_1_S50_L008_R1_001             8300  5577  15318  8057  4942  4724
# AV_47d_puro_1_S51_L008_R1_001        8272  5578  15262  8166  4831  4734
# AV_ALS17_5_1_S45_L007_R1_001         8305  5664  15275  8079  4949  4754
# AV_ALS17_5_puro_1_S46_L007_R1_001    8212  5558  15100  8243  4838  4738
# AV_CVB_S56_L008_R1_001               7844  5285  14638  7776  4632  4635
# AV_CVB_puro_S49_L007_R1_001          7605  5104  14805  7980  4516  4594
# AV_GY6_2_1_S43_L007_R1_001           8500  5728  15474  8146  5039  4822
# AV_GY6_2_puro_1_S44_L007_R1_001      8723  5826  15667  8326  5140  4903
# AV_Kin1ALS17_3_S47_L007_R1_001       7248  4932  14003  7582  4288  4374
# AV_Kin1ALS17_3_puro_S48_L007_R1_001  7583  5140  14342  7877  4403  4512
# KK_MN_shFUS_7_S55_L008_R1_001        8153  5574  15495  8162  4951  4748
# KK_MN_shSCR_3_S53_L008_R1_001        8410  5703  15529  8156  5071  4797
# KK_MN_shTAF_5_S54_L008_R1_001        8368  5740  15607  8179  5050  4804
# KK_MN_shTDP_1_S52_L008_R1_001        8392  5704  15543  8140  5005  4769
#
# splice_type                             SE  TANDEMUTR
# sample_id
# AV_47d_1_S50_L008_R1_001             27309       2148
# AV_47d_puro_1_S51_L008_R1_001        27361       2158
# AV_ALS17_5_1_S45_L007_R1_001         27519       2171
# AV_ALS17_5_puro_1_S46_L007_R1_001    27387       2182
# AV_CVB_S56_L008_R1_001               25706       2110
# AV_CVB_puro_S49_L007_R1_001          25326       2128
# AV_GY6_2_1_S43_L007_R1_001           27965       2183
# AV_GY6_2_puro_1_S44_L007_R1_001      28651       2197
# AV_Kin1ALS17_3_S47_L007_R1_001       24233       2078
# AV_Kin1ALS17_3_puro_S48_L007_R1_001  25118       2130
# KK_MN_shFUS_7_S55_L008_R1_001        27255       2190
# KK_MN_shSCR_3_S53_L008_R1_001        27990       2205
# KK_MN_shTAF_5_S54_L008_R1_001        28095       2200
# KK_MN_shTDP_1_S52_L008_R1_001        27961       2216

# %%
all_splicing_events = pd.read_csv("/home/gpratt/projects/cryptic_exons/analysis/av_resequencing_v1/combined_output/miso_summary_filtered.csv", index_col=[-2, 2])
se_splicing_events = all_splicing_events[all_splicing_events.splice_type == "SE"]
splicing_df = se_splicing_events.groupby(level=["sample_id", "event_name"]).first().miso_posterior_mean.unstack().fillna(.5)

# %%
metadata = pd.DataFrame(index=splicing_df.index)
metadata['cell_type'] = "MN"
metadata['exp'] = ["_".join(item.split("_")[:-4]) for item in metadata.index]
metadata['stress'] = ["puro" in item for item in metadata.index]
metadata['outlier'] = False
metadata['phenotype'] = ["_".join(item.split("_")[:-4]) for item in metadata.index]
metadata['paired_with_stress'] = ["KK" not in item for item in metadata.index]

# %%
mn_study = flotilla.Study(# The metadata describing phenotype and pooled samples
                       metadata,
                       # A version for this data
                       version='0.1.0',
                       expression_data = rpkm_df,
                       # Dataframe of the splicing data
                       splicing_data=splicing_df,
                       expression_thresh = 1,
                       species="hg19"
)
# Out:
# No phenotype to color mapping was provided, falling back on reasonable defaults.
# No phenotype to marker (matplotlib plotting symbol) was provided, so each phenotype will be plotted as a circle in visualizations.
# Error loading species hg19 data: Could not reserve memory block
# 2016-01-04 17:25:36	Initializing Study
# 2016-01-04 17:25:36	Initializing Predictor configuration manager for Study
# 2016-01-04 17:25:36	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2016-01-04 17:25:36	Added ExtraTreesClassifier to default predictors
# 2016-01-04 17:25:36	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2016-01-04 17:25:36	Added ExtraTreesRegressor to default predictors
# 2016-01-04 17:25:36	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2016-01-04 17:25:36	Added GradientBoostingClassifier to default predictors
# 2016-01-04 17:25:36	Predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# 2016-01-04 17:25:36	Added GradientBoostingRegressor to default predictors
# 2016-01-04 17:25:36	Loading metadata
# 2016-01-04 17:25:36	Loading species metadata from ~/flotilla_packages
# 2016-01-04 17:25:39	Loading expression data
# 2016-01-04 17:25:39	Initializing expression
# 2016-01-04 17:25:39	Done initializing expression
# 2016-01-04 17:25:40	Loading splicing data
# 2016-01-04 17:25:40	Initializing splicing
# 2016-01-04 17:25:40	Done initializing splicing
# 2016-01-04 17:25:40	Successfully initialized a Study object!

# %%
mn_study.plot_pca(data_type="splicing", show_point_labels=True)

# %%
mn_study_stress = flotilla.Study(# The metadata describing phenotype and pooled samples
                       metadata[metadata.paired_with_stress],
                       # A version for this data
                       version='0.1.0',
                       expression_data = rpkm_df[metadata.paired_with_stress],
                       # Dataframe of the splicing data
                       splicing_data=splicing_df[metadata.paired_with_stress],
                       expression_thresh = 1,
                       species="hg19"
)
# Out:
# /home/gpratt/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:1942: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)
# No phenotype to color mapping was provided, falling back on reasonable defaults.
# No phenotype to marker (matplotlib plotting symbol) was provided, so each phenotype will be plotted as a circle in visualizations.
# Error loading species hg19 data: Could not reserve memory block
# 2016-01-04 17:25:57	Initializing Study
# 2016-01-04 17:25:57	Initializing Predictor configuration manager for Study
# 2016-01-04 17:25:57	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2016-01-04 17:25:57	Added ExtraTreesClassifier to default predictors
# 2016-01-04 17:25:57	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2016-01-04 17:25:57	Added ExtraTreesRegressor to default predictors
# 2016-01-04 17:25:57	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2016-01-04 17:25:57	Added GradientBoostingClassifier to default predictors
# 2016-01-04 17:25:57	Predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# 2016-01-04 17:25:57	Added GradientBoostingRegressor to default predictors
# 2016-01-04 17:25:57	Loading metadata
# 2016-01-04 17:25:57	Loading species metadata from ~/flotilla_packages
# 2016-01-04 17:25:59	Loading expression data
# 2016-01-04 17:25:59	Initializing expression
# 2016-01-04 17:25:59	Done initializing expression
# 2016-01-04 17:26:01	Loading splicing data
# 2016-01-04 17:26:01	Initializing splicing
# 2016-01-04 17:26:01	Done initializing splicing
# 2016-01-04 17:26:01	Successfully initialized a Study object!

# %%
splicing_pca = mn_study_stress.plot_pca(data_type="expression", show_point_labels=True)

